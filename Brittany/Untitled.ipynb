# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import re
import sys 
#sys.path.append('C:\\Users\\brittany henderson\\GitHub\\GBM_for_CPTAC\\')
#import cis_functions as f

import cptac
import cptac.utils as u

# %%
cptac.download(dataset="HNSCC")
# Out:
# Password: ········
# True

# %%
renal = cptac.Ccrcc()

# %%
CNV = renal.get_CNV()
CNV.tail()
# Out:
# Name                      A1BG               A1CF                A2M  \
# Database_ID ENSG00000121410.11 ENSG00000148584.14 ENSG00000175899.14
# Sample_ID
# S106                  0.026528           0.065469           0.074286
# S107                  0.003589          -0.017667          -0.009598
# S108                  0.017956           0.019480           0.026971
# S109                  0.163116          -0.331378           0.140222
# S110                 -0.025767          -0.022834          -0.019618
#
# Name                     A2ML1           A3GALT2             A4GALT  \
# Database_ID ENSG00000166535.19 ENSG00000184389.9 ENSG00000128274.15
# Sample_ID
# S106                  0.074286          0.031000           0.031598
# S107                 -0.009598         -0.003569          -0.000926
# S108                  0.026971          0.017902           0.020458
# S109                  0.140222         -0.055388          -0.049226
# S110                 -0.019618         -0.026103          -0.023638
#
# Name                    A4GNT               AAAS               AACS  \
# Database_ID ENSG00000118017.3 ENSG00000094914.12 ENSG00000081760.16
# Sample_ID
# S106                 0.288325           0.062137           0.063978
# S107                -0.009770          -0.004919          -0.004919
# S108                 0.020200           0.028800           0.028800
# S109                 0.134608           0.142253           0.142253
# S110                 0.382217          -0.019048          -0.019048
#
# Name                     AADAC  ...             ZWILCH              ZWINT  \
# Database_ID ENSG00000114771.13  ... ENSG00000174442.11 ENSG00000122952.16
# Sample_ID                       ...
# S106                  0.288325  ...           0.033744           0.030586
# S107                 -0.009770  ...          -0.007744          -0.008758
# S108                  0.020200  ...           0.017537           0.019480
# S109                  0.134608  ...          -0.315716          -0.321503
# S110                  0.382012  ...          -0.024736          -0.022834
#
# Name                     ZXDA              ZXDB               ZXDC  \
# Database_ID ENSG00000198205.6 ENSG00000198455.4 ENSG00000070476.14
# Sample_ID
# S106                 0.027502          0.027502           0.288325
# S107                -0.009086         -0.009086          -0.009770
# S108                 0.020941          0.020941           0.020200
# S109                 0.114801          0.114801           0.134608
# S110                -0.027958         -0.027958          -0.593051
#
# Name                   ZYG11A             ZYG11B                ZYX  \
# Database_ID ENSG00000203995.9 ENSG00000162378.12 ENSG00000159840.15
# Sample_ID
# S106                 0.031000           0.031000           0.033042
# S107                -0.003569          -0.003569          -0.014371
# S108                 0.017902           0.017902           0.328963
# S109                -0.055388          -0.055388           0.145273
# S110                -0.026103          -0.026103           0.380146
#
# Name                     ZZEF1               ZZZ3
# Database_ID ENSG00000074755.14 ENSG00000036549.12
# Sample_ID
# S106                  0.024613           0.031000
# S107                  0.003618          -0.003569
# S108                  0.021064           0.017902
# S109                 -0.051065          -0.078956
# S110                 -0.023639          -0.026103
#
# [5 rows x 19285 columns]

# %%
clin = renal.get_clinical()
clin_list = []
clin_list = clin["Patient_ID"]
clin
# Out:
# Name       Patient_ID Sample_Tumor_Normal tumor/normal  gender  age  \
# Sample_ID
# S001        C3L-00004               Tumor           TN    Male   72
# S002        C3L-00010               Tumor           TN    Male   30
# S003        C3L-00011               Tumor           TN  Female   63
# S004        C3L-00026               Tumor           TN  Female   65
# S005        C3L-00079               Tumor           TN    Male   49
# ...               ...                 ...          ...     ...  ...
# S190       NC3N-01646              Normal          NaN     NaN  NaN
# S191       NC3N-01648              Normal          NaN     NaN  NaN
# S192       NC3N-01649              Normal          NaN     NaN  NaN
# S193       NC3N-01651              Normal          NaN     NaN  NaN
# S194       NC3N-01808              Normal          NaN     NaN  NaN
#
# Name       height_in_cm  height_in_inch  weight_in_kg  weight_in_lb    BMI  \
# Sample_ID
# S001              170.0            67.0          66.0         145.0  22.80
# S002              177.0            70.0         107.0         236.0  34.15
# S003              180.0            71.0          89.0         196.0  27.47
# S004              163.0            64.0          75.0         165.0  28.23
# S005              175.0            69.0         116.0         256.0  37.88
# ...                 ...             ...           ...           ...    ...
# S190                NaN             NaN           NaN           NaN    NaN
# S191                NaN             NaN           NaN           NaN    NaN
# S192                NaN             NaN           NaN           NaN    NaN
# S193                NaN             NaN           NaN           NaN    NaN
# S194                NaN             NaN           NaN           NaN    NaN
#
# Name       ... slide_is_free_of_tumor consistent_with_local_pathology_report  \
# Sample_ID  ...
# S001       ...                    NaN                                    Yes
# S002       ...                    NaN                                    Yes
# S003       ...                    NaN                                    Yes
# S004       ...                    NaN                                    Yes
# S005       ...                    NaN                                    Yes
# ...        ...                    ...                                    ...
# S190       ...                    Yes                                    Yes
# S191       ...                    Yes                                    Yes
# S192       ...                    Yes                                    Yes
# S193       ...                    Yes                                    Yes
# S194       ...                    Yes                                    Yes
#
# Name      findings_not_consistent_with_local_pathology_report weight_in_mg  \
# Sample_ID
# S001                                                     NaN         484.0
# S002                                                     NaN         575.0
# S003                                                     NaN         272.0
# S004                                                     NaN         212.0
# S005                                                     NaN         675.0
# ...                                                      ...           ...
# S190                                                     NaN         256.0
# S191                                                     NaN         288.0
# S192                                                     NaN         301.0
# S193                                                     NaN         280.0
# S194                                                     NaN         195.0
#
# Name      minutes_clamp_1_to_collection  minutes_clamp_2_to_collection  \
# Sample_ID
# S001                                NaN                            NaN
# S002                                NaN                            NaN
# S003                                NaN                            NaN
# S004                               13.0                            NaN
# S005                                NaN                            NaN
# ...                                 ...                            ...
# S190                                NaN                            NaN
# S191                                NaN                            NaN
# S192                                NaN                            NaN
# S193                                NaN                            NaN
# S194                                NaN                            NaN
#
# Name      minutes_collection_to_frozen consistent_with_diagnostic_report  \
# Sample_ID
# S001                                21                               Yes
# S002                                17                               Yes
# S003                                18                               Yes
# S004                                13                               Yes
# S005                                28                               Yes
# ...                                ...                               ...
# S190                                20                               NaN
# S191                                 8                               NaN
# S192                                29                               NaN
# S193                                22                               NaN
# S194                                29                               NaN
#
# Name                                     patient_medications  \
# Sample_ID
# S001       rivaroxaban,tylenol,Aspirin,glycolax,colace,zocor
# S002                      Rivaroxaban,Esomeprazole ,Tramadol
# S003       Multi Vitamin,Levothyroxine Sodium,Ibandronate...
# S004       Levothyroxine Sodium,Cyproheptadine HCL,Citrac...
# S005                                 ibuprofen,Norco,miralax
# ...                                                      ...
# S190                                                     NaN
# S191                                                     NaN
# S192                                                     NaN
# S193                                                     NaN
# S194                                                     NaN
#
# Name                  Immune Group
# Sample_ID
# S001       Metabolic immune-desert
# S002       Metabolic immune-desert
# S003       Metabolic immune-desert
# S004                 CD8+ inflamed
# S005                 CD8+ inflamed
# ...                            ...
# S190                      Pure NAT
# S191               Infiltrated NAT
# S192                      Pure NAT
# S193                      Pure NAT
# S194                      Pure NAT
#
# [194 rows x 173 columns]
