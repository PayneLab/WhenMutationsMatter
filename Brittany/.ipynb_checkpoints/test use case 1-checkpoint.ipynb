# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import CPTAC.Endometrial as en
# Out:
# Welcome to the CPTAC data service package. Available datasets may be
# viewed using CPTAC.list_data(). In order to access a specific data
# set, import a CPTAC subfolder using either 'import CPTAC.Dataset' or
# 'from CPTAC import Dataset'.
# ******
# Version: 0.2.7
# ******
# Loading Endometrial CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Acetylation Proteomics Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %%
proteomics = en.get_proteomics()
transcriptomics = en.get_transcriptomics()

# %%
A1BG_cross = en.compare_gene(df1=proteomics, df2=transcriptomics, gene='A1BG')
A1BG_cross.head()
# Out:
#       proteomics  transcriptomics_linear
# S001      -1.180                    4.02
# S002      -0.685                    4.81
# S003      -0.528                    6.24
# S005      -1.670                    5.31
# S006      -0.374                    9.84

# %%
sns.set(style="darkgrid")
plot = sns.regplot(x="proteomics", y="transcriptomics_linear", 
                   data=A1BG_cross)
plot.set(xlabel='Proteomics', ylabel='Transcriptomics', 
         title='Proteomics vs. Transcriptomics for the A1BG gene')
plt.show()

# %%
gene = 'RPL11'
gene_cross = en.compare_gene(df1=proteomics, df2=transcriptomics, gene=gene)
plot = sns.regplot(x=gene_cross.columns[0], y=gene_cross.columns[1], data=gene_cross, color="green")
plot.set(xlabel='Proteomics', ylabel='Transcriptomics', title='Proteomics vs. Transcriptomics for the ' + gene + ' gene')
plt.show()

# %%
import CPTAC.Ovarian as ov
# Out:
# Loading Ovarian CPTAC data:
# Loading clinical data...
# Loading cnv data...
# Loading phosphoproteomics data...
# Loading proteomics data...
# Loading somatic_19 data...
# Loading somatic_38 data...
# Loading transcriptomics data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until June 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until June 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %%
proteomics = ov.get_proteomics()
transcriptomics = ov.get_transcriptomics()
ovarian_cross = ov.compare_gene(df1=proteomics, df2=transcriptomics, gene='PTEN')
ovarian_cross.head()
# Out:
#             proteomics  transcriptomics patient_key
# patient_id
# 01OV007       0.509384          34.9050          S2
# 01OV017      -0.425281          19.2267          S6
# 01OV018       0.683198          19.4822          S7
# 01OV023       0.062758          12.2103          S9
# 01OV026       0.560112          15.7597         S11

# %%
sns.set(style="darkgrid")
plot = sns.regplot(x="proteomics", y="transcriptomics", data=ovarian_cross)
plot.set(xlabel='Proteomics', ylabel='Transcriptomics', title='Proteomics vs. Transcriptomics for the PTEN gene')
plt.show()
