# %% [markdown]
# # get_freq_mutations test colon

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import CPTAC.Colon as co

# %%
def get_frequently_mutated(somatic_df, omics_mutations_df, cutoff=.1):  
    unique_genes = somatic_df['Gene'].unique() # get series of all mutated genes
    freq_mutated = []
    
    # get total tumor patients
    tumors = omics_mutations_df.loc[omics_mutations_df['Sample_Status'] == 'Tumor']
    total_tumor_patients = len(tumors) 
    
    for gene in unique_genes:
        gene_mutated = somatic_df.loc[somatic['Gene'] == gene]
        num_gene_mutated = len(gene_mutated)
        if (num_gene_mutated / total_tumor_patients) > cutoff:
            freq_mutated.append(gene)
        
    return freq_mutated

# %% [markdown]
# # find number of tumor patients

# %%
somatic = co.get_mutations()
prot = co.get_proteomics()
clinical = co.get_clinical()
total = clinical.loc[clinical['Tumor.Status'] == 'With tumor']
print(len(total)) #NOT RIGHT TOTAL 16
# Out:
# 16
#        SampleID    Gene           Mutation Location
# 97227   01CO001   SCN2A  nonsynonymous SNV    E999K
# 4732    01CO001  AKAP13  nonsynonymous SNV    R572Q
# 4733    01CO001  AKAP13  nonsynonymous SNV    R572Q
# 118867  01CO001   TSSC4  nonsynonymous SNV    P151L
# 118866  01CO001   TSSC4  nonsynonymous SNV    P151L

# %%
#find all tumor patients
gene = 'TP53'
omics_mutations = co.append_mutations_to_omics(mutation_genes=gene, omics_df=prot, omics_genes=gene)
tumors = omics_mutations.loc[omics_mutations['Sample_Status'] == 'Tumor']
total_tumor_count = len(tumors)
print(total_tumor_count) #97
omics_mutations.head() 
somatic.head()
# Out:
# 97
#        SampleID    Gene           Mutation Location
# 97227   01CO001   SCN2A  nonsynonymous SNV    E999K
# 4732    01CO001  AKAP13  nonsynonymous SNV    R572Q
# 4733    01CO001  AKAP13  nonsynonymous SNV    R572Q
# 118867  01CO001   TSSC4  nonsynonymous SNV    P151L
# 118866  01CO001   TSSC4  nonsynonymous SNV    P151L

# %% [markdown]
# Test 1 colon:

# %%
list1 = get_frequently_mutated(somatic, omics_mutations)

# %%
#How many genes were frequently mutated compared to all mutated genes
print('freq_mutated: ',len(list1))
total_genes = somatic['Gene'].unique()
print('total_genes: ',len(total_genes))
# Out:
# freq_mutated:  3912
# total_genes:  15175

# %%
list1
# Out:
# ['SCN2A',
#  'AKAP13',
#  'TSSC4',
#  'MRC2',
#  'ARHGEF5',
#  'STK31',
#  'APC',
#  'GRIN2A',
#  'PTPN22',
#  'ALDH16A1',
#  'LAMA4',
#  'CDH23',
#  'NRXN1',
#  'MCTP2',
#  'CADPS',
#  'DNAH8',
#  'WDR81',
#  'SEZ6L',
#  'AHRR',
#  'ITIH5',
#  'TRPV1',
#  'NAB1',
#  'ZMYM1',
#  'FBXW7',
#  'IGSF3',
#  'ZNF880',
#  'COL6A3',
#  'INSC',
#  'ABCA8',
#  'CPZ',
#  'TP53',
#  'RB1CC1',
#  'ZNF839',
#  'NTRK2',
#  'ADAMTS16',
#  'ETV1',
#  'ADGRG4',
#  'EVC2',
#  'ZFYVE16',
#  'ADGRE2',
#  'PTPRZ1',
#  'SMAD4',
#  'ZFP36L2',
#  'MUC16',
#  'CARD11',
#  'CARMIL1',
#  'DHX57',
#  'ZNF540',
#  'CCDC103',
#  'MATN4',
#  'MAGEC1',
#  'TDRD6',
#  'FAT3',
#  'MYO7A',
#  'PCDH17',
#  'FBXO38',
#  'SLC6A2',
#  'CHN2',
#  'SENP6',
#  'RUNDC1',
#  'HMCN1',
#  'SAP130',
#  'APOB',
#  'SYNE1',
#  'ANKRD26',
#  'BIRC6',
#  'IGSF9',
#  'CP',
#  'MEMO1',
#  'PKD1L1',
#  'DHCR7',
#  'PYHIN1',
#  'RBMXL2',
#  'SNCAIP',
#  'MYH14',
#  'DNM2',
#  'OTOGL',
#  'PMEPA1',
#  'MROH7',
#  'ACSBG2',
#  'FAM184B',
#  'LUZP1',
#  'ASPM',
#  'RREB1',
#  'AFF2',
#  'DNAH7',
#  'ZNF611',
#  'TTN',
#  'HRNR',
#  'MST1R',
#  'SOX5',
#  'GABRA5',
#  'LIMCH1',
#  'KMT2B',
#  'PRDM5',
#  'GRIA4',
#  'ARID4A',
#  'MACF1',
#  'NOTCH1',
#  'ADGRL2',
#  'DOCK2',
#  'YEATS2',
#  'CLN3',
#  'CLASRP',
#  'C10orf71',
#  'KRTAP9-1',
#  'BRINP3',
#  'GUCY1A3',
#  'BSN',
#  'KIAA1109',
#  'VCAN',
#  'RP1L1',
#  'NBEA',
#  'KCNQ4',
#  'AEBP1',
#  'NAE1',
#  'RYR3',
#  'DCT',
#  'FREM3',
#  'EPHA4',
#  'CEP350',
#  'KMT2D',
#  'ADAM21',
#  'ANKLE1',
#  'ARID1A',
#  'LRRC4B',
#  'ICAM4',
#  'WDFY3',
#  'CSMD3',
#  'PLCB1',
#  'RANBP3L',
#  'FAM47A',
#  'CASZ1',
#  'AP2A2',
#  'PPL',
#  'ARHGAP29',
#  'SETDB1',
#  'RNF43',
#  'MYH7',
#  'ZNF804B',
#  'TAOK2',
#  'TBL1XR1',
#  'PC',
#  'PLA2R1',
#  'MORC2',
#  'ZNF169',
#  'ZFHX3',
#  'SCARF2',
#  'LRP1B',
#  'AUTS2',
#  'ABI1',
#  'GRM1',
#  'SMARCA2',
#  'CFAP65',
#  'FBN1',
#  'SPATA31D1',
#  'CSMD1',
#  'CAPRIN2',
#  'PCDH18',
#  'BEST1',
#  'PHACTR3',
#  'PCDHA1',
#  'FAM184A',
#  'MAPK8',
#  'UNC13C',
#  'WDR49',
#  'GAS2L3',
#  'GAS7',
#  'GPR179',
#  'SETX',
#  'PTPRN2',
#  'AGTR1',
#  'OPA1',
#  'USH1G',
#  'PCDHA13',
#  'USH2A',
#  'PTPRU',
#  'HELZ2',
#  'YLPM1',
#  'ANLN',
#  'SPTA1',
#  'FLT4',
#  'PTPRT',
#  'AKAP11',
#  'DNAH2',
#  'TENM1',
#  'PIEZO2',
#  'PIK3R3',
#  'SALL3',
#  'TJP3',
#  'IL12RB1',
#  'IGFN1',
#  'SCN10A',
#  'KRAS',
#  'RBMXL3',
#  'ARFGEF2',
#  'ATP2B3',
#  'C3',
#  'CFP',
#  'ZNF530',
#  'USP5',
#  'TCF7L2',
#  'CPEB3',
#  'PCDH10',
#  'DLGAP2',
#  'IGFALS',
#  'COL22A1',
#  'BOC',
#  'SIGLEC1',
#  'OBSCN',
#  'NTM',
#  'VPS13A',
#  'OR7E24',
#  'GIGYF2',
#  'TRPM3',
#  'CSPG4',
#  'CHD3',
#  'DSPP',
#  'CD109',
#  'MYO16',
#  'MN1',
#  'ATXN3',
#  'MGAT4B',
#  'DLEC1',
#  'DNAI2',
#  'NAV2',
#  'TRANK1',
#  'OTOG',
#  'PCDHA5',
#  'TIAM2',
#  'PNLIPRP1',
#  'C7orf57',
#  'HLCS',
#  'R3HDM2',
#  'COL6A6',
#  'EP400',
#  'PTPRB',
#  'NIPBL',
#  'PIDD1',
#  'ZNF700',
#  'MYH2',
#  'HNF1A',
#  'PPRC1',
#  'JAG2',
#  'TVP23A',
#  'MYCBP2',
#  'MTSS1',
#  'FILIP1',
#  'MEGF10',
#  'SREBF1',
#  'SULF1',
#  'DIAPH1',
#  'NOL8',
#  'PCDHGA9',
#  'MTUS2',
#  'NDUFAF7',
#  'NOD2',
#  'NOMO1',
#  'SETD1A',
#  'SALL1',
#  'TPTE',
#  'TJP2',
#  'PCDHGA12',
#  'ASH1L',
#  'TMEM263',
#  'SETD5',
#  'PCSK2',
#  'PRC1',
#  'GOT1L1',
#  'R3HDM1',
#  'ATP8B2',
#  'NCOA2',
#  'DAAM1',
#  'SMARCAD1',
#  'LTF',
#  'CYP39A1',
#  'ZFHX4',
#  'CD34',
#  'PRX',
#  'SNX18',
#  'CLTC',
#  'ADAMTSL1',
#  'ASCC3',
#  'ITSN1',
#  'DAG1',
#  'MCTP1',
#  'DIDO1',
#  'NNT',
#  'SETD1B',
#  'MTRR',
#  'GON4L',
#  'ASIC3',
#  'NMNAT3',
#  'SYK',
#  'RRP12',
#  'DAB2IP',
#  'MEF2A',
#  'SEPT9',
#  'CNDP2',
#  'TUBGCP2',
#  'PLCB2',
#  'RNF111',
#  'DDX27',
#  'LRRIQ3',
#  'ZNF423',
#  'ATN1',
#  'TRAPPC2L',
#  'FKBP8',
#  'CNR1',
#  'APBB1',
#  'CCDC141',
#  'LDLRAP1',
#  'PARPBP',
#  'ADCYAP1R1',
#  'IL4R',
#  'TRAF5',
#  'ATG4A',
#  'TLN2',
#  'SEPT10',
#  'EXO1',
#  'DFFB',
#  'MUC3A',
#  'NPHP1',
#  'MUC5B',
#  'OR5D18',
#  'DENND4A',
#  'SAMD9',
#  'CMYA5',
#  'LEF1',
#  'XKR5',
#  'XIRP1',
#  'SMG5',
#  'ADD3',
#  'CCAR2',
#  'JUP',
#  'TLR9',
#  'ATP13A2',
#  'RBPJ',
#  'NPAT',
#  'SMG1',
#  'MUSK',
#  'DENND1A',
#  'ATF5',
#  'ADNP',
#  'TLE4',
#  'MECOM',
#  'NCOR2',
#  'MXRA8',
#  'NOSTRIN',
#  'GOLGA3',
#  'JAKMIP1',
#  'SHCBP1',
#  'HNF4G',
#  'SLC22A6',
#  'DCHS1',
#  'ZNF469',
#  'ZNF415',
#  'SUPT5H',
#  'SMTN',
#  'ATP2B4',
#  'DCTN1',
#  'CCDC18',
#  'MECP2',
#  'DDC',
#  'TMEM132E',
#  'CNGA3',
#  'SYCP1',
#  'ADGRV1',
#  'MXRA5',
#  'EYS',
#  'FAM208A',
#  'CPS1',
#  'ZMIZ1',
#  'FMO3',
#  'ARHGAP24',
#  'NFATC1',
#  'SH2D3C',
#  'PAX7',
#  'MAP3K9',
#  'RXFP1',
#  'IRAK4',
#  'TP63',
#  'CFAP46',
#  'ANKRD6',
#  'FBXL18',
#  'ARHGAP20',
#  'CGNL1',
#  'IFT88',
#  'CPNE1',
#  'PIWIL1',
#  'MATN2',
#  'NFASC',
#  'STEAP2',
#  'CEP170B',
#  'SLAMF1',
#  'CEP295',
#  'STAU2',
#  'ZC3H18',
#  'CRTC1',
#  'ARHGAP44',
#  'TRPM6',
#  'ZNF184',
#  'CEP170',
#  'TOPAZ1',
#  'IRS4',
#  'COL12A1',
#  'RYR2',
#  'AMOTL2',
#  'ARHGAP25',
#  'MAGEL2',
#  'RET',
#  'CERS5',
#  'FAT2',
#  'SIRT6',
#  'FCRL5',
#  'SSC5D',
#  'SIGLEC6',
#  'SH3KBP1',
#  'COL4A3',
#  'MAP3K21',
#  'NBAS',
#  'TRIOBP',
#  'PKHD1L1',
#  'RYR1',
#  'CLCN4',
#  'SSPO',
#  'FEZF1',
#  'TRIM37',
#  'FOXO4',
#  'CHRM3',
#  'PAQR6',
#  'IGSF8',
#  'PKM',
#  'FDXR',
#  'SIGLEC12',
#  'ZMYM4',
#  'ZMYM2',
#  'COL5A1',
#  'COL5A2',
#  'RGS9BP',
#  'PRR12',
#  'NAV3',
#  'NELL1',
#  'NEU4',
#  'SH3BP2',
#  'ST5',
#  'STAB1',
#  'FBXO21',
#  'ZDBF2',
#  'LAMA1',
#  'FREM2',
#  'CORIN',
#  'CHD8',
#  'ARAP1',
#  'SPEG',
#  'APC2',
#  'SPEN',
#  'COLEC12',
#  'MANBA',
#  'ZNF106',
#  'ARFGAP2',
#  'CHD6',
#  'SFMBT2',
#  'SOHLH1',
#  'ZNF292',
#  'P2RX2',
#  'NLRC5',
#  'ZC3H12A',
#  'PARD3',
#  'CDH1',
#  'FAM193A',
#  'SLC16A12',
#  'PIK3CA',
#  'CNTROB',
#  'MAPK8IP3',
#  'SORBS2',
#  'MCF2L',
#  'ITGAX',
#  'CDHR1',
#  'CDHR2',
#  'COBL',
#  'RIMS2',
#  'SLC12A6',
#  'CDK13',
#  'TNFRSF25',
#  'HTR1F',
#  'MYH11',
#  'TTK',
#  'PRDM15',
#  'CYP11B1',
#  'PCDHB6',
#  'ZIC4',
#  'MYH15',
#  'ANO3',
#  'STXBP5L',
#  'PCDHGA1',
#  'AGO3',
#  'ZIC3',
#  'PAX3',
#  'GBP3',
#  'ARMCX4',
#  'STS',
#  'CLOCK',
#  'RSPH4A',
#  'PTPRG',
#  'AHDC1',
#  'ITIH6',
#  'LARS',
#  'PRDM2',
#  'NLRP11',
#  'PLEC',
#  'PIP5K1C',
#  'FAN1',
#  'CSMD2',
#  'FLYWCH1',
#  'KMT2C',
#  'MAGEB1',
#  'RIMS1',
#  'INO80E',
#  'TNS1',
#  'PSD3',
#  'ARHGEF11',
#  'ANKS1B',
#  'MYO1F',
#  'MYO7B',
#  'CEP131',
#  'IRX4',
#  'FXR1',
#  'CEP162',
#  'ARHGEF1',
#  'TOP2A',
#  'TRPS1',
#  'CSE1L',
#  'CDKN1A',
#  'TNPO2',
#  'CDK8',
#  'ZNF234',
#  'ITGA8',
#  'SORL1',
#  'COBLL1',
#  'ARHGEF26',
#  'ICE1',
#  'ARHGEF17',
#  'ARHGEF40',
#  'GALC',
#  'TNRC18',
#  'TNRC6A',
#  'USF2',
#  'TDRD15',
#  'DPP6',
#  'MGST1',
#  'HECW2',
#  'ADA2',
#  'PHACTR1',
#  'KIF26B',
#  'EMC2',
#  'PHF8',
#  'SBNO1',
#  'ABLIM1',
#  'KIF13A',
#  'PDS5B',
#  'RALGAPA1',
#  'MPP2',
#  'GRINA',
#  'ZNF717',
#  'TGFBR2',
#  'GPR141',
#  'NTAN1',
#  'CAND1',
#  'ZNF749',
#  'BCR',
#  'EPPK1',
#  'USP28',
#  'SEC31A',
#  'OGDHL',
#  'HEATR5A',
#  'WASF3',
#  'KIDINS220',
#  'DSC2',
#  'KIF2A',
#  'OFD1',
#  'RPS6KA4',
#  'HDLBP',
#  'KDM5C',
#  'TGM2',
#  'TCHH',
#  'KCNH6',
#  'ABI2',
#  'USP26',
#  'EPS8',
#  'ZNF638',
#  'HHIPL1',
#  'RBL2',
#  'ULK4',
#  'ACSL4',
#  'CACNA1I',
#  'BAZ2B',
#  'LRP2',
#  'WDR55',
#  'ZNF667',
#  'ACVR2A',
#  'SLC34A3',
#  'NRXN2',
#  'SLIT2',
#  'GPRASP2',
#  'HIP1',
#  'SLC30A3',
#  'LRP5',
#  'UEVLD',
#  'DNAH9',
#  'RABL6',
#  'SLITRK3',
#  'UBXN11',
#  'HIF1A',
#  'TEX11',
#  'GPT2',
#  'CACNA2D2',
#  'DNAJC13',
#  'CACNA1D',
#  'HK1',
#  'HERC2',
#  'PHACTR4',
#  'SMAD2',
#  'UPF2',
#  'CAMKK2',
#  'DOCK3',
#  'USF3',
#  'HEPH',
#  'GRIN2B',
#  'SLC8B1',
#  'DOK1',
#  'TECPR2',
#  'DOK3',
#  'OPCML',
#  'DOC2A',
#  'KCNN3',
#  'ZNF668',
#  'KCNQ2',
#  'UBR5',
#  'HIVEP1',
#  'TENM4',
#  'TACC2',
#  'MSH6',
#  'ZNF687',
#  'UNC80',
#  'RADIL',
#  'SEC13',
#  'UNC79',
#  'RNF213',
#  'VEPH1',
#  'KIAA1522',
#  'CASP1',
#  'DYSF',
#  'BRF1',
#  'VIT',
#  'SCN3A',
#  'U2SURP',
#  'MLPH',
#  'ATRN',
#  'SEMA5B',
#  'NUTM2G',
#  'KIF5C',
#  'GYG2',
#  'DLG4',
#  'UACA',
#  'WNK2',
#  'NUP93',
#  'GZF1',
#  'POLA1',
#  'ATRX',
#  'VPS13D',
#  'SEMA6C',
#  'ZNF517',
#  'AACS',
#  'POLQ',
#  'HMGA1',
#  'BTN2A1',
#  'CASP5',
#  'EFCAB6',
#  'BTBD7',
#  'A2M',
#  'SLC25A39',
#  'BSDC1',
#  'EGLN1',
#  'HCFC1',
#  'TBL1X',
#  'KIAA1211',
#  'PLXNA3',
#  'ADAMTS5',
#  'ROBO2',
#  'ERBIN',
#  'SCN11A',
#  'HDGFRP2',
#  'KCNH3',
#  'POP1',
#  'NRG1',
#  'MMRN1',
#  'POMP',
#  'ELMSAN1',
#  'ABCB6',
#  'UTRN',
#  'RANBP6',
#  'UTP20',
#  'GPATCH8',
#  'TAGAP',
#  'VWA5A',
#  'ABCC11',
#  'MNS1',
#  'RNGTT',
#  'LHCGR',
#  'DLL3',
#  'ABCC5',
#  'KDM6B',
#  'USP9X',
#  'KCNH1',
#  'DYNC2H1',
#  'ATXN7',
#  'RAP1GDS1',
#  'TANC1',
#  'SLC7A3',
#  'BRAF',
#  'SCN1A',
#  'ABCB4',
#  'DYNC1H1',
#  'THBS4',
#  'SPTAN1',
#  'ZFP1',
#  'TRPC3',
#  'EGF',
#  'CACNB2',
#  'HGFAC',
#  'CHD4',
#  'SLIT3',
#  'PROM2',
#  'VPS13C',
#  'ARHGAP22',
#  'ABCC8',
#  'CACNB3',
#  'GEMIN5',
#  'MYH13',
#  'CFAP47',
#  'RUNX1T1',
#  'ENPP2',
#  'TNIK',
#  'GTDC1',
#  'LAMA3',
#  'SLC4A5',
#  'EML3',
#  'CABIN1',
#  'KCNT2',
#  'SOX9',
#  'NBEAL2',
#  'GABRB3',
#  'SPAG17',
#  'AMER3',
#  'ARFGAP1',
#  'FHL5',
#  'ARMC5',
#  'GRIA2',
#  'DRC7',
#  'CERS3',
#  'ILK',
#  'MROH2B',
#  'NRXN3',
#  'AQP7',
#  'MYO10',
#  'PLD1',
#  'CAMTA1',
#  'SEMA4B',
#  'PDE1A',
#  'JMJD1C',
#  'EPHA6',
#  'LHX6',
#  'ADAMTS2',
#  'LDB1',
#  'UBAP2L',
#  'GOLIM4',
#  'ATP2A1',
#  'DAPK1',
#  'EYA4',
#  'ESPNL',
#  'PCLO',
#  'DNAH11',
#  'PDE4DIP',
#  'PCDH9',
#  'ZNF41',
#  'RAPGEF4',
#  'HUWE1',
#  'DLG2',
#  'VWDE',
#  'WDTC1',
#  'ADAD1',
#  'PCDHA6',
#  'GDF5',
#  'RNF144A',
#  'CAPN9',
#  'KIAA0040',
#  'KIRREL2',
#  'TKTL1',
#  'ARHGAP4',
#  'FLT1',
#  'IMPG1',
#  'COL6A5',
#  'ANO6',
#  'OR5M3',
#  'FCGBP',
#  'CEP164',
#  'CNTNAP4',
#  'ALS2CL',
#  'NWD1',
#  'PAPPA2',
#  'GRM8',
#  'DYNC1I1',
#  'STAT5A',
#  'SPATA13',
#  'NKTR',
#  'DIS3L',
#  'MDN1',
#  'LRRIQ1',
#  'CASR',
#  'CCDC88C',
#  'SCN4A',
#  'ZNF224',
#  'MAGEC3',
#  'FAT4',
#  'PROZ',
#  'OBSL1',
#  'MAP1B',
#  'CHIT1',
#  'TUBB4A',
#  'RPH3A',
#  'CHFR',
#  'PNPLA8',
#  'GSN',
#  'WNK1',
#  'MAP2',
#  'ATXN2L',
#  'ROBO1',
#  'LONRF3',
#  'APOBEC3G',
#  'PLCZ1',
#  'VAMP4',
#  'FNDC3B',
#  'VANGL1',
#  'NEDD4L',
#  'CIC',
#  'SLC25A13',
#  'PPIP5K2',
#  'CHRD',
#  'ATP2A3',
#  'PLXNB1',
#  'C1S',
#  'CHRNA10',
#  'NUGGC',
#  'CC2D2B',
#  'MAP3K1',
#  'USP7',
#  'SLC24A1',
#  'USP33',
#  'NF1',
#  'FRMD3',
#  'NTRK3',
#  'NPAS3',
#  'ATP12A',
#  'FRMD4A',
#  'PANX2',
#  'GSE1',
#  'CHAT',
#  'LAMA2',
#  'USP40',
#  'MAN2A2',
#  'BLM',
#  'USP35',
#  'LDLRAD4',
#  'PNMA3',
#  'ATP10D',
#  'POSTN',
#  'C8orf34',
#  'CFI',
#  'FRMD6',
#  'ATP11B',
#  'ARHGAP11A',
#  'FOXP2',
#  'PLOD2',
#  'CHD7',
#  'PNPLA7',
#  'PROX1',
#  'L3MBTL4',
#  'SIPA1L1',
#  'MAP1A',
#  'SIN3B',
#  'C2CD6',
#  'PAPPA',
#  'IGSF10',
#  'CHD9',
#  'PLD5',
#  'HDC',
#  'VWA5B2',
#  'OCIAD1',
#  'GNAI2',
#  'ATP1A1',
#  'OCA2',
#  'CHD5',
#  'PLRG1',
#  'SLC4A3',
#  'PPP1R16A',
#  'ATP6V1B1',
#  'HACE1',
#  'TRDN',
#  'MAP4K4',
#  'CLSPN',
#  'SLC45A4',
#  'RUNX2',
#  'PARD3B',
#  'NDUFC2-KCTD14',
#  'BRSK2',
#  'MAP4K5',
#  'FLNC',
#  'CLUH',
#  'HMMR',
#  'CASS4',
#  'ATP7B',
#  'NDUFC2',
#  'ROCK1',
#  'PPP1R21',
#  'PLPPR4',
#  'NDUFS1',
#  'HACD4',
#  'HCN1',
#  'SMC2',
#  'CLMN',
#  'BRIP1',
#  'PPP1R26',
#  'RGS3',
#  'PRRG1',
#  'VLDLR',
#  'GP2',
#  'ATRIP',
#  'ZFP64',
#  'PRRT2',
#  'PARP8',
#  'PARP6',
#  'LRRC4C',
#  'PPP1R12A',
#  'POLM',
#  'HMGB3',
#  'AP4B1',
#  'ROR2',
#  'RUSC2',
#  'TRAPPC9',
#  'IL21R',
#  'PLCB3',
#  'FLNB',
#  'LMNTD1',
#  'WNT5B',
#  'FN1',
#  'NUP88',
#  'ZEB1',
#  'POM121',
#  'ATP2B2',
#  'CASK',
#  'SLC52A1',
#  'FMR1',
#  'NEB',
#  'CLCNKA',
#  'NEDD4',
#  'CIZ1',
#  'VAV2',
#  'NUP210',
#  'BPTF',
#  'CLASP2',
#  'RTN3',
#  'CLCN3',
#  'BRCA1',
#  'NRBP1',
#  'TRIM51',
#  'WT1',
#  'POLR3E',
#  'PLCH1',
#  'WWC1',
#  'PPP1R7',
#  'PLCE1',
#  'TRIM17',
#  'GOLGA6L2',
#  'ZFAT',
#  'LRRC8B',
#  'HDAC6',
#  'WWOX',
#  'PLXNA4',
#  'WIZ',
#  'CDH10',
#  'GRIA3',
#  'NLRP1',
#  'TTC3',
#  'WDR90',
#  'ZBTB7C',
#  'GPR161',
#  'SLC9C2',
#  'LARP4B',
#  'ASTE1',
#  ...]

# %%
# check genes in freq_mutated list
gene = 'ASTE1'
total_tumor_patients = 97
cutoff = .1
gene_mutated = somatic.loc[somatic['Gene'] == gene]
num_gene_mutated = len(gene_mutated)
print(num_gene_mutated, ' / ', total_tumor_patients, ' ', (num_gene_mutated / total_tumor_patients))
if (num_gene_mutated / total_tumor_patients) > cutoff:
    print('true')
else:
    print('false')
# Out:
# 54  /  97   0.5567010309278351
# true

# %% [markdown]
# test2: using list1, test if all returned

# %%
list1_somatic = somatic.loc[somatic['Gene'] == list1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-21c76ba2e7f3> in <module>
# ----> 1 list1_somatic = somatic.loc[somatic['Gene'] == list1]
#
# ~\Anaconda3\envs\Research\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1743             # as it will broadcast
#    1744             if other.ndim != 0 and len(self) != len(other):
# -> 1745                 raise ValueError('Lengths must match to compare')
#    1746
#    1747             res_values = na_op(self.values, np.asarray(other))
#
# ValueError: Lengths must match to compare
