# %% [markdown]
# # Survival Analysis of Ovarian Cancer: Tumor Pathological Stage

# %% [markdown]
# Through modern statistical methods, we can determine survival risk based on a variety of factors.  In this tutorial, we will walk through a small example of something you could do with our data to understand what factors relate with survival in various different types of cancer.  In this use case, we will be looking at Ovarian Cancer

# %% [markdown]
# ## Step 1: Import Data and Dependencies

# %%
import pandas as pd
import cptac
import numpy as np
import sksurv
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import lifelines
from lifelines import KaplanMeierFitter
# %matplotlib inline

# %%
ov = cptac.Ovarian()
clinical = ov.get_clinical()
proteomics = ov.get_proteomics()
follow_up = pd.read_excel('../Follow_Up_Data/Ovary_One_Year_Clinical_Data_20160927.xls')

# %% [markdown]
# ## Step 2: Data Preparation
# We will be focusing on the discovery cohort of tumors, for which we have follow-up data. We will perform some data cleaning, and then merge the tables together for analysis. While you could study a wide variety of factors related to survival, such as country of origin or number of full pregnancies, we will be focusing on tumor stage and grade.

# %%
#Replace things that mess up the analysis       
to_replace = ['Not Reported/ Unknown', 'Reported/ Unknown',
              'Not Applicable', 'na', 'unknown', 'Not Performed',
              'Unknown tumor status', 'Unknown',
              'Unknown Tumor Status', 'Not specified']

for col in follow_up.columns:
    follow_up[col] = follow_up[col].replace(to_replace, 
                                            np.nan)

# %%
#Rename column to merge on, and then merge follow-up with clinical data
follow_up = follow_up.rename({'PPID': 'Patient_ID'}, axis='columns')

patient_data = pd.merge(clinical, follow_up, on = 'Patient_ID')

# %%
patient_data.columns
# Out:
# Index(['Patient_ID', 'Sample_Tumor_Normal', 'Participant_Procurement_Age',
#        'Participant_Gender', 'Participant_Race', 'Participant_Ethnicity',
#        'Participant_Jewish_Heritage', 'Participant_History_Malignancy',
#        'Participant_History_Chemotherapy',
#        'Participant_History_Neo-adjuvant_Treatment',
#        ...
#        'Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted to CPTAC to Date Radiation Therapy Started for this Other Malignancy',
#        'Was the patient staged using FIGO?',
#        'FIGO Staging System (Gynecologic Tumors Only)', 'FIGO Stage',
#        ' Was the patient staged using AJCC?', 'AJCC Cancer Staging Edition',
#        'Pathologic Spread: Primary Tumor (pT)',
#        'Pathologic Spread: Lymph Nodes (pN)', 'Distant Metastases (M)',
#        'AJCC Tumor Stage'],
#       dtype='object', length=159)

# %%
for col in patient_data.columns:
    print(col)
    print(patient_data[col].value_counts(), '\n')
# Out:
# Patient_ID
# 01OV018    8
# 01OV045    8
# 20OV005    7
# 26OV008    6
# 04OV018    5
#           ..
# 26OV011    1
# 17OV004    1
# 17OV040    1
# 17OV015    1
# 02OV044    1
# Name: Patient_ID, Length: 105, dtype: int64
#
# Sample_Tumor_Normal
# Tumor    304
# Name: Sample_Tumor_Normal, dtype: int64
#
# Participant_Procurement_Age
# 790.0    8
# 535.0    8
# 665.0    8
# 612.0    8
# 687.0    8
#         ..
# 656.0    1
# 908.0    1
# 688.0    1
# 620.0    1
# 861.0    1
# Name: Participant_Procurement_Age, Length: 88, dtype: int64
#
# Participant_Gender
# Female    304
# Name: Participant_Gender, dtype: int64
#
# Participant_Race
# White                                          267
# Asian                                           22
# Unknown (Could not be determined or unsure)      8
# Black or African American                        5
# American Indian or Alaska Native                 2
# Name: Participant_Race, dtype: int64
#
# Participant_Ethnicity
# Not Hispanic or Latino    280
# Unknown                    15
# Not Evaluated               6
# Hispanic or Latino          3
# Name: Participant_Ethnicity, dtype: int64
#
# Participant_Jewish_Heritage
# Not Jewish     202
# Unknown         56
# Ashkenazi       28
# Jewish, NOS     18
# Name: Participant_Jewish_Heritage, dtype: int64
#
# Participant_History_Malignancy
# No                                                        286
# Yes, History of Other Cancer Greater Than One Year Ago     18
# Name: Participant_History_Malignancy, dtype: int64
#
# Participant_History_Chemotherapy
# No     280
# Yes     24
# Name: Participant_History_Chemotherapy, dtype: int64
#
# Participant_History_Neo-adjuvant_Treatment
# No     296
# Yes      8
# Name: Participant_History_Neo-adjuvant_Treatment, dtype: int64
#
# Participant_History_Radiation_Therapy
# No     296
# Yes      8
# Name: Participant_History_Radiation_Therapy, dtype: int64
#
# Participant_History_Hormonal_Therapy
# No     296
# Yes      8
# Name: Participant_History_Hormonal_Therapy, dtype: int64
#
# Aliquots_Plasma
# 2.0    239
# 0.0     36
# 1.0     17
# 3.0      9
# 4.0      3
# Name: Aliquots_Plasma, dtype: int64
#
# Blood_Collection_Time
# Not Reported/ Unknown    36
# 630                      20
# 1300                     13
# 700                      13
# 930                      10
#                          ..
# 1410                      1
# 1630                      1
# 1430                      1
# 1339                      1
# 1345                      1
# Name: Blood_Collection_Time, Length: 72, dtype: int64
#
# Blood_Collection_Method
# Venipuncture (Vacutainer Apparatus)    153
# IV Catheter                             92
# Venipuncture (Syringe)                  59
# Name: Blood_Collection_Method, dtype: int64
#
# Anesthesia_Time
# 655.0     11
# 725.0      9
# 1017.0     9
# 730.0      9
# 1301.0     9
#           ..
# 1431.0     1
# 1025.0     1
# 902.0      1
# 1230.0     1
# 1057.0     1
# Name: Anesthesia_Time, Length: 87, dtype: int64
#
# Tumor_Surgical_Devascularized_Time
# 1.0       36
# 1429.0     8
# 920.0      8
# 1349.0     8
# 1200.0     7
#           ..
# 1130.0     1
# 1413.0     1
# 1414.0     1
# 1202.0     1
# 1253.0     1
# Name: Tumor_Surgical_Devascularized_Time, Length: 87, dtype: int64
#
# Tumor_Sample_Number
# 4.0    147
# 3.0     82
# 1.0     36
# 5.0     27
# 2.0     11
# 6.0      1
# Name: Tumor_Sample_Number, dtype: int64
#
# Tumor_Sample_1_Weight
# 160.0     10
# 200.0      9
# 460.0      8
# 180.0      8
# 690.0      8
#           ..
# 520.0      1
# 1240.0     1
# 290.0      1
# 100.0      1
# 1200.0     1
# Name: Tumor_Sample_1_Weight, Length: 85, dtype: int64
#
# Tumor_Sample_1_LN2_Time
# 21.0      11
# 1439.0     8
# 1354.0     8
# 932.0      8
# 906.0      7
#           ..
# 2127.0     1
# 1203.0     1
# 1422.0     1
# 1538.0     1
# 1255.0     1
# Name: Tumor_Sample_1_LN2_Time, Length: 93, dtype: int64
#
# Tumor_Sample_1_Ischemia_Time
# 4.0     57
# 5.0     54
# 2.0     28
# 3.0     26
# 7.0     26
# 1.0     16
# 20.0    15
# 6.0     11
# 12.0    10
# 25.0    10
# 15.0    10
# 10.0     8
# 27.0     7
# 11.0     5
# 26.0     4
# 30.0     4
# 18.0     3
# 19.0     3
# 8.0      1
# 0.0      1
# 22.0     1
# 24.0     1
# Name: Tumor_Sample_1_Ischemia_Time, dtype: int64
#
# Tumor_Sample_2_Weight
# 420.0    9
# 120.0    8
# 310.0    8
# 200.0    8
# 134.0    7
#         ..
# 50.0     1
# 370.0    1
# 520.0    1
# 30.0     1
# 720.0    1
# Name: Tumor_Sample_2_Weight, Length: 84, dtype: int64
#
# Tumor_Sample_2_LN2_Time
# 957.0     9
# 932.0     9
# 1439.0    8
# 1354.0    8
# 927.0     8
#          ..
# 852.0     1
# 1608.0    1
# 1520.0    1
# 1423.0    1
# 1056.0    1
# Name: Tumor_Sample_2_LN2_Time, Length: 85, dtype: int64
#
# Tumor_Sample_2_Ischemia_Time
# 4.0     52
# 5.0     49
# 7.0     34
# 3.0     30
# 6.0     27
# 2.0     16
# 15.0    10
# 12.0    10
# 10.0     8
# 20.0     7
# 25.0     6
# 11.0     5
# 30.0     4
# 19.0     3
# 29.0     3
# 18.0     3
# 26.0     1
# 1.0      1
# 22.0     1
# 8.0      1
# Name: Tumor_Sample_2_Ischemia_Time, dtype: int64
#
# Tumor_Sample_3_Weight
# 200.0     9
# 440.0     9
# 103.0     8
# 468.0     8
# 350.0     7
#          ..
# 50.0      1
# 30.0      1
# 490.0     1
# 1230.0    1
# 1650.0    1
# Name: Tumor_Sample_3_Weight, Length: 77, dtype: int64
#
# Tumor_Sample_3_LN2_Time
# 1439.0    8
# 1354.0    8
# 932.0     8
# 906.0     7
# 1121.0    7
#          ..
# 933.0     1
# 1205.0    1
# 1218.0    1
# 912.0     1
# 1609.0    1
# Name: Tumor_Sample_3_LN2_Time, Length: 85, dtype: int64
#
# Tumor_Sample_3_Ischemia_Time
# 5.0     52
# 4.0     43
# 3.0     37
# 7.0     30
# 10.0    16
# 6.0     16
# 8.0     10
# 12.0    10
# 30.0     7
# 15.0     7
# 9.0      6
# 28.0     6
# 11.0     5
# 20.0     4
# 18.0     3
# 19.0     3
# 22.0     1
# 2.0      1
# Name: Tumor_Sample_3_Ischemia_Time, dtype: int64
#
# Tumor_Sample_4_Weight
# 460.0     11
# 290.0      7
# 414.0      6
# 117.0      5
# 130.0      5
# 91.0       5
# 569.0      5
# 850.0      5
# 419.0      5
# 371.0      5
# 587.0      4
# 390.0      4
# 1251.0     4
# 357.0      4
# 375.0      4
# 219.0      4
# 112.0      4
# 990.0      4
# 498.0      4
# 155.0      4
# 144.0      3
# 358.0      3
# 236.0      3
# 241.0      3
# 700.0      3
# 595.0      3
# 193.0      3
# 134.0      3
# 142.0      3
# 165.0      3
# 255.0      3
# 306.0      3
# 153.0      3
# 405.0      3
# 395.0      3
# 127.0      3
# 128.0      3
# 226.0      3
# 102.0      3
# 150.0      2
# 376.6      2
# 225.0      2
# 1590.0     1
# 2000.0     1
# 120.0      1
# 230.0      1
# 300.0      1
# 540.0      1
# 220.0      1
# 420.0      1
# 1790.0     1
# 1010.0     1
# 550.0      1
# 570.0      1
# 670.0      1
# 1320.0     1
# Name: Tumor_Sample_4_Weight, dtype: int64
#
# Tumor_Sample_4_LN2_Time
# 932.0     11
# 906.0      7
# 1121.0     7
# 1228.0     6
# 1002.0     5
# 1336.0     5
# 927.0      5
# 1212.0     5
# 1601.0     5
# 1408.0     5
# 1418.0     4
# 1235.0     4
# 1400.0     4
# 1044.0     4
# 957.0      4
# 1619.0     4
# 857.0      4
# 1126.0     4
# 942.0      4
# 1133.0     4
# 1312.0     4
# 1744.0     4
# 914.0      3
# 1413.0     3
# 1138.0     3
# 1244.0     3
# 1532.0     3
# 836.0      3
# 1203.0     3
# 1019.0     3
# 1252.0     3
# 850.0      3
# 1541.0     3
# 1150.0     3
# 1038.0     3
# 1648.0     3
# 1759.0     3
# 1120.0     3
# 1009.0     2
# 1611.0     2
# 904.0      1
# 900.0      1
# 854.0      1
# 844.0      1
# 1549.0     1
# 839.0      1
# 815.0      1
# 1610.0     1
# 1057.0     1
# 1158.0     1
# 1134.0     1
# 1522.0     1
# 1206.0     1
# 1411.0     1
# Name: Tumor_Sample_4_LN2_Time, dtype: int64
#
# Tumor_Sample_4_Ischemia_Time
# 4.0     34
# 5.0     24
# 12.0    21
# 7.0     14
# 6.0     14
# 9.0     13
# 3.0     10
# 11.0     8
# 30.0     7
# 15.0     7
# 28.0     6
# 8.0      4
# 18.0     3
# 10.0     3
# 20.0     3
# 19.0     3
# 22.0     1
# Name: Tumor_Sample_4_Ischemia_Time, dtype: int64
#
# Tumor_Sample_5_Weight
# 81.0      5
# 105.0     5
# 132.0     4
# 1650.0    3
# 268.0     3
# 126.0     3
# 102.0     3
# 1950.0    1
# 310.0     1
# 100.0     1
# Name: Tumor_Sample_5_Weight, dtype: int64
#
# Tumor_Sample_5_LN2_Time
# 1336.0    5
# 1214.0    5
# 1045.0    4
# 850.0     3
# 1204.0    3
# 1133.0    3
# 1152.0    3
# 1135.0    1
# 1057.0    1
# Name: Tumor_Sample_5_LN2_Time, dtype: int64
#
# Tumor_Sample_5_Ischemia_Time
# 11.0    10
# 9.0      7
# 30.0     3
# 20.0     3
# 6.0      3
# 22.0     1
# 5.0      1
# Name: Tumor_Sample_5_Ischemia_Time, dtype: int64
#
# Normal_Sample_Number
# 0.0    225
# 3.0     43
# 2.0     16
# 1.0     12
# 4.0      5
# 5.0      3
# Name: Normal_Sample_Number, dtype: int64
#
# Normal_Sample_1_Surgical_Devascularized_Time
# 1411.0    8
# 835.0     8
# 1600.0    8
# 850.0     5
# 928.0     5
# 1500.0    5
# 1119.0    4
# 1228.0    4
# 1341.0    4
# 1101.0    3
# 1535.0    3
# 1650.0    3
# 1139.0    3
# 1348.0    3
# 1002.0    2
# 1340.0    2
# 1058.0    1
# 2145.0    1
# 816.0     1
# 1428.0    1
# 1512.0    1
# 1530.0    1
# 1303.0    1
# 1610.0    1
# 1332.0    1
# Name: Normal_Sample_1_Surgical_Devascularized_Time, dtype: int64
#
# Normal_Sample_1_Weight
# 30.0     12
# 64.0      8
# 28.0      7
# 84.0      5
# 638.0     5
# 137.0     5
# 130.0     5
# 74.0      4
# 134.0     4
# 96.0      4
# 800.0     3
# 387.0     3
# 155.0     3
# 100.0     2
# 700.0     2
# 213.3     2
# 325.0     1
# 60.0      1
# 180.0     1
# 340.0     1
# 260.0     1
# Name: Normal_Sample_1_Weight, dtype: int64
#
# Normal_Sample_1_LN2_Time
# 1416.0    8
# 1607.0    8
# 837.0     8
# 1505.0    5
# 937.0     5
# 855.0     5
# 1345.0    4
# 1234.0    4
# 1121.0    4
# 1653.0    3
# 1540.0    3
# 1127.0    3
# 1355.0    3
# 1140.0    3
# 1347.0    2
# 1011.0    2
# 1538.0    1
# 1616.0    1
# 1429.0    1
# 1105.0    1
# 1305.0    1
# 818.0     1
# 1343.0    1
# 1515.0    1
# 2147.0    1
# Name: Normal_Sample_1_LN2_Time, dtype: int64
#
# Normal_Sample_1_Ischemia_Time
# 5.0     21
# 2.0     15
# 7.0     14
# 9.0      7
# 6.0      5
# 1.0      4
# 4.0      4
# 3.0      4
# 26.0     3
# 11.0     1
# 8.0      1
# Name: Normal_Sample_1_Ischemia_Time, dtype: int64
#
# Normal_Sample_2_Surgical_Devascularized_Time
# 835.0     8
# 1411.0    8
# 850.0     5
# 928.0     5
# 1500.0    4
# 1228.0    4
# 1341.0    4
# 1119.0    4
# 1650.0    3
# 1101.0    3
# 1348.0    3
# 1140.0    3
# 1535.0    3
# 1002.0    2
# 1610.0    1
# 1429.0    1
# 1303.0    1
# 1332.0    1
# 816.0     1
# 1512.0    1
# 1530.0    1
# 2145.0    1
# Name: Normal_Sample_2_Surgical_Devascularized_Time, dtype: int64
#
# Normal_Sample_2_Weight
# 35.0     8
# 31.0     5
# 534.0    5
# 121.0    5
# 60.0     4
# 98.0     4
# 112.0    4
# 62.0     4
# 15.0     3
# 700.0    3
# 30.0     3
# 114.0    3
# 160.0    3
# 415.0    3
# 180.0    2
# 286.3    2
# 100.0    1
# 120.0    1
# 480.0    1
# 300.0    1
# 50.0     1
# 155.0    1
# Name: Normal_Sample_2_Weight, dtype: int64
#
# Normal_Sample_2_LN2_Time
# 1416.0    8
# 837.0     8
# 855.0     5
# 931.0     5
# 1505.0    4
# 1345.0    4
# 1121.0    4
# 1234.0    4
# 1127.0    3
# 1141.0    3
# 1540.0    3
# 1653.0    3
# 1355.0    3
# 1011.0    2
# 2147.0    1
# 1306.0    1
# 1516.0    1
# 819.0     1
# 1538.0    1
# 1344.0    1
# 1616.0    1
# 1430.0    1
# Name: Normal_Sample_2_LN2_Time, dtype: int64
#
# Normal_Sample_2_Ischemia_Time
# 5.0     20
# 2.0     13
# 3.0     10
# 4.0      5
# 6.0      5
# 1.0      4
# 26.0     3
# 7.0      3
# 9.0      2
# 12.0     1
# 8.0      1
# Name: Normal_Sample_2_Ischemia_Time, dtype: int64
#
# Normal_Sample_3_Surgical_Devascularized_Time
# 1411.0    8
# 835.0     8
# 850.0     5
# 1228.0    4
# 1119.0    4
# 1500.0    4
# 1101.0    3
# 1650.0    3
# 1141.0    3
# 1002.0    2
# 1610.0    1
# 2145.0    1
# 1303.0    1
# 1430.0    1
# 1332.0    1
# 816.0     1
# 1512.0    1
# Name: Normal_Sample_3_Surgical_Devascularized_Time, dtype: int64
#
# Normal_Sample_3_Weight
# 156.0    8
# 513.0    5
# 134.0    5
# 72.0     4
# 60.0     4
# 94.0     4
# 120.0    3
# 270.0    3
# 364.0    3
# 550.0    3
# 215.6    2
# 110.0    1
# 80.0     1
# 150.0    1
# 100.0    1
# 430.0    1
# 200.0    1
# 167.0    1
# Name: Normal_Sample_3_Weight, dtype: int64
#
# Normal_Sample_3_LN2_Time
# 1416.0    8
# 837.0     8
# 855.0     5
# 1505.0    4
# 1121.0    4
# 1234.0    4
# 1127.0    3
# 1653.0    3
# 1141.0    3
# 1013.0    2
# 1616.0    1
# 820.0     1
# 1517.0    1
# 1307.0    1
# 1431.0    1
# 2147.0    1
# 1345.0    1
# Name: Normal_Sample_3_LN2_Time, dtype: int64
#
# Normal_Sample_3_Ischemia_Time
# 5.0     18
# 2.0     13
# 6.0      5
# 26.0     3
# 0.0      3
# 3.0      3
# 4.0      2
# 11.0     2
# 13.0     1
# 1.0      1
# Name: Normal_Sample_3_Ischemia_Time, dtype: int64
#
# Normal_Sample_4_Surgical_Devascularized_Time
# 1142.0    3
# 1101.0    3
# 1002.0    2
# Name: Normal_Sample_4_Surgical_Devascularized_Time, dtype: int64
#
# Normal_Sample_4_Weight
# 95.0     3
# 500.0    3
# 117.7    2
# Name: Normal_Sample_4_Weight, dtype: int64
#
# Normal_Sample_4_LN2_Time
# 1127.0    3
# 1142.0    3
# 1014.0    2
# Name: Normal_Sample_4_LN2_Time, dtype: int64
#
# Normal_Sample_4_Ischemia_Time
# 26.0    3
# 0.0     3
# 12.0    2
# Name: Normal_Sample_4_Ischemia_Time, dtype: int64
#
# Normal_Sample_5_Surgical_Devascularized_Time
# 1142.0    3
# Name: Normal_Sample_5_Surgical_Devascularized_Time, dtype: int64
#
# Normal_Sample_5_Weight
# 700.0    3
# Name: Normal_Sample_5_Weight, dtype: int64
#
# Normal_Sample_5_LN2_Time
# 1143.0    3
# Name: Normal_Sample_5_LN2_Time, dtype: int64
#
# Normal_Sample_5_Ischemia_Time
# 1.0    3
# Name: Normal_Sample_5_Ischemia_Time, dtype: int64
#
# Origin_Site_Disease
# Ovary             194
# Fallopian tube     82
# Peritoneum         24
# Name: Origin_Site_Disease, dtype: int64
#
# Anatomic_Site_Tumor
# Omentum                  151
# Ovary                    141
# Pelvic mass                5
# Peritoneum                 2
# Not Reported/ Unknown      1
# Name: Anatomic_Site_Tumor, dtype: int64
#
# Anatomic_Lateral_Position_Tumor
# Not applicable           157
# Right                     83
# Left                      26
# Bilateral                 20
# Not Reported/ Unknown     14
# Name: Anatomic_Lateral_Position_Tumor, dtype: int64
#
# Histological_Subtype
# Serous Adenocarcinoma    300
# Name: Histological_Subtype, dtype: int64
#
# Method_of_Pathologic_Diagnosis
# Tumor resection      252
# Incisional Biopsy     33
# Excisional Biopsy     15
# Name: Method_of_Pathologic_Diagnosis, dtype: int64
#
# Tumor_Stage_Ovary_FIGO
# IIIC                     212
# IV                        55
# IIIB                      20
# Not Reported/ Unknown      6
# IC                         3
# III                        2
# IIIA                       2
# Name: Tumor_Stage_Ovary_FIGO, dtype: int64
#
# Tumor_Grade
# G3                       273
# Not Reported/ Unknown     11
# G2                         6
# G1                         5
# GB                         3
# GX                         2
# Name: Tumor_Grade, dtype: int64
#
# Tumor_Residual_Disease_Max_Diameter
# None                     186
# 1-10 mm                   62
# greater than 20 mm        37
# 11-20 mm                  10
# Not Reported/ Unknown      5
# Name: Tumor_Residual_Disease_Max_Diameter, dtype: int64
#
# Days_Between_Collection_And_Last_Contact
# 387.0    13
# 351.0    10
# 354.0    10
# 357.0    10
# 367.0     9
#          ..
# 296.0     1
# 117.0     1
# 304.0     1
# 370.0     1
# 270.0     1
# Name: Days_Between_Collection_And_Last_Contact, Length: 78, dtype: int64
#
# Vital_Status
# Living      278
# Deceased     26
# Name: Vital_Status, dtype: int64
#
# Days_Between_Collection_And_Death
# 399.0     6
# 977.0     4
# 1402.0    4
# 1256.0    4
# 330.0     3
# 112.0     3
# 28.0      1
# 181.0     1
# Name: Days_Between_Collection_And_Death, dtype: int64
#
# Tumor_Status
# Tumor free              171
# With tumor              101
# Not Reported/Unknown     32
# Name: Tumor_Status, dtype: int64
#
# Review_Of_Initial_Pathological_Findings
# Yes               280
# No                 16
# Not Applicable      8
# Name: Review_Of_Initial_Pathological_Findings, dtype: int64
#
# Pathology_Review_Consistent_With_Diagnosis
# Yes               292
# Not Applicable     12
# Name: Pathology_Review_Consistent_With_Diagnosis, dtype: int64
#
# Adjuvant_Radiation_Therapy
# No                      302
# Not Reported/Unknown      2
# Name: Adjuvant_Radiation_Therapy, dtype: int64
#
# Adjuvant_Pharmaceutical_Therapy
# Yes                     294
# No                        8
# Not Reported/Unknown      2
# Name: Adjuvant_Pharmaceutical_Therapy, dtype: int64
#
# Adjuvant_Immunotherapy
# No                      300
# Not Reported/Unknown      3
# Yes                       1
# Name: Adjuvant_Immunotherapy, dtype: int64
#
# Adjuvant_Hormone_Therapy
# No                      296
# Yes                       5
# Not Reported/Unknown      3
# Name: Adjuvant_Hormone_Therapy, dtype: int64
#
# Adjuvant_Targeted_Molecular_Therapy
# No                      266
# Yes                      35
# Not Reported/Unknown      3
# Name: Adjuvant_Targeted_Molecular_Therapy, dtype: int64
#
# Response_After_Surgery_And_Adjuvant_Therapies
# Complete Response       215
# Stable Disease           25
# Progressive Disease      23
# Not Reported/Unknown     22
# Partial Response         19
# Name: Response_After_Surgery_And_Adjuvant_Therapies, dtype: int64
#
# New_Tumor_Event_After_Initial_Treatment
# No                      233
# Yes                      57
# Not Reported/Unknown      8
# Not Applicable            6
# Name: New_Tumor_Event_After_Initial_Treatment, dtype: int64
#
# New_Tumor_Event_Type
# Locoregional Disease                        37
# Metastatic                                  10
# Both Locoregional and Distant Metastasis    10
# Not Reported/Unknown                         5
# Name: New_Tumor_Event_Type, dtype: int64
#
# New_Tumor_Event_Site
# Abdomen                               31
# Other (specify)                        8
# Pelvis; Abdomen                        4
# Chest; Abdomen                         4
# Abdomen; Other (specify); Pelvis       3
# Lymph Node only (specify location)     3
# Abdomen; Chest                         3
# Other (specify); Chest                 1
# Name: New_Tumor_Event_Site, dtype: int64
#
# Other_New_Tumor_Event_Site
# Vaginal cuff, right hepatorenal recess, liver, and spleen    8
# Inguinal lymph node                                          3
# Left external iliac lymph node                               3
# Liver                                                        1
# Name: Other_New_Tumor_Event_Site, dtype: int64
#
# Days_Between_Collection_And_New_Tumor_Event
# 325.0    8
# 273.0    5
# 315.0    5
# 277.0    4
# 411.0    4
# 286.0    4
# 420.0    4
# 453.0    4
# 149.0    3
# 390.0    3
# 321.0    3
# 302.0    3
# 404.0    3
# 436.0    2
# 296.0    1
# 378.0    1
# Name: Days_Between_Collection_And_New_Tumor_Event, dtype: int64
#
# New_Tumor_Event_Diagnosis
# Convincing imaging               48
# Positive Biomarkers               7
# First seen at further surgery     2
# Name: New_Tumor_Event_Diagnosis, dtype: int64
#
# New_Tumor_Event_Surgery
# No                      41
# Not Reported/Unknown    11
# Yes                      5
# Name: New_Tumor_Event_Surgery, dtype: int64
#
# Days_Between_Collection_And_New_Tumor_Event_Surgery
# 481.0    3
# 436.0    2
# Name: Days_Between_Collection_And_New_Tumor_Event_Surgery, dtype: int64
#
# New_Tumor_Event_Chemotherapy
# Yes                     35
# No                      11
# Not Reported/Unknown    11
# Name: New_Tumor_Event_Chemotherapy, dtype: int64
#
# New_Tumor_Event_Immunotherapy
# No                      38
# Not Reported/Unknown    11
# Yes                      8
# Name: New_Tumor_Event_Immunotherapy, dtype: int64
#
# New_Tumor_Event_Hormone_Therapy
# No                      46
# Not Reported/Unknown    11
# Name: New_Tumor_Event_Hormone_Therapy, dtype: int64
#
# New_Tumor_Event_Targeted_Molecular_Therapy
# No                      43
# Not Reported/Unknown    11
# Yes                      3
# Name: New_Tumor_Event_Targeted_Molecular_Therapy, dtype: int64
#
# Short Title
# CPTAC-MS-04OV    120
# CPTAC-WU-01OV     64
# CPTAC-CS-02OV     54
# CPTAC-UO-17OV     24
# CPTAC-UP-26OV     16
# CPTAC-UK-13OV      8
# CPTAC-JC-20OV      7
# CPTAC-AE-15OV      3
# CPTAC-HF-22OV      3
# CPTAC-CL-18OV      2
# CPTAC-MO-14OV      2
# CPTAC-AS-11OV      1
# Name: Short Title, dtype: int64
#
# Event
# Collection     301
# Pre Surgery      3
# Name: Event, dtype: int64
#
# Modified Time
# 2016-04-13    56
# 2016-04-22    50
# 2016-05-03    35
# 2016-03-21    30
# 2016-04-11    30
# 2016-03-25    28
# 2016-04-25    15
# 2016-02-17    15
# 2016-04-21    14
# 2016-06-23     5
# 2016-06-15     4
# 2016-03-17     3
# 2016-04-28     3
# 2016-05-02     3
# 2016-03-18     2
# 2015-07-13     1
# 2015-07-07     1
# 2015-11-06     1
# 2015-06-17     1
# 2016-03-22     1
# 2015-10-29     1
# 2016-04-05     1
# 2016-01-25     1
# 2016-03-24     1
# 2016-01-19     1
# 2015-05-29     1
# Name: Modified Time, dtype: int64
#
# Modified By
# Khandekar, Divya     295
# Snowbarger, Carie      4
# Lester, Jenny          3
# Guo, Lei               2
# Name: Modified By, dtype: int64
#
# Status
# Locked      297
# Active        5
# Disabled      2
# Name: Status, dtype: int64
#
# CRF Name
# Pharmaceutical Supplemental form      196
# One Year                              105
# Other Malignancy Supplemental form      2
# Radiation Supplemental form             1
# Name: CRF Name, dtype: int64
#
# Date of Last Contact (Do not answer if patient is deceased)
# 2015-05-26    4
# 2015-11-20    3
# 2016-04-20    3
# 2015-05-22    3
# 2015-11-04    2
#              ..
# 2015-11-13    1
# 2015-12-14    1
# 2016-03-16    1
# 2015-08-25    1
# 2014-01-24    1
# Name: Date of Last Contact (Do not answer if patient is deceased), Length: 77, dtype: int64
#
# Vital Status (at time of last contact)
# Living      97
# Deceased     8
# Name: Vital Status (at time of last contact), dtype: int64
#
# Date of Death
# 2014-10-16    1
# 2014-11-08    1
# 2012-02-09    1
# 2015-04-01    1
# 2015-06-05    1
# 2013-12-28    1
# 2013-11-16    1
# 2014-05-30    1
# Name: Date of Death, dtype: int64
#
# Tumor Status at Time of Last Contact or Death
# Tumor free    51
# With tumor    43
# Name: Tumor Status at Time of Last Contact or Death, dtype: int64
#
# Was a Review of the Initial Pathological Findings Done?
# Yes    97
# No      6
# Name: Was a Review of the Initial Pathological Findings Done?, dtype: int64
#
# Was the Pathology Review consistent with the Diagnosis?
# Yes    100
# Name: Was the Pathology Review consistent with the Diagnosis?, dtype: int64
#
# Adjuvant (Post-Operative) Radiation Therapy
# No    103
# Name: Adjuvant (Post-Operative) Radiation Therapy, dtype: int64
#
# Adjuvant (Post-Operative) Pharmaceutical Therapy
# Yes    97
# No      6
# Name: Adjuvant (Post-Operative) Pharmaceutical Therapy, dtype: int64
#
# Adjuvant (Post-Operative) Immunotherapy
# No     101
# Yes      1
# Name: Adjuvant (Post-Operative) Immunotherapy, dtype: int64
#
# Adjuvant (Post-Operative) Hormone Therapy
# No     101
# Yes      1
# Name: Adjuvant (Post-Operative) Hormone Therapy, dtype: int64
#
# Adjuvant (Post-Operative) Targeted Molecular Therapy
# No     95
# Yes     8
# Name: Adjuvant (Post-Operative) Targeted Molecular Therapy, dtype: int64
#
# Measure of Success of Outcome at the Completion of Initial First Course Treatment (surgery and adjuvant therapies)
# Complete Response      60
# Stable Disease         19
# Progressive Disease     8
# Partial Response        6
# Name: Measure of Success of Outcome at the Completion of Initial First Course Treatment (surgery and adjuvant therapies), dtype: int64
#
#  New Tumor Event After Initial Treatment?
# No     83
# Yes    16
# Name:  New Tumor Event After Initial Treatment?, dtype: int64
#
# Type of New Tumor Event
# Locoregional Disease                        10
# Metastatic                                   3
# Both Locoregional and Distant Metastasis     3
# Name: Type of New Tumor Event, dtype: int64
#
# Anatomic Site of New Tumor Event
# Abdomen;                               9
# Other (specify);Chest;                 1
# Abdomen;Chest;                         1
# Chest;Abdomen;                         1
# Other (specify);                       1
# Lymph Node only (specify location);    1
# Abdomen;Other (specify);Pelvis;        1
# Pelvis;Abdomen;                        1
# Name: Anatomic Site of New Tumor Event, dtype: int64
#
# Other Site of New Tumor Event or Lymph Node Location
# Liver                                                        1
# Inguinal lymph node                                          1
# vaginal cuff, right hepatorenal recess, liver, and spleen    1
# Left external iliac lymph node                               1
# Name: Other Site of New Tumor Event or Lymph Node Location, dtype: int64
#
# Date of New Tumor Event
# 2016-01-07    1
# 2015-11-09    1
# 2013-02-26    1
# 2016-04-01    1
# 2011-12-12    1
# 2015-10-07    1
# 2016-03-10    1
# 2015-09-09    1
# 2012-07-25    1
# 2011-05-24    1
# 2016-04-25    1
# 2015-12-09    1
# 2016-02-29    1
# 2016-03-03    1
# 2011-08-12    1
# 2015-03-17    1
# Name: Date of New Tumor Event, dtype: int64
#
# Method Of Diagnosis of New Tumor Event
# Convincing imaging               13
# Positive Biomarkers               2
# First seen at further surgery     1
# Name: Method Of Diagnosis of New Tumor Event, dtype: int64
#
# Other Method Of Diagnosis of New Tumor Event
# Series([], Name: Other Method Of Diagnosis of New Tumor Event, dtype: int64)
#
# Additional Surgery for New Tumor Event
# No     11
# Yes     2
# Name: Additional Surgery for New Tumor Event, dtype: int64
#
# Date of Additional Surgery for New Tumor Event
# 2016-01-07    1
# 2012-03-12    1
# Name: Date of Additional Surgery for New Tumor Event, dtype: int64
#
# Additional Chemotherapy Treatment of New Tumor Event
# Yes    10
# No      3
# Name: Additional Chemotherapy Treatment of New Tumor Event, dtype: int64
#
# Additional Immunotherapy Treatment of New Tumor Event
# No     11
# Yes     2
# Name: Additional Immunotherapy Treatment of New Tumor Event, dtype: int64
#
# Additional Hormone Therapy Treatment of New Tumor Event
# No    13
# Name: Additional Hormone Therapy Treatment of New Tumor Event, dtype: int64
#
# Additional Targeted Molecular Therapy Treatment of New Tumor Event
# No     12
# Yes     1
# Name: Additional Targeted Molecular Therapy Treatment of New Tumor Event, dtype: int64
#
# Radiation Type
# Series([], Name: Radiation Type, dtype: int64)
#
# Location of Radiation Treatment
# Series([], Name: Location of Radiation Treatment, dtype: int64)
#
# Number of Days from Date of Initial Pathologic Diagnosis to the Date Radiation Therapy Started
# Series([], Name: Number of Days from Date of Initial Pathologic Diagnosis to the Date Radiation Therapy Started, dtype: int64)
#
# Total Dose
# Series([], Name: Total Dose, dtype: int64)
#
# Units
# Series([], Name: Units, dtype: int64)
#
# Total Number of Fractions
# Series([], Name: Total Number of Fractions, dtype: int64)
#
# Radiation Treatment Ongoing
# Series([], Name: Radiation Treatment Ongoing, dtype: int64)
#
# Number of Days from Date of Initial Pathologic Diagnosis to the Date Radiation Therapy Ended
# Series([], Name: Number of Days from Date of Initial Pathologic Diagnosis to the Date Radiation Therapy Ended, dtype: int64)
#
# Measure of Best Response of Radiation Treatment
# Series([], Name: Measure of Best Response of Radiation Treatment, dtype: int64)
#
# Was Patient Treated on a Clinical Trial?
# No     154
# Yes     32
# Name: Was Patient Treated on a Clinical Trial?, dtype: int64
#
# Drug Name (Brand or Generic)
# Carboplatin                                 53
# Paclitaxel                                  45
# Cisplatin                                   31
# Taxol                                       13
# Docetaxel                                    6
# Bevacizumab                                  6
# Gemcitabine                                  5
# Avastin                                      5
# Taxotere                                     5
# Doxil                                        2
# Veliparib (ABTNot Performed)                 2
# Olaparib                                     2
# Caroplatin                                   1
# Paclitaxel IV                                1
# carboplatin                                  1
# Bevacizumab IV                               1
# taxol                                        1
# Paclitaxel IP                                1
# avastin                                      1
# Doxorubicin                                  1
# ABT Not Performed PO                         1
# Arimidex                                     1
# Carboplatin IP                               1
# CARBOPLATIN, PACLITAXEL                      1
# topotecan hcl                                1
# Liposomal Doxorubicin                        1
# taxotere                                     1
# Paclitaxol                                   1
# CisPlatin                                    1
# Carboplatin cyclophosphamide doxorubicin     1
# Docetaxel IV                                 1
# Paclitaxel - Dose Dense                      1
# Name: Drug Name (Brand or Generic), dtype: int64
#
# Clinical Trial Drug Classification
# Chemotherapy               13
# Phase I                     5
# Chemo                       3
# plant alkaloid              2
# chemotherapy                2
# alkylating agent            2
# With other Phase I drug     1
# aromatase inhibitor         1
# Pahse I                     1
# PARP Inhibitor              1
# Phase 1                     1
# monoclonal antibody         1
# GOG9923                     1
# Name: Clinical Trial Drug Classification, dtype: int64
#
# Pharmaceutical Type
# Chemotherapy                  181
# Targeted Molecular Therapy     10
# Hormone Therapy                 3
# Immunotherapy                   1
# Name: Pharmaceutical Type, dtype: int64
#
# Number of Days from Date of Initial Pathologic Diagnosis to Date of Therapy Start
# 41.0     9
# 42.0     9
# 27.0     7
# 21.0     6
# 22.0     6
#         ..
# 157.0    1
# 195.0    1
# 105.0    1
# 196.0    1
# 85.0     1
# Name: Number of Days from Date of Initial Pathologic Diagnosis to Date of Therapy Start, Length: 73, dtype: int64
#
# Therapy Ongoing
# No     186
# Yes      8
# Name: Therapy Ongoing, dtype: int64
#
# Number of Days from Date of Initial Pathologic Diagnosis to Date of Therapy End
# 134.0    8
# 128.0    6
# 138.0    6
# 147.0    5
# 178.0    4
#         ..
# 167.0    1
# 237.0    1
# 166.0    1
# 180.0    1
# 219.0    1
# Name: Number of Days from Date of Initial Pathologic Diagnosis to Date of Therapy End, Length: 101, dtype: int64
#
# Measure of Best Response of Pharmaceutical Treatment
# Complete Response                   129
# Partial Response                     23
# Progressive Disease                  13
# Not Applicable (Therapy Ongoing)      8
# Stable Disease                        5
# Name: Measure of Best Response of Pharmaceutical Treatment, dtype: int64
#
# What Type of Malignancy was This?
# Synchronous Malignancy (diagnosis coincided with the diagnosis of the specimen submitted for CPTAC)    1
# Prior Malignancy (diagnosed prior to the diagnosis of the specimen submitted for CPTAC)                1
# Name: What Type of Malignancy was This?, dtype: int64
#
# Primary Site of Disease
# thyroid                                                      1
# vaginal cuff, right hepatorenal recess, liver, and spleen    1
# Name: Primary Site of Disease, dtype: int64
#
# Laterality of the Disease
# Series([], Name: Laterality of the Disease, dtype: int64)
#
# Histological Type
# unknown thyroid cancer    1
# Name: Histological Type, dtype: int64
#
# Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to the Date of Initial Diagnosis of Other Malignancy
# 326.0    1
# Name: Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to the Date of Initial Diagnosis of Other Malignancy, dtype: int64
#
# Did the patient have surgery for this malignancy?
# No                                                1
# Yes (Complete the following surgery questions)    1
# Name: Did the patient have surgery for this malignancy?, dtype: int64
#
# Type of Surgery
# thyroidectomy    1
# Name: Type of Surgery, dtype: int64
#
# Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to the Date of Surgical Resection for this Other Malignancy
# 7665.0    1
# Name: Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to the Date of Surgical Resection for this Other Malignancy, dtype: int64
#
# Did the patient receive pharmaceutical therapy for this malignancy?
# No     1
# Yes    1
# Name: Did the patient receive pharmaceutical therapy for this malignancy?, dtype: int64
#
# Extent of Pharmaceutical Therapy
# Systemic    1
# Name: Extent of Pharmaceutical Therapy, dtype: int64
#
# Drug Name(s) (Brand or Generic)
# LY2228820    1
# Name: Drug Name(s) (Brand or Generic), dtype: int64
#
# Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to Date Pharmaceutical Therapy Started for this Other Malignancy
# 10.0    1
# Name: Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted for CPTAC to Date Pharmaceutical Therapy Started for this Other Malignancy, dtype: int64
#
# Did the patient receive radiation therapy for this malignancy?
# No    2
# Name: Did the patient receive radiation therapy for this malignancy?, dtype: int64
#
# Extent of Radiation Therapy
# Series([], Name: Extent of Radiation Therapy, dtype: int64)
#
# If the patient received locoregional radiation, was the radiation therapy received in the same field as the tumor submitted for CPTAC?
# Series([], Name: If the patient received locoregional radiation, was the radiation therapy received in the same field as the tumor submitted for CPTAC?, dtype: int64)
#
# Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted to CPTAC to Date Radiation Therapy Started for this Other Malignancy
# Series([], Name: Number of Days from Date of Initial Pathologic Diagnosis of the Tumor Submitted to CPTAC to Date Radiation Therapy Started for this Other Malignancy, dtype: int64)
#
# Was the patient staged using FIGO?
# No     1
# Yes    1
# Name: Was the patient staged using FIGO?, dtype: int64
#
# FIGO Staging System (Gynecologic Tumors Only)
# 2009.0    1
# Name: FIGO Staging System (Gynecologic Tumors Only), dtype: int64
#
# FIGO Stage
# Stage IIIC    1
# Name: FIGO Stage, dtype: int64
#
#  Was the patient staged using AJCC?
# No     1
# Yes    1
# Name:  Was the patient staged using AJCC?, dtype: int64
#
# AJCC Cancer Staging Edition
# 7th Edition (2012-present)    1
# Name: AJCC Cancer Staging Edition, dtype: int64
#
# Pathologic Spread: Primary Tumor (pT)
# Series([], Name: Pathologic Spread: Primary Tumor (pT), dtype: int64)
#
# Pathologic Spread: Lymph Nodes (pN)
# Series([], Name: Pathologic Spread: Lymph Nodes (pN), dtype: int64)
#
# Distant Metastases (M)
# Series([], Name: Distant Metastases (M), dtype: int64)
#
# AJCC Tumor Stage
# Series([], Name: AJCC Tumor Stage, dtype: int64)

# %%
#Determine columns to focus on, and create a subset to work with
columns_to_focus_on = ['Patient_ID', 'Vital_Status', 'Vital Status (at time of last contact)',
                       'Tumor_Stage_Ovary_FIGO', 'Days_Between_Collection_And_Last_Contact', 
                       'Tumor_Grade', 'New_Tumor_Event_After_Initial_Treatment', 
                       'Date of Last Contact (Do not answer if patient is deceased)', 
                       'Date of Death', 'Tumor Status at Time of Last Contact or Death', 
                       'Date of New Tumor Event', 'Pharmaceutical Type']

focus_group = patient_data[columns_to_focus_on].copy().drop_duplicates()
focus_group = focus_group[['Vital Status',
                           'Path Diag to Last Contact(Day)',
                           'Histologic_Grade_FIGO',
                           'tumor_Stage-Pathological']].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-ed98b4a08e17> in <module>()
#      11                            'Path Diag to Last Contact(Day)',
#      12                            'Histologic_Grade_FIGO',
# ---> 13                            'tumor_Stage-Pathological']].copy()
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~\AppData\Local\conda\conda\envs\Research\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['Vital Status', 'Path Diag to Last Contact(Day)',\n       'Histologic_Grade_FIGO', 'tumor_Stage-Pathological'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# ## Step 2b: Prepare data for Kaplan Meier Plotting and Survival Analysis

# %%
patient_data[patient_data['Vital Status'] == "Deceased"]
# Out:
#     Patient_ID Proteomics_Tumor_Normal        Country Histologic_Grade_FIGO  \
# 25   C3L-00139                   Tumor  United States                   NaN
# 82   C3L-00771                   Tumor  Other_specify          FIGO grade 2
# 83   C3L-00771       Myometrium_normal            NaN                   NaN
# 146  C3L-01307                   Tumor  United States          FIGO grade 3
# 147  C3L-01307         Adjacent_normal            NaN                   NaN
# 162  C3N-00200                   Tumor  United States          FIGO grade 2
# 164  C3N-00200       Myometrium_normal            NaN                   NaN
# 247  C3N-01349                   Tumor         Poland                   NaN
# 251  C3N-01520                   Tumor        Ukraine          FIGO grade 2
#
#     Myometrial_invasion_Specify Histologic_type Treatment_naive Tumor_purity  \
# 25                 50 % or more          Serous             YES       Normal
# 82                 50 % or more    Endometrioid             YES       Normal
# 83                          NaN             NaN             NaN          NaN
# 146                  under 50 %    Endometrioid             YES       Normal
# 147                         NaN             NaN             NaN          NaN
# 162              Not identified    Endometrioid             YES       Normal
# 164                         NaN             NaN             NaN          NaN
# 247                50 % or more          Serous             YES       Normal
# 251                  under 50 %    Endometrioid             YES       Normal
#
#     Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  ...  \
# 25             pT3a (FIGO IIIA)                           pNX  ...
# 82             pT3a (FIGO IIIA)                           pN0  ...
# 83                          NaN                           NaN  ...
# 146              pT1a (FIGO IA)                           pNX  ...
# 147                         NaN                           NaN  ...
# 162               pT2 (FIGO II)              pN1 (FIGO IIIC1)  ...
# 164                         NaN                           NaN  ...
# 247              pT1b (FIGO IB)                           pN0  ...
# 251              pT1a (FIGO IA)                           pNX  ...
#
#     New Tumor Procedure Unknown New Tumor Excisional biopsy  \
# 25                          NaN                         NaN
# 82                          NaN                         NaN
# 83                          NaN                         NaN
# 146                         NaN                         NaN
# 147                         NaN                         NaN
# 162                         NaN                         NaN
# 164                         NaN                         NaN
# 247                         NaN                         NaN
# 251                         NaN                         NaN
#
#     New Tumor Incisional biopsy New Tumor Surgical Resection  \
# 25                          NaN                          NaN
# 82                          NaN                          NaN
# 83                          NaN                          NaN
# 146                         NaN                          NaN
# 147                         NaN                          NaN
# 162                         NaN                          NaN
# 164                         NaN                          NaN
# 247                         NaN                          NaN
# 251                         NaN                          NaN
#
#      Other New Tumor Procedure  Specify Other New Tumor Proc  \
# 25                         NaN                           NaN
# 82                         NaN                           NaN
# 83                         NaN                           NaN
# 146                        NaN                           NaN
# 147                        NaN                           NaN
# 162                        NaN                           NaN
# 164                        NaN                           NaN
# 247                        NaN                           NaN
# 251                        NaN                           NaN
#
#      Residual Tumor After Surgery Radiation for New Tumor  \
# 25                            NaN                     NaN
# 82                            NaN                     NaN
# 83                            NaN                     NaN
# 146                           NaN                     NaN
# 147                           NaN                     NaN
# 162                           NaN                      No
# 164                           NaN                      No
# 247                           NaN                     NaN
# 251                           NaN                     NaN
#
#     Pharmaceutical for New Tumor Immunological for New Tumor
# 25                           NaN                         NaN
# 82                           NaN                         NaN
# 83                           NaN                         NaN
# 146                          NaN                         NaN
# 147                          NaN                         NaN
# 162                           No                          No
# 164                           No                          No
# 247                          NaN                         NaN
# 251                          NaN                         NaN
#
# [9 rows x 75 columns]

# %%
focus_group = focus_group.replace('Living', 0)
focus_group = focus_group.replace('Deceased', 1)
focus_group = focus_group.dropna()

# %% [markdown]
# For Kaplan Meier plots, your data needs to be in a format similar to that shown below.  Particularly, it needs a boolean column for the 'event' you are interested in (in this case, vital status), where True denotes the event you are tracking, and False denotes an individual that never had the event of interest occur (in this case, their vital status is 'living').  It also needs a column with a numeric time frame, which we have as 'Path Diag to Last Contact(Day)'.  The other columns contain categorical data that we are testing to find meaningful connections with positive or negative event outcomes.

# %%
focus_group.head()
# Out:
#    Vital Status  Path Diag to Last Contact(Day) Histologic_Grade_FIGO  \
# 0             0                           494.0          FIGO grade 1
# 1             0                           717.0          FIGO grade 1
# 2             0                           737.0          FIGO grade 1
# 6             0                           440.0          FIGO grade 1
# 7             0                           624.0          FIGO grade 1
#
#   tumor_Stage-Pathological
# 0                  Stage I
# 1                  Stage I
# 2                  Stage I
# 6                 Stage IV
# 7                 Stage IV

# %%
time = focus_group['Path Diag to Last Contact(Day)'].copy()
vital_status = focus_group['Vital Status'].copy()

# %% [markdown]
# Kaplan Meier plots show us the probability of some event occuring over a given length of time, based on some attribute.  Oftentimes, they are used to plot the probability of death for different attributes, however they could also be used in a variety of other contexts.  Below are a few examples of Kaplan Meier Plots in regards to Histologic Grade, and Tumor Stage of patients with Endometrial Cancer:

# %%
kmf = KaplanMeierFitter()
kmf.fit(time, event_observed = vital_status)
# Out:
# <lifelines.KaplanMeierFitter: fitted with 171 total observations, 167 right-censored observations>

# %%
#groups = focus_group
kmf.plot()

# %%
from lifelines import CoxPHFitter

# %%
figo_map = {"FIGO grade 1": 1, "FIGO grade 2": 2, "FIGO grade 3" : 3}
focus_group['Histologic_Grade_FIGO'] = focus_group['Histologic_Grade_FIGO'].map(figo_map)

# %%
tumor_map = {"Stage I" : 1, "Stage II" : 2, "Stage III" : 3, "Stage IV" : 4}
focus_group['tumor_Stage-Pathological'] = focus_group['tumor_Stage-Pathological'].map(tumor_map)

# %%
cph = CoxPHFitter()
cph.fit(focus_group, duration_col = "Path Diag to Last Contact(Day)", event_col = "Vital Status")
# Out:
# <lifelines.CoxPHFitter: fitted with 171 total observations, 167 right-censored observations>

# %%
cph.print_summary(model="untransformed variables", decimals=3)
# Out:
# <lifelines.CoxPHFitter: fitted with 171 total observations, 167 right-censored observations>
#       duration col = 'Path Diag to Last Contact(Day)'
#          event col = 'Vital Status'
# number of observations = 171.0
# number of events observed = 4.0
# partial log-likelihood = -13.537
#   time fit was run = 2019-11-21 21:16:18 UTC
#              model = untransformed variables
#
#
# ---
#                           coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# Histologic_Grade_FIGO    1.109     3.031     0.659          -0.182           2.399               0.834              11.018
# tumor_Stage-Pathological 1.218     3.380     0.512           0.215           2.221               1.239               9.217
#
#                              z     p  -log2(p)
# Histologic_Grade_FIGO    1.684 0.092     3.438
# tumor_Stage-Pathological 2.379 0.017     5.848
# ---
# Concordance = 0.837
# Log-likelihood ratio test = 9.982 on 2 df, -log2(p)=7.201

# %%
focus_group['Vital Status'].value_counts()
# Out:
# 0    167
# 1      4
# Name: Vital Status, dtype: int64

# %%
from lifelines.statistics import proportional_hazard_test

results = proportional_hazard_test(cph, focus_group, time_transform='rank')
results.print_summary(decimals=3, model="untransformed variables")
# Out:
# <lifelines.StatisticalResult>
#          test_name = proportional_hazard_test
#     time_transform = rank
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              model = untransformed variables
#
# ---
#                           test_statistic     p  -log2(p)
# Histologic_Grade_FIGO              0.014 0.905     0.145
# tumor_Stage-Pathological           0.291 0.590     0.762

# %%
cph.plot()

# %%
wbf = lifelines.WeibullFitter().fit(time, vital_status)

# %%
wbf.plot_survival_function()

# %% [markdown]
# ## Step 3: Separate the data for pre-processing, and to prepare for Cox Proportional Hazard Test
# Cox Proportional Hazard Test is a statistical test used to interpret the significance of Kaplan Meier plots, and potential connections between attributes and an event of interest (in this case, survival).
#
# For the test to be performed properly, our data needs to be in a specific format. It requires data about Vital Status and time to event/last contact to be in a structured array, which we have titled 'survival_array' below.
#
# Additionally, the attributes we are interested in studying, which are the tumor stage and histologic grade, need to be separate from this array. We separated this data into a DataFrame we call 'tumor_stage_data' below.

# %%
tumor_stage_data = focus_group[["tumor_Stage-Pathological",
                                "Histologic_Grade_FIGO"]].copy()
#tumor_stage_data = pd.DataFrame(focus_group['tumor_Stage-Pathological'].copy())

survival_data = focus_group[['Vital Status',
                             "Path Diag to Last Contact(Day)"]].copy()

survival_array = np.zeros(len(survival_data),
                          dtype={"names":("Vital Status",
                                          "Path Diag to Last Contact(Day)"),
                                 "formats":("?", "<f8")})

survival_array['Vital Status'] = survival_data['Vital Status'].values
survival_array['Path Diag to Last Contact(Day)'] = survival_data['Path Diag to Last Contact(Day)'].values

# %% [markdown]
# Sometimes in the conversion, merging, and manipulation of DataFrames, columns' data types get mixed up.  Sci-kit learn requires columns of type "category" or "numeric" to perform pre-processing, which will create a binary DataFrame ready for performing Cox Proportional Hazard, as well as many other predictive analyses.  Oftentimes, these data types become an "object" type, so we will change them to type "category".

# %%
for col in tumor_stage_data.columns:
    tumor_stage_data[col] = tumor_stage_data[col].astype("category")

# %% [markdown]
# ## Step 4: Perform Cox Proportional Hazard Test

# %% [markdown]
# In order to perform Cox Proportional Hazard Test, as well as many other Machine Learning and other statistical tests, our data needs to be pre-processed.  This is oftentimes done with Sci-kit Learn's encoder entitled "OneHotEncoder".  OneHotEncoder will create a new binary DataFrame of 0 and 1 for all the attributes in the DataFrame you give it, which will now be in the format for the test to be performed.

# %%
for col in tumor_stage_data.columns:
    print(tumor_stage_data[col].value_counts(), '\n')
# Out:
# Stage I      127
# Stage III     19
# Stage II      19
# Stage IV       6
# Name: tumor_Stage-Pathological, dtype: int64
#
# FIGO grade 1    80
# FIGO grade 2    76
# FIGO grade 3    15
# Name: Histologic_Grade_FIGO, dtype: int64

# %%
tumor_stage_numeric = OneHotEncoder().fit_transform(tumor_stage_data)
test2 = OneHotEncoder().fit_transform(tumor_stage_data[["Histologic_Grade_FIGO", "tumor_Stage-Pathological"]])

# %%
#What happened to stage I and grade 1?
tumor_stage_numeric.columns
# Out:
# Index(['tumor_Stage-Pathological=Stage II',
#        'tumor_Stage-Pathological=Stage III',
#        'tumor_Stage-Pathological=Stage IV',
#        'Histologic_Grade_FIGO=FIGO grade 2',
#        'Histologic_Grade_FIGO=FIGO grade 3'],
#       dtype='object')

# %%
test2.columns
# Out:
# Index(['Histologic_Grade_FIGO=FIGO grade 2',
#        'Histologic_Grade_FIGO=FIGO grade 3',
#        'tumor_Stage-Pathological=Stage II',
#        'tumor_Stage-Pathological=Stage III',
#        'tumor_Stage-Pathological=Stage IV'],
#       dtype='object')

# %% [markdown]
# Here we will use our estimator of choice, Cox Proportional Hazard, to perform the test.

# %%
estimator = CoxPHSurvivalAnalysis()
estimator.fit(tumor_stage_numeric, survival_array)
# Out:
# CoxPHSurvivalAnalysis(alpha=0, n_iter=100, ties='breslow', tol=1e-09, verbose=0)

# %% [markdown]
# We can now look at our proportional hazard rations by viewing the following Series, based on the coefficients of the estimator, and the index of the pre-processed data.  These ratios help us know how influential a particular attribute is in relation to survival.  For instance, the ratio of 2.6235030 for Stage III tumors shows us that patients with a Stage III tumor had a 26.2% higher likelihood of death than if they did not have a Stage III tumor.

# %%
pd.Series(estimator.coef_, index=tumor_stage_numeric.columns)
# Out:
# tumor_Stage-Pathological=Stage II    -20.501921
# tumor_Stage-Pathological=Stage III     2.623530
# tumor_Stage-Pathological=Stage IV     25.649083
# Histologic_Grade_FIGO=FIGO grade 2    43.161388
# Histologic_Grade_FIGO=FIGO grade 3    22.798626
# dtype: float64

# %% [markdown]
# If you are interested in the accuracy of your model for predicting a positive or negative outcome based on your survival_array, you can view the estimator's "score" method.  This score is particularly relevant when testing your model against new data, but is still helpful in understanding its standalone accuracy as well.

# %%
estimator.score(tumor_stage_numeric, survival_array)
# Out:
# 0.8166666666666667

# %% [markdown]
# Those are the basics of Survival Analysis on the cancer data we have provided in the cptac package.  This is by no means the only way this could have been done.  There are many other questions we could ask ourselves, and continue to study once we get to this point:
#
# How well does our model hold up for new data? What other attributes may be important for survival? What if I want to study the connection between clinical attributes and the likelihood of developing a second tumor during treatment?
#
# With the functionality and flexibility of cptac, Sci-kit Survival and Sci-kit Learn, these answers can be explored, and a variety of other research projects could be done.  This use case is intended to be a springboard to help researchers get started in survival analysis, and leverage the cancer data we have to find important connections between clinical or molecular attributes and clinical outcomes.
