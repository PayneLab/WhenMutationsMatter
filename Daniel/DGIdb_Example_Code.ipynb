# %% [markdown]
# ## This notebook's purpose serves to give a short demonstration on how to connect drug or gene lists found through Outlier Analysis with the Druggable Genome Interactive Database.

# %%
import pandas as pd
import binarization_functions as bf
import requests
import json

# %% [markdown]
# First we will generate a list of genes or drugs. This will be generated by patient or by clinical attributes with other functions within cptac.utils, but to demonstrate how to use DGIdb, we will make an arbitrary list of genes as an example.

# %%
gene_list = ['AVL9', 'COG1', 'GOLPH3L', 'RAB3GAP1', 'RAB3GAP2']

# %%
r = bf.dgidb_get_request(genes_or_drugs_list=gene_list, 
                         genes=True, drugs=False, 
                         interaction_sources=['TTD','DrugBank','TALC'], 
                         interaction_types=['inhibitor','activator'], 
                         fda_approved_drug=True, immunotherapy=True,
                         anti_neoplastic=True, clinically_actionable=True, 
                         druggable_genome=True, drug_resistance=True, 
                         gene_categories=['tumor suppressor','dna repair', 'kinase'], 
                         source_trust_levels=['Expert cUrated'])

# %% [markdown]
# An HTTP GET request to DGIdb will return a large JSON object, with a lot of information, some of which may not be necessary for our analysis. However, if you would like the whole JSON object, it will saved as a Python dictionary to whatever value you set bf.dgidb_get_request() to, in this case, "r".

# %%
r
# Out:
# {'ambiguousTerms': [],
#  'matchedTerms': [{'entrezId': 23080,
#    'geneCategories': [],
#    'geneLongName': 'AVL9 CELL MIGRATION ASSOCIATED',
#    'geneName': 'AVL9',
#    'interactions': [],
#    'searchTerm': 'AVL9'},
#   {'entrezId': 9382,
#    'geneCategories': [],
#    'geneLongName': 'COMPONENT OF OLIGOMERIC GOLGI COMPLEX 1',
#    'geneName': 'COG1',
#    'interactions': [],
#    'searchTerm': 'COG1'},
#   {'entrezId': 55204,
#    'geneCategories': [],
#    'geneLongName': 'GOLGI PHOSPHOPROTEIN 3 LIKE',
#    'geneName': 'GOLPH3L',
#    'interactions': [],
#    'searchTerm': 'GOLPH3L'},
#   {'entrezId': 22930,
#    'geneCategories': [],
#    'geneLongName': 'RAB3 GTPASE ACTIVATING PROTEIN CATALYTIC SUBUNIT 1',
#    'geneName': 'RAB3GAP1',
#    'interactions': [],
#    'searchTerm': 'RAB3GAP1'},
#   {'entrezId': 25782,
#    'geneCategories': [],
#    'geneLongName': 'RAB3 GTPASE ACTIVATING NON-CATALYTIC PROTEIN SUBUNIT 2',
#    'geneName': 'RAB3GAP2',
#    'interactions': [],
#    'searchTerm': 'RAB3GAP2'}],
#  'unmatchedTerms': []}

# %% [markdown]
# You will notice that when using dgidb_json_parse() on "r", there are "No Gene/Drug interactions".  dgidb_json_parse() will parse through a rather complicated json object, and return a dictionary of genes and their interactions with drugs (or the inverse if a list of drugs were given rather than a list of genes to dgidb_get_request()). Because there were no interactions, there are no drugs in DGIdb that are related to regulating the expression of genes in our list.

# %%
drug_dict = bf.dgidb_json_parse(r, genes=True)
# Out:
# No Gene/Drug interactions

# %% [markdown]
# Below is an example of genes with many interactions, and a lot of extra information we likely do not need for our analysis. The JSON object of our query before and after dgidb_json_parse() will illustrate that fact, and help extract some of the more meaningful information from our query.

# %%
gene_list2 = ["ATP1B2", "SHBG", "CD38", "P2RX4"]
r2 = bf.dgidb_get_request(gene_list2, genes=True)

# %%
r2
# Out:
# {'ambiguousTerms': [],
#  'matchedTerms': [{'entrezId': 482,
#    'geneCategories': [{'id': '9bcd3de20cbc41da8d8ba4c693c93c8b',
#      'name': 'TRANSPORTER'},
#     {'id': '00f6836cd18c4d1ab6fa29d672375ae0', 'name': 'ABC TRANSPORTER'},
#     {'id': 'd3ec2631e0b2434b9dcc008e793d3fa5', 'name': 'DRUGGABLE GENOME'}],
#    'geneLongName': 'ATPASE NA+/K+ TRANSPORTING SUBUNIT BETA 2',
#    'geneName': 'ATP1B2',
#    'interactions': [{'drugChemblId': 'CHEMBL1614',
#      'drugName': 'DESLANOSIDE',
#      'interactionId': '51136830-a97d-4b77-9d92-5edebeb782d8',
#      'interactionTypes': ['inhibitor'],
#      'pmids': [],
#      'score': 1,
#      'sources': ['ChemblInteractions']},
#     {'drugChemblId': 'CHEMBL254219',
#      'drugName': 'DIGITOXIN',
#      'interactionId': 'f5a8b9ba-b3f3-40b5-b394-4e2432c6e4c1',
#      'interactionTypes': ['inhibitor'],
#      'pmids': [],
#      'score': 1,
#      'sources': ['ChemblInteractions']},
#     {'drugChemblId': 'CHEMBL1751',
#      'drugName': 'DIGOXIN',
#      'interactionId': 'a6e61319-e04a-4ad4-9cab-c1f835137f6d',
#      'interactionTypes': ['inhibitor'],
#      'pmids': [],
#      'score': 1,
#      'sources': ['ChemblInteractions']},
#     {'drugChemblId': 'CHEMBL3545057',
#      'drugName': 'ACETYLDIGITOXIN',
#      'interactionId': 'f3c47f7b-836b-4dc2-8b2d-3ae7976f1b08',
#      'interactionTypes': ['inhibitor'],
#      'pmids': [],
#      'score': 1,
#      'sources': ['ChemblInteractions']}],
#    'searchTerm': 'ATP1B2'},
#   {'entrezId': 6462,
#    'geneCategories': [{'id': 'd3ec2631e0b2434b9dcc008e793d3fa5',
#      'name': 'DRUGGABLE GENOME'}],
#    'geneLongName': 'SEX HORMONE BINDING GLOBULIN',
#    'geneName': 'SHBG',
#    'interactions': [{'drugChemblId': 'CHEMBL1393',
#      'drugName': 'SPIRONOLACTONE',
#      'interactionId': 'e6d2d057-a8f8-42fc-a310-1265464ad676',
#      'interactionTypes': ['binder'],
#      'pmids': [17881754],
#      'score': 2,
#      'sources': ['DrugBank']},
#     {'drugChemblId': 'CHEMBL820',
#      'drugName': 'BUSULFAN',
#      'interactionId': 'f3c397cd-dab8-4193-8c58-3f6758297d46',
#      'interactionTypes': [],
#      'pmids': [3692618],
#      'score': 2,
#      'sources': ['NCI']},
#     {'drugChemblId': 'CHEMBL1237',
#      'drugName': 'LISINOPRIL',
#      'interactionId': 'f26befdd-11e8-4bda-aa9e-61258e002632',
#      'interactionTypes': [],
#      'pmids': [11872207],
#      'score': 2,
#      'sources': ['NCI']},
#     {'drugChemblId': 'CHEMBL2107797',
#      'drugName': 'NORGESTREL',
#      'interactionId': '7f8b225b-6d29-4644-8b37-a1641475d911',
#      'interactionTypes': [],
#      'pmids': [573191],
#      'score': 2,
#      'sources': ['NCI']},
#     {'drugChemblId': 'CHEMBL487',
#      'drugName': 'DROLOXIFENE',
#      'interactionId': '51f0ed1a-c5ef-4c19-8adb-97b21d8891ef',
#      'interactionTypes': [],
#      'pmids': [7561649],
#      'score': 2,
#      'sources': ['NCI']}],
#    'searchTerm': 'SHBG'},
#   {'entrezId': 952,
#    'geneCategories': [{'id': '26f6a4ea7779433ea2cbf524683accf7',
#      'name': 'CELL SURFACE'},
#     {'id': '655bedfa9d71482796a5a34b87dfb297', 'name': 'DRUG RESISTANCE'},
#     {'id': 'd3ec2631e0b2434b9dcc008e793d3fa5', 'name': 'DRUGGABLE GENOME'}],
#    'geneLongName': 'CD38 MOLECULE',
#    'geneName': 'CD38',
#    'interactions': [{'drugChemblId': 'CHEMBL1743007',
#      'drugName': 'DARATUMUMAB',
#      'interactionId': 'a48f99e7-1e4a-4e65-9523-4bbf927f0efa',
#      'interactionTypes': ['antibody', 'inhibitor'],
#      'pmids': [],
#      'score': 3,
#      'sources': ['MyCancerGenome',
#       'GuideToPharmacologyInteractions',
#       'ChemblInteractions']},
#     {'drugChemblId': 'CHEMBL3545131',
#      'drugName': 'ISATUXIMAB',
#      'interactionId': '9dc47080-210b-4630-aac3-f775fb83baf9',
#      'interactionTypes': ['antibody'],
#      'pmids': [],
#      'score': 1,
#      'sources': ['GuideToPharmacologyInteractions']},
#     {'drugChemblId': 'CHEMBL2109270',
#      'drugName': 'SAR-650984',
#      'interactionId': '07bcee0f-af96-4e1a-9030-6c75e16e4e9a',
#      'interactionTypes': [],
#      'pmids': [],
#      'score': 1,
#      'sources': ['TdgClinicalTrial']},
#     {'drugChemblId': 'CHEMBL2109269',
#      'drugName': 'HuMax-CD38',
#      'interactionId': '374dee91-d101-443d-813e-39fad7a17fa7',
#      'interactionTypes': [],
#      'pmids': [],
#      'score': 1,
#      'sources': ['TdgClinicalTrial']},
#     {'drugChemblId': 'CHEMBL2108110',
#      'drugName': 'THROMBIN',
#      'interactionId': '3478e4f3-ddef-48e5-9fae-7d5bc7547c77',
#      'interactionTypes': [],
#      'pmids': [9654134],
#      'score': 2,
#      'sources': ['NCI']}],
#    'searchTerm': 'CD38'},
#   {'entrezId': 5025,
#    'geneCategories': [{'id': '9bcd3de20cbc41da8d8ba4c693c93c8b',
#      'name': 'TRANSPORTER'},
#     {'id': 'b2e1d6814868498b8865b055d8972250', 'name': 'ION CHANNEL'},
#     {'id': 'd3ec2631e0b2434b9dcc008e793d3fa5', 'name': 'DRUGGABLE GENOME'}],
#    'geneLongName': 'PURINERGIC RECEPTOR P2X 4',
#    'geneName': 'P2RX4',
#    'interactions': [{'drugChemblId': 'CHEMBL87992',
#      'drugName': 'ESLICARBAZEPINE ACETATE',
#      'interactionId': '4578fde0-64fa-42c5-b930-6e45dc6edede',
#      'interactionTypes': ['antagonist'],
#      'pmids': [24411477],
#      'score': 2,
#      'sources': ['DrugBank']}],
#    'searchTerm': 'P2RX4'}],
#  'unmatchedTerms': []}

# %%
drug_dict2 = bf.dgidb_json_parse(r2, genes=True)

# %%
#Note: Key = Gene, Value = {Key = Drug, Value = [Interaction Type(s)]}
print(json.dumps(drug_dict2, indent=4))
# Out:
# {
#     "ATP1B2": {
#         "DESLANOSIDE": [
#             "inhibitor"
#         ],
#         "DIGITOXIN": [
#             "inhibitor"
#         ],
#         "DIGOXIN": [
#             "inhibitor"
#         ],
#         "ACETYLDIGITOXIN": [
#             "inhibitor"
#         ]
#     },
#     "SHBG": {
#         "SPIRONOLACTONE": [
#             "binder"
#         ],
#         "BUSULFAN": [],
#         "LISINOPRIL": [],
#         "NORGESTREL": [],
#         "DROLOXIFENE": []
#     },
#     "CD38": {
#         "DARATUMUMAB": [
#             "antibody",
#             "inhibitor"
#         ],
#         "ISATUXIMAB": [
#             "antibody"
#         ],
#         "SAR-650984": [],
#         "HuMax-CD38": [],
#         "THROMBIN": []
#     },
#     "P2RX4": {
#         "ESLICARBAZEPINE ACETATE": [
#             "antagonist"
#         ]
#     }
# }

# %% [markdown]
# Below is an example of searching with a list of drugs, rather than genes

# %%
drug_list = ["DESLANOSIDE", "SPIRONOLACTONE", "DARATUMUMAB"]

# %%
r3 = bf.dgidb_get_request(drug_list, genes=False, drugs=True)

# %%
gene_dict = bf.dgidb_json_parse(r3, drugs=True)

# %%
#Note: Key = Drug, Value = {Key = Gene, Value = [Interaction type(s)]}
print(json.dumps(gene_dict, indent=4))
# Out:
# {
#     "DESLANOSIDE": {
#         "ATP1A1": [
#             "inhibitor",
#             "binder"
#         ],
#         "ATP1B2": [
#             "inhibitor"
#         ],
#         "ATP1A3": [
#             "inhibitor"
#         ],
#         "ATP1A4": [
#             "inhibitor"
#         ],
#         "ATP1B3": [
#             "inhibitor"
#         ],
#         "ATP1A2": [
#             "inhibitor"
#         ],
#         "ATP1B1": [
#             "inhibitor"
#         ],
#         "FXYD2": [
#             "inhibitor"
#         ]
#     },
#     "SPIRONOLACTONE": {
#         "NR3C2": [
#             "antagonist"
#         ],
#         "AR": [
#             "antagonist"
#         ],
#         "PGR": [
#             "agonist"
#         ],
#         "NR3C1": [
#             "antagonist"
#         ],
#         "CYP11B2": [
#             "antagonist"
#         ],
#         "SHBG": [
#             "binder"
#         ],
#         "SSTR2": [
#             "agonist"
#         ],
#         "CACNG1": [],
#         "CYP7B1": [],
#         "ACE": [],
#         "CYP1A2": [],
#         "ADIPOQ": [],
#         "CTGF": [],
#         "ERBB3": [],
#         "CYP1B1": [],
#         "NR1I2": [],
#         "TNF": [],
#         "ABCB1": [],
#         "CYP1A1": []
#     },
#     "DARATUMUMAB": {
#         "CD38": [
#             "antibody",
#             "inhibitor"
#         ]
#     }
# }
