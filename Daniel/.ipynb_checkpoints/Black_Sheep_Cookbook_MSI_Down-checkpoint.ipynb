# %% [markdown]
# ## BlackSheep Cookbook MSI Down Regulation
#
# The Black Sheep Analysis allows researchers to find trends in abnormal protein enrichment among patients in CPTAC datasets. In this Cookbook, we will go through the steps needed to perform a full Black Sheep Analysis, to answer a research question, of if BMI, age, or country of origin play a role in protein enrichments for patients with Endometrial Cancer.

# %% [markdown]
# ### Step 1a: Import Dependencies
# First, import the necessary dependencies and install cptac through pip.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cptac
import binarization_functions as bf
import blackSheepCPTACmoduleCopy as blsh
# Out:
# Welcome to cptac, a python package for disseminating cancer
# proteogenomics data. To view available datasets, enter
# 'cptac.list_data()'. Extensive tutorials are available at
# https://github.com/PayneLab/cptac/tree/master/doc
#
# ******
# Version: 0.4.5
# ******

# %% [markdown]
# ## Step 1b: Load Data and Choose Omics Table

# %%
en = cptac.Endometrial()
proteomics = en.get_proteomics()
phospho = en.get_phosphoproteomics()
mRNA = en.get_transcriptomics()
clinical = en.get_clinical()
# Out:
# Checking that data files are up-to-date...
# 100% [..................................................................................] 649 / 649
# Data check complete.
# endometrial data version: 2.1
#
# Loading acetylproteomics data...
# Loading clinical data...
# Loading CNA data...
# Loading definitions data...
# Loading miRNA data...
# Loading phosphoproteomics_gene data...
# Loading phosphoproteomics_site data...
# Loading proteomics data...
# Loading somatic data...
# Loading somatic_binary data...
# Loading transcriptomics_circular data...
# Loading transcriptomics_linear data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but analysis may not be
# published until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter cptac.embargo() to open the webpage for more details.

# %%
#Append Genomics_subtype and MSI_status to en.get_clinical()
df= en.get_derived_molecular()
#clinical['Genomics_subtype'] = df['Genomics_subtype']
clinical['MSI_status'] = df['MSI_status']

# %% [markdown]
# ## Step 2: Determine what attributes you would like to A/B test.
# For this analysis, we will be testing MSI_status versus BMI in the proteomics dataset, and Histologic_type versus Age in the phosphoproteomics dataset.

# %%
#Create a subset copy of the original Clinical DataFrame for MSI.
annotations = pd.DataFrame(clinical['MSI_status'].copy())

# %% [markdown]
# ## Step 3: Perform outliers analysis

# %%
outliers_prot = blsh.make_outliers_table(proteomics, iqrs=1.5, 
                                         up_or_down='down', 
                                         aggregate=False, 
                                         frac_table=False)

outliers_mRNA = blsh.make_outliers_table(mRNA, iqrs=1.5, 
                                         up_or_down='down', 
                                         aggregate=False, 
                                         frac_table=False)
# Out:
# C:\Users\Daniel\AppData\Local\conda\conda\envs\Research\lib\site-packages\numpy\lib\nanfunctions.py:1354: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)

# %%
prot_just_outliers = outliers_prot[:144]

# %%
for col in prot_just_outliers:
    print(col)
    print(prot_just_outliers[col].value_counts())
    print('\n')
# Out:
# A1BG
# 0.0    144
# Name: A1BG, dtype: int64
#
#
# A2M
# 0.0    143
# 1.0      1
# Name: A2M, dtype: int64
#
#
# A2ML1
# 0.0    124
# 1.0      2
# Name: A2ML1, dtype: int64
#
#
# A4GALT
# 0.0    93
# 1.0     3
# Name: A4GALT, dtype: int64
#
#
# AAAS
# 0.0    139
# 1.0      5
# Name: AAAS, dtype: int64
#
#
# AACS
# 0.0    143
# 1.0      1
# Name: AACS, dtype: int64
#
#
# AADAT
# 0.0    132
# 1.0      4
# Name: AADAT, dtype: int64
#
#
# AAED1
# 0.0    131
# 1.0      4
# Name: AAED1, dtype: int64
#
#
# AAGAB
# 0.0    141
# 1.0      3
# Name: AAGAB, dtype: int64
#
#
# AAK1
# 0.0    143
# 1.0      1
# Name: AAK1, dtype: int64
#
#
# AAMDC
# 0.0    142
# 1.0      2
# Name: AAMDC, dtype: int64
#
#
# AAMP
# 0.0    134
# 1.0     10
# Name: AAMP, dtype: int64
#
#
# AAR2
# 0.0    142
# 1.0      2
# Name: AAR2, dtype: int64
#
#
# AARS
# 0.0    142
# 1.0      2
# Name: AARS, dtype: int64
#
#
# AARS2
# 0.0    137
# 1.0      7
# Name: AARS2, dtype: int64
#
#
# AARSD1
# 0.0    135
# 1.0      9
# Name: AARSD1, dtype: int64
#
#
# AASDHPPT
# 0.0    141
# 1.0      3
# Name: AASDHPPT, dtype: int64
#
#
# AASS
# 0.0    144
# Name: AASS, dtype: int64
#
#
# AATF
# 0.0    140
# 1.0      4
# Name: AATF, dtype: int64
#
#
# ABAT
# 0.0    141
# 1.0      3
# Name: ABAT, dtype: int64
#
#
# ABCA8
# 0.0    135
# Name: ABCA8, dtype: int64
#
#
# ABCB1
# 0.0    143
# 1.0      1
# Name: ABCB1, dtype: int64
#
#
# ABCB10
# 0.0    137
# 1.0      7
# Name: ABCB10, dtype: int64
#
#
# ABCB6
# 0.0    134
# 1.0     10
# Name: ABCB6, dtype: int64
#
#
# ABCB7
# 0.0    141
# 1.0      3
# Name: ABCB7, dtype: int64
#
#
# ABCB8
# 0.0    140
# 1.0      4
# Name: ABCB8, dtype: int64
#
#
# ABCC1
# 0.0    142
# 1.0      2
# Name: ABCC1, dtype: int64
#
#
# ABCC10
# 0.0    129
# 1.0      6
# Name: ABCC10, dtype: int64
#
#
# ABCC3
# 0.0    141
# 1.0      3
# Name: ABCC3, dtype: int64
#
#
# ABCC4
# 0.0    142
# 1.0      2
# Name: ABCC4, dtype: int64
#
#
# ABCD1
# 0.0    138
# 1.0      6
# Name: ABCD1, dtype: int64
#
#
# ABCD3
# 0.0    143
# 1.0      1
# Name: ABCD3, dtype: int64
#
#
# ABCD4
# 0.0    138
# 1.0      6
# Name: ABCD4, dtype: int64
#
#
# ABCE1
# 0.0    141
# 1.0      3
# Name: ABCE1, dtype: int64
#
#
# ABCF1
# 0.0    142
# 1.0      2
# Name: ABCF1, dtype: int64
#
#
# ABCF2
# 0.0    142
# 1.0      2
# Name: ABCF2, dtype: int64
#
#
# ABCF3
# 0.0    143
# 1.0      1
# Name: ABCF3, dtype: int64
#
#
# ABCG1
# 0.0    142
# 1.0      2
# Name: ABCG1, dtype: int64
#
#
# ABHD10
# 0.0    143
# 1.0      1
# Name: ABHD10, dtype: int64
#
#
# ABHD11
# 0.0    143
# 1.0      1
# Name: ABHD11, dtype: int64
#
#
# ABHD12
# 0.0    139
# 1.0      5
# Name: ABHD12, dtype: int64
#
#
# ABHD13
# 0.0    129
# 1.0      6
# Name: ABHD13, dtype: int64
#
#
# ABHD14A
# 0.0    52
# 1.0     5
# Name: ABHD14A, dtype: int64
#
#
# ABHD14A-ACY1
# 0.0    143
# 1.0      1
# Name: ABHD14A-ACY1, dtype: int64
#
#
# ABHD14B
# 0.0    142
# 1.0      2
# Name: ABHD14B, dtype: int64
#
#
# ABHD16A
# 0.0    141
# 1.0      3
# Name: ABHD16A, dtype: int64
#
#
# ABHD17A
# 0.0    71
# 1.0     4
# Name: ABHD17A, dtype: int64
#
#
# ABHD17B
# 0.0    130
# 1.0      7
# Name: ABHD17B, dtype: int64
#
#
# ABHD17C
# 0.0    78
# Name: ABHD17C, dtype: int64
#
#
# ABHD2
# 0.0    49
# 1.0     3
# Name: ABHD2, dtype: int64
#
#
# ABHD3
# 0.0    115
# 1.0      3
# Name: ABHD3, dtype: int64
#
#
# ABHD4
# 0.0    143
# 1.0      1
# Name: ABHD4, dtype: int64
#
#
# ABHD5
# 0.0    134
# 1.0      2
# Name: ABHD5, dtype: int64
#
#
# ABHD6
# 0.0    140
# 1.0      4
# Name: ABHD6, dtype: int64
#
#
# ABI1
# 0.0    138
# 1.0      6
# Name: ABI1, dtype: int64
#
#
# ABI2
# 0.0    143
# 1.0      1
# Name: ABI2, dtype: int64
#
#
# ABI3
# 0.0    138
# 1.0      6
# Name: ABI3, dtype: int64
#
#
# ABI3BP
# 0.0    144
# Name: ABI3BP, dtype: int64
#
#
# ABL1
# 0.0    144
# Name: ABL1, dtype: int64
#
#
# ABL2
# 0.0    141
# 1.0      3
# Name: ABL2, dtype: int64
#
#
# ABLIM1
# 0.0    144
# Name: ABLIM1, dtype: int64
#
#
# ABLIM2
# 0.0    132
# 1.0      3
# Name: ABLIM2, dtype: int64
#
#
# ABLIM3
# 0.0    67
# Name: ABLIM3, dtype: int64
#
#
# ABO
# 0.0    13
# 1.0     2
# Name: ABO, dtype: int64
#
#
# ABR
# 0.0    139
# 1.0      5
# Name: ABR, dtype: int64
#
#
# ABRACL
# 0.0    140
# 1.0      4
# Name: ABRACL, dtype: int64
#
#
# ABRAXAS1
# 0.0    141
# 1.0      3
# Name: ABRAXAS1, dtype: int64
#
#
# ABRAXAS2
# 0.0    140
# 1.0      4
# Name: ABRAXAS2, dtype: int64
#
#
# ABT1
# 0.0    143
# 1.0      1
# Name: ABT1, dtype: int64
#
#
# ABTB2
# 0.0    132
# 1.0      3
# Name: ABTB2, dtype: int64
#
#
# ACAA1
# 0.0    140
# 1.0      4
# Name: ACAA1, dtype: int64
#
#
# ACAA2
# 0.0    136
# 1.0      8
# Name: ACAA2, dtype: int64
#
#
# ACACA
# 0.0    144
# Name: ACACA, dtype: int64
#
#
# ACACB
# 0.0    35
# Name: ACACB, dtype: int64
#
#
# ACAD10
# 0.0    144
# Name: ACAD10, dtype: int64
#
#
# ACAD11
# 0.0    143
# 1.0      1
# Name: ACAD11, dtype: int64
#
#
# ACAD8
# 0.0    137
# 1.0      7
# Name: ACAD8, dtype: int64
#
#
# ACAD9
# 0.0    141
# 1.0      3
# Name: ACAD9, dtype: int64
#
#
# ACADL
# 0.0    76
# 1.0     3
# Name: ACADL, dtype: int64
#
#
# ACADM
# 0.0    144
# Name: ACADM, dtype: int64
#
#
# ACADS
# 0.0    142
# 1.0      2
# Name: ACADS, dtype: int64
#
#
# ACADSB
# 0.0    142
# 1.0      2
# Name: ACADSB, dtype: int64
#
#
# ACADVL
# 0.0    140
# 1.0      4
# Name: ACADVL, dtype: int64
#
#
# ACAP1
# 0.0    141
# 1.0      3
# Name: ACAP1, dtype: int64
#
#
# ACAP2
# 0.0    142
# 1.0      2
# Name: ACAP2, dtype: int64
#
#
# ACAP3
# 0.0    74
# 1.0     3
# Name: ACAP3, dtype: int64
#
#
# ACAT1
# 0.0    142
# 1.0      2
# Name: ACAT1, dtype: int64
#
#
# ACAT2
# 0.0    142
# 1.0      2
# Name: ACAT2, dtype: int64
#
#
# ACBD3
# 0.0    144
# Name: ACBD3, dtype: int64
#
#
# ACBD5
# 0.0    144
# Name: ACBD5, dtype: int64
#
#
# ACBD6
# 0.0    144
# Name: ACBD6, dtype: int64
#
#
# ACBD7
# 0.0    144
# Name: ACBD7, dtype: int64
#
#
# ACD
# 0.0    139
# 1.0      5
# Name: ACD, dtype: int64
#
#
# ACE
# 0.0    143
# 1.0      1
# Name: ACE, dtype: int64
#
#
# ACIN1
# 0.0    141
# 1.0      3
# Name: ACIN1, dtype: int64
#
#
# ACLY
# 0.0    144
# Name: ACLY, dtype: int64
#
#
# ACO1
# 0.0    141
# 1.0      3
# Name: ACO1, dtype: int64
#
#
# ACO2
# 0.0    142
# 1.0      2
# Name: ACO2, dtype: int64
#
#
# ACOT1
# 0.0    133
# 1.0      2
# Name: ACOT1, dtype: int64
#
#
# ACOT11
# 0.0    140
# 1.0      4
# Name: ACOT11, dtype: int64
#
#
# ACOT13
# 0.0    142
# 1.0      2
# Name: ACOT13, dtype: int64
#
#
# ACOT2
# 0.0    24
# 1.0     2
# Name: ACOT2, dtype: int64
#
#
# ACOT4
# 0.0    85
# 1.0     5
# Name: ACOT4, dtype: int64
#
#
# ACOT7
# 0.0    143
# 1.0      1
# Name: ACOT7, dtype: int64
#
#
# ACOT8
# 0.0    144
# Name: ACOT8, dtype: int64
#
#
# ACOT9
# 0.0    144
# Name: ACOT9, dtype: int64
#
#
# ACOX1
# 0.0    143
# 1.0      1
# Name: ACOX1, dtype: int64
#
#
# ACOX2
# 0.0    129
# 1.0      7
# Name: ACOX2, dtype: int64
#
#
# ACOX3
# 0.0    144
# Name: ACOX3, dtype: int64
#
#
# ACP1
# 0.0    144
# Name: ACP1, dtype: int64
#
#
# ACP2
# 0.0    138
# 1.0      6
# Name: ACP2, dtype: int64
#
#
# ACP5
# 0.0    135
# 1.0      9
# Name: ACP5, dtype: int64
#
#
# ACP6
# 0.0    131
# 1.0     13
# Name: ACP6, dtype: int64
#
#
# ACPP
# 0.0    134
# 1.0      3
# Name: ACPP, dtype: int64
#
#
# ACSF2
# 0.0    144
# Name: ACSF2, dtype: int64
#
#
# ACSF3
# 0.0    142
# 1.0      2
# Name: ACSF3, dtype: int64
#
#
# ACSL1
# 0.0    129
# 1.0     15
# Name: ACSL1, dtype: int64
#
#
# ACSL3
# 0.0    142
# 1.0      2
# Name: ACSL3, dtype: int64
#
#
# ACSL4
# 0.0    143
# 1.0      1
# Name: ACSL4, dtype: int64
#
#
# ACSL5
# 0.0    144
# Name: ACSL5, dtype: int64
#
#
# ACSM3
# 0.0    144
# Name: ACSM3, dtype: int64
#
#
# ACSS1
# 0.0    136
# 1.0      8
# Name: ACSS1, dtype: int64
#
#
# ACSS2
# 0.0    140
# 1.0      4
# Name: ACSS2, dtype: int64
#
#
# ACSS3
# 0.0    144
# Name: ACSS3, dtype: int64
#
#
# ACTA1
# 0.0    129
# 1.0      2
# Name: ACTA1, dtype: int64
#
#
# ACTA2
# 0.0    141
# 1.0      3
# Name: ACTA2, dtype: int64
#
#
# ACTB
# 0.0    144
# Name: ACTB, dtype: int64
#
#
# ACTBL2
# 0.0    144
# Name: ACTBL2, dtype: int64
#
#
# ACTG1
# 0.0    143
# 1.0      1
# Name: ACTG1, dtype: int64
#
#
# ACTG2
# 0.0    137
# 1.0      7
# Name: ACTG2, dtype: int64
#
#
# ACTL6A
# 0.0    142
# 1.0      2
# Name: ACTL6A, dtype: int64
#
#
# ACTL6B
# 0.0    9
# Name: ACTL6B, dtype: int64
#
#
# ACTL8
# 0.0    40
# 1.0     1
# Name: ACTL8, dtype: int64
#
#
# ACTN1
# 0.0    144
# Name: ACTN1, dtype: int64
#
#
# ACTN2
# 0.0    144
# Name: ACTN2, dtype: int64
#
#
# ACTN3
# 0.0    35
# Name: ACTN3, dtype: int64
#
#
# ACTN4
# 0.0    144
# Name: ACTN4, dtype: int64
#
#
# ACTR10
# 0.0    138
# 1.0      6
# Name: ACTR10, dtype: int64
#
#
# ACTR1A
# 0.0    142
# 1.0      2
# Name: ACTR1A, dtype: int64
#
#
# ACTR1B
# 0.0    141
# 1.0      3
# Name: ACTR1B, dtype: int64
#
#
# ACTR2
# 0.0    143
# 1.0      1
# Name: ACTR2, dtype: int64
#
#
# ACTR3
# 0.0    134
# 1.0     10
# Name: ACTR3, dtype: int64
#
#
# ACTR3B
# 0.0    144
# Name: ACTR3B, dtype: int64
#
#
# ACTR5
# 0.0    142
# 1.0      2
# Name: ACTR5, dtype: int64
#
#
# ACTR6
# 0.0    140
# 1.0      4
# Name: ACTR6, dtype: int64
#
#
# ACTR8
# 0.0    138
# 1.0      6
# Name: ACTR8, dtype: int64
#
#
# ACTRT2
# 0.0    18
# Name: ACTRT2, dtype: int64
#
#
# ACVR1
# 0.0    130
# 1.0      6
# Name: ACVR1, dtype: int64
#
#
# ACY3
# 0.0    120
# 1.0      6
# Name: ACY3, dtype: int64
#
#
# ACYP1
# 0.0    140
# 1.0      4
# Name: ACYP1, dtype: int64
#
#
# ACYP2
# 0.0    130
# 1.0     14
# Name: ACYP2, dtype: int64
#
#
# ADA
# 0.0    142
# 1.0      2
# Name: ADA, dtype: int64
#
#
# ADA2
# 0.0    140
# 1.0      4
# Name: ADA2, dtype: int64
#
#
# ADAL
# 0.0    120
# 1.0      9
# Name: ADAL, dtype: int64
#
#
# ADAM10
# 0.0    143
# 1.0      1
# Name: ADAM10, dtype: int64
#
#
# ADAM15
# 0.0    140
# 1.0      4
# Name: ADAM15, dtype: int64
#
#
# ADAM17
# 0.0    142
# 1.0      2
# Name: ADAM17, dtype: int64
#
#
# ADAM28
# 0.0    144
# Name: ADAM28, dtype: int64
#
#
# ADAM9
# 0.0    144
# Name: ADAM9, dtype: int64
#
#
# ADAMDEC1
# 0.0    83
# 1.0     1
# Name: ADAMDEC1, dtype: int64
#
#
# ADAMTS1
# 0.0    143
# 1.0      1
# Name: ADAMTS1, dtype: int64
#
#
# ADAMTS15
# 0.0    49
# 1.0     1
# Name: ADAMTS15, dtype: int64
#
#
# ADAMTS2
# 0.0    131
# 1.0      4
# Name: ADAMTS2, dtype: int64
#
#
# ADAMTS5
# 0.0    109
# Name: ADAMTS5, dtype: int64
#
#
# ADAMTS8
# 0.0    39
# 1.0     2
# Name: ADAMTS8, dtype: int64
#
#
# ADAMTS9
# 0.0    68
# 1.0     2
# Name: ADAMTS9, dtype: int64
#
#
# ADAMTSL1
# 0.0    132
# 1.0      3
# Name: ADAMTSL1, dtype: int64
#
#
# ADAMTSL2
# 0.0    132
# 1.0      3
# Name: ADAMTSL2, dtype: int64
#
#
# ADAMTSL3
# 0.0    117
# Name: ADAMTSL3, dtype: int64
#
#
# ADAMTSL4
# 0.0    144
# Name: ADAMTSL4, dtype: int64
#
#
# ADAMTSL5
# 0.0    144
# Name: ADAMTSL5, dtype: int64
#
#
# ADAP1
# 0.0    138
# 1.0      6
# Name: ADAP1, dtype: int64
#
#
# ADAP2
# 0.0    71
# 1.0     7
# Name: ADAP2, dtype: int64
#
#
# ADAR
# 0.0    141
# 1.0      3
# Name: ADAR, dtype: int64
#
#
# ADARB1
# 0.0    144
# Name: ADARB1, dtype: int64
#
#
# ADAT1
# 0.0    131
# 1.0      4
# Name: ADAT1, dtype: int64
#
#
# ADAT2
# 0.0    141
# 1.0      3
# Name: ADAT2, dtype: int64
#
#
# ADAT3
# 0.0    142
# 1.0      2
# Name: ADAT3, dtype: int64
#
#
# ADCK1
# 0.0    143
# 1.0      1
# Name: ADCK1, dtype: int64
#
#
# ADCK5
# 0.0    57
# 1.0     4
# Name: ADCK5, dtype: int64
#
#
# ADCY3
# 0.0    64
# 1.0     3
# Name: ADCY3, dtype: int64
#
#
# ADCY5
# 0.0    37
# 1.0     4
# Name: ADCY5, dtype: int64
#
#
# ADCY6
# 0.0    125
# 1.0      1
# Name: ADCY6, dtype: int64
#
#
# ADD1
# 0.0    138
# 1.0      6
# Name: ADD1, dtype: int64
#
#
# ADD2
# 0.0    144
# Name: ADD2, dtype: int64
#
#
# ADD3
# 0.0    134
# 1.0     10
# Name: ADD3, dtype: int64
#
#
# ADGRA3
# 0.0    119
# 1.0      7
# Name: ADGRA3, dtype: int64
#
#
# ADGRE2
# 0.0    108
# 1.0      5
# Name: ADGRE2, dtype: int64
#
#
# ADGRE5
# 0.0    144
# Name: ADGRE5, dtype: int64
#
#
# ADGRF5
# 0.0    123
# 1.0      3
# Name: ADGRF5, dtype: int64
#
#
# ADGRG1
# 0.0    142
# 1.0      2
# Name: ADGRG1, dtype: int64
#
#
# ADGRG2
# 0.0    108
# 1.0      1
# Name: ADGRG2, dtype: int64
#
#
# ADGRG3
# 0.0    47
# 1.0     1
# Name: ADGRG3, dtype: int64
#
#
# ADGRL1
# 0.0    106
# 1.0      4
# Name: ADGRL1, dtype: int64
#
#
# ADGRL2
# 0.0    131
# 1.0     13
# Name: ADGRL2, dtype: int64
#
#
# ADGRL3
# 0.0    87
# 1.0     3
# Name: ADGRL3, dtype: int64
#
#
# ADGRL4
# 0.0    99
# Name: ADGRL4, dtype: int64
#
#
# ADH1A
# 0.0    101
# 1.0      2
# Name: ADH1A, dtype: int64
#
#
# ADH1B
# 0.0    141
# 1.0      3
# Name: ADH1B, dtype: int64
#
#
# ADH1C
# 0.0    141
# 1.0      3
# Name: ADH1C, dtype: int64
#
#
# ADH4
# 0.0    123
# 1.0      3
# Name: ADH4, dtype: int64
#
#
# ADH5
# 0.0    141
# 1.0      3
# Name: ADH5, dtype: int64
#
#
# ADH6
# 0.0    63
# 1.0     3
# Name: ADH6, dtype: int64
#
#
# ADH7
# 0.0    39
# 1.0     1
# Name: ADH7, dtype: int64
#
#
# ADHFE1
# 0.0    17
# 1.0     1
# Name: ADHFE1, dtype: int64
#
#
# ADI1
# 0.0    143
# 1.0      1
# Name: ADI1, dtype: int64
#
#
# ADIPOQ
# 0.0    143
# 1.0      1
# Name: ADIPOQ, dtype: int64
#
#
# ADIPOR1
# 0.0    25
# 1.0     1
# Name: ADIPOR1, dtype: int64
#
#
# ADIRF
# 0.0    143
# 1.0      1
# Name: ADIRF, dtype: int64
#
#
# ADK
# 0.0    139
# 1.0      5
# Name: ADK, dtype: int64
#
#
# ADM
# 0.0    67
# 1.0     1
# Name: ADM, dtype: int64
#
#
# ADNP
# 0.0    139
# 1.0      5
# Name: ADNP, dtype: int64
#
#
# ADO
# 0.0    144
# Name: ADO, dtype: int64
#
#
# ADPGK
# 0.0    144
# Name: ADPGK, dtype: int64
#
#
# ADPRH
# 0.0    138
# 1.0      6
# Name: ADPRH, dtype: int64
#
#
# ADPRHL2
# 0.0    143
# 1.0      1
# Name: ADPRHL2, dtype: int64
#
#
# ADPRM
# 0.0    34
# 1.0     2
# Name: ADPRM, dtype: int64
#
#
# ADRA2A
# 0.0    41
# 1.0     1
# Name: ADRA2A, dtype: int64
#
#
# ADRM1
# 0.0    142
# 1.0      2
# Name: ADRM1, dtype: int64
#
#
# ADSL
# 0.0    133
# 1.0     11
# Name: ADSL, dtype: int64
#
#
# ADSS
# 0.0    143
# 1.0      1
# Name: ADSS, dtype: int64
#
#
# ADSSL1
# 0.0    138
# 1.0      6
# Name: ADSSL1, dtype: int64
#
#
# AEBP1
# 0.0    144
# Name: AEBP1, dtype: int64
#
#
# AEBP2
# 0.0    43
# Name: AEBP2, dtype: int64
#
#
# AES
# 0.0    138
# 1.0      6
# Name: AES, dtype: int64
#
#
# AFAP1
# 0.0    144
# Name: AFAP1, dtype: int64
#
#
# AFAP1L1
# 0.0    80
# 1.0     2
# Name: AFAP1L1, dtype: int64
#
#
# AFAP1L2
# 0.0    144
# Name: AFAP1L2, dtype: int64
#
#
# AFDN
# 0.0    144
# Name: AFDN, dtype: int64
#
#
# AFF1
# 0.0    137
# 1.0      7
# Name: AFF1, dtype: int64
#
#
# AFF4
# 0.0    138
# 1.0      6
# Name: AFF4, dtype: int64
#
#
# AFG1L
# 0.0    124
# 1.0     11
# Name: AFG1L, dtype: int64
#
#
# AFG3L2
# 0.0    140
# 1.0      4
# Name: AFG3L2, dtype: int64
#
#
# AFM
# 0.0    144
# Name: AFM, dtype: int64
#
#
# AFMID
# 0.0    138
# 1.0      6
# Name: AFMID, dtype: int64
#
#
# AFTPH
# 0.0    138
# 1.0      6
# Name: AFTPH, dtype: int64
#
#
# AGA
# 0.0    143
# 1.0      1
# Name: AGA, dtype: int64
#
#
# AGAP1
# 0.0    136
# 1.0      8
# Name: AGAP1, dtype: int64
#
#
# AGAP2
# 0.0    115
# 1.0      2
# Name: AGAP2, dtype: int64
#
#
# AGAP3
# 0.0    142
# 1.0      2
# Name: AGAP3, dtype: int64
#
#
# AGFG1
# 0.0    137
# 1.0      7
# Name: AGFG1, dtype: int64
#
#
# AGFG2
# 0.0    143
# 1.0      1
# Name: AGFG2, dtype: int64
#
#
# AGGF1
# 0.0    140
# 1.0      4
# Name: AGGF1, dtype: int64
#
#
# AGK
# 0.0    141
# 1.0      3
# Name: AGK, dtype: int64
#
#
# AGL
# 0.0    136
# 1.0      8
# Name: AGL, dtype: int64
#
#
# AGMAT
# 0.0    144
# Name: AGMAT, dtype: int64
#
#
# AGO1
# 0.0    144
# Name: AGO1, dtype: int64
#
#
# AGO2
# 0.0    144
# Name: AGO2, dtype: int64
#
#
# AGO3
# 0.0    143
# 1.0      1
# Name: AGO3, dtype: int64
#
#
# AGO4
# 0.0    133
# 1.0      2
# Name: AGO4, dtype: int64
#
#
# AGPAT1
# 0.0    131
# 1.0     13
# Name: AGPAT1, dtype: int64
#
#
# AGPAT2
# 0.0    141
# 1.0      3
# Name: AGPAT2, dtype: int64
#
#
# AGPAT3
# 0.0    138
# 1.0      6
# Name: AGPAT3, dtype: int64
#
#
# AGPAT4
# 0.0    120
# 1.0      6
# Name: AGPAT4, dtype: int64
#
#
# AGPAT5
# 0.0    140
# 1.0      4
# Name: AGPAT5, dtype: int64
#
#
# AGPS
# 0.0    144
# Name: AGPS, dtype: int64
#
#
# AGR2
# 0.0    142
# 1.0      2
# Name: AGR2, dtype: int64
#
#
# AGR3
# 0.0    142
# 1.0      2
# Name: AGR3, dtype: int64
#
#
# AGRN
# 0.0    142
# 1.0      2
# Name: AGRN, dtype: int64
#
#
# AGT
# 0.0    144
# Name: AGT, dtype: int64
#
#
# AGTPBP1
# 0.0    140
# 1.0      4
# Name: AGTPBP1, dtype: int64
#
#
# AGTRAP
# 0.0    137
# 1.0      7
# Name: AGTRAP, dtype: int64
#
#
# AHCTF1
# 0.0    138
# 1.0      6
# Name: AHCTF1, dtype: int64
#
#
# AHCY
# 0.0    143
# 1.0      1
# Name: AHCY, dtype: int64
#
#
# AHCYL1
# 0.0    135
# 1.0      9
# Name: AHCYL1, dtype: int64
#
#
# AHCYL2
# 0.0    143
# 1.0      1
# Name: AHCYL2, dtype: int64
#
#
# AHDC1
# 0.0    143
# 1.0      1
# Name: AHDC1, dtype: int64
#
#
# AHNAK
# 0.0    144
# Name: AHNAK, dtype: int64
#
#
# AHNAK2
# 0.0    144
# Name: AHNAK2, dtype: int64
#
#
# AHR
# 0.0    142
# 1.0      2
# Name: AHR, dtype: int64
#
#
# AHSA1
# 0.0    140
# 1.0      4
# Name: AHSA1, dtype: int64
#
#
# AHSG
# 0.0    143
# 1.0      1
# Name: AHSG, dtype: int64
#
#
# AHSP
# 0.0    143
# 1.0      1
# Name: AHSP, dtype: int64
#
#
# AIDA
# 0.0    143
# 1.0      1
# Name: AIDA, dtype: int64
#
#
# AIF1
# 0.0    142
# 1.0      2
# Name: AIF1, dtype: int64
#
#
# AIF1L
# 0.0    140
# 1.0      4
# Name: AIF1L, dtype: int64
#
#
# AIFM1
# 0.0    143
# 1.0      1
# Name: AIFM1, dtype: int64
#
#
# AIFM2
# 0.0    144
# Name: AIFM2, dtype: int64
#
#
# AIG1
# 0.0    99
# 1.0     6
# Name: AIG1, dtype: int64
#
#
# AIMP1
# 0.0    144
# Name: AIMP1, dtype: int64
#
#
# AIMP2
# 0.0    139
# 1.0      5
# Name: AIMP2, dtype: int64
#
#
# AIP
# 0.0    143
# 1.0      1
# Name: AIP, dtype: int64
#
#
# AJUBA
# 0.0    136
# 1.0      8
# Name: AJUBA, dtype: int64
#
#
# AK1
# 0.0    141
# 1.0      3
# Name: AK1, dtype: int64
#
#
# AK2
# 0.0    141
# 1.0      3
# Name: AK2, dtype: int64
#
#
# AK3
# 0.0    141
# 1.0      3
# Name: AK3, dtype: int64
#
#
# AK4
# 0.0    142
# 1.0      2
# Name: AK4, dtype: int64
#
#
# AK6
# 0.0    143
# 1.0      1
# Name: AK6, dtype: int64
#
#
# AK7
# 0.0    99
# 1.0     1
# Name: AK7, dtype: int64
#
#
# AK8
# 0.0    18
# Name: AK8, dtype: int64
#
#
# AKAP1
# 0.0    144
# Name: AKAP1, dtype: int64
#
#
# AKAP10
# 0.0    138
# 1.0      6
# Name: AKAP10, dtype: int64
#
#
# AKAP11
# 0.0    144
# Name: AKAP11, dtype: int64
#
#
# AKAP12
# 0.0    144
# Name: AKAP12, dtype: int64
#
#
# AKAP13
# 0.0    137
# 1.0      7
# Name: AKAP13, dtype: int64
#
#
# AKAP17A
# 0.0    134
# 1.0     10
# Name: AKAP17A, dtype: int64
#
#
# AKAP5
# 0.0    98
# 1.0     4
# Name: AKAP5, dtype: int64
#
#
# AKAP7
# 0.0    143
# 1.0      1
# Name: AKAP7, dtype: int64
#
#
# AKAP8
# 0.0    141
# 1.0      3
# Name: AKAP8, dtype: int64
#
#
# AKAP8L
# 0.0    140
# 1.0      4
# Name: AKAP8L, dtype: int64
#
#
# AKAP9
# 0.0    142
# 1.0      2
# Name: AKAP9, dtype: int64
#
#
# AKIP1
# 0.0    23
# Name: AKIP1, dtype: int64
#
#
# AKIRIN2
# 0.0    26
# Name: AKIRIN2, dtype: int64
#
#
# AKNA
# 0.0    144
# Name: AKNA, dtype: int64
#
#
# AKR1A1
# 0.0    137
# 1.0      7
# Name: AKR1A1, dtype: int64
#
#
# AKR1B1
# 0.0    142
# 1.0      2
# Name: AKR1B1, dtype: int64
#
#
# AKR1B10
# 0.0    143
# 1.0      1
# Name: AKR1B10, dtype: int64
#
#
# AKR1B15
# 0.0    26
# Name: AKR1B15, dtype: int64
#
#
# AKR1C1
# 0.0    132
# 1.0      3
# Name: AKR1C1, dtype: int64
#
#
# AKR1C2
# 0.0    143
# Name: AKR1C2, dtype: int64
#
#
# AKR1C3
# 0.0    132
# 1.0     12
# Name: AKR1C3, dtype: int64
#
#
# AKR1C4
# 0.0    40
# 1.0     2
# Name: AKR1C4, dtype: int64
#
#
# AKR1D1
# 0.0    135
# 1.0      9
# Name: AKR1D1, dtype: int64
#
#
# AKR7A2
# 0.0    142
# 1.0      2
# Name: AKR7A2, dtype: int64
#
#
# AKR7A3
# 0.0    125
# 1.0      2
# Name: AKR7A3, dtype: int64
#
#
# AKT1
# 0.0    136
# 1.0      8
# Name: AKT1, dtype: int64
#
#
# AKT1S1
# 0.0    139
# 1.0      5
# Name: AKT1S1, dtype: int64
#
#
# AKT2
# 0.0    143
# 1.0      1
# Name: AKT2, dtype: int64
#
#
# AKT3
# 0.0    144
# Name: AKT3, dtype: int64
#
#
# AKTIP
# 0.0    141
# 1.0      3
# Name: AKTIP, dtype: int64
#
#
# ALAD
# 0.0    142
# 1.0      2
# Name: ALAD, dtype: int64
#
#
# ALAS1
# 0.0    98
# 1.0     5
# Name: ALAS1, dtype: int64
#
#
# ALB
# 0.0    144
# Name: ALB, dtype: int64
#
#
# ALCAM
# 0.0    143
# 1.0      1
# Name: ALCAM, dtype: int64
#
#
# ALDH16A1
# 0.0    139
# 1.0      5
# Name: ALDH16A1, dtype: int64
#
#
# ALDH18A1
# 0.0    144
# Name: ALDH18A1, dtype: int64
#
#
# ALDH1A1
# 0.0    144
# Name: ALDH1A1, dtype: int64
#
#
# ALDH1A2
# 0.0    144
# Name: ALDH1A2, dtype: int64
#
#
# ALDH1A3
# 0.0    138
# 1.0      6
# Name: ALDH1A3, dtype: int64
#
#
# ALDH1B1
# 0.0    144
# Name: ALDH1B1, dtype: int64
#
#
# ALDH1L1
# 0.0    144
# Name: ALDH1L1, dtype: int64
#
#
# ALDH1L2
# 0.0    144
# Name: ALDH1L2, dtype: int64
#
#
# ALDH2
# 0.0    140
# 1.0      4
# Name: ALDH2, dtype: int64
#
#
# ALDH3A1
# 0.0    141
# 1.0      3
# Name: ALDH3A1, dtype: int64
#
#
# ALDH3A2
# 0.0    142
# 1.0      2
# Name: ALDH3A2, dtype: int64
#
#
# ALDH3B1
# 0.0    143
# 1.0      1
# Name: ALDH3B1, dtype: int64
#
#
# ALDH4A1
# 0.0    138
# 1.0      6
# Name: ALDH4A1, dtype: int64
#
#
# ALDH5A1
# 0.0    141
# 1.0      3
# Name: ALDH5A1, dtype: int64
#
#
# ALDH6A1
# 0.0    142
# 1.0      2
# Name: ALDH6A1, dtype: int64
#
#
# ALDH7A1
# 0.0    138
# 1.0      6
# Name: ALDH7A1, dtype: int64
#
#
# ALDH9A1
# 0.0    144
# Name: ALDH9A1, dtype: int64
#
#
# ALDOA
# 0.0    138
# 1.0      6
# Name: ALDOA, dtype: int64
#
#
# ALDOB
# 0.0    132
# 1.0      6
# Name: ALDOB, dtype: int64
#
#
# ALDOC
# 0.0    144
# Name: ALDOC, dtype: int64
#
#
# ALG1
# 0.0    138
# 1.0      6
# Name: ALG1, dtype: int64
#
#
# ALG10
# 0.0    93
# 1.0     7
# Name: ALG10, dtype: int64
#
#
# ALG11
# 0.0    129
# 1.0     15
# Name: ALG11, dtype: int64
#
#
# ALG12
# 0.0    123
# 1.0     12
# Name: ALG12, dtype: int64
#
#
# ALG13
# 0.0    144
# Name: ALG13, dtype: int64
#
#
# ALG14
# 0.0    138
# 1.0      6
# Name: ALG14, dtype: int64
#
#
# ALG2
# 0.0    138
# 1.0      6
# Name: ALG2, dtype: int64
#
#
# ALG5
# 0.0    141
# 1.0      3
# Name: ALG5, dtype: int64
#
#
# ALG6
# 0.0    137
# 1.0      7
# Name: ALG6, dtype: int64
#
#
# ALG8
# 0.0    131
# 1.0      4
# Name: ALG8, dtype: int64
#
#
# ALG9
# 0.0    136
# 1.0      8
# Name: ALG9, dtype: int64
#
#
# ALKBH1
# 0.0    133
# 1.0      3
# Name: ALKBH1, dtype: int64
#
#
# ALKBH2
# 0.0    125
# 1.0     10
# Name: ALKBH2, dtype: int64
#
#
# ALKBH3
# 0.0    74
# 1.0     3
# Name: ALKBH3, dtype: int64
#
#
# ALKBH4
# 0.0    143
# 1.0      1
# Name: ALKBH4, dtype: int64
#
#
# ALKBH5
# 0.0    137
# 1.0      7
# Name: ALKBH5, dtype: int64
#
#
# ALKBH6
# 0.0    57
# 1.0     3
# Name: ALKBH6, dtype: int64
#
#
# ALKBH7
# 0.0    134
# 1.0      3
# Name: ALKBH7, dtype: int64
#
#
# ALKBH8
# 0.0    142
# 1.0      2
# Name: ALKBH8, dtype: int64
#
#
# ALMS1
# 0.0    141
# 1.0      3
# Name: ALMS1, dtype: int64
#
#
# ALOX15
# 0.0    134
# 1.0      1
# Name: ALOX15, dtype: int64
#
#
# ALOX15B
# 0.0    42
# 1.0     2
# Name: ALOX15B, dtype: int64
#
#
# ALOX5
# 0.0    139
# 1.0      5
# Name: ALOX5, dtype: int64
#
#
# ALOX5AP
# 0.0    141
# 1.0      3
# Name: ALOX5AP, dtype: int64
#
#
# ALPG
# 0.0    129
# 1.0      9
# Name: ALPG, dtype: int64
#
#
# ALPK1
# 0.0    78
# 1.0     7
# Name: ALPK1, dtype: int64
#
#
# ALPL
# 0.0    142
# 1.0      2
# Name: ALPL, dtype: int64
#
#
# ALPP
# 0.0    126
# 1.0     18
# Name: ALPP, dtype: int64
#
#
# ALS2
# 0.0    138
# 1.0      6
# Name: ALS2, dtype: int64
#
#
# ALYREF
# 0.0    137
# 1.0      7
# Name: ALYREF, dtype: int64
#
#
# AMACR
# 0.0    143
# 1.0      1
# Name: AMACR, dtype: int64
#
#
# AMBP
# 0.0    144
# Name: AMBP, dtype: int64
#
#
# AMBRA1
# 0.0    136
# 1.0      8
# Name: AMBRA1, dtype: int64
#
#
# AMD1
# 0.0    84
# 1.0     1
# Name: AMD1, dtype: int64
#
#
# AMDHD2
# 0.0    143
# 1.0      1
# Name: AMDHD2, dtype: int64
#
#
# AMFR
# 0.0    127
# 1.0      8
# Name: AMFR, dtype: int64
#
#
# AMMECR1
# 0.0    33
# 1.0     1
# Name: AMMECR1, dtype: int64
#
#
# AMMECR1L
# 0.0    41
# 1.0     1
# Name: AMMECR1L, dtype: int64
#
#
# AMN1
# 0.0    116
# 1.0      3
# Name: AMN1, dtype: int64
#
#
# AMOT
# 0.0    141
# 1.0      3
# Name: AMOT, dtype: int64
#
#
# AMOTL1
# 0.0    142
# 1.0      2
# Name: AMOTL1, dtype: int64
#
#
# AMOTL2
# 0.0    137
# 1.0      7
# Name: AMOTL2, dtype: int64
#
#
# AMPD1
# 0.0    9
# Name: AMPD1, dtype: int64
#
#
# AMPD2
# 0.0    142
# 1.0      2
# Name: AMPD2, dtype: int64
#
#
# AMPD3
# 0.0    143
# 1.0      1
# Name: AMPD3, dtype: int64
#
#
# AMPH
# 0.0    144
# Name: AMPH, dtype: int64
#
#
# AMT
# 0.0    143
# 1.0      1
# Name: AMT, dtype: int64
#
#
# AMY1B
# 0.0    143
# 1.0      1
# Name: AMY1B, dtype: int64
#
#
# AMZ2
# 0.0    125
# 1.0      2
# Name: AMZ2, dtype: int64
#
#
# ANAPC1
# 0.0    139
# 1.0      5
# Name: ANAPC1, dtype: int64
#
#
# ANAPC10
# 0.0    138
# 1.0      6
# Name: ANAPC10, dtype: int64
#
#
# ANAPC11
# 0.0    132
# 1.0      3
# Name: ANAPC11, dtype: int64
#
#
# ANAPC13
# 0.0    133
# 1.0     10
# Name: ANAPC13, dtype: int64
#
#
# ANAPC15
# 0.0    39
# 1.0     5
# Name: ANAPC15, dtype: int64
#
#
# ANAPC16
# 0.0    138
# 1.0      6
# Name: ANAPC16, dtype: int64
#
#
# ANAPC2
# 0.0    140
# 1.0      4
# Name: ANAPC2, dtype: int64
#
#
# ANAPC4
# 0.0    140
# 1.0      4
# Name: ANAPC4, dtype: int64
#
#
# ANAPC5
# 0.0    143
# 1.0      1
# Name: ANAPC5, dtype: int64
#
#
# ANAPC7
# 0.0    144
# Name: ANAPC7, dtype: int64
#
#
# ANG
# 0.0    144
# Name: ANG, dtype: int64
#
#
# ANGEL2
# 0.0    141
# 1.0      3
# Name: ANGEL2, dtype: int64
#
#
# ANGPT2
# 0.0    121
# 1.0      5
# Name: ANGPT2, dtype: int64
#
#
# ANGPT4
# 0.0    6
# Name: ANGPT4, dtype: int64
#
#
# ANGPTL1
# 0.0    39
# 1.0     1
# Name: ANGPTL1, dtype: int64
#
#
# ANGPTL2
# 0.0    144
# Name: ANGPTL2, dtype: int64
#
#
# ANGPTL4
# 0.0    91
# Name: ANGPTL4, dtype: int64
#
#
# ANK1
# 0.0    144
# Name: ANK1, dtype: int64
#
#
# ANK2
# 0.0    144
# Name: ANK2, dtype: int64
#
#
# ANK3
# 0.0    134
# 1.0     10
# Name: ANK3, dtype: int64
#
#
# ANKFY1
# 0.0    139
# 1.0      5
# Name: ANKFY1, dtype: int64
#
#
# ANKHD1
# 0.0    135
# 1.0      1
# Name: ANKHD1, dtype: int64
#
#
# ANKHD1-EIF4EBP3
# 0.0    103
# 1.0      2
# Name: ANKHD1-EIF4EBP3, dtype: int64
#
#
# ANKIB1
# 0.0    142
# 1.0      2
# Name: ANKIB1, dtype: int64
#
#
# ANKLE2
# 0.0    143
# 1.0      1
# Name: ANKLE2, dtype: int64
#
#
# ANKMY2
# 0.0    142
# 1.0      2
# Name: ANKMY2, dtype: int64
#
#
# ANKRD10
# 0.0    137
# 1.0      7
# Name: ANKRD10, dtype: int64
#
#
# ANKRD11
# 0.0    139
# 1.0      5
# Name: ANKRD11, dtype: int64
#
#
# ANKRD12
# 0.0    108
# 1.0      9
# Name: ANKRD12, dtype: int64
#
#
# ANKRD13A
# 0.0    142
# 1.0      2
# Name: ANKRD13A, dtype: int64
#
#
# ANKRD13D
# 0.0    137
# 1.0      7
# Name: ANKRD13D, dtype: int64
#
#
# ANKRD16
# 0.0    136
# 1.0      8
# Name: ANKRD16, dtype: int64
#
#
# ANKRD17
# 0.0    142
# 1.0      2
# Name: ANKRD17, dtype: int64
#
#
# ANKRD2
# 0.0    27
# Name: ANKRD2, dtype: int64
#
#
# ANKRD22
# 0.0    142
# 1.0      2
# Name: ANKRD22, dtype: int64
#
#
# ANKRD26
# 0.0    128
# 1.0      7
# Name: ANKRD26, dtype: int64
#
#
# ANKRD27
# 0.0    143
# 1.0      1
# Name: ANKRD27, dtype: int64
#
#
# ANKRD28
# 0.0    144
# Name: ANKRD28, dtype: int64
#
#
# ANKRD35
# 0.0    141
# 1.0      3
# Name: ANKRD35, dtype: int64
#
#
# ANKRD39
# 0.0    119
# 1.0     16
# Name: ANKRD39, dtype: int64
#
#
# ANKRD40
# 0.0    143
# 1.0      1
# Name: ANKRD40, dtype: int64
#
#
# ANKRD42
# 0.0    32
# 1.0     1
# Name: ANKRD42, dtype: int64
#
#
# ANKRD44
# 0.0    141
# 1.0      3
# Name: ANKRD44, dtype: int64
#
#
# ANKRD45
# 0.0    121
# 1.0      7
# Name: ANKRD45, dtype: int64
#
#
# ANKRD46
# 0.0    84
# 1.0     8
# Name: ANKRD46, dtype: int64
#
#
# ANKRD49
# 0.0    132
# 1.0      3
# Name: ANKRD49, dtype: int64
#
#
# ANKRD50
# 0.0    138
# 1.0      6
# Name: ANKRD50, dtype: int64
#
#
# ANKRD52
# 0.0    140
# 1.0      4
# Name: ANKRD52, dtype: int64
#
#
# ANKRD54
# 0.0    140
# 1.0      4
# Name: ANKRD54, dtype: int64
#
#
# ANKS1A
# 0.0    143
# 1.0      1
# Name: ANKS1A, dtype: int64
#
#
# ANKS3
# 0.0    72
# 1.0     3
# Name: ANKS3, dtype: int64
#
#
# ANKS4B
# 0.0    16
# Name: ANKS4B, dtype: int64
#
#
# ANKS6
# 0.0    113
# 1.0      4
# Name: ANKS6, dtype: int64
#
#
# ANKZF1
# 0.0    144
# Name: ANKZF1, dtype: int64
#
#
# ANLN
# 0.0    143
# 1.0      1
# Name: ANLN, dtype: int64
#
#
# ANO1
# 0.0    144
# Name: ANO1, dtype: int64
#
#
# ANO10
# 0.0    136
# 1.0      8
# Name: ANO10, dtype: int64
#
#
# ANO6
# 0.0    137
# 1.0      7
# Name: ANO6, dtype: int64
#
#
# ANO9
# 0.0    76
# 1.0     2
# Name: ANO9, dtype: int64
#
#
# ANOS1
# 0.0    26
# Name: ANOS1, dtype: int64
#
#
# ANP32A
# 0.0    139
# 1.0      5
# Name: ANP32A, dtype: int64
#
#
# ANP32B
# 0.0    140
# 1.0      4
# Name: ANP32B, dtype: int64
#
#
# ANP32C
# 0.0    16
# Name: ANP32C, dtype: int64
#
#
# ANP32E
# 0.0    144
# Name: ANP32E, dtype: int64
#
#
# ANPEP
# 0.0    144
# Name: ANPEP, dtype: int64
#
#
# ANTXR1
# 0.0    138
# 1.0      6
# Name: ANTXR1, dtype: int64
#
#
# ANTXR2
# 0.0    143
# 1.0      1
# Name: ANTXR2, dtype: int64
#
#
# ANXA1
# 0.0    142
# 1.0      2
# Name: ANXA1, dtype: int64
#
#
# ANXA11
# 0.0    143
# 1.0      1
# Name: ANXA11, dtype: int64
#
#
# ANXA13
# 0.0    126
# 1.0      1
# Name: ANXA13, dtype: int64
#
#
# ANXA2
# 0.0    144
# Name: ANXA2, dtype: int64
#
#
# ANXA3
# 0.0    137
# 1.0      7
# Name: ANXA3, dtype: int64
#
#
# ANXA4
# 0.0    137
# 1.0      7
# Name: ANXA4, dtype: int64
#
#
# ANXA5
# 0.0    141
# 1.0      3
# Name: ANXA5, dtype: int64
#
#
# ANXA6
# 0.0    144
# Name: ANXA6, dtype: int64
#
#
# ANXA7
# 0.0    144
# Name: ANXA7, dtype: int64
#
#
# ANXA8
# 0.0    56
# 1.0     4
# Name: ANXA8, dtype: int64
#
#
# ANXA8L1
# 0.0    34
# Name: ANXA8L1, dtype: int64
#
#
# ANXA9
# 0.0    133
# 1.0      2
# Name: ANXA9, dtype: int64
#
#
# AOAH
# 0.0    106
# 1.0      3
# Name: AOAH, dtype: int64
#
#
# AOC1
# 0.0    144
# Name: AOC1, dtype: int64
#
#
# AOC3
# 0.0    144
# Name: AOC3, dtype: int64
#
#
# AOX1
# 0.0    136
# Name: AOX1, dtype: int64
#
#
# AP1AR
# 0.0    111
# 1.0      8
# Name: AP1AR, dtype: int64
#
#
# AP1B1
# 0.0    142
# 1.0      2
# Name: AP1B1, dtype: int64
#
#
# AP1G1
# 0.0    144
# Name: AP1G1, dtype: int64
#
#
# AP1G2
# 0.0    144
# Name: AP1G2, dtype: int64
#
#
# AP1M1
# 0.0    135
# 1.0      9
# Name: AP1M1, dtype: int64
#
#
# AP1M2
# 0.0    140
# 1.0      4
# Name: AP1M2, dtype: int64
#
#
# AP1S1
# 0.0    140
# 1.0      4
# Name: AP1S1, dtype: int64
#
#
# AP1S2
# 0.0    134
# 1.0     10
# Name: AP1S2, dtype: int64
#
#
# AP1S3
# 0.0    133
# 1.0      2
# Name: AP1S3, dtype: int64
#
#
# AP2A1
# 0.0    141
# 1.0      3
# Name: AP2A1, dtype: int64
#
#
# AP2A2
# 0.0    134
# 1.0     10
# Name: AP2A2, dtype: int64
#
#
# AP2B1
# 0.0    141
# 1.0      3
# Name: AP2B1, dtype: int64
#
#
# AP2M1
# 0.0    138
# 1.0      6
# Name: AP2M1, dtype: int64
#
#
# AP2S1
# 0.0    137
# 1.0      7
# Name: AP2S1, dtype: int64
#
#
# AP3B1
# 0.0    142
# 1.0      2
# Name: AP3B1, dtype: int64
#
#
# AP3B2
# 0.0    50
# 1.0     3
# Name: AP3B2, dtype: int64
#
#
# AP3D1
# 0.0    142
# 1.0      2
# Name: AP3D1, dtype: int64
#
#
# AP3M1
# 0.0    139
# 1.0      5
# Name: AP3M1, dtype: int64
#
#
# AP3M2
# 0.0    140
# 1.0      4
# Name: AP3M2, dtype: int64
#
#
# AP3S1
# 0.0    141
# 1.0      3
# Name: AP3S1, dtype: int64
#
#
# AP3S2
# 0.0    104
# 1.0      1
# Name: AP3S2, dtype: int64
#
#
# AP4B1
# 0.0    141
# 1.0      3
# Name: AP4B1, dtype: int64
#
#
# AP4E1
# 0.0    138
# 1.0      6
# Name: AP4E1, dtype: int64
#
#
# AP4M1
# 0.0    141
# 1.0      3
# Name: AP4M1, dtype: int64
#
#
# AP4S1
# 0.0    91
# 1.0     2
# Name: AP4S1, dtype: int64
#
#
# AP5B1
# 0.0    137
# 1.0      7
# Name: AP5B1, dtype: int64
#
#
# AP5M1
# 0.0    138
# 1.0      6
# Name: AP5M1, dtype: int64
#
#
# AP5S1
# 0.0    133
# 1.0     11
# Name: AP5S1, dtype: int64
#
#
# AP5Z1
# 0.0    143
# 1.0      1
# Name: AP5Z1, dtype: int64
#
#
# APAF1
# 0.0    143
# 1.0      1
# Name: APAF1, dtype: int64
#
#
# APBA1
# 0.0    139
# 1.0      5
# Name: APBA1, dtype: int64
#
#
# APBA2
# 0.0    127
# 1.0      8
# Name: APBA2, dtype: int64
#
#
# APBA3
# 0.0    141
# 1.0      3
# Name: APBA3, dtype: int64
#
#
# APBB1
# 0.0    141
# 1.0      3
# Name: APBB1, dtype: int64
#
#
# APBB1IP
# 0.0    142
# 1.0      2
# Name: APBB1IP, dtype: int64
#
#
# APBB2
# 0.0    143
# 1.0      1
# Name: APBB2, dtype: int64
#
#
# APC
# 0.0    137
# 1.0      7
# Name: APC, dtype: int64
#
#
# APCDD1
# 0.0    144
# Name: APCDD1, dtype: int64
#
#
# APCS
# 0.0    141
# 1.0      3
# Name: APCS, dtype: int64
#
#
# APEH
# 0.0    131
# 1.0     13
# Name: APEH, dtype: int64
#
#
# APEX1
# 0.0    143
# 1.0      1
# Name: APEX1, dtype: int64
#
#
# APEX2
# 0.0    128
# 1.0      7
# Name: APEX2, dtype: int64
#
#
# APH1A
# 0.0    31
# 1.0     1
# Name: APH1A, dtype: int64
#
#
# API5
# 0.0    139
# 1.0      5
# Name: API5, dtype: int64
#
#
# APIP
# 0.0    140
# 1.0      4
# Name: APIP, dtype: int64
#
#
# APLF
# 0.0    134
# 1.0     10
# Name: APLF, dtype: int64
#
#
# APLP2
# 0.0    142
# 1.0      2
# Name: APLP2, dtype: int64
#
#
# APMAP
# 0.0    136
# 1.0      8
# Name: APMAP, dtype: int64
#
#
# APOA1
# 0.0    143
# 1.0      1
# Name: APOA1, dtype: int64
#
#
# APOA2
# 0.0    143
# 1.0      1
# Name: APOA2, dtype: int64
#
#
# APOA4
# 0.0    143
# 1.0      1
# Name: APOA4, dtype: int64
#
#
# APOA5
# 0.0    17
# 1.0     1
# Name: APOA5, dtype: int64
#
#
# APOB
# 0.0    144
# Name: APOB, dtype: int64
#
#
# APOBEC3A
# 0.0    76
# Name: APOBEC3A, dtype: int64
#
#
# APOBEC3B
# 0.0    142
# 1.0      2
# Name: APOBEC3B, dtype: int64
#
#
# APOBEC3C
# 0.0    139
# 1.0      5
# Name: APOBEC3C, dtype: int64
#
#
# APOBEC3D
# 0.0    59
# 1.0     2
# Name: APOBEC3D, dtype: int64
#
#
# APOBEC3F
# 0.0    124
# 1.0     11
# Name: APOBEC3F, dtype: int64
#
#
# APOBEC3G
# 0.0    139
# 1.0      5
# Name: APOBEC3G, dtype: int64
#
#
# APOBR
# 0.0    142
# 1.0      2
# Name: APOBR, dtype: int64
#
#
# APOC1
# 0.0    142
# 1.0      2
# Name: APOC1, dtype: int64
#
#
# APOC2
# 0.0    144
# Name: APOC2, dtype: int64
#
#
# APOC3
# 0.0    142
# 1.0      2
# Name: APOC3, dtype: int64
#
#
# APOC4
# 0.0    132
# 1.0      3
# Name: APOC4, dtype: int64
#
#
# APOD
# 0.0    144
# Name: APOD, dtype: int64
#
#
# APOE
# 0.0    143
# 1.0      1
# Name: APOE, dtype: int64
#
#
# APOF
# 0.0    143
# 1.0      1
# Name: APOF, dtype: int64
#
#
# APOH
# 0.0    143
# 1.0      1
# Name: APOH, dtype: int64
#
#
# APOL1
# 0.0    143
# 1.0      1
# Name: APOL1, dtype: int64
#
#
# APOL2
# 0.0    143
# 1.0      1
# Name: APOL2, dtype: int64
#
#
# APOL3
# 0.0    140
# 1.0      4
# Name: APOL3, dtype: int64
#
#
# APOL6
# 0.0    95
# 1.0     1
# Name: APOL6, dtype: int64
#
#
# APOM
# 0.0    144
# Name: APOM, dtype: int64
#
#
# APOO
# 0.0    143
# 1.0      1
# Name: APOO, dtype: int64
#
#
# APOOL
# 0.0    142
# 1.0      2
# Name: APOOL, dtype: int64
#
#
# APOPT1
# 0.0    84
# 1.0     1
# Name: APOPT1, dtype: int64
#
#
# APP
# 0.0    144
# Name: APP, dtype: int64
#
#
# APPBP2
# 0.0    129
# 1.0      6
# Name: APPBP2, dtype: int64
#
#
# APPL1
# 0.0    142
# 1.0      2
# Name: APPL1, dtype: int64
#
#
# APPL2
# 0.0    134
# 1.0     10
# Name: APPL2, dtype: int64
#
#
# APRT
# 0.0    138
# 1.0      6
# Name: APRT, dtype: int64
#
#
# APTX
# 0.0    140
# 1.0      4
# Name: APTX, dtype: int64
#
#
# AQP1
# 0.0    135
# 1.0      9
# Name: AQP1, dtype: int64
#
#
# AQP5
# 0.0    144
# Name: AQP5, dtype: int64
#
#
# AQR
# 0.0    138
# 1.0      6
# Name: AQR, dtype: int64
#
#
# AR
# 0.0    140
# 1.0      4
# Name: AR, dtype: int64
#
#
# ARAF
# 0.0    140
# 1.0      4
# Name: ARAF, dtype: int64
#
#
# ARAP1
# 0.0    139
# 1.0      5
# Name: ARAP1, dtype: int64
#
#
# ARAP2
# 0.0    94
# 1.0    14
# Name: ARAP2, dtype: int64
#
#
# ARAP3
# 0.0    133
# 1.0     11
# Name: ARAP3, dtype: int64
#
#
# ARCN1
# 0.0    138
# 1.0      6
# Name: ARCN1, dtype: int64
#
#
# ARF1
# 0.0    131
# 1.0      4
# Name: ARF1, dtype: int64
#
#
# ARF3
# 0.0    133
# 1.0      2
# Name: ARF3, dtype: int64
#
#
# ARF4
# 0.0    142
# 1.0      2
# Name: ARF4, dtype: int64
#
#
# ARF5
# 0.0    144
# Name: ARF5, dtype: int64
#
#
# ARF6
# 0.0    143
# 1.0      1
# Name: ARF6, dtype: int64
#
#
# ARFGAP1
# 0.0    141
# 1.0      3
# Name: ARFGAP1, dtype: int64
#
#
# ARFGAP2
# 0.0    141
# 1.0      3
# Name: ARFGAP2, dtype: int64
#
#
# ARFGAP3
# 0.0    144
# Name: ARFGAP3, dtype: int64
#
#
# ARFGEF1
# 0.0    143
# 1.0      1
# Name: ARFGEF1, dtype: int64
#
#
# ARFGEF2
# 0.0    136
# 1.0      8
# Name: ARFGEF2, dtype: int64
#
#
# ARFGEF3
# 0.0    143
# 1.0      1
# Name: ARFGEF3, dtype: int64
#
#
# ARFIP1
# 0.0    144
# Name: ARFIP1, dtype: int64
#
#
# ARFIP2
# 0.0    143
# 1.0      1
# Name: ARFIP2, dtype: int64
#
#
# ARFRP1
# 0.0    141
# 1.0      3
# Name: ARFRP1, dtype: int64
#
#
# ARG1
# 0.0    144
# Name: ARG1, dtype: int64
#
#
# ARG2
# 0.0    134
# 1.0      2
# Name: ARG2, dtype: int64
# ARGLU1
# 0.0    141
# 1.0      3
# Name: ARGLU1, dtype: int64
#
#
# ARHGAP1
# 0.0    141
# 1.0      3
# Name: ARHGAP1, dtype: int64
#
#
# ARHGAP10
# 0.0    143
# 1.0      1
# Name: ARHGAP10, dtype: int64
#
#
# ARHGAP12
# 0.0    140
# 1.0      4
# Name: ARHGAP12, dtype: int64
#
#
# ARHGAP15
# 0.0    131
# 1.0      5
# Name: ARHGAP15, dtype: int64
#
#
# ARHGAP17
# 0.0    140
# 1.0      4
# Name: ARHGAP17, dtype: int64
#
#
# ARHGAP18
# 0.0    142
# 1.0      2
# Name: ARHGAP18, dtype: int64
#
#
# ARHGAP21
# 0.0    140
# 1.0      4
# Name: ARHGAP21, dtype: int64
#
#
# ARHGAP23
# 0.0    144
# Name: ARHGAP23, dtype: int64
#
#
# ARHGAP24
# 0.0    122
# 1.0      4
# Name: ARHGAP24, dtype: int64
#
#
# ARHGAP25
# 0.0    137
# 1.0      7
# Name: ARHGAP25, dtype: int64
#
#
# ARHGAP26
# 0.0    141
# 1.0      3
# Name: ARHGAP26, dtype: int64
#
#
# ARHGAP27
# 0.0    144
# Name: ARHGAP27, dtype: int64
#
#
# ARHGAP28
# 0.0    31
# 1.0     1
# Name: ARHGAP28, dtype: int64
#
#
# ARHGAP29
# 0.0    141
# 1.0      3
# Name: ARHGAP29, dtype: int64
#
#
# ARHGAP30
# 0.0    139
# 1.0      5
# Name: ARHGAP30, dtype: int64
#
#
# ARHGAP31
# 0.0    144
# Name: ARHGAP31, dtype: int64
#
#
# ARHGAP32
# 0.0    140
# 1.0      4
# Name: ARHGAP32, dtype: int64
#
#
# ARHGAP35
# 0.0    134
# 1.0     10
# Name: ARHGAP35, dtype: int64
#
#
# ARHGAP39
# 0.0    135
# 1.0      9
# Name: ARHGAP39, dtype: int64
#
#
# ARHGAP4
# 0.0    142
# 1.0      2
# Name: ARHGAP4, dtype: int64
#
#
# ARHGAP42
# 0.0    142
# 1.0      2
# Name: ARHGAP42, dtype: int64
#
#
# ARHGAP44
# 0.0    118
# 1.0     11
# Name: ARHGAP44, dtype: int64
#
#
# ARHGAP45
# 0.0    137
# 1.0      7
# Name: ARHGAP45, dtype: int64
#
#
# ARHGAP5
# 0.0    136
# 1.0      8
# Name: ARHGAP5, dtype: int64
#
#
# ARHGAP6
# 0.0    144
# Name: ARHGAP6, dtype: int64
#
#
# ARHGAP9
# 0.0    142
# 1.0      2
# Name: ARHGAP9, dtype: int64
#
#
# ARHGDIA
# 0.0    140
# 1.0      4
# Name: ARHGDIA, dtype: int64
#
#
# ARHGDIB
# 0.0    141
# 1.0      3
# Name: ARHGDIB, dtype: int64
#
#
# ARHGEF1
# 0.0    140
# 1.0      4
# Name: ARHGEF1, dtype: int64
#
#
# ARHGEF10
# 0.0    140
# 1.0      4
# Name: ARHGEF10, dtype: int64
#
#
# ARHGEF10L
# 0.0    140
# 1.0      4
# Name: ARHGEF10L, dtype: int64
#
#
# ARHGEF11
# 0.0    144
# Name: ARHGEF11, dtype: int64
#
#
# ARHGEF12
# 0.0    138
# 1.0      6
# Name: ARHGEF12, dtype: int64
#
#
# ARHGEF16
# 0.0    141
# 1.0      3
# Name: ARHGEF16, dtype: int64
#
#
# ARHGEF17
# 0.0    144
# Name: ARHGEF17, dtype: int64
#
#
# ARHGEF18
# 0.0    139
# 1.0      5
# Name: ARHGEF18, dtype: int64
#
#
# ARHGEF19
# 0.0    41
# Name: ARHGEF19, dtype: int64
#
#
# ARHGEF2
# 0.0    141
# 1.0      3
# Name: ARHGEF2, dtype: int64
#
#
# ARHGEF25
# 0.0    144
# Name: ARHGEF25, dtype: int64
#
#
# ARHGEF26
# 0.0    122
# 1.0      4
# Name: ARHGEF26, dtype: int64
#
#
# ARHGEF28
# 0.0    136
# 1.0      8
# Name: ARHGEF28, dtype: int64
#
#
# ARHGEF3
# 0.0    140
# 1.0      4
# Name: ARHGEF3, dtype: int64
#
#
# ARHGEF35
# 0.0    132
# 1.0      5
# Name: ARHGEF35, dtype: int64
#
#
# ARHGEF37
# 0.0    141
# 1.0      3
# Name: ARHGEF37, dtype: int64
#
#
# ARHGEF38
# 0.0    99
# 1.0     5
# Name: ARHGEF38, dtype: int64
#
#
# ARHGEF40
# 0.0    142
# 1.0      2
# Name: ARHGEF40, dtype: int64
#
#
# ARHGEF5
# 0.0    143
# 1.0      1
# Name: ARHGEF5, dtype: int64
#
#
# ARHGEF6
# 0.0    144
# Name: ARHGEF6, dtype: int64
#
#
# ARHGEF7
# 0.0    135
# 1.0      9
# Name: ARHGEF7, dtype: int64
#
#
# ARID1A
# 0.0    123
# 1.0     21
# Name: ARID1A, dtype: int64
#
#
# ARID1B
# 0.0    141
# 1.0      3
# Name: ARID1B, dtype: int64
#
#
# ARID2
# 0.0    143
# 1.0      1
# Name: ARID2, dtype: int64
#
#
# ARID3A
# 0.0    131
# 1.0      4
# Name: ARID3A, dtype: int64
#
#
# ARID3B
# 0.0    57
# 1.0     2
# Name: ARID3B, dtype: int64
#
#
# ARID4A
# 0.0    142
# 1.0      2
# Name: ARID4A, dtype: int64
#
#
# ARID4B
# 0.0    144
# Name: ARID4B, dtype: int64
#
#
# ARID5B
# 0.0    138
# 1.0      6
# Name: ARID5B, dtype: int64
#
#
# ARIH1
# 0.0    137
# 1.0      7
# Name: ARIH1, dtype: int64
#
#
# ARIH2
# 0.0    139
# 1.0      5
# Name: ARIH2, dtype: int64
#
#
# ARL1
# 0.0    139
# 1.0      5
# Name: ARL1, dtype: int64
#
#
# ARL13B
# 0.0    40
# 1.0     2
# Name: ARL13B, dtype: int64
#
#
# ARL14EP
# 0.0    140
# 1.0      4
# Name: ARL14EP, dtype: int64
#
#
# ARL15
# 0.0    137
# 1.0      7
# Name: ARL15, dtype: int64
#
#
# ARL2
# 0.0    138
# 1.0      6
# Name: ARL2, dtype: int64
#
#
# ARL2BP
# 0.0    144
# Name: ARL2BP, dtype: int64
#
#
# ARL3
# 0.0    127
# 1.0     17
# Name: ARL3, dtype: int64
#
#
# ARL4A
# 0.0    33
# 1.0     1
# Name: ARL4A, dtype: int64
#
#
# ARL4C
# 0.0    98
# 1.0     3
# Name: ARL4C, dtype: int64
#
#
# ARL4D
# 0.0    16
# 1.0     1
# Name: ARL4D, dtype: int64
#
#
# ARL5A
# 0.0    92
# 1.0     2
# Name: ARL5A, dtype: int64
#
#
# ARL5B
# 0.0    121
# 1.0      5
# Name: ARL5B, dtype: int64
#
#
# ARL6
# 0.0    141
# 1.0      3
# Name: ARL6, dtype: int64
#
#
# ARL6IP1
# 0.0    136
# 1.0      8
# Name: ARL6IP1, dtype: int64
#
#
# ARL6IP4
# 0.0    141
# 1.0      3
# Name: ARL6IP4, dtype: int64
#
#
# ARL6IP5
# 0.0    136
# 1.0      8
# Name: ARL6IP5, dtype: int64
#
#
# ARL6IP6
# 0.0    136
# 1.0      8
# Name: ARL6IP6, dtype: int64
#
#
# ARL8A
# 0.0    138
# 1.0      6
# Name: ARL8A, dtype: int64
#
#
# ARL8B
# 0.0    137
# 1.0      7
# Name: ARL8B, dtype: int64
#
#
# ARMC1
# 0.0    135
# 1.0      9
# Name: ARMC1, dtype: int64
#
#
# ARMC10
# 0.0    143
# 1.0      1
# Name: ARMC10, dtype: int64
#
#
# ARMC3
# 0.0    99
# 1.0     3
# Name: ARMC3, dtype: int64
#
#
# ARMC4
# 0.0    89
# 1.0     4
# Name: ARMC4, dtype: int64
#
#
# ARMC5
# 0.0    111
# 1.0      1
# Name: ARMC5, dtype: int64
#
#
# ARMC6
# 0.0    140
# 1.0      4
# Name: ARMC6, dtype: int64
#
#
# ARMC7
# 0.0    68
# 1.0     3
# Name: ARMC7, dtype: int64
#
#
# ARMC8
# 0.0    140
# 1.0      4
# Name: ARMC8, dtype: int64
#
#
# ARMC9
# 0.0    141
# 1.0      3
# Name: ARMC9, dtype: int64
#
#
# ARMCX1
# 0.0    140
# 1.0      4
# Name: ARMCX1, dtype: int64
#
#
# ARMCX2
# 0.0    132
# 1.0     12
# Name: ARMCX2, dtype: int64
#
#
# ARMCX3
# 0.0    143
# 1.0      1
# Name: ARMCX3, dtype: int64
#
#
# ARMCX5
# 0.0    138
# 1.0      6
# Name: ARMCX5, dtype: int64
#
#
# ARMH3
# 0.0    143
# 1.0      1
# Name: ARMH3, dtype: int64
#
#
# ARMT1
# 0.0    141
# 1.0      3
# Name: ARMT1, dtype: int64
#
#
# ARNT
# 0.0    143
# 1.0      1
# Name: ARNT, dtype: int64
#
#
# ARNT2
# 0.0    136
# 1.0      8
# Name: ARNT2, dtype: int64
#
#
# ARNTL
# 0.0    125
# 1.0      4
# Name: ARNTL, dtype: int64
#
#
# ARPC1A
# 0.0    143
# 1.0      1
# Name: ARPC1A, dtype: int64
#
#
# ARPC1B
# 0.0    144
# Name: ARPC1B, dtype: int64
#
#
# ARPC2
# 0.0    144
# Name: ARPC2, dtype: int64
#
#
# ARPC3
# 0.0    140
# 1.0      4
# Name: ARPC3, dtype: int64
#
#
# ARPC4
# 0.0    140
# 1.0      4
# Name: ARPC4, dtype: int64
#
#
# ARPC5
# 0.0    132
# 1.0     12
# Name: ARPC5, dtype: int64
#
#
# ARPC5L
# 0.0    136
# 1.0      8
# Name: ARPC5L, dtype: int64
#
#
# ARPIN
# 0.0    84
# 1.0     1
# Name: ARPIN, dtype: int64
#
#
# ARPP19
# 0.0    142
# 1.0      2
# Name: ARPP19, dtype: int64
#
#
# ARR3
# 0.0    140
# 1.0      4
# Name: ARR3, dtype: int64
#
#
# ARRB1
# 0.0    140
# 1.0      4
# Name: ARRB1, dtype: int64
#
#
# ARRB2
# 0.0    142
# 1.0      2
# Name: ARRB2, dtype: int64
#
#
# ARRDC1
# 0.0    142
# 1.0      2
# Name: ARRDC1, dtype: int64
#
#
# ARSA
# 0.0    143
# 1.0      1
# Name: ARSA, dtype: int64
#
#
# ARSB
# 0.0    142
# 1.0      2
# Name: ARSB, dtype: int64
#
#
# ARSD
# 0.0    143
# 1.0      1
# Name: ARSD, dtype: int64
#
#
# ARSE
# 0.0    124
# 1.0      5
# Name: ARSE, dtype: int64
#
#
# ARSK
# 0.0    76
# 1.0     2
# Name: ARSK, dtype: int64
#
#
# ARV1
# 0.0    134
# 1.0      2
# Name: ARV1, dtype: int64
#
#
# ARVCF
# 0.0    142
# 1.0      2
# Name: ARVCF, dtype: int64
#
#
# ARX
# 0.0    42
# 1.0     2
# Name: ARX, dtype: int64
#
#
# AS3MT
# 0.0    141
# 1.0      3
# Name: AS3MT, dtype: int64
#
#
# ASAH1
# 0.0    144
# Name: ASAH1, dtype: int64
#
#
# ASAP1
# 0.0    139
# 1.0      5
# Name: ASAP1, dtype: int64
#
#
# ASAP2
# 0.0    143
# 1.0      1
# Name: ASAP2, dtype: int64
#
#
# ASAP3
# 0.0    133
# 1.0     11
# Name: ASAP3, dtype: int64
#
#
# ASB1
# 0.0    66
# 1.0     1
# Name: ASB1, dtype: int64
#
#
# ASB13
# 0.0    59
# 1.0     3
# Name: ASB13, dtype: int64
#
#
# ASB6
# 0.0    114
# 1.0      3
# Name: ASB6, dtype: int64
#
#
# ASB7
# 0.0    87
# 1.0     4
# Name: ASB7, dtype: int64
#
#
# ASB8
# 0.0    25
# Name: ASB8, dtype: int64
#
#
# ASB9
# 0.0    58
# 1.0    11
# Name: ASB9, dtype: int64
#
#
# ASCC1
# 0.0    143
# 1.0      1
# Name: ASCC1, dtype: int64
#
#
# ASCC2
# 0.0    142
# 1.0      2
# Name: ASCC2, dtype: int64
#
#
# ASCC3
# 0.0    143
# 1.0      1
# Name: ASCC3, dtype: int64
#
#
# ASDURF
# 0.0    142
# 1.0      2
# Name: ASDURF, dtype: int64
#
#
# ASF1A
# 0.0    138
# 1.0      6
# Name: ASF1A, dtype: int64
#
#
# ASF1B
# 0.0    124
# 1.0      3
# Name: ASF1B, dtype: int64
#
#
# ASH1L
# 0.0    135
# 1.0      9
# Name: ASH1L, dtype: int64
#
#
# ASH2L
# 0.0    141
# 1.0      3
# Name: ASH2L, dtype: int64
#
#
# ASL
# 0.0    139
# 1.0      5
# Name: ASL, dtype: int64
#
#
# ASMTL
# 0.0    135
# 1.0      9
# Name: ASMTL, dtype: int64
#
#
# ASNA1
# 0.0    137
# 1.0      7
# Name: ASNA1, dtype: int64
#
#
# ASNS
# 0.0    143
# 1.0      1
# Name: ASNS, dtype: int64
#
#
# ASNSD1
# 0.0    106
# 1.0      2
# Name: ASNSD1, dtype: int64
#
#
# ASPA
# 0.0    135
# Name: ASPA, dtype: int64
#
#
# ASPH
# 0.0    133
# 1.0     11
# Name: ASPH, dtype: int64
#
#
# ASPN
# 0.0    144
# Name: ASPN, dtype: int64
#
#
# ASPRV1
# 0.0    34
# 1.0     1
# Name: ASPRV1, dtype: int64
#
#
# ASPSCR1
# 0.0    143
# 1.0      1
# Name: ASPSCR1, dtype: int64
#
#
# ASRGL1
# 0.0    140
# 1.0      4
# Name: ASRGL1, dtype: int64
#
#
# ASS1
# 0.0    129
# 1.0     15
# Name: ASS1, dtype: int64
#
#
# ASTE1
# 0.0    74
# 1.0     2
# Name: ASTE1, dtype: int64
#
#
# ASXL2
# 0.0    134
# 1.0      2
# Name: ASXL2, dtype: int64
#
#
# ATAD1
# 0.0    140
# 1.0      4
# Name: ATAD1, dtype: int64
#
#
# ATAD2
# 0.0    144
# Name: ATAD2, dtype: int64
#
#
# ATAD2B
# 0.0    141
# 1.0      3
# Name: ATAD2B, dtype: int64
#
#
# ATAD3A
# 0.0    144
# Name: ATAD3A, dtype: int64
#
#
# ATAD3B
# 0.0    115
# 1.0      4
# Name: ATAD3B, dtype: int64
#
#
# ATAT1
# 0.0    141
# 1.0      3
# Name: ATAT1, dtype: int64
#
#
# ATE1
# 0.0    143
# 1.0      1
# Name: ATE1, dtype: int64
#
#
# ATF1
# 0.0    138
# 1.0      6
# Name: ATF1, dtype: int64
#
#
# ATF2
# 0.0    140
# 1.0      4
# Name: ATF2, dtype: int64
#
#
# ATF3
# 0.0    35
# Name: ATF3, dtype: int64
#
#
# ATF6
# 0.0    127
# 1.0      9
# Name: ATF6, dtype: int64
#
#
# ATF6B
# 0.0    52
# Name: ATF6B, dtype: int64
#
#
# ATF7
# 0.0    142
# 1.0      2
# Name: ATF7, dtype: int64
#
#
# ATF7IP
# 0.0    143
# 1.0      1
# Name: ATF7IP, dtype: int64
#
#
# ATG10
# 0.0    51
# 1.0     2
# Name: ATG10, dtype: int64
#
#
# ATG101
# 0.0    140
# 1.0      4
# Name: ATG101, dtype: int64
#
#
# ATG12
# 0.0    142
# 1.0      2
# Name: ATG12, dtype: int64
#
#
# ATG13
# 0.0    141
# 1.0      3
# Name: ATG13, dtype: int64
#
#
# ATG14
# 0.0    137
# 1.0      7
# Name: ATG14, dtype: int64
#
#
# ATG16L1
# 0.0    139
# 1.0      5
# Name: ATG16L1, dtype: int64
#
#
# ATG2A
# 0.0    140
# 1.0      4
# Name: ATG2A, dtype: int64
#
#
# ATG2B
# 0.0    143
# 1.0      1
# Name: ATG2B, dtype: int64
#
#
# ATG3
# 0.0    142
# 1.0      2
# Name: ATG3, dtype: int64
#
#
# ATG4A
# 0.0    111
# 1.0      1
# Name: ATG4A, dtype: int64
#
#
# ATG4B
# 0.0    138
# 1.0      6
# Name: ATG4B, dtype: int64
#
#
# ATG4C
# 0.0    139
# 1.0      5
# Name: ATG4C, dtype: int64
#
#
# ATG5
# 0.0    142
# 1.0      2
# Name: ATG5, dtype: int64
#
#
# ATG7
# 0.0    134
# 1.0     10
# Name: ATG7, dtype: int64
#
#
# ATG9A
# 0.0    142
# 1.0      2
# Name: ATG9A, dtype: int64
#
#
# ATIC
# 0.0    140
# 1.0      4
# Name: ATIC, dtype: int64
#
#
# ATL1
# 0.0    140
# 1.0      4
# Name: ATL1, dtype: int64
#
#
# ATL2
# 0.0    137
# 1.0      7
# Name: ATL2, dtype: int64
#
#
# ATL3
# 0.0    128
# 1.0     16
# Name: ATL3, dtype: int64
#
#
# ATM
# 0.0    132
# 1.0     12
# Name: ATM, dtype: int64
#
#
# ATN1
# 0.0    141
# 1.0      3
# Name: ATN1, dtype: int64
#
#
# ATOX1
# 0.0    143
# 1.0      1
# Name: ATOX1, dtype: int64
#
#
# ATP11A
# 0.0    143
# 1.0      1
# Name: ATP11A, dtype: int64
#
#
# ATP11B
# 0.0    133
# 1.0     11
# Name: ATP11B, dtype: int64
#
#
# ATP11C
# 0.0    133
# 1.0     11
# Name: ATP11C, dtype: int64
#
#
# ATP12A
# 0.0    73
# 1.0     2
# Name: ATP12A, dtype: int64
#
#
# ATP13A1
# 0.0    141
# 1.0      3
# Name: ATP13A1, dtype: int64
#
#
# ATP13A2
# 0.0    134
# 1.0      1
# Name: ATP13A2, dtype: int64
#
#
# ATP13A3
# 0.0    139
# 1.0      5
# Name: ATP13A3, dtype: int64
#
#
# ATP1A1
# 0.0    142
# 1.0      2
# Name: ATP1A1, dtype: int64
#
#
# ATP1A2
# 0.0    43
# Name: ATP1A2, dtype: int64
#
#
# ATP1B1
# 0.0    140
# 1.0      4
# Name: ATP1B1, dtype: int64
#
#
# ATP1B2
# 0.0    89
# 1.0     2
# Name: ATP1B2, dtype: int64
#
#
# ATP1B3
# 0.0    140
# 1.0      4
# Name: ATP1B3, dtype: int64
#
#
# ATP23
# 0.0    140
# 1.0      4
# Name: ATP23, dtype: int64
#
#
# ATP2A2
# 0.0    138
# 1.0      6
# Name: ATP2A2, dtype: int64
#
#
# ATP2A3
# 0.0    141
# 1.0      3
# Name: ATP2A3, dtype: int64
#
#
# ATP2B1
# 0.0    140
# 1.0      4
# Name: ATP2B1, dtype: int64
#
#
# ATP2B2
# 0.0    120
# 1.0      6
# Name: ATP2B2, dtype: int64
#
#
# ATP2B3
# 0.0    110
# 1.0      3
# Name: ATP2B3, dtype: int64
#
#
# ATP2B4
# 0.0    129
# 1.0     15
# Name: ATP2B4, dtype: int64
#
#
# ATP2C1
# 0.0    141
# 1.0      3
# Name: ATP2C1, dtype: int64
#
#
# ATP2C2
# 0.0    94
# 1.0     1
# Name: ATP2C2, dtype: int64
#
#
# ATP5F1A
# 0.0    143
# 1.0      1
# Name: ATP5F1A, dtype: int64
#
#
# ATP5F1B
# 0.0    142
# 1.0      2
# Name: ATP5F1B, dtype: int64
#
#
# ATP5F1C
# 0.0    143
# 1.0      1
# Name: ATP5F1C, dtype: int64
#
#
# ATP5F1D
# 0.0    144
# Name: ATP5F1D, dtype: int64
#
#
# ATP5F1E
# 0.0    131
# 1.0     13
# Name: ATP5F1E, dtype: int64
#
#
# ATP5IF1
# 0.0    144
# Name: ATP5IF1, dtype: int64
#
#
# ATP5MC1
# 0.0    127
# 1.0      9
# Name: ATP5MC1, dtype: int64
#
#
# ATP5MD
# 0.0    136
# 1.0      8
# Name: ATP5MD, dtype: int64
#
#
# ATP5ME
# 0.0    143
# 1.0      1
# Name: ATP5ME, dtype: int64
#
#
# ATP5MF
# 0.0    137
# 1.0      7
# Name: ATP5MF, dtype: int64
#
#
# ATP5MF-PTCD1
# 0.0    143
# 1.0      1
# Name: ATP5MF-PTCD1, dtype: int64
#
#
# ATP5MG
# 0.0    140
# 1.0      4
# Name: ATP5MG, dtype: int64
#
#
# ATP5MPL
# 0.0    138
# 1.0      6
# Name: ATP5MPL, dtype: int64
#
#
# ATP5PB
# 0.0    140
# 1.0      4
# Name: ATP5PB, dtype: int64
#
#
# ATP5PD
# 0.0    142
# 1.0      2
# Name: ATP5PD, dtype: int64
#
#
# ATP5PF
# 0.0    142
# 1.0      2
# Name: ATP5PF, dtype: int64
#
#
# ATP5PO
# 0.0    143
# 1.0      1
# Name: ATP5PO, dtype: int64
#
#
# ATP5S
# 0.0    142
# 1.0      2
# Name: ATP5S, dtype: int64
#
#
# ATP6AP1
# 0.0    136
# 1.0      8
# Name: ATP6AP1, dtype: int64
#
#
# ATP6AP2
# 0.0    143
# 1.0      1
# Name: ATP6AP2, dtype: int64
#
#
# ATP6V0A1
# 0.0    139
# 1.0      5
# Name: ATP6V0A1, dtype: int64
#
#
# ATP6V0A2
# 0.0    137
# 1.0      7
# Name: ATP6V0A2, dtype: int64
#
#
# ATP6V0C
# 0.0    129
# 1.0      7
# Name: ATP6V0C, dtype: int64
#
#
# ATP6V0D1
# 0.0    144
# Name: ATP6V0D1, dtype: int64
#
#
# ATP6V0D2
# 0.0    130
# 1.0     14
# Name: ATP6V0D2, dtype: int64
#
#
# ATP6V1A
# 0.0    140
# 1.0      4
# Name: ATP6V1A, dtype: int64
#
#
# ATP6V1B1
# 0.0    113
# 1.0      5
# Name: ATP6V1B1, dtype: int64
#
#
# ATP6V1B2
# 0.0    137
# 1.0      7
# Name: ATP6V1B2, dtype: int64
#
#
# ATP6V1C1
# 0.0    144
# Name: ATP6V1C1, dtype: int64
#
#
# ATP6V1C2
# 0.0    144
# Name: ATP6V1C2, dtype: int64
#
#
# ATP6V1D
# 0.0    142
# 1.0      2
# Name: ATP6V1D, dtype: int64
#
#
# ATP6V1E1
# 0.0    144
# Name: ATP6V1E1, dtype: int64
#
#
# ATP6V1E2
# 0.0    8
# 1.0    1
# Name: ATP6V1E2, dtype: int64
#
#
# ATP6V1F
# 0.0    142
# 1.0      2
# Name: ATP6V1F, dtype: int64
#
#
# ATP6V1G1
# 0.0    142
# 1.0      2
# Name: ATP6V1G1, dtype: int64
#
#
# ATP6V1G2
# 0.0    133
# 1.0      3
# Name: ATP6V1G2, dtype: int64
#
#
# ATP6V1H
# 0.0    139
# 1.0      5
# Name: ATP6V1H, dtype: int64
#
#
# ATP7A
# 0.0    140
# 1.0      4
# Name: ATP7A, dtype: int64
#
#
# ATP7B
# 0.0    95
# Name: ATP7B, dtype: int64
#
#
# ATP8A1
# 0.0    138
# 1.0      6
# Name: ATP8A1, dtype: int64
#
#
# ATP8B1
# 0.0    144
# Name: ATP8B1, dtype: int64
#
#
# ATP9A
# 0.0    142
# 1.0      2
# Name: ATP9A, dtype: int64
#
#
# ATP9B
# 0.0    135
# 1.0      9
# Name: ATP9B, dtype: int64
#
#
# ATPAF1
# 0.0    144
# Name: ATPAF1, dtype: int64
#
#
# ATPAF2
# 0.0    144
# Name: ATPAF2, dtype: int64
#
#
# ATR
# 0.0    141
# 1.0      3
# Name: ATR, dtype: int64
#
#
# ATRAID
# 0.0    133
# 1.0      2
# Name: ATRAID, dtype: int64
#
#
# ATRIP
# 0.0    138
# 1.0      6
# Name: ATRIP, dtype: int64
#
#
# ATRN
# 0.0    143
# 1.0      1
# Name: ATRN, dtype: int64
#
#
# ATRX
# 0.0    136
# 1.0      8
# Name: ATRX, dtype: int64
#
#
# ATXN1
# 0.0    140
# 1.0      4
# Name: ATXN1, dtype: int64
#
#
# ATXN10
# 0.0    140
# 1.0      4
# Name: ATXN10, dtype: int64
#
#
# ATXN1L
# 0.0    141
# 1.0      3
# Name: ATXN1L, dtype: int64
#
#
# ATXN2
# 0.0    138
# 1.0      6
# Name: ATXN2, dtype: int64
#
#
# ATXN2L
# 0.0    144
# Name: ATXN2L, dtype: int64
#
#
# ATXN3
# 0.0    143
# 1.0      1
# Name: ATXN3, dtype: int64
#
#
# ATXN7
# 0.0    140
# 1.0      4
# Name: ATXN7, dtype: int64
#
#
# ATXN7L3
# 0.0    127
# 1.0      9
# Name: ATXN7L3, dtype: int64
#
#
# ATXN7L3B
# 0.0    140
# 1.0      4
# Name: ATXN7L3B, dtype: int64
#
#
# AUH
# 0.0    139
# 1.0      5
# Name: AUH, dtype: int64
#
#
# AUP1
# 0.0    139
# 1.0      5
# Name: AUP1, dtype: int64
#
#
# AURKA
# 0.0    85
# 1.0     7
# Name: AURKA, dtype: int64
#
#
# AURKB
# 0.0    108
# Name: AURKB, dtype: int64
#
#
# AUTS2
# 0.0    143
# 1.0      1
# Name: AUTS2, dtype: int64
#
#
# AVEN
# 0.0    135
# 1.0      9
# Name: AVEN, dtype: int64
#
#
# AVL9
# 0.0    144
# Name: AVL9, dtype: int64
# AXIN1
# 0.0    97
# 1.0     3
# Name: AXIN1, dtype: int64
#
#
# AXL
# 0.0    50
# Name: AXL, dtype: int64
#
#
# AZGP1
# 0.0    144
# Name: AZGP1, dtype: int64
#
#
# AZI2
# 0.0    124
# 1.0     11
# Name: AZI2, dtype: int64
#
#
# AZU1
# 0.0    142
# 1.0      2
# Name: AZU1, dtype: int64
#
#
# B2M
# 0.0    144
# Name: B2M, dtype: int64
#
#
# B3GALNT1
# 0.0    52
# 1.0     1
# Name: B3GALNT1, dtype: int64
#
#
# B3GALT5
# 0.0    50
# Name: B3GALT5, dtype: int64
#
#
# B3GALT6
# 0.0    130
# 1.0      5
# Name: B3GALT6, dtype: int64
#
#
# B3GAT3
# 0.0    142
# 1.0      2
# Name: B3GAT3, dtype: int64
#
#
# B3GLCT
# 0.0    143
# 1.0      1
# Name: B3GLCT, dtype: int64
#
#
# B3GNT2
# 0.0    129
# 1.0      6
# Name: B3GNT2, dtype: int64
#
#
# B3GNT3
# 0.0    58
# Name: B3GNT3, dtype: int64
#
#
# B3GNT7
# 0.0    94
# 1.0     1
# Name: B3GNT7, dtype: int64
#
#
# B3GNTL1
# 0.0    130
# 1.0      5
# Name: B3GNTL1, dtype: int64
#
#
# B4GALNT3
# 0.0    123
# 1.0      6
# Name: B4GALNT3, dtype: int64
#
#
# B4GALT1
# 0.0    142
# 1.0      2
# Name: B4GALT1, dtype: int64
#
#
# B4GALT3
# 0.0    115
# 1.0      2
# Name: B4GALT3, dtype: int64
#
#
# B4GALT4
# 0.0    144
# Name: B4GALT4, dtype: int64
#
#
# B4GALT5
# 0.0    139
# 1.0      5
# Name: B4GALT5, dtype: int64
#
#
# B4GALT7
# 0.0    95
# ...
#
#
# ZC3H7B
# 0.0    133
# 1.0     11
# Name: ZC3H7B, dtype: int64
# ZC3H8
# 0.0    131
# 1.0      4
# Name: ZC3H8, dtype: int64
#
#
# ZC3HAV1
# 0.0    141
# 1.0      3
# Name: ZC3HAV1, dtype: int64
#
#
# ZC3HAV1L
# 0.0    141
# 1.0      3
# Name: ZC3HAV1L, dtype: int64
#
#
# ZC3HC1
# 0.0    141
# 1.0      3
# Name: ZC3HC1, dtype: int64
#
#
# ZCCHC10
# 0.0    88
# 1.0     7
# Name: ZCCHC10, dtype: int64
#
#
# ZCCHC12
# 0.0    107
# 1.0      4
# Name: ZCCHC12, dtype: int64
#
#
# ZCCHC17
# 0.0    141
# 1.0      3
# Name: ZCCHC17, dtype: int64
#
#
# ZCCHC24
# 0.0    143
# 1.0      1
# Name: ZCCHC24, dtype: int64
#
#
# ZCCHC3
# 0.0    143
# 1.0      1
# Name: ZCCHC3, dtype: int64
#
#
# ZCCHC4
# 0.0    80
# 1.0     5
# Name: ZCCHC4, dtype: int64
#
#
# ZCCHC7
# 0.0    142
# 1.0      2
# Name: ZCCHC7, dtype: int64
#
#
# ZCCHC8
# 0.0    138
# 1.0      6
# Name: ZCCHC8, dtype: int64
#
#
# ZCCHC9
# 0.0    137
# 1.0      7
# Name: ZCCHC9, dtype: int64
#
#
# ZCRB1
# 0.0    144
# Name: ZCRB1, dtype: int64
#
#
# ZDHHC13
# 0.0    141
# 1.0      3
# Name: ZDHHC13, dtype: int64
#
#
# ZDHHC17
# 0.0    138
# 1.0      5
# Name: ZDHHC17, dtype: int64
#
#
# ZDHHC18
# 0.0    76
# 1.0     2
# Name: ZDHHC18, dtype: int64
#
#
# ZDHHC2
# 0.0    33
# 1.0     1
# Name: ZDHHC2, dtype: int64
#
#
# ZDHHC20
# 0.0    137
# 1.0      7
# Name: ZDHHC20, dtype: int64
#
#
# ZDHHC21
# 0.0    105
# 1.0      3
# Name: ZDHHC21, dtype: int64
#
#
# ZDHHC3
# 0.0    137
# 1.0      7
# Name: ZDHHC3, dtype: int64
#
#
# ZDHHC4
# 0.0    86
# 1.0     8
# Name: ZDHHC4, dtype: int64
#
#
# ZDHHC5
# 0.0    141
# 1.0      3
# Name: ZDHHC5, dtype: int64
#
#
# ZDHHC6
# 0.0    135
# Name: ZDHHC6, dtype: int64
#
#
# ZDHHC7
# 0.0    100
# 1.0      4
# Name: ZDHHC7, dtype: int64
#
#
# ZEB1
# 0.0    144
# Name: ZEB1, dtype: int64
#
#
# ZEB2
# 0.0    144
# Name: ZEB2, dtype: int64
#
#
# ZER1
# 0.0    140
# 1.0      4
# Name: ZER1, dtype: int64
#
#
# ZFAND1
# 0.0    140
# 1.0      4
# Name: ZFAND1, dtype: int64
#
#
# ZFAND2B
# 0.0    142
# 1.0      2
# Name: ZFAND2B, dtype: int64
#
#
# ZFAND3
# 0.0    140
# 1.0      4
# Name: ZFAND3, dtype: int64
#
#
# ZFAND5
# 0.0    136
# 1.0      8
# Name: ZFAND5, dtype: int64
#
#
# ZFAND6
# 0.0    142
# 1.0      2
# Name: ZFAND6, dtype: int64
#
#
# ZFC3H1
# 0.0    141
# 1.0      3
# Name: ZFC3H1, dtype: int64
#
#
# ZFHX3
# 0.0    138
# 1.0      6
# Name: ZFHX3, dtype: int64
#
#
# ZFP1
# 0.0    100
# 1.0      2
# Name: ZFP1, dtype: int64
#
#
# ZFP3
# 0.0    111
# 1.0      9
# Name: ZFP3, dtype: int64
#
#
# ZFP36
# 0.0    73
# Name: ZFP36, dtype: int64
#
#
# ZFP36L1
# 0.0    138
# 1.0      6
# Name: ZFP36L1, dtype: int64
#
#
# ZFP36L2
# 0.0    140
# 1.0      4
# Name: ZFP36L2, dtype: int64
#
#
# ZFP37
# 0.0    47
# 1.0     4
# Name: ZFP37, dtype: int64
#
#
# ZFP62
# 0.0    51
# 1.0     2
# Name: ZFP62, dtype: int64
#
#
# ZFP64
# 0.0    144
# Name: ZFP64, dtype: int64
#
#
# ZFP90
# 0.0    139
# 1.0      5
# Name: ZFP90, dtype: int64
#
#
# ZFP91
# 0.0    132
# 1.0     12
# Name: ZFP91, dtype: int64
#
#
# ZFP92
# 0.0    26
# Name: ZFP92, dtype: int64
#
#
# ZFPL1
# 0.0    142
# 1.0      2
# Name: ZFPL1, dtype: int64
#
#
# ZFR
# 0.0    134
# 1.0     10
# Name: ZFR, dtype: int64
#
#
# ZFX
# 0.0    140
# 1.0      4
# Name: ZFX, dtype: int64
#
#
# ZFYVE1
# 0.0    135
# 1.0      9
# Name: ZFYVE1, dtype: int64
#
#
# ZFYVE16
# 0.0    138
# 1.0      6
# Name: ZFYVE16, dtype: int64
#
#
# ZFYVE19
# 0.0    136
# 1.0      8
# Name: ZFYVE19, dtype: int64
#
#
# ZFYVE21
# 0.0    144
# Name: ZFYVE21, dtype: int64
#
#
# ZFYVE26
# 0.0    138
# 1.0      6
# Name: ZFYVE26, dtype: int64
#
#
# ZFYVE27
# 0.0    143
# 1.0      1
# Name: ZFYVE27, dtype: int64
#
#
# ZFYVE9
# 0.0    141
# 1.0      3
# Name: ZFYVE9, dtype: int64
#
#
# ZG16B
# 0.0    59
# 1.0     1
# Name: ZG16B, dtype: int64
#
#
# ZGPAT
# 0.0    141
# 1.0      3
# Name: ZGPAT, dtype: int64
#
#
# ZHX1
# 0.0    139
# 1.0      5
# Name: ZHX1, dtype: int64
#
#
# ZHX2
# 0.0    137
# 1.0      7
# Name: ZHX2, dtype: int64
#
#
# ZHX3
# 0.0    144
# Name: ZHX3, dtype: int64
#
#
# ZKSCAN1
# 0.0    139
# 1.0      5
# Name: ZKSCAN1, dtype: int64
#
#
# ZKSCAN3
# 0.0    15
# 1.0     1
# Name: ZKSCAN3, dtype: int64
#
#
# ZKSCAN4
# 0.0    112
# 1.0      6
# Name: ZKSCAN4, dtype: int64
#
#
# ZKSCAN8
# 0.0    140
# 1.0      4
# Name: ZKSCAN8, dtype: int64
#
#
# ZMAT2
# 0.0    136
# 1.0      8
# Name: ZMAT2, dtype: int64
#
#
# ZMAT3
# 0.0    105
# 1.0      5
# Name: ZMAT3, dtype: int64
#
#
# ZMAT5
# 0.0    84
# 1.0     3
# Name: ZMAT5, dtype: int64
#
#
# ZMIZ1
# 0.0    140
# 1.0      4
# Name: ZMIZ1, dtype: int64
#
#
# ZMIZ2
# 0.0    143
# 1.0      1
# Name: ZMIZ2, dtype: int64
#
#
# ZMPSTE24
# 0.0    133
# 1.0     11
# Name: ZMPSTE24, dtype: int64
#
#
# ZMYM1
# 0.0    140
# 1.0      4
# Name: ZMYM1, dtype: int64
#
#
# ZMYM2
# 0.0    144
# Name: ZMYM2, dtype: int64
#
#
# ZMYM3
# 0.0    133
# 1.0     11
# Name: ZMYM3, dtype: int64
#
#
# ZMYM4
# 0.0    136
# 1.0      8
# Name: ZMYM4, dtype: int64
#
#
# ZMYND10
# 0.0    130
# 1.0      5
# Name: ZMYND10, dtype: int64
#
#
# ZMYND11
# 0.0    143
# 1.0      1
# Name: ZMYND11, dtype: int64
#
#
# ZMYND8
# 0.0    142
# 1.0      2
# Name: ZMYND8, dtype: int64
#
#
# ZNF100
# 0.0    23
# Name: ZNF100, dtype: int64
#
#
# ZNF106
# 0.0    121
# 1.0      5
# Name: ZNF106, dtype: int64
#
#
# ZNF12
# 0.0    74
# Name: ZNF12, dtype: int64
#
#
# ZNF121
# 0.0    115
# 1.0      3
# Name: ZNF121, dtype: int64
#
#
# ZNF131
# 0.0    142
# 1.0      2
# Name: ZNF131, dtype: int64
#
#
# ZNF134
# 0.0    8
# 1.0    1
# Name: ZNF134, dtype: int64
#
#
# ZNF138
# 0.0    16
# Name: ZNF138, dtype: int64
#
#
# ZNF140
# 0.0    16
# 1.0     1
# Name: ZNF140, dtype: int64
#
#
# ZNF143
# 0.0    139
# 1.0      5
# Name: ZNF143, dtype: int64
#
#
# ZNF146
# 0.0    137
# 1.0      7
# Name: ZNF146, dtype: int64
#
#
# ZNF148
# 0.0    139
# 1.0      5
# Name: ZNF148, dtype: int64
#
#
# ZNF157
# 0.0    5
# 1.0    1
# Name: ZNF157, dtype: int64
#
#
# ZNF16
# 0.0    42
# 1.0     5
# Name: ZNF16, dtype: int64
#
#
# ZNF17
# 0.0    8
# Name: ZNF17, dtype: int64
#
#
# ZNF174
# 0.0    92
# Name: ZNF174, dtype: int64
#
#
# ZNF184
# 0.0    108
# 1.0     14
# Name: ZNF184, dtype: int64
#
#
# ZNF185
# 0.0    144
# Name: ZNF185, dtype: int64
#
#
# ZNF195
# 0.0    66
# 1.0     6
# Name: ZNF195, dtype: int64
#
#
# ZNF2
# 0.0    35
# 1.0     1
# Name: ZNF2, dtype: int64
#
#
# ZNF207
# 0.0    137
# 1.0      7
# Name: ZNF207, dtype: int64
#
#
# ZNF217
# 0.0    143
# 1.0      1
# Name: ZNF217, dtype: int64
#
#
# ZNF219
# 0.0    142
# 1.0      2
# Name: ZNF219, dtype: int64
#
#
# ZNF22
# 0.0    140
# 1.0      4
# Name: ZNF22, dtype: int64
#
#
# ZNF224
# 0.0    23
# 1.0     4
# Name: ZNF224, dtype: int64
#
#
# ZNF239
# 0.0    34
# Name: ZNF239, dtype: int64
#
#
# ZNF24
# 0.0    144
# Name: ZNF24, dtype: int64
#
#
# ZNF248
# 0.0    9
# Name: ZNF248, dtype: int64
#
#
# ZNF250
# 0.0    96
# 1.0     4
# Name: ZNF250, dtype: int64
#
#
# ZNF253
# 0.0    66
# 1.0     2
# Name: ZNF253, dtype: int64
#
#
# ZNF260
# 0.0    96
# 1.0    11
# Name: ZNF260, dtype: int64
#
#
# ZNF263
# 0.0    57
# 1.0     3
# Name: ZNF263, dtype: int64
#
#
# ZNF264
# 0.0    94
# 1.0     1
# Name: ZNF264, dtype: int64
#
#
# ZNF268
# 0.0    31
# 1.0     4
# Name: ZNF268, dtype: int64
#
#
# ZNF275
# 0.0    42
# 1.0     1
# Name: ZNF275, dtype: int64
#
#
# ZNF276
# 0.0    136
# 1.0      8
# Name: ZNF276, dtype: int64
#
#
# ZNF277
# 0.0    64
# 1.0     5
# Name: ZNF277, dtype: int64
#
#
# ZNF28
# 0.0    17
# Name: ZNF28, dtype: int64
#
#
# ZNF280C
# 0.0    144
# Name: ZNF280C, dtype: int64
#
#
# ZNF280D
# 0.0    139
# 1.0      5
# Name: ZNF280D, dtype: int64
#
#
# ZNF281
# 0.0    141
# 1.0      3
# Name: ZNF281, dtype: int64
#
#
# ZNF282
# 0.0    132
# 1.0      4
# Name: ZNF282, dtype: int64
#
#
# ZNF286A
# 0.0    15
# 1.0     2
# Name: ZNF286A, dtype: int64
#
#
# ZNF292
# 0.0    138
# 1.0      6
# Name: ZNF292, dtype: int64
#
#
# ZNF3
# 0.0    106
# 1.0      2
# Name: ZNF3, dtype: int64
#
#
# ZNF302
# 0.0    35
# Name: ZNF302, dtype: int64
#
#
# ZNF304
# 0.0    24
# 1.0     2
# Name: ZNF304, dtype: int64
#
#
# ZNF316
# 0.0    140
# 1.0      4
# Name: ZNF316, dtype: int64
#
#
# ZNF318
# 0.0    142
# 1.0      2
# Name: ZNF318, dtype: int64
#
#
# ZNF32
# 0.0    67
# Name: ZNF32, dtype: int64
#
#
# ZNF320
# 0.0    72
# 1.0     2
# Name: ZNF320, dtype: int64
#
#
# ZNF324
# 0.0    83
# 1.0     3
# Name: ZNF324, dtype: int64
#
#
# ZNF326
# 0.0    138
# 1.0      6
# Name: ZNF326, dtype: int64
#
#
# ZNF329
# 0.0    92
# 1.0     6
# Name: ZNF329, dtype: int64
#
#
# ZNF330
# 0.0    135
# 1.0      9
# Name: ZNF330, dtype: int64
#
#
# ZNF331
# 0.0    132
# 1.0      4
# Name: ZNF331, dtype: int64
#
#
# ZNF33A
# 0.0    66
# 1.0     1
# Name: ZNF33A, dtype: int64
#
#
# ZNF346
# 0.0    136
# 1.0      8
# Name: ZNF346, dtype: int64
#
#
# ZNF358
# 0.0    140
# 1.0      4
# Name: ZNF358, dtype: int64
#
#
# ZNF362
# 0.0    137
# 1.0      7
# Name: ZNF362, dtype: int64
#
#
# ZNF37A
# 0.0    17
# Name: ZNF37A, dtype: int64
#
#
# ZNF384
# 0.0    138
# 1.0      6
# Name: ZNF384, dtype: int64
#
#
# ZNF385A
# 0.0    107
# 1.0      2
# Name: ZNF385A, dtype: int64
#
#
# ZNF391
# 0.0    89
# 1.0     4
# Name: ZNF391, dtype: int64
#
#
# ZNF395
# 0.0    108
# 1.0      1
# Name: ZNF395, dtype: int64
#
#
# ZNF397
# 0.0    122
# 1.0      4
# Name: ZNF397, dtype: int64
#
#
# ZNF407
# 0.0    127
# 1.0      2
# Name: ZNF407, dtype: int64
#
#
# ZNF408
# 0.0    82
# 1.0    13
# Name: ZNF408, dtype: int64
#
#
# ZNF41
# 0.0    53
# Name: ZNF41, dtype: int64
#
#
# ZNF410
# 0.0    133
# 1.0      2
# Name: ZNF410, dtype: int64
#
#
# ZNF414
# 0.0    134
# 1.0     10
# Name: ZNF414, dtype: int64
#
#
# ZNF416
# 0.0    6
# Name: ZNF416, dtype: int64
#
#
# ZNF417
# 0.0    68
# Name: ZNF417, dtype: int64
#
#
# ZNF418
# 0.0    24
# 1.0     1
# Name: ZNF418, dtype: int64
#
#
# ZNF423
# 0.0    123
# 1.0     12
# Name: ZNF423, dtype: int64
#
#
# ZNF428
# 0.0    140
# 1.0      4
# Name: ZNF428, dtype: int64
#
#
# ZNF430
# 0.0    27
# 1.0     4
# Name: ZNF430, dtype: int64
#
#
# ZNF431
# 0.0    68
# 1.0     2
# Name: ZNF431, dtype: int64
#
#
# ZNF432
# 0.0    29
# 1.0     3
# Name: ZNF432, dtype: int64
#
#
# ZNF436
# 0.0    138
# 1.0      6
# Name: ZNF436, dtype: int64
#
#
# ZNF444
# 0.0    127
# 1.0      1
# Name: ZNF444, dtype: int64
#
#
# ZNF446
# 0.0    129
# 1.0     15
# Name: ZNF446, dtype: int64
#
#
# ZNF451
# 0.0    136
# 1.0      8
# Name: ZNF451, dtype: int64
#
#
# ZNF460
# 0.0    140
# 1.0      4
# Name: ZNF460, dtype: int64
#
#
# ZNF462
# 0.0    133
# 1.0     11
# Name: ZNF462, dtype: int64
#
#
# ZNF467
# 0.0    78
# 1.0     6
# Name: ZNF467, dtype: int64
#
#
# ZNF48
# 0.0    123
# 1.0      3
# Name: ZNF48, dtype: int64
#
#
# ZNF480
# 0.0    29
# 1.0     2
# Name: ZNF480, dtype: int64
#
#
# ZNF501
# 0.0    60
# 1.0     1
# Name: ZNF501, dtype: int64
#
#
# ZNF502
# 0.0    8
# 1.0    1
# Name: ZNF502, dtype: int64
#
#
# ZNF503
# 0.0    144
# Name: ZNF503, dtype: int64
#
#
# ZNF506
# 0.0    15
# Name: ZNF506, dtype: int64
#
#
# ZNF507
# 0.0    55
# 1.0     2
# Name: ZNF507, dtype: int64
#
#
# ZNF511
# 0.0    140
# 1.0      4
# Name: ZNF511, dtype: int64
#
#
# ZNF512
# 0.0    143
# 1.0      1
# Name: ZNF512, dtype: int64
#
#
# ZNF512B
# 0.0    140
# 1.0      4
# Name: ZNF512B, dtype: int64
#
#
# ZNF516
# 0.0    140
# 1.0      4
# Name: ZNF516, dtype: int64
#
#
# ZNF525
# 0.0    25
# Name: ZNF525, dtype: int64
#
#
# ZNF526
# 0.0    135
# 1.0      8
# Name: ZNF526, dtype: int64
#
#
# ZNF532
# 0.0    138
# 1.0      6
# Name: ZNF532, dtype: int64
#
#
# ZNF543
# 0.0    16
# 1.0     1
# Name: ZNF543, dtype: int64
#
#
# ZNF548
# 0.0    16
# 1.0     2
# Name: ZNF548, dtype: int64
#
#
# ZNF551
# 0.0    22
# 1.0     3
# Name: ZNF551, dtype: int64
#
#
# ZNF552
# 0.0    125
# 1.0      1
# Name: ZNF552, dtype: int64
#
#
# ZNF561
# 0.0    23
# 1.0     1
# Name: ZNF561, dtype: int64
#
#
# ZNF562
# 0.0    18
# Name: ZNF562, dtype: int64
#
#
# ZNF565
# 0.0    78
# 1.0     5
# Name: ZNF565, dtype: int64
#
#
# ZNF568
# 0.0    16
# 1.0     2
# Name: ZNF568, dtype: int64
#
#
# ZNF570
# 0.0    24
# 1.0     3
# Name: ZNF570, dtype: int64
#
#
# ZNF574
# 0.0    138
# 1.0      6
# Name: ZNF574, dtype: int64
#
#
# ZNF575
# 0.0    32
# Name: ZNF575, dtype: int64
#
#
# ZNF579
# 0.0    134
# 1.0     10
# Name: ZNF579, dtype: int64
#
#
# ZNF580
# 0.0    80
# 1.0     7
# Name: ZNF580, dtype: int64
#
#
# ZNF581
# 0.0    130
# 1.0      5
# Name: ZNF581, dtype: int64
#
#
# ZNF584
# 0.0    24
# Name: ZNF584, dtype: int64
#
#
# ZNF586
# 0.0    26
# Name: ZNF586, dtype: int64
#
#
# ZNF587
# 0.0    102
# Name: ZNF587, dtype: int64
#
#
# ZNF589
# 0.0    80
# 1.0     7
# Name: ZNF589, dtype: int64
#
#
# ZNF592
# 0.0    138
# 1.0      6
# Name: ZNF592, dtype: int64
#
#
# ZNF593
# 0.0    138
# 1.0      6
# Name: ZNF593, dtype: int64
#
#
# ZNF595
# 0.0    18
# Name: ZNF595, dtype: int64
#
#
# ZNF597
# 0.0    89
# 1.0     4
# Name: ZNF597, dtype: int64
#
#
# ZNF598
# 0.0    143
# 1.0      1
# Name: ZNF598, dtype: int64
#
#
# ZNF605
# 0.0    144
# Name: ZNF605, dtype: int64
#
#
# ZNF608
# 0.0    135
# Name: ZNF608, dtype: int64
#
#
# ZNF609
# 0.0    135
# 1.0      9
# Name: ZNF609, dtype: int64
#
#
# ZNF611
# 0.0    73
# Name: ZNF611, dtype: int64
#
#
# ZNF618
# 0.0    140
# 1.0      4
# Name: ZNF618, dtype: int64
#
#
# ZNF622
# 0.0    140
# 1.0      4
# Name: ZNF622, dtype: int64
#
#
# ZNF623
# 0.0    49
# 1.0     1
# Name: ZNF623, dtype: int64
#
#
# ZNF627
# 0.0    98
# 1.0     4
# Name: ZNF627, dtype: int64
#
#
# ZNF629
# 0.0    142
# 1.0      2
# Name: ZNF629, dtype: int64
#
#
# ZNF630
# 0.0    26
# Name: ZNF630, dtype: int64
#
#
# ZNF638
# 0.0    141
# 1.0      3
# Name: ZNF638, dtype: int64
#
#
# ZNF639
# 0.0    120
# 1.0      6
# Name: ZNF639, dtype: int64
#
#
# ZNF644
# 0.0    137
# 1.0      7
# Name: ZNF644, dtype: int64
#
#
# ZNF649
# 0.0    102
# 1.0      8
# Name: ZNF649, dtype: int64
#
#
# ZNF652
# 0.0    140
# 1.0      4
# Name: ZNF652, dtype: int64
#
#
# ZNF654
# 0.0    131
# 1.0      4
# Name: ZNF654, dtype: int64
#
#
# ZNF655
# 0.0    105
# 1.0      6
# Name: ZNF655, dtype: int64
#
#
# ZNF658
# 0.0    35
# 1.0     3
# Name: ZNF658, dtype: int64
#
#
# ZNF660
# 0.0    25
# 1.0     1
# Name: ZNF660, dtype: int64
#
#
# ZNF662
# 0.0    59
# Name: ZNF662, dtype: int64
#
#
# ZNF664
# 0.0    109
# 1.0      3
# Name: ZNF664, dtype: int64
#
#
# ZNF664-RFLNA
# 0.0    34
# Name: ZNF664-RFLNA, dtype: int64
#
#
# ZNF668
# 0.0    122
# 1.0      7
# Name: ZNF668, dtype: int64
#
#
# ZNF672
# 0.0    100
# 1.0     10
# Name: ZNF672, dtype: int64
#
#
# ZNF687
# 0.0    142
# 1.0      2
# Name: ZNF687, dtype: int64
#
#
# ZNF688
# 0.0    134
# 1.0      1
# Name: ZNF688, dtype: int64
#
#
# ZNF69
# 0.0    7
# Name: ZNF69, dtype: int64
#
#
# ZNF691
# 0.0    141
# 1.0      3
# Name: ZNF691, dtype: int64
#
#
# ZNF7
# 0.0    46
# 1.0     5
# Name: ZNF7, dtype: int64
#
#
# ZNF701
# 0.0    50
# Name: ZNF701, dtype: int64
#
#
# ZNF703
# 0.0    137
# 1.0      7
# Name: ZNF703, dtype: int64
#
#
# ZNF704
# 0.0    143
# 1.0      1
# Name: ZNF704, dtype: int64
#
#
# ZNF706
# 0.0    139
# 1.0      5
# Name: ZNF706, dtype: int64
#
#
# ZNF713
# 0.0    80
# 1.0     6
# Name: ZNF713, dtype: int64
#
#
# ZNF737
# 0.0    17
# Name: ZNF737, dtype: int64
#
#
# ZNF740
# 0.0    142
# 1.0      2
# Name: ZNF740, dtype: int64
#
#
# ZNF746
# 0.0    128
# 1.0      6
# Name: ZNF746, dtype: int64
#
#
# ZNF76
# 0.0    129
# 1.0      6
# Name: ZNF76, dtype: int64
#
#
# ZNF761
# 0.0    34
# Name: ZNF761, dtype: int64
#
#
# ZNF765
# 0.0    76
# Name: ZNF765, dtype: int64
#
#
# ZNF768
# 0.0    141
# 1.0      3
# Name: ZNF768, dtype: int64
#
#
# ZNF771
# 0.0    132
# 1.0      4
# Name: ZNF771, dtype: int64
#
#
# ZNF772
# 0.0    8
# Name: ZNF772, dtype: int64
#
#
# ZNF773
# 0.0    34
# 1.0     1
# Name: ZNF773, dtype: int64
#
#
# ZNF776
# 0.0    64
# Name: ZNF776, dtype: int64
#
#
# ZNF777
# 0.0    100
# 1.0      1
# Name: ZNF777, dtype: int64
#
#
# ZNF780A
# 0.0    35
# 1.0     1
# Name: ZNF780A, dtype: int64
#
#
# ZNF784
# 0.0    68
# Name: ZNF784, dtype: int64
#
#
# ZNF787
# 0.0    137
# 1.0      7
# Name: ZNF787, dtype: int64
#
#
# ZNF79
# 0.0    9
# Name: ZNF79, dtype: int64
#
#
# ZNF8
# 0.0    136
# 1.0      8
# Name: ZNF8, dtype: int64
#
#
# ZNF800
# 0.0    143
# 1.0      1
# Name: ZNF800, dtype: int64
#
#
# ZNF805
# 0.0    9
# Name: ZNF805, dtype: int64
#
#
# ZNF813
# 0.0    41
# Name: ZNF813, dtype: int64
#
#
# ZNF816
# 0.0    26
# 1.0     1
# Name: ZNF816, dtype: int64
#
#
# ZNF827
# 0.0    137
# 1.0      7
# Name: ZNF827, dtype: int64
#
#
# ZNF830
# 0.0    142
# 1.0      2
# Name: ZNF830, dtype: int64
#
#
# ZNF837
# 0.0    56
# 1.0     2
# Name: ZNF837, dtype: int64
#
#
# ZNF84
# 0.0    92
# 1.0     1
# Name: ZNF84, dtype: int64
#
#
# ZNF845
# 0.0    55
# 1.0     3
# Name: ZNF845, dtype: int64
#
#
# ZNF852
# 0.0    52
# 1.0     7
# Name: ZNF852, dtype: int64
#
#
# ZNF888
# 0.0    41
# 1.0     2
# Name: ZNF888, dtype: int64
#
#
# ZNFX1
# 0.0    139
# 1.0      5
# Name: ZNFX1, dtype: int64
#
#
# ZNHIT1
# 0.0    136
# 1.0      8
# Name: ZNHIT1, dtype: int64
#
#
# ZNHIT2
# 0.0    140
# 1.0      4
# Name: ZNHIT2, dtype: int64
#
#
# ZNHIT3
# 0.0    126
# 1.0      1
# Name: ZNHIT3, dtype: int64
#
#
# ZNHIT6
# 0.0    143
# 1.0      1
# Name: ZNHIT6, dtype: int64
#
#
# ZNRD1
# 0.0    137
# 1.0      7
# Name: ZNRD1, dtype: int64
#
#
# ZNRF1
# 0.0    123
# 1.0      4
# Name: ZNRF1, dtype: int64
#
#
# ZNRF2
# 0.0    143
# 1.0      1
# Name: ZNRF2, dtype: int64
#
#
# ZPR1
# 0.0    142
# 1.0      2
# Name: ZPR1, dtype: int64
#
#
# ZRANB2
# 0.0    140
# 1.0      4
# Name: ZRANB2, dtype: int64
#
#
# ZRSR2
# 0.0    129
# 1.0      7
# Name: ZRSR2, dtype: int64
#
#
# ZSCAN12
# 0.0    42
# Name: ZSCAN12, dtype: int64
#
#
# ZSCAN18
# 0.0    142
# 1.0      2
# Name: ZSCAN18, dtype: int64
#
#
# ZSCAN2
# 0.0    74
# Name: ZSCAN2, dtype: int64
#
#
# ZSCAN21
# 0.0    130
# 1.0      7
# Name: ZSCAN21, dtype: int64
#
#
# ZSCAN26
# 0.0    142
# 1.0      2
# Name: ZSCAN26, dtype: int64
#
#
# ZSCAN30
# 0.0    50
# Name: ZSCAN30, dtype: int64
#
#
# ZSCAN31
# 0.0    106
# 1.0     11
# Name: ZSCAN31, dtype: int64
#
#
# ZSWIM8
# 0.0    139
# 1.0      5
# Name: ZSWIM8, dtype: int64
#
#
# ZSWIM9
# 0.0    99
# 1.0     1
# Name: ZSWIM9, dtype: int64
#
#
# ZW10
# 0.0    139
# 1.0      5
# Name: ZW10, dtype: int64
#
#
# ZWILCH
# 0.0    143
# 1.0      1
# Name: ZWILCH, dtype: int64
#
#
# ZWINT
# 0.0    112
# 1.0      6
# Name: ZWINT, dtype: int64
#
#
# ZXDC
# 0.0    139
# 1.0      5
# Name: ZXDC, dtype: int64
#
#
# ZYG11B
# 0.0    143
# 1.0      1
# Name: ZYG11B, dtype: int64
#
#
# ZYX
# 0.0    144
# Name: ZYX, dtype: int64
#
#
# ZZEF1
# 0.0    137
# 1.0      7
# Name: ZZEF1, dtype: int64
#
#
# ZZZ3
# 0.0    140
# 1.0      4
# Name: ZZZ3, dtype: int64

# %%
just_outliers_copy = prot_just_outliers.copy()
for col in prot_just_outliers.columns:
    if (len(prot_just_outliers[col].value_counts()) == 1):
        just_outliers_copy = just_outliers_copy.drop(col, axis=1)
print(just_outliers_copy.columns)
# Out:
# Index(['A2M', 'A2ML1', 'A4GALT', 'AAAS', 'AACS', 'AADAT', 'AAED1', 'AAGAB',
#        'AAK1', 'AAMDC',
#        ...
#        'ZSCAN31', 'ZSWIM8', 'ZSWIM9', 'ZW10', 'ZWILCH', 'ZWINT', 'ZXDC',
#        'ZYG11B', 'ZZEF1', 'ZZZ3'],
#       dtype='object', length=8883)

# %%
for col in just_outliers_copy.columns:
    print(col)
    print(just_outliers_copy[col].value_counts())
    print('\n')
# Out:
# A2M
# 0.0    143
# 1.0      1
# Name: A2M, dtype: int64
#
#
# A2ML1
# 0.0    124
# 1.0      2
# Name: A2ML1, dtype: int64
#
#
# A4GALT
# 0.0    93
# 1.0     3
# Name: A4GALT, dtype: int64
#
#
# AAAS
# 0.0    139
# 1.0      5
# Name: AAAS, dtype: int64
#
#
# AACS
# 0.0    143
# 1.0      1
# Name: AACS, dtype: int64
#
#
# AADAT
# 0.0    132
# 1.0      4
# Name: AADAT, dtype: int64
#
#
# AAED1
# 0.0    131
# 1.0      4
# Name: AAED1, dtype: int64
#
#
# AAGAB
# 0.0    141
# 1.0      3
# Name: AAGAB, dtype: int64
#
#
# AAK1
# 0.0    143
# 1.0      1
# Name: AAK1, dtype: int64
#
#
# AAMDC
# 0.0    142
# 1.0      2
# Name: AAMDC, dtype: int64
#
#
# AAMP
# 0.0    134
# 1.0     10
# Name: AAMP, dtype: int64
#
#
# AAR2
# 0.0    142
# 1.0      2
# Name: AAR2, dtype: int64
#
#
# AARS
# 0.0    142
# 1.0      2
# Name: AARS, dtype: int64
#
#
# AARS2
# 0.0    137
# 1.0      7
# Name: AARS2, dtype: int64
#
#
# AARSD1
# 0.0    135
# 1.0      9
# Name: AARSD1, dtype: int64
#
#
# AASDHPPT
# 0.0    141
# 1.0      3
# Name: AASDHPPT, dtype: int64
#
#
# AATF
# 0.0    140
# 1.0      4
# Name: AATF, dtype: int64
#
#
# ABAT
# 0.0    141
# 1.0      3
# Name: ABAT, dtype: int64
#
#
# ABCB1
# 0.0    143
# 1.0      1
# Name: ABCB1, dtype: int64
#
#
# ABCB10
# 0.0    137
# 1.0      7
# Name: ABCB10, dtype: int64
#
#
# ABCB6
# 0.0    134
# 1.0     10
# Name: ABCB6, dtype: int64
#
#
# ABCB7
# 0.0    141
# 1.0      3
# Name: ABCB7, dtype: int64
#
#
# ABCB8
# 0.0    140
# 1.0      4
# Name: ABCB8, dtype: int64
#
#
# ABCC1
# 0.0    142
# 1.0      2
# Name: ABCC1, dtype: int64
#
#
# ABCC10
# 0.0    129
# 1.0      6
# Name: ABCC10, dtype: int64
#
#
# ABCC3
# 0.0    141
# 1.0      3
# Name: ABCC3, dtype: int64
#
#
# ABCC4
# 0.0    142
# 1.0      2
# Name: ABCC4, dtype: int64
#
#
# ABCD1
# 0.0    138
# 1.0      6
# Name: ABCD1, dtype: int64
#
#
# ABCD3
# 0.0    143
# 1.0      1
# Name: ABCD3, dtype: int64
#
#
# ABCD4
# 0.0    138
# 1.0      6
# Name: ABCD4, dtype: int64
#
#
# ABCE1
# 0.0    141
# 1.0      3
# Name: ABCE1, dtype: int64
#
#
# ABCF1
# 0.0    142
# 1.0      2
# Name: ABCF1, dtype: int64
#
#
# ABCF2
# 0.0    142
# 1.0      2
# Name: ABCF2, dtype: int64
#
#
# ABCF3
# 0.0    143
# 1.0      1
# Name: ABCF3, dtype: int64
#
#
# ABCG1
# 0.0    142
# 1.0      2
# Name: ABCG1, dtype: int64
#
#
# ABHD10
# 0.0    143
# 1.0      1
# Name: ABHD10, dtype: int64
#
#
# ABHD11
# 0.0    143
# 1.0      1
# Name: ABHD11, dtype: int64
#
#
# ABHD12
# 0.0    139
# 1.0      5
# Name: ABHD12, dtype: int64
#
#
# ABHD13
# 0.0    129
# 1.0      6
# Name: ABHD13, dtype: int64
#
#
# ABHD14A
# 0.0    52
# 1.0     5
# Name: ABHD14A, dtype: int64
#
#
# ABHD14A-ACY1
# 0.0    143
# 1.0      1
# Name: ABHD14A-ACY1, dtype: int64
#
#
# ABHD14B
# 0.0    142
# 1.0      2
# Name: ABHD14B, dtype: int64
#
#
# ABHD16A
# 0.0    141
# 1.0      3
# Name: ABHD16A, dtype: int64
#
#
# ABHD17A
# 0.0    71
# 1.0     4
# Name: ABHD17A, dtype: int64
#
#
# ABHD17B
# 0.0    130
# 1.0      7
# Name: ABHD17B, dtype: int64
#
#
# ABHD2
# 0.0    49
# 1.0     3
# Name: ABHD2, dtype: int64
#
#
# ABHD3
# 0.0    115
# 1.0      3
# Name: ABHD3, dtype: int64
#
#
# ABHD4
# 0.0    143
# 1.0      1
# Name: ABHD4, dtype: int64
#
#
# ABHD5
# 0.0    134
# 1.0      2
# Name: ABHD5, dtype: int64
#
#
# ABHD6
# 0.0    140
# 1.0      4
# Name: ABHD6, dtype: int64
#
#
# ABI1
# 0.0    138
# 1.0      6
# Name: ABI1, dtype: int64
#
#
# ABI2
# 0.0    143
# 1.0      1
# Name: ABI2, dtype: int64
#
#
# ABI3
# 0.0    138
# 1.0      6
# Name: ABI3, dtype: int64
#
#
# ABL2
# 0.0    141
# 1.0      3
# Name: ABL2, dtype: int64
#
#
# ABLIM2
# 0.0    132
# 1.0      3
# Name: ABLIM2, dtype: int64
#
#
# ABO
# 0.0    13
# 1.0     2
# Name: ABO, dtype: int64
#
#
# ABR
# 0.0    139
# 1.0      5
# Name: ABR, dtype: int64
#
#
# ABRACL
# 0.0    140
# 1.0      4
# Name: ABRACL, dtype: int64
#
#
# ABRAXAS1
# 0.0    141
# 1.0      3
# Name: ABRAXAS1, dtype: int64
#
#
# ABRAXAS2
# 0.0    140
# 1.0      4
# Name: ABRAXAS2, dtype: int64
#
#
# ABT1
# 0.0    143
# 1.0      1
# Name: ABT1, dtype: int64
#
#
# ABTB2
# 0.0    132
# 1.0      3
# Name: ABTB2, dtype: int64
#
#
# ACAA1
# 0.0    140
# 1.0      4
# Name: ACAA1, dtype: int64
#
#
# ACAA2
# 0.0    136
# 1.0      8
# Name: ACAA2, dtype: int64
#
#
# ACAD11
# 0.0    143
# 1.0      1
# Name: ACAD11, dtype: int64
#
#
# ACAD8
# 0.0    137
# 1.0      7
# Name: ACAD8, dtype: int64
#
#
# ACAD9
# 0.0    141
# 1.0      3
# Name: ACAD9, dtype: int64
#
#
# ACADL
# 0.0    76
# 1.0     3
# Name: ACADL, dtype: int64
#
#
# ACADS
# 0.0    142
# 1.0      2
# Name: ACADS, dtype: int64
#
#
# ACADSB
# 0.0    142
# 1.0      2
# Name: ACADSB, dtype: int64
#
#
# ACADVL
# 0.0    140
# 1.0      4
# Name: ACADVL, dtype: int64
#
#
# ACAP1
# 0.0    141
# 1.0      3
# Name: ACAP1, dtype: int64
#
#
# ACAP2
# 0.0    142
# 1.0      2
# Name: ACAP2, dtype: int64
#
#
# ACAP3
# 0.0    74
# 1.0     3
# Name: ACAP3, dtype: int64
#
#
# ACAT1
# 0.0    142
# 1.0      2
# Name: ACAT1, dtype: int64
#
#
# ACAT2
# 0.0    142
# 1.0      2
# Name: ACAT2, dtype: int64
#
#
# ACD
# 0.0    139
# 1.0      5
# Name: ACD, dtype: int64
#
#
# ACE
# 0.0    143
# 1.0      1
# Name: ACE, dtype: int64
#
#
# ACIN1
# 0.0    141
# 1.0      3
# Name: ACIN1, dtype: int64
#
#
# ACO1
# 0.0    141
# 1.0      3
# Name: ACO1, dtype: int64
#
#
# ACO2
# 0.0    142
# 1.0      2
# Name: ACO2, dtype: int64
#
#
# ACOT1
# 0.0    133
# 1.0      2
# Name: ACOT1, dtype: int64
#
#
# ACOT11
# 0.0    140
# 1.0      4
# Name: ACOT11, dtype: int64
#
#
# ACOT13
# 0.0    142
# 1.0      2
# Name: ACOT13, dtype: int64
#
#
# ACOT2
# 0.0    24
# 1.0     2
# Name: ACOT2, dtype: int64
#
#
# ACOT4
# 0.0    85
# 1.0     5
# Name: ACOT4, dtype: int64
#
#
# ACOT7
# 0.0    143
# 1.0      1
# Name: ACOT7, dtype: int64
#
#
# ACOX1
# 0.0    143
# 1.0      1
# Name: ACOX1, dtype: int64
#
#
# ACOX2
# 0.0    129
# 1.0      7
# Name: ACOX2, dtype: int64
#
#
# ACP2
# 0.0    138
# 1.0      6
# Name: ACP2, dtype: int64
#
#
# ACP5
# 0.0    135
# 1.0      9
# Name: ACP5, dtype: int64
#
#
# ACP6
# 0.0    131
# 1.0     13
# Name: ACP6, dtype: int64
#
#
# ACPP
# 0.0    134
# 1.0      3
# Name: ACPP, dtype: int64
#
#
# ACSF3
# 0.0    142
# 1.0      2
# Name: ACSF3, dtype: int64
#
#
# ACSL1
# 0.0    129
# 1.0     15
# Name: ACSL1, dtype: int64
#
#
# ACSL3
# 0.0    142
# 1.0      2
# Name: ACSL3, dtype: int64
#
#
# ACSL4
# 0.0    143
# 1.0      1
# Name: ACSL4, dtype: int64
#
#
# ACSS1
# 0.0    136
# 1.0      8
# Name: ACSS1, dtype: int64
#
#
# ACSS2
# 0.0    140
# 1.0      4
# Name: ACSS2, dtype: int64
#
#
# ACTA1
# 0.0    129
# 1.0      2
# Name: ACTA1, dtype: int64
#
#
# ACTA2
# 0.0    141
# 1.0      3
# Name: ACTA2, dtype: int64
#
#
# ACTG1
# 0.0    143
# 1.0      1
# Name: ACTG1, dtype: int64
#
#
# ACTG2
# 0.0    137
# 1.0      7
# Name: ACTG2, dtype: int64
#
#
# ACTL6A
# 0.0    142
# 1.0      2
# Name: ACTL6A, dtype: int64
#
#
# ACTL8
# 0.0    40
# 1.0     1
# Name: ACTL8, dtype: int64
#
#
# ACTR10
# 0.0    138
# 1.0      6
# Name: ACTR10, dtype: int64
#
#
# ACTR1A
# 0.0    142
# 1.0      2
# Name: ACTR1A, dtype: int64
#
#
# ACTR1B
# 0.0    141
# 1.0      3
# Name: ACTR1B, dtype: int64
#
#
# ACTR2
# 0.0    143
# 1.0      1
# Name: ACTR2, dtype: int64
#
#
# ACTR3
# 0.0    134
# 1.0     10
# Name: ACTR3, dtype: int64
#
#
# ACTR5
# 0.0    142
# 1.0      2
# Name: ACTR5, dtype: int64
#
#
# ACTR6
# 0.0    140
# 1.0      4
# Name: ACTR6, dtype: int64
#
#
# ACTR8
# 0.0    138
# 1.0      6
# Name: ACTR8, dtype: int64
#
#
# ACVR1
# 0.0    130
# 1.0      6
# Name: ACVR1, dtype: int64
#
#
# ACY3
# 0.0    120
# 1.0      6
# Name: ACY3, dtype: int64
#
#
# ACYP1
# 0.0    140
# 1.0      4
# Name: ACYP1, dtype: int64
#
#
# ACYP2
# 0.0    130
# 1.0     14
# Name: ACYP2, dtype: int64
#
#
# ADA
# 0.0    142
# 1.0      2
# Name: ADA, dtype: int64
#
#
# ADA2
# 0.0    140
# 1.0      4
# Name: ADA2, dtype: int64
#
#
# ADAL
# 0.0    120
# 1.0      9
# Name: ADAL, dtype: int64
#
#
# ADAM10
# 0.0    143
# 1.0      1
# Name: ADAM10, dtype: int64
#
#
# ADAM15
# 0.0    140
# 1.0      4
# Name: ADAM15, dtype: int64
#
#
# ADAM17
# 0.0    142
# 1.0      2
# Name: ADAM17, dtype: int64
#
#
# ADAMDEC1
# 0.0    83
# 1.0     1
# Name: ADAMDEC1, dtype: int64
#
#
# ADAMTS1
# 0.0    143
# 1.0      1
# Name: ADAMTS1, dtype: int64
#
#
# ADAMTS15
# 0.0    49
# 1.0     1
# Name: ADAMTS15, dtype: int64
#
#
# ADAMTS2
# 0.0    131
# 1.0      4
# Name: ADAMTS2, dtype: int64
#
#
# ADAMTS8
# 0.0    39
# 1.0     2
# Name: ADAMTS8, dtype: int64
#
#
# ADAMTS9
# 0.0    68
# 1.0     2
# Name: ADAMTS9, dtype: int64
#
#
# ADAMTSL1
# 0.0    132
# 1.0      3
# Name: ADAMTSL1, dtype: int64
#
#
# ADAMTSL2
# 0.0    132
# 1.0      3
# Name: ADAMTSL2, dtype: int64
#
#
# ADAP1
# 0.0    138
# 1.0      6
# Name: ADAP1, dtype: int64
#
#
# ADAP2
# 0.0    71
# 1.0     7
# Name: ADAP2, dtype: int64
#
#
# ADAR
# 0.0    141
# 1.0      3
# Name: ADAR, dtype: int64
#
#
# ADAT1
# 0.0    131
# 1.0      4
# Name: ADAT1, dtype: int64
#
#
# ADAT2
# 0.0    141
# 1.0      3
# Name: ADAT2, dtype: int64
#
#
# ADAT3
# 0.0    142
# 1.0      2
# Name: ADAT3, dtype: int64
#
#
# ADCK1
# 0.0    143
# 1.0      1
# Name: ADCK1, dtype: int64
#
#
# ADCK5
# 0.0    57
# 1.0     4
# Name: ADCK5, dtype: int64
#
#
# ADCY3
# 0.0    64
# 1.0     3
# Name: ADCY3, dtype: int64
#
#
# ADCY5
# 0.0    37
# 1.0     4
# Name: ADCY5, dtype: int64
#
#
# ADCY6
# 0.0    125
# 1.0      1
# Name: ADCY6, dtype: int64
#
#
# ADD1
# 0.0    138
# 1.0      6
# Name: ADD1, dtype: int64
#
#
# ADD3
# 0.0    134
# 1.0     10
# Name: ADD3, dtype: int64
#
#
# ADGRA3
# 0.0    119
# 1.0      7
# Name: ADGRA3, dtype: int64
#
#
# ADGRE2
# 0.0    108
# 1.0      5
# Name: ADGRE2, dtype: int64
#
#
# ADGRF5
# 0.0    123
# 1.0      3
# Name: ADGRF5, dtype: int64
#
#
# ADGRG1
# 0.0    142
# 1.0      2
# Name: ADGRG1, dtype: int64
#
#
# ADGRG2
# 0.0    108
# 1.0      1
# Name: ADGRG2, dtype: int64
#
#
# ADGRG3
# 0.0    47
# 1.0     1
# Name: ADGRG3, dtype: int64
#
#
# ADGRL1
# 0.0    106
# 1.0      4
# Name: ADGRL1, dtype: int64
#
#
# ADGRL2
# 0.0    131
# 1.0     13
# Name: ADGRL2, dtype: int64
#
#
# ADGRL3
# 0.0    87
# 1.0     3
# Name: ADGRL3, dtype: int64
#
#
# ADH1A
# 0.0    101
# 1.0      2
# Name: ADH1A, dtype: int64
#
#
# ADH1B
# 0.0    141
# 1.0      3
# Name: ADH1B, dtype: int64
#
#
# ADH1C
# 0.0    141
# 1.0      3
# Name: ADH1C, dtype: int64
#
#
# ADH4
# 0.0    123
# 1.0      3
# Name: ADH4, dtype: int64
#
#
# ADH5
# 0.0    141
# 1.0      3
# Name: ADH5, dtype: int64
#
#
# ADH6
# 0.0    63
# 1.0     3
# Name: ADH6, dtype: int64
#
#
# ADH7
# 0.0    39
# 1.0     1
# Name: ADH7, dtype: int64
#
#
# ADHFE1
# 0.0    17
# 1.0     1
# Name: ADHFE1, dtype: int64
#
#
# ADI1
# 0.0    143
# 1.0      1
# Name: ADI1, dtype: int64
#
#
# ADIPOQ
# 0.0    143
# 1.0      1
# Name: ADIPOQ, dtype: int64
#
#
# ADIPOR1
# 0.0    25
# 1.0     1
# Name: ADIPOR1, dtype: int64
#
#
# ADIRF
# 0.0    143
# 1.0      1
# Name: ADIRF, dtype: int64
#
#
# ADK
# 0.0    139
# 1.0      5
# Name: ADK, dtype: int64
#
#
# ADM
# 0.0    67
# 1.0     1
# Name: ADM, dtype: int64
#
#
# ADNP
# 0.0    139
# 1.0      5
# Name: ADNP, dtype: int64
#
#
# ADPRH
# 0.0    138
# 1.0      6
# Name: ADPRH, dtype: int64
#
#
# ADPRHL2
# 0.0    143
# 1.0      1
# Name: ADPRHL2, dtype: int64
#
#
# ADPRM
# 0.0    34
# 1.0     2
# Name: ADPRM, dtype: int64
#
#
# ADRA2A
# 0.0    41
# 1.0     1
# Name: ADRA2A, dtype: int64
#
#
# ADRM1
# 0.0    142
# 1.0      2
# Name: ADRM1, dtype: int64
#
#
# ADSL
# 0.0    133
# 1.0     11
# Name: ADSL, dtype: int64
#
#
# ADSS
# 0.0    143
# 1.0      1
# Name: ADSS, dtype: int64
#
#
# ADSSL1
# 0.0    138
# 1.0      6
# Name: ADSSL1, dtype: int64
#
#
# AES
# 0.0    138
# 1.0      6
# Name: AES, dtype: int64
#
#
# AFAP1L1
# 0.0    80
# 1.0     2
# Name: AFAP1L1, dtype: int64
#
#
# AFF1
# 0.0    137
# 1.0      7
# Name: AFF1, dtype: int64
#
#
# AFF4
# 0.0    138
# 1.0      6
# Name: AFF4, dtype: int64
#
#
# AFG1L
# 0.0    124
# 1.0     11
# Name: AFG1L, dtype: int64
#
#
# AFG3L2
# 0.0    140
# 1.0      4
# Name: AFG3L2, dtype: int64
#
#
# AFMID
# 0.0    138
# 1.0      6
# Name: AFMID, dtype: int64
#
#
# AFTPH
# 0.0    138
# 1.0      6
# Name: AFTPH, dtype: int64
#
#
# AGA
# 0.0    143
# 1.0      1
# Name: AGA, dtype: int64
#
#
# AGAP1
# 0.0    136
# 1.0      8
# Name: AGAP1, dtype: int64
#
#
# AGAP2
# 0.0    115
# 1.0      2
# Name: AGAP2, dtype: int64
#
#
# AGAP3
# 0.0    142
# 1.0      2
# Name: AGAP3, dtype: int64
#
#
# AGFG1
# 0.0    137
# 1.0      7
# Name: AGFG1, dtype: int64
#
#
# AGFG2
# 0.0    143
# 1.0      1
# Name: AGFG2, dtype: int64
#
#
# AGGF1
# 0.0    140
# 1.0      4
# Name: AGGF1, dtype: int64
#
#
# AGK
# 0.0    141
# 1.0      3
# Name: AGK, dtype: int64
#
#
# AGL
# 0.0    136
# 1.0      8
# Name: AGL, dtype: int64
#
#
# AGO3
# 0.0    143
# 1.0      1
# Name: AGO3, dtype: int64
#
#
# AGO4
# 0.0    133
# 1.0      2
# Name: AGO4, dtype: int64
#
#
# AGPAT1
# 0.0    131
# 1.0     13
# Name: AGPAT1, dtype: int64
#
#
# AGPAT2
# 0.0    141
# 1.0      3
# Name: AGPAT2, dtype: int64
#
#
# AGPAT3
# 0.0    138
# 1.0      6
# Name: AGPAT3, dtype: int64
#
#
# AGPAT4
# 0.0    120
# 1.0      6
# Name: AGPAT4, dtype: int64
#
#
# AGPAT5
# 0.0    140
# 1.0      4
# Name: AGPAT5, dtype: int64
#
#
# AGR2
# 0.0    142
# 1.0      2
# Name: AGR2, dtype: int64
#
#
# AGR3
# 0.0    142
# 1.0      2
# Name: AGR3, dtype: int64
#
#
# AGRN
# 0.0    142
# 1.0      2
# Name: AGRN, dtype: int64
#
#
# AGTPBP1
# 0.0    140
# 1.0      4
# Name: AGTPBP1, dtype: int64
#
#
# AGTRAP
# 0.0    137
# 1.0      7
# Name: AGTRAP, dtype: int64
#
#
# AHCTF1
# 0.0    138
# 1.0      6
# Name: AHCTF1, dtype: int64
#
#
# AHCY
# 0.0    143
# 1.0      1
# Name: AHCY, dtype: int64
#
#
# AHCYL1
# 0.0    135
# 1.0      9
# Name: AHCYL1, dtype: int64
#
#
# AHCYL2
# 0.0    143
# 1.0      1
# Name: AHCYL2, dtype: int64
#
#
# AHDC1
# 0.0    143
# 1.0      1
# Name: AHDC1, dtype: int64
#
#
# AHR
# 0.0    142
# 1.0      2
# Name: AHR, dtype: int64
#
#
# AHSA1
# 0.0    140
# 1.0      4
# Name: AHSA1, dtype: int64
#
#
# AHSG
# 0.0    143
# 1.0      1
# Name: AHSG, dtype: int64
#
#
# AHSP
# 0.0    143
# 1.0      1
# Name: AHSP, dtype: int64
#
#
# AIDA
# 0.0    143
# 1.0      1
# Name: AIDA, dtype: int64
#
#
# AIF1
# 0.0    142
# 1.0      2
# Name: AIF1, dtype: int64
#
#
# AIF1L
# 0.0    140
# 1.0      4
# Name: AIF1L, dtype: int64
#
#
# AIFM1
# 0.0    143
# 1.0      1
# Name: AIFM1, dtype: int64
#
#
# AIG1
# 0.0    99
# 1.0     6
# Name: AIG1, dtype: int64
#
#
# AIMP2
# 0.0    139
# 1.0      5
# Name: AIMP2, dtype: int64
#
#
# AIP
# 0.0    143
# 1.0      1
# Name: AIP, dtype: int64
#
#
# AJUBA
# 0.0    136
# 1.0      8
# Name: AJUBA, dtype: int64
#
#
# AK1
# 0.0    141
# 1.0      3
# Name: AK1, dtype: int64
#
#
# AK2
# 0.0    141
# 1.0      3
# Name: AK2, dtype: int64
#
#
# AK3
# 0.0    141
# 1.0      3
# Name: AK3, dtype: int64
#
#
# AK4
# 0.0    142
# 1.0      2
# Name: AK4, dtype: int64
#
#
# AK6
# 0.0    143
# 1.0      1
# Name: AK6, dtype: int64
#
#
# AK7
# 0.0    99
# 1.0     1
# Name: AK7, dtype: int64
#
#
# AKAP10
# 0.0    138
# 1.0      6
# Name: AKAP10, dtype: int64
#
#
# AKAP13
# 0.0    137
# 1.0      7
# Name: AKAP13, dtype: int64
#
#
# AKAP17A
# 0.0    134
# 1.0     10
# Name: AKAP17A, dtype: int64
#
#
# AKAP5
# 0.0    98
# 1.0     4
# Name: AKAP5, dtype: int64
#
#
# AKAP7
# 0.0    143
# 1.0      1
# Name: AKAP7, dtype: int64
#
#
# AKAP8
# 0.0    141
# 1.0      3
# Name: AKAP8, dtype: int64
#
#
# AKAP8L
# 0.0    140
# 1.0      4
# Name: AKAP8L, dtype: int64
#
#
# AKAP9
# 0.0    142
# 1.0      2
# Name: AKAP9, dtype: int64
#
#
# AKR1A1
# 0.0    137
# 1.0      7
# Name: AKR1A1, dtype: int64
#
#
# AKR1B1
# 0.0    142
# 1.0      2
# Name: AKR1B1, dtype: int64
#
#
# AKR1B10
# 0.0    143
# 1.0      1
# Name: AKR1B10, dtype: int64
#
#
# AKR1C1
# 0.0    132
# 1.0      3
# Name: AKR1C1, dtype: int64
#
#
# AKR1C3
# 0.0    132
# 1.0     12
# Name: AKR1C3, dtype: int64
#
#
# AKR1C4
# 0.0    40
# 1.0     2
# Name: AKR1C4, dtype: int64
#
#
# AKR1D1
# 0.0    135
# 1.0      9
# Name: AKR1D1, dtype: int64
#
#
# AKR7A2
# 0.0    142
# 1.0      2
# Name: AKR7A2, dtype: int64
#
#
# AKR7A3
# 0.0    125
# 1.0      2
# Name: AKR7A3, dtype: int64
#
#
# AKT1
# 0.0    136
# 1.0      8
# Name: AKT1, dtype: int64
#
#
# AKT1S1
# 0.0    139
# 1.0      5
# Name: AKT1S1, dtype: int64
#
#
# AKT2
# 0.0    143
# 1.0      1
# Name: AKT2, dtype: int64
#
#
# AKTIP
# 0.0    141
# 1.0      3
# Name: AKTIP, dtype: int64
#
#
# ALAD
# 0.0    142
# 1.0      2
# Name: ALAD, dtype: int64
#
#
# ALAS1
# 0.0    98
# 1.0     5
# Name: ALAS1, dtype: int64
#
#
# ALCAM
# 0.0    143
# 1.0      1
# Name: ALCAM, dtype: int64
#
#
# ALDH16A1
# 0.0    139
# 1.0      5
# Name: ALDH16A1, dtype: int64
#
#
# ALDH1A3
# 0.0    138
# 1.0      6
# Name: ALDH1A3, dtype: int64
#
#
# ALDH2
# 0.0    140
# 1.0      4
# Name: ALDH2, dtype: int64
#
#
# ALDH3A1
# 0.0    141
# 1.0      3
# Name: ALDH3A1, dtype: int64
#
#
# ALDH3A2
# 0.0    142
# 1.0      2
# Name: ALDH3A2, dtype: int64
#
#
# ALDH3B1
# 0.0    143
# 1.0      1
# Name: ALDH3B1, dtype: int64
#
#
# ALDH4A1
# 0.0    138
# 1.0      6
# Name: ALDH4A1, dtype: int64
#
#
# ALDH5A1
# 0.0    141
# 1.0      3
# Name: ALDH5A1, dtype: int64
#
#
# ALDH6A1
# 0.0    142
# 1.0      2
# Name: ALDH6A1, dtype: int64
#
#
# ALDH7A1
# 0.0    138
# 1.0      6
# Name: ALDH7A1, dtype: int64
#
#
# ALDOA
# 0.0    138
# 1.0      6
# Name: ALDOA, dtype: int64
#
#
# ALDOB
# 0.0    132
# 1.0      6
# Name: ALDOB, dtype: int64
#
#
# ALG1
# 0.0    138
# 1.0      6
# Name: ALG1, dtype: int64
#
#
# ALG10
# 0.0    93
# 1.0     7
# Name: ALG10, dtype: int64
#
#
# ALG11
# 0.0    129
# 1.0     15
# Name: ALG11, dtype: int64
#
#
# ALG12
# 0.0    123
# 1.0     12
# Name: ALG12, dtype: int64
#
#
# ALG14
# 0.0    138
# 1.0      6
# Name: ALG14, dtype: int64
#
#
# ALG2
# 0.0    138
# 1.0      6
# Name: ALG2, dtype: int64
#
#
# ALG5
# 0.0    141
# 1.0      3
# Name: ALG5, dtype: int64
#
#
# ALG6
# 0.0    137
# 1.0      7
# Name: ALG6, dtype: int64
#
#
# ALG8
# 0.0    131
# 1.0      4
# Name: ALG8, dtype: int64
#
#
# ALG9
# 0.0    136
# 1.0      8
# Name: ALG9, dtype: int64
#
#
# ALKBH1
# 0.0    133
# 1.0      3
# Name: ALKBH1, dtype: int64
#
#
# ALKBH2
# 0.0    125
# 1.0     10
# Name: ALKBH2, dtype: int64
#
#
# ALKBH3
# 0.0    74
# 1.0     3
# Name: ALKBH3, dtype: int64
#
#
# ALKBH4
# 0.0    143
# 1.0      1
# Name: ALKBH4, dtype: int64
#
#
# ALKBH5
# 0.0    137
# 1.0      7
# Name: ALKBH5, dtype: int64
#
#
# ALKBH6
# 0.0    57
# 1.0     3
# Name: ALKBH6, dtype: int64
#
#
# ALKBH7
# 0.0    134
# 1.0      3
# Name: ALKBH7, dtype: int64
#
#
# ALKBH8
# 0.0    142
# 1.0      2
# Name: ALKBH8, dtype: int64
#
#
# ALMS1
# 0.0    141
# 1.0      3
# Name: ALMS1, dtype: int64
#
#
# ALOX15
# 0.0    134
# 1.0      1
# Name: ALOX15, dtype: int64
#
#
# ALOX15B
# 0.0    42
# 1.0     2
# Name: ALOX15B, dtype: int64
#
#
# ALOX5
# 0.0    139
# 1.0      5
# Name: ALOX5, dtype: int64
#
#
# ALOX5AP
# 0.0    141
# 1.0      3
# Name: ALOX5AP, dtype: int64
#
#
# ALPG
# 0.0    129
# 1.0      9
# Name: ALPG, dtype: int64
#
#
# ALPK1
# 0.0    78
# 1.0     7
# Name: ALPK1, dtype: int64
#
#
# ALPL
# 0.0    142
# 1.0      2
# Name: ALPL, dtype: int64
#
#
# ALPP
# 0.0    126
# 1.0     18
# Name: ALPP, dtype: int64
#
#
# ALS2
# 0.0    138
# 1.0      6
# Name: ALS2, dtype: int64
#
#
# ALYREF
# 0.0    137
# 1.0      7
# Name: ALYREF, dtype: int64
#
#
# AMACR
# 0.0    143
# 1.0      1
# Name: AMACR, dtype: int64
#
#
# AMBRA1
# 0.0    136
# 1.0      8
# Name: AMBRA1, dtype: int64
#
#
# AMD1
# 0.0    84
# 1.0     1
# Name: AMD1, dtype: int64
#
#
# AMDHD2
# 0.0    143
# 1.0      1
# Name: AMDHD2, dtype: int64
#
#
# AMFR
# 0.0    127
# 1.0      8
# Name: AMFR, dtype: int64
#
#
# AMMECR1
# 0.0    33
# 1.0     1
# Name: AMMECR1, dtype: int64
#
#
# AMMECR1L
# 0.0    41
# 1.0     1
# Name: AMMECR1L, dtype: int64
#
#
# AMN1
# 0.0    116
# 1.0      3
# Name: AMN1, dtype: int64
#
#
# AMOT
# 0.0    141
# 1.0      3
# Name: AMOT, dtype: int64
#
#
# AMOTL1
# 0.0    142
# 1.0      2
# Name: AMOTL1, dtype: int64
#
#
# AMOTL2
# 0.0    137
# 1.0      7
# Name: AMOTL2, dtype: int64
#
#
# AMPD2
# 0.0    142
# 1.0      2
# Name: AMPD2, dtype: int64
#
#
# AMPD3
# 0.0    143
# 1.0      1
# Name: AMPD3, dtype: int64
#
#
# AMT
# 0.0    143
# 1.0      1
# Name: AMT, dtype: int64
#
#
# AMY1B
# 0.0    143
# 1.0      1
# Name: AMY1B, dtype: int64
#
#
# AMZ2
# 0.0    125
# 1.0      2
# Name: AMZ2, dtype: int64
#
#
# ANAPC1
# 0.0    139
# 1.0      5
# Name: ANAPC1, dtype: int64
#
#
# ANAPC10
# 0.0    138
# 1.0      6
# Name: ANAPC10, dtype: int64
#
#
# ANAPC11
# 0.0    132
# 1.0      3
# Name: ANAPC11, dtype: int64
#
#
# ANAPC13
# 0.0    133
# 1.0     10
# Name: ANAPC13, dtype: int64
#
#
# ANAPC15
# 0.0    39
# 1.0     5
# Name: ANAPC15, dtype: int64
#
#
# ANAPC16
# 0.0    138
# 1.0      6
# Name: ANAPC16, dtype: int64
#
#
# ANAPC2
# 0.0    140
# 1.0      4
# Name: ANAPC2, dtype: int64
#
#
# ANAPC4
# 0.0    140
# 1.0      4
# Name: ANAPC4, dtype: int64
#
#
# ANAPC5
# 0.0    143
# 1.0      1
# Name: ANAPC5, dtype: int64
#
#
# ANGEL2
# 0.0    141
# 1.0      3
# Name: ANGEL2, dtype: int64
#
#
# ANGPT2
# 0.0    121
# 1.0      5
# Name: ANGPT2, dtype: int64
#
#
# ANGPTL1
# 0.0    39
# 1.0     1
# Name: ANGPTL1, dtype: int64
#
#
# ANK3
# 0.0    134
# 1.0     10
# Name: ANK3, dtype: int64
#
#
# ANKFY1
# 0.0    139
# 1.0      5
# Name: ANKFY1, dtype: int64
#
#
# ANKHD1
# 0.0    135
# 1.0      1
# Name: ANKHD1, dtype: int64
#
#
# ANKHD1-EIF4EBP3
# 0.0    103
# 1.0      2
# Name: ANKHD1-EIF4EBP3, dtype: int64
#
#
# ANKIB1
# 0.0    142
# 1.0      2
# Name: ANKIB1, dtype: int64
#
#
# ANKLE2
# 0.0    143
# 1.0      1
# Name: ANKLE2, dtype: int64
#
#
# ANKMY2
# 0.0    142
# 1.0      2
# Name: ANKMY2, dtype: int64
#
#
# ANKRD10
# 0.0    137
# 1.0      7
# Name: ANKRD10, dtype: int64
#
#
# ANKRD11
# 0.0    139
# 1.0      5
# Name: ANKRD11, dtype: int64
#
#
# ANKRD12
# 0.0    108
# 1.0      9
# Name: ANKRD12, dtype: int64
#
#
# ANKRD13A
# 0.0    142
# 1.0      2
# Name: ANKRD13A, dtype: int64
#
#
# ANKRD13D
# 0.0    137
# 1.0      7
# Name: ANKRD13D, dtype: int64
#
#
# ANKRD16
# 0.0    136
# 1.0      8
# Name: ANKRD16, dtype: int64
#
#
# ANKRD17
# 0.0    142
# 1.0      2
# Name: ANKRD17, dtype: int64
#
#
# ANKRD22
# 0.0    142
# 1.0      2
# Name: ANKRD22, dtype: int64
#
#
# ANKRD26
# 0.0    128
# 1.0      7
# Name: ANKRD26, dtype: int64
#
#
# ANKRD27
# 0.0    143
# 1.0      1
# Name: ANKRD27, dtype: int64
#
#
# ANKRD35
# 0.0    141
# 1.0      3
# Name: ANKRD35, dtype: int64
#
#
# ANKRD39
# 0.0    119
# 1.0     16
# Name: ANKRD39, dtype: int64
#
#
# ANKRD40
# 0.0    143
# 1.0      1
# Name: ANKRD40, dtype: int64
#
#
# ANKRD42
# 0.0    32
# 1.0     1
# Name: ANKRD42, dtype: int64
#
#
# ANKRD44
# 0.0    141
# 1.0      3
# Name: ANKRD44, dtype: int64
#
#
# ANKRD45
# 0.0    121
# 1.0      7
# Name: ANKRD45, dtype: int64
#
#
# ANKRD46
# 0.0    84
# 1.0     8
# Name: ANKRD46, dtype: int64
#
#
# ANKRD49
# 0.0    132
# 1.0      3
# Name: ANKRD49, dtype: int64
#
#
# ANKRD50
# 0.0    138
# 1.0      6
# Name: ANKRD50, dtype: int64
#
#
# ANKRD52
# 0.0    140
# 1.0      4
# Name: ANKRD52, dtype: int64
#
#
# ANKRD54
# 0.0    140
# 1.0      4
# Name: ANKRD54, dtype: int64
#
#
# ANKS1A
# 0.0    143
# 1.0      1
# Name: ANKS1A, dtype: int64
#
#
# ANKS3
# 0.0    72
# 1.0     3
# Name: ANKS3, dtype: int64
#
#
# ANKS6
# 0.0    113
# 1.0      4
# Name: ANKS6, dtype: int64
#
#
# ANLN
# 0.0    143
# 1.0      1
# Name: ANLN, dtype: int64
#
#
# ANO10
# 0.0    136
# 1.0      8
# Name: ANO10, dtype: int64
#
#
# ANO6
# 0.0    137
# 1.0      7
# Name: ANO6, dtype: int64
#
#
# ANO9
# 0.0    76
# 1.0     2
# Name: ANO9, dtype: int64
#
#
# ANP32A
# 0.0    139
# 1.0      5
# Name: ANP32A, dtype: int64
#
#
# ANP32B
# 0.0    140
# 1.0      4
# Name: ANP32B, dtype: int64
#
#
# ANTXR1
# 0.0    138
# 1.0      6
# Name: ANTXR1, dtype: int64
#
#
# ANTXR2
# 0.0    143
# 1.0      1
# Name: ANTXR2, dtype: int64
#
#
# ANXA1
# 0.0    142
# 1.0      2
# Name: ANXA1, dtype: int64
#
#
# ANXA11
# 0.0    143
# 1.0      1
# Name: ANXA11, dtype: int64
#
#
# ANXA13
# 0.0    126
# 1.0      1
# Name: ANXA13, dtype: int64
#
#
# ANXA3
# 0.0    137
# 1.0      7
# Name: ANXA3, dtype: int64
#
#
# ANXA4
# 0.0    137
# 1.0      7
# Name: ANXA4, dtype: int64
#
#
# ANXA5
# 0.0    141
# 1.0      3
# Name: ANXA5, dtype: int64
#
#
# ANXA8
# 0.0    56
# 1.0     4
# Name: ANXA8, dtype: int64
#
#
# ANXA9
# 0.0    133
# 1.0      2
# Name: ANXA9, dtype: int64
#
#
# AOAH
# 0.0    106
# 1.0      3
# Name: AOAH, dtype: int64
#
#
# AP1AR
# 0.0    111
# 1.0      8
# Name: AP1AR, dtype: int64
#
#
# AP1B1
# 0.0    142
# 1.0      2
# Name: AP1B1, dtype: int64
#
#
# AP1M1
# 0.0    135
# 1.0      9
# Name: AP1M1, dtype: int64
#
#
# AP1M2
# 0.0    140
# 1.0      4
# Name: AP1M2, dtype: int64
#
#
# AP1S1
# 0.0    140
# 1.0      4
# Name: AP1S1, dtype: int64
#
#
# AP1S2
# 0.0    134
# 1.0     10
# Name: AP1S2, dtype: int64
#
#
# AP1S3
# 0.0    133
# 1.0      2
# Name: AP1S3, dtype: int64
#
#
# AP2A1
# 0.0    141
# 1.0      3
# Name: AP2A1, dtype: int64
#
#
# AP2A2
# 0.0    134
# 1.0     10
# Name: AP2A2, dtype: int64
#
#
# AP2B1
# 0.0    141
# 1.0      3
# Name: AP2B1, dtype: int64
#
#
# AP2M1
# 0.0    138
# 1.0      6
# Name: AP2M1, dtype: int64
#
#
# AP2S1
# 0.0    137
# 1.0      7
# Name: AP2S1, dtype: int64
#
#
# AP3B1
# 0.0    142
# 1.0      2
# Name: AP3B1, dtype: int64
#
#
# AP3B2
# 0.0    50
# 1.0     3
# Name: AP3B2, dtype: int64
#
#
# AP3D1
# 0.0    142
# 1.0      2
# Name: AP3D1, dtype: int64
#
#
# AP3M1
# 0.0    139
# 1.0      5
# Name: AP3M1, dtype: int64
#
#
# AP3M2
# 0.0    140
# 1.0      4
# Name: AP3M2, dtype: int64
#
#
# AP3S1
# 0.0    141
# 1.0      3
# Name: AP3S1, dtype: int64
#
#
# AP3S2
# 0.0    104
# 1.0      1
# Name: AP3S2, dtype: int64
#
#
# AP4B1
# 0.0    141
# 1.0      3
# Name: AP4B1, dtype: int64
#
#
# AP4E1
# 0.0    138
# 1.0      6
# Name: AP4E1, dtype: int64
#
#
# AP4M1
# 0.0    141
# 1.0      3
# Name: AP4M1, dtype: int64
#
#
# AP4S1
# 0.0    91
# 1.0     2
# Name: AP4S1, dtype: int64
#
#
# AP5B1
# 0.0    137
# 1.0      7
# Name: AP5B1, dtype: int64
#
#
# AP5M1
# 0.0    138
# 1.0      6
# Name: AP5M1, dtype: int64
#
#
# AP5S1
# 0.0    133
# 1.0     11
# Name: AP5S1, dtype: int64
#
#
# AP5Z1
# 0.0    143
# 1.0      1
# Name: AP5Z1, dtype: int64
#
#
# APAF1
# 0.0    143
# 1.0      1
# Name: APAF1, dtype: int64
#
#
# APBA1
# 0.0    139
# 1.0      5
# Name: APBA1, dtype: int64
#
#
# APBA2
# 0.0    127
# 1.0      8
# Name: APBA2, dtype: int64
#
#
# APBA3
# 0.0    141
# 1.0      3
# Name: APBA3, dtype: int64
#
#
# APBB1
# 0.0    141
# 1.0      3
# Name: APBB1, dtype: int64
#
#
# APBB1IP
# 0.0    142
# 1.0      2
# Name: APBB1IP, dtype: int64
#
#
# APBB2
# 0.0    143
# 1.0      1
# Name: APBB2, dtype: int64
#
#
# APC
# 0.0    137
# 1.0      7
# Name: APC, dtype: int64
#
#
# APCS
# 0.0    141
# 1.0      3
# Name: APCS, dtype: int64
#
#
# APEH
# 0.0    131
# 1.0     13
# Name: APEH, dtype: int64
#
#
# APEX1
# 0.0    143
# 1.0      1
# Name: APEX1, dtype: int64
#
#
# APEX2
# 0.0    128
# 1.0      7
# Name: APEX2, dtype: int64
#
#
# APH1A
# 0.0    31
# 1.0     1
# Name: APH1A, dtype: int64
#
#
# API5
# 0.0    139
# 1.0      5
# Name: API5, dtype: int64
#
#
# APIP
# 0.0    140
# 1.0      4
# Name: APIP, dtype: int64
#
#
# APLF
# 0.0    134
# 1.0     10
# Name: APLF, dtype: int64
#
#
# APLP2
# 0.0    142
# 1.0      2
# Name: APLP2, dtype: int64
#
#
# APMAP
# 0.0    136
# 1.0      8
# Name: APMAP, dtype: int64
#
#
# APOA1
# 0.0    143
# 1.0      1
# Name: APOA1, dtype: int64
#
#
# APOA2
# 0.0    143
# 1.0      1
# Name: APOA2, dtype: int64
#
#
# APOA4
# 0.0    143
# 1.0      1
# Name: APOA4, dtype: int64
#
#
# APOA5
# 0.0    17
# 1.0     1
# Name: APOA5, dtype: int64
#
#
# APOBEC3B
# 0.0    142
# 1.0      2
# Name: APOBEC3B, dtype: int64
#
#
# APOBEC3C
# 0.0    139
# 1.0      5
# Name: APOBEC3C, dtype: int64
#
#
# APOBEC3D
# 0.0    59
# 1.0     2
# Name: APOBEC3D, dtype: int64
#
#
# APOBEC3F
# 0.0    124
# 1.0     11
# Name: APOBEC3F, dtype: int64
#
#
# APOBEC3G
# 0.0    139
# 1.0      5
# Name: APOBEC3G, dtype: int64
#
#
# APOBR
# 0.0    142
# 1.0      2
# Name: APOBR, dtype: int64
#
#
# APOC1
# 0.0    142
# 1.0      2
# Name: APOC1, dtype: int64
#
#
# APOC3
# 0.0    142
# 1.0      2
# Name: APOC3, dtype: int64
#
#
# APOC4
# 0.0    132
# 1.0      3
# Name: APOC4, dtype: int64
#
#
# APOE
# 0.0    143
# 1.0      1
# Name: APOE, dtype: int64
#
#
# APOF
# 0.0    143
# 1.0      1
# Name: APOF, dtype: int64
#
#
# APOH
# 0.0    143
# 1.0      1
# Name: APOH, dtype: int64
#
#
# APOL1
# 0.0    143
# 1.0      1
# Name: APOL1, dtype: int64
#
#
# APOL2
# 0.0    143
# 1.0      1
# Name: APOL2, dtype: int64
#
#
# APOL3
# 0.0    140
# 1.0      4
# Name: APOL3, dtype: int64
#
#
# APOL6
# 0.0    95
# 1.0     1
# Name: APOL6, dtype: int64
#
#
# APOO
# 0.0    143
# 1.0      1
# Name: APOO, dtype: int64
#
#
# APOOL
# 0.0    142
# 1.0      2
# Name: APOOL, dtype: int64
#
#
# APOPT1
# 0.0    84
# 1.0     1
# Name: APOPT1, dtype: int64
#
#
# APPBP2
# 0.0    129
# 1.0      6
# Name: APPBP2, dtype: int64
#
#
# APPL1
# 0.0    142
# 1.0      2
# Name: APPL1, dtype: int64
#
#
# APPL2
# 0.0    134
# 1.0     10
# Name: APPL2, dtype: int64
#
#
# APRT
# 0.0    138
# 1.0      6
# Name: APRT, dtype: int64
#
#
# APTX
# 0.0    140
# 1.0      4
# Name: APTX, dtype: int64
#
#
# AQP1
# 0.0    135
# 1.0      9
# Name: AQP1, dtype: int64
#
#
# AQR
# 0.0    138
# 1.0      6
# Name: AQR, dtype: int64
#
#
# AR
# 0.0    140
# 1.0      4
# Name: AR, dtype: int64
#
#
# ARAF
# 0.0    140
# 1.0      4
# Name: ARAF, dtype: int64
#
#
# ARAP1
# 0.0    139
# 1.0      5
# Name: ARAP1, dtype: int64
#
#
# ARAP2
# 0.0    94
# 1.0    14
# Name: ARAP2, dtype: int64
#
#
# ARAP3
# 0.0    133
# 1.0     11
# Name: ARAP3, dtype: int64
#
#
# ARCN1
# 0.0    138
# 1.0      6
# Name: ARCN1, dtype: int64
#
#
# ARF1
# 0.0    131
# 1.0      4
# Name: ARF1, dtype: int64
#
#
# ARF3
# 0.0    133
# 1.0      2
# Name: ARF3, dtype: int64
#
#
# ARF4
# 0.0    142
# 1.0      2
# Name: ARF4, dtype: int64
#
#
# ARF6
# 0.0    143
# 1.0      1
# Name: ARF6, dtype: int64
#
#
# ARFGAP1
# 0.0    141
# 1.0      3
# Name: ARFGAP1, dtype: int64
#
#
# ARFGAP2
# 0.0    141
# 1.0      3
# Name: ARFGAP2, dtype: int64
#
#
# ARFGEF1
# 0.0    143
# 1.0      1
# Name: ARFGEF1, dtype: int64
#
#
# ARFGEF2
# 0.0    136
# 1.0      8
# Name: ARFGEF2, dtype: int64
#
#
# ARFGEF3
# 0.0    143
# 1.0      1
# Name: ARFGEF3, dtype: int64
#
#
# ARFIP2
# 0.0    143
# 1.0      1
# Name: ARFIP2, dtype: int64
#
#
# ARFRP1
# 0.0    141
# 1.0      3
# Name: ARFRP1, dtype: int64
#
#
# ARG2
# 0.0    134
# 1.0      2
# Name: ARG2, dtype: int64
#
#
# ARGLU1
# 0.0    141
# 1.0      3
# Name: ARGLU1, dtype: int64
#
#
# ARHGAP1
# 0.0    141
# 1.0      3
# Name: ARHGAP1, dtype: int64
#
#
# ARHGAP10
# 0.0    143
# 1.0      1
# Name: ARHGAP10, dtype: int64
#
#
# ARHGAP12
# 0.0    140
# 1.0      4
# Name: ARHGAP12, dtype: int64
#
#
# ARHGAP15
# 0.0    131
# 1.0      5
# Name: ARHGAP15, dtype: int64
#
#
# ARHGAP17
# 0.0    140
# 1.0      4
# Name: ARHGAP17, dtype: int64
#
#
# ARHGAP18
# 0.0    142
# 1.0      2
# Name: ARHGAP18, dtype: int64
#
#
# ARHGAP21
# 0.0    140
# 1.0      4
# Name: ARHGAP21, dtype: int64
#
#
# ARHGAP24
# 0.0    122
# 1.0      4
# Name: ARHGAP24, dtype: int64
#
#
# ARHGAP25
# 0.0    137
# 1.0      7
# Name: ARHGAP25, dtype: int64
#
#
# ARHGAP26
# 0.0    141
# 1.0      3
# Name: ARHGAP26, dtype: int64
# ARHGAP28
# 0.0    31
# 1.0     1
# Name: ARHGAP28, dtype: int64
#
#
# ARHGAP29
# 0.0    141
# 1.0      3
# Name: ARHGAP29, dtype: int64
#
#
# ARHGAP30
# 0.0    139
# 1.0      5
# Name: ARHGAP30, dtype: int64
#
#
# ARHGAP32
# 0.0    140
# 1.0      4
# Name: ARHGAP32, dtype: int64
#
#
# ARHGAP35
# 0.0    134
# 1.0     10
# Name: ARHGAP35, dtype: int64
#
#
# ARHGAP39
# 0.0    135
# 1.0      9
# Name: ARHGAP39, dtype: int64
#
#
# ARHGAP4
# 0.0    142
# 1.0      2
# Name: ARHGAP4, dtype: int64
#
#
# ARHGAP42
# 0.0    142
# 1.0      2
# Name: ARHGAP42, dtype: int64
#
#
# ARHGAP44
# 0.0    118
# 1.0     11
# Name: ARHGAP44, dtype: int64
#
#
# ARHGAP45
# 0.0    137
# 1.0      7
# Name: ARHGAP45, dtype: int64
#
#
# ARHGAP5
# 0.0    136
# 1.0      8
# Name: ARHGAP5, dtype: int64
#
#
# ARHGAP9
# 0.0    142
# 1.0      2
# Name: ARHGAP9, dtype: int64
#
#
# ARHGDIA
# 0.0    140
# 1.0      4
# Name: ARHGDIA, dtype: int64
#
#
# ARHGDIB
# 0.0    141
# 1.0      3
# Name: ARHGDIB, dtype: int64
#
#
# ARHGEF1
# 0.0    140
# 1.0      4
# Name: ARHGEF1, dtype: int64
#
#
# ARHGEF10
# 0.0    140
# 1.0      4
# Name: ARHGEF10, dtype: int64
#
#
# ARHGEF10L
# 0.0    140
# 1.0      4
# Name: ARHGEF10L, dtype: int64
#
#
# ARHGEF12
# 0.0    138
# 1.0      6
# Name: ARHGEF12, dtype: int64
#
#
# ARHGEF16
# 0.0    141
# 1.0      3
# Name: ARHGEF16, dtype: int64
#
#
# ARHGEF18
# 0.0    139
# 1.0      5
# Name: ARHGEF18, dtype: int64
#
#
# ARHGEF2
# 0.0    141
# 1.0      3
# Name: ARHGEF2, dtype: int64
#
#
# ARHGEF26
# 0.0    122
# 1.0      4
# Name: ARHGEF26, dtype: int64
#
#
# ARHGEF28
# 0.0    136
# 1.0      8
# Name: ARHGEF28, dtype: int64
#
#
# ARHGEF3
# 0.0    140
# 1.0      4
# Name: ARHGEF3, dtype: int64
#
#
# ARHGEF35
# 0.0    132
# 1.0      5
# Name: ARHGEF35, dtype: int64
#
#
# ARHGEF37
# 0.0    141
# 1.0      3
# Name: ARHGEF37, dtype: int64
#
#
# ARHGEF38
# 0.0    99
# 1.0     5
# Name: ARHGEF38, dtype: int64
#
#
# ARHGEF40
# 0.0    142
# 1.0      2
# Name: ARHGEF40, dtype: int64
#
#
# ARHGEF5
# 0.0    143
# 1.0      1
# Name: ARHGEF5, dtype: int64
#
#
# ARHGEF7
# 0.0    135
# 1.0      9
# Name: ARHGEF7, dtype: int64
#
#
# ARID1A
# 0.0    123
# 1.0     21
# Name: ARID1A, dtype: int64
#
#
# ARID1B
# 0.0    141
# 1.0      3
# Name: ARID1B, dtype: int64
#
#
# ARID2
# 0.0    143
# 1.0      1
# Name: ARID2, dtype: int64
#
#
# ARID3A
# 0.0    131
# 1.0      4
# Name: ARID3A, dtype: int64
#
#
# ARID3B
# 0.0    57
# 1.0     2
# Name: ARID3B, dtype: int64
#
#
# ARID4A
# 0.0    142
# 1.0      2
# Name: ARID4A, dtype: int64
#
#
# ARID5B
# 0.0    138
# 1.0      6
# Name: ARID5B, dtype: int64
#
#
# ARIH1
# 0.0    137
# 1.0      7
# Name: ARIH1, dtype: int64
#
#
# ARIH2
# 0.0    139
# 1.0      5
# Name: ARIH2, dtype: int64
#
#
# ARL1
# 0.0    139
# 1.0      5
# Name: ARL1, dtype: int64
#
#
# ARL13B
# 0.0    40
# 1.0     2
# Name: ARL13B, dtype: int64
#
#
# ARL14EP
# 0.0    140
# 1.0      4
# Name: ARL14EP, dtype: int64
#
#
# ARL15
# 0.0    137
# 1.0      7
# Name: ARL15, dtype: int64
#
#
# ARL2
# 0.0    138
# 1.0      6
# Name: ARL2, dtype: int64
#
#
# ARL3
# 0.0    127
# 1.0     17
# Name: ARL3, dtype: int64
#
#
# ARL4A
# 0.0    33
# 1.0     1
# Name: ARL4A, dtype: int64
#
#
# ARL4C
# 0.0    98
# 1.0     3
# Name: ARL4C, dtype: int64
#
#
# ARL4D
# 0.0    16
# 1.0     1
# Name: ARL4D, dtype: int64
#
#
# ARL5A
# 0.0    92
# 1.0     2
# Name: ARL5A, dtype: int64
#
#
# ARL5B
# 0.0    121
# 1.0      5
# Name: ARL5B, dtype: int64
#
#
# ARL6
# 0.0    141
# 1.0      3
# Name: ARL6, dtype: int64
#
#
# ARL6IP1
# 0.0    136
# 1.0      8
# Name: ARL6IP1, dtype: int64
#
#
# ARL6IP4
# 0.0    141
# 1.0      3
# Name: ARL6IP4, dtype: int64
#
#
# ARL6IP5
# 0.0    136
# 1.0      8
# Name: ARL6IP5, dtype: int64
#
#
# ARL6IP6
# 0.0    136
# 1.0      8
# Name: ARL6IP6, dtype: int64
#
#
# ARL8A
# 0.0    138
# 1.0      6
# Name: ARL8A, dtype: int64
#
#
# ARL8B
# 0.0    137
# 1.0      7
# Name: ARL8B, dtype: int64
#
#
# ARMC1
# 0.0    135
# 1.0      9
# Name: ARMC1, dtype: int64
#
#
# ARMC10
# 0.0    143
# 1.0      1
# Name: ARMC10, dtype: int64
#
#
# ARMC3
# 0.0    99
# 1.0     3
# Name: ARMC3, dtype: int64
#
#
# ARMC4
# 0.0    89
# 1.0     4
# Name: ARMC4, dtype: int64
#
#
# ARMC5
# 0.0    111
# 1.0      1
# Name: ARMC5, dtype: int64
#
#
# ARMC6
# 0.0    140
# 1.0      4
# Name: ARMC6, dtype: int64
#
#
# ARMC7
# 0.0    68
# 1.0     3
# Name: ARMC7, dtype: int64
#
#
# ARMC8
# 0.0    140
# 1.0      4
# Name: ARMC8, dtype: int64
#
#
# ARMC9
# 0.0    141
# 1.0      3
# Name: ARMC9, dtype: int64
#
#
# ARMCX1
# 0.0    140
# 1.0      4
# Name: ARMCX1, dtype: int64
#
#
# ARMCX2
# 0.0    132
# 1.0     12
# Name: ARMCX2, dtype: int64
#
#
# ARMCX3
# 0.0    143
# 1.0      1
# Name: ARMCX3, dtype: int64
#
#
# ARMCX5
# 0.0    138
# 1.0      6
# Name: ARMCX5, dtype: int64
#
#
# ARMH3
# 0.0    143
# 1.0      1
# Name: ARMH3, dtype: int64
#
#
# ARMT1
# 0.0    141
# 1.0      3
# Name: ARMT1, dtype: int64
#
#
# ARNT
# 0.0    143
# 1.0      1
# Name: ARNT, dtype: int64
#
#
# ARNT2
# 0.0    136
# 1.0      8
# Name: ARNT2, dtype: int64
#
#
# ARNTL
# 0.0    125
# 1.0      4
# Name: ARNTL, dtype: int64
#
#
# ARPC1A
# 0.0    143
# 1.0      1
# Name: ARPC1A, dtype: int64
#
#
# ARPC3
# 0.0    140
# 1.0      4
# Name: ARPC3, dtype: int64
#
#
# ARPC4
# 0.0    140
# 1.0      4
# Name: ARPC4, dtype: int64
#
#
# ARPC5
# 0.0    132
# 1.0     12
# Name: ARPC5, dtype: int64
#
#
# ARPC5L
# 0.0    136
# 1.0      8
# Name: ARPC5L, dtype: int64
#
#
# ARPIN
# 0.0    84
# 1.0     1
# Name: ARPIN, dtype: int64
#
#
# ARPP19
# 0.0    142
# 1.0      2
# Name: ARPP19, dtype: int64
#
#
# ARR3
# 0.0    140
# 1.0      4
# Name: ARR3, dtype: int64
#
#
# ARRB1
# 0.0    140
# 1.0      4
# Name: ARRB1, dtype: int64
#
#
# ARRB2
# 0.0    142
# 1.0      2
# Name: ARRB2, dtype: int64
#
#
# ARRDC1
# 0.0    142
# 1.0      2
# Name: ARRDC1, dtype: int64
#
#
# ARSA
# 0.0    143
# 1.0      1
# Name: ARSA, dtype: int64
#
#
# ARSB
# 0.0    142
# 1.0      2
# Name: ARSB, dtype: int64
#
#
# ARSD
# 0.0    143
# 1.0      1
# Name: ARSD, dtype: int64
#
#
# ARSE
# 0.0    124
# 1.0      5
# Name: ARSE, dtype: int64
#
#
# ARSK
# 0.0    76
# 1.0     2
# Name: ARSK, dtype: int64
#
#
# ARV1
# 0.0    134
# 1.0      2
# Name: ARV1, dtype: int64
#
#
# ARVCF
# 0.0    142
# 1.0      2
# Name: ARVCF, dtype: int64
#
#
# ARX
# 0.0    42
# 1.0     2
# Name: ARX, dtype: int64
#
#
# AS3MT
# 0.0    141
# 1.0      3
# Name: AS3MT, dtype: int64
#
#
# ASAP1
# 0.0    139
# 1.0      5
# Name: ASAP1, dtype: int64
#
#
# ASAP2
# 0.0    143
# 1.0      1
# Name: ASAP2, dtype: int64
#
#
# ASAP3
# 0.0    133
# 1.0     11
# Name: ASAP3, dtype: int64
#
#
# ASB1
# 0.0    66
# 1.0     1
# Name: ASB1, dtype: int64
#
#
# ASB13
# 0.0    59
# 1.0     3
# Name: ASB13, dtype: int64
#
#
# ASB6
# 0.0    114
# 1.0      3
# Name: ASB6, dtype: int64
#
#
# ASB7
# 0.0    87
# 1.0     4
# Name: ASB7, dtype: int64
#
#
# ASB9
# 0.0    58
# 1.0    11
# Name: ASB9, dtype: int64
#
#
# ASCC1
# 0.0    143
# 1.0      1
# Name: ASCC1, dtype: int64
#
#
# ASCC2
# 0.0    142
# 1.0      2
# Name: ASCC2, dtype: int64
#
#
# ASCC3
# 0.0    143
# 1.0      1
# Name: ASCC3, dtype: int64
#
#
# ASDURF
# 0.0    142
# 1.0      2
# Name: ASDURF, dtype: int64
#
#
# ASF1A
# 0.0    138
# 1.0      6
# Name: ASF1A, dtype: int64
#
#
# ASF1B
# 0.0    124
# 1.0      3
# Name: ASF1B, dtype: int64
#
#
# ASH1L
# 0.0    135
# 1.0      9
# Name: ASH1L, dtype: int64
#
#
# ASH2L
# 0.0    141
# 1.0      3
# Name: ASH2L, dtype: int64
#
#
# ASL
# 0.0    139
# 1.0      5
# Name: ASL, dtype: int64
#
#
# ASMTL
# 0.0    135
# 1.0      9
# Name: ASMTL, dtype: int64
#
#
# ASNA1
# 0.0    137
# 1.0      7
# Name: ASNA1, dtype: int64
#
#
# ASNS
# 0.0    143
# 1.0      1
# Name: ASNS, dtype: int64
#
#
# ASNSD1
# 0.0    106
# 1.0      2
# Name: ASNSD1, dtype: int64
#
#
# ASPH
# 0.0    133
# 1.0     11
# Name: ASPH, dtype: int64
#
#
# ASPRV1
# 0.0    34
# 1.0     1
# Name: ASPRV1, dtype: int64
#
#
# ASPSCR1
# 0.0    143
# 1.0      1
# Name: ASPSCR1, dtype: int64
#
#
# ASRGL1
# 0.0    140
# 1.0      4
# Name: ASRGL1, dtype: int64
#
#
# ASS1
# 0.0    129
# 1.0     15
# Name: ASS1, dtype: int64
#
#
# ASTE1
# 0.0    74
# 1.0     2
# Name: ASTE1, dtype: int64
#
#
# ASXL2
# 0.0    134
# 1.0      2
# Name: ASXL2, dtype: int64
#
#
# ATAD1
# 0.0    140
# 1.0      4
# Name: ATAD1, dtype: int64
#
#
# ATAD2B
# 0.0    141
# 1.0      3
# Name: ATAD2B, dtype: int64
#
#
# ATAD3B
# 0.0    115
# 1.0      4
# Name: ATAD3B, dtype: int64
#
#
# ATAT1
# 0.0    141
# 1.0      3
# Name: ATAT1, dtype: int64
#
#
# ATE1
# 0.0    143
# 1.0      1
# Name: ATE1, dtype: int64
#
#
# ATF1
# 0.0    138
# 1.0      6
# Name: ATF1, dtype: int64
#
#
# ATF2
# 0.0    140
# 1.0      4
# Name: ATF2, dtype: int64
#
#
# ATF6
# 0.0    127
# 1.0      9
# Name: ATF6, dtype: int64
#
#
# ATF7
# 0.0    142
# 1.0      2
# Name: ATF7, dtype: int64
#
#
# ATF7IP
# 0.0    143
# 1.0      1
# Name: ATF7IP, dtype: int64
#
#
# ATG10
# 0.0    51
# 1.0     2
# Name: ATG10, dtype: int64
#
#
# ATG101
# 0.0    140
# 1.0      4
# Name: ATG101, dtype: int64
#
#
# ATG12
# 0.0    142
# 1.0      2
# Name: ATG12, dtype: int64
#
#
# ATG13
# 0.0    141
# 1.0      3
# Name: ATG13, dtype: int64
#
#
# ATG14
# 0.0    137
# 1.0      7
# Name: ATG14, dtype: int64
#
#
# ATG16L1
# 0.0    139
# 1.0      5
# Name: ATG16L1, dtype: int64
#
#
# ATG2A
# 0.0    140
# 1.0      4
# Name: ATG2A, dtype: int64
#
#
# ATG2B
# 0.0    143
# 1.0      1
# Name: ATG2B, dtype: int64
#
#
# ATG3
# 0.0    142
# 1.0      2
# Name: ATG3, dtype: int64
#
#
# ATG4A
# 0.0    111
# 1.0      1
# Name: ATG4A, dtype: int64
#
#
# ATG4B
# 0.0    138
# 1.0      6
# Name: ATG4B, dtype: int64
#
#
# ATG4C
# 0.0    139
# 1.0      5
# Name: ATG4C, dtype: int64
#
#
# ATG5
# 0.0    142
# 1.0      2
# Name: ATG5, dtype: int64
#
#
# ATG7
# 0.0    134
# 1.0     10
# Name: ATG7, dtype: int64
#
#
# ATG9A
# 0.0    142
# 1.0      2
# Name: ATG9A, dtype: int64
#
#
# ATIC
# 0.0    140
# 1.0      4
# Name: ATIC, dtype: int64
#
#
# ATL1
# 0.0    140
# 1.0      4
# Name: ATL1, dtype: int64
#
#
# ATL2
# 0.0    137
# 1.0      7
# Name: ATL2, dtype: int64
#
#
# ATL3
# 0.0    128
# 1.0     16
# Name: ATL3, dtype: int64
#
#
# ATM
# 0.0    132
# 1.0     12
# Name: ATM, dtype: int64
#
#
# ATN1
# 0.0    141
# 1.0      3
# Name: ATN1, dtype: int64
#
#
# ATOX1
# 0.0    143
# 1.0      1
# Name: ATOX1, dtype: int64
#
#
# ATP11A
# 0.0    143
# 1.0      1
# Name: ATP11A, dtype: int64
#
#
# ATP11B
# 0.0    133
# 1.0     11
# Name: ATP11B, dtype: int64
#
#
# ATP11C
# 0.0    133
# 1.0     11
# Name: ATP11C, dtype: int64
#
#
# ATP12A
# 0.0    73
# 1.0     2
# Name: ATP12A, dtype: int64
#
#
# ATP13A1
# 0.0    141
# 1.0      3
# Name: ATP13A1, dtype: int64
#
#
# ATP13A2
# 0.0    134
# 1.0      1
# Name: ATP13A2, dtype: int64
#
#
# ATP13A3
# 0.0    139
# 1.0      5
# Name: ATP13A3, dtype: int64
#
#
# ATP1A1
# 0.0    142
# 1.0      2
# Name: ATP1A1, dtype: int64
#
#
# ATP1B1
# 0.0    140
# 1.0      4
# Name: ATP1B1, dtype: int64
#
#
# ATP1B2
# 0.0    89
# 1.0     2
# Name: ATP1B2, dtype: int64
#
#
# ATP1B3
# 0.0    140
# 1.0      4
# Name: ATP1B3, dtype: int64
#
#
# ATP23
# 0.0    140
# 1.0      4
# Name: ATP23, dtype: int64
#
#
# ATP2A2
# 0.0    138
# 1.0      6
# Name: ATP2A2, dtype: int64
#
#
# ATP2A3
# 0.0    141
# 1.0      3
# Name: ATP2A3, dtype: int64
#
#
# ATP2B1
# 0.0    140
# 1.0      4
# Name: ATP2B1, dtype: int64
#
#
# ATP2B2
# 0.0    120
# 1.0      6
# Name: ATP2B2, dtype: int64
#
#
# ATP2B3
# 0.0    110
# 1.0      3
# Name: ATP2B3, dtype: int64
#
#
# ATP2B4
# 0.0    129
# 1.0     15
# Name: ATP2B4, dtype: int64
#
#
# ATP2C1
# 0.0    141
# 1.0      3
# Name: ATP2C1, dtype: int64
#
#
# ATP2C2
# 0.0    94
# 1.0     1
# Name: ATP2C2, dtype: int64
#
#
# ATP5F1A
# 0.0    143
# 1.0      1
# Name: ATP5F1A, dtype: int64
#
#
# ATP5F1B
# 0.0    142
# 1.0      2
# Name: ATP5F1B, dtype: int64
#
#
# ATP5F1C
# 0.0    143
# 1.0      1
# Name: ATP5F1C, dtype: int64
#
#
# ATP5F1E
# 0.0    131
# 1.0     13
# Name: ATP5F1E, dtype: int64
#
#
# ATP5MC1
# 0.0    127
# 1.0      9
# Name: ATP5MC1, dtype: int64
#
#
# ATP5MD
# 0.0    136
# 1.0      8
# Name: ATP5MD, dtype: int64
#
#
# ATP5ME
# 0.0    143
# 1.0      1
# Name: ATP5ME, dtype: int64
#
#
# ATP5MF
# 0.0    137
# 1.0      7
# Name: ATP5MF, dtype: int64
#
#
# ATP5MF-PTCD1
# 0.0    143
# 1.0      1
# Name: ATP5MF-PTCD1, dtype: int64
#
#
# ATP5MG
# 0.0    140
# 1.0      4
# Name: ATP5MG, dtype: int64
#
#
# ATP5MPL
# 0.0    138
# 1.0      6
# Name: ATP5MPL, dtype: int64
#
#
# ATP5PB
# 0.0    140
# 1.0      4
# Name: ATP5PB, dtype: int64
#
#
# ATP5PD
# 0.0    142
# 1.0      2
# Name: ATP5PD, dtype: int64
#
#
# ATP5PF
# 0.0    142
# 1.0      2
# Name: ATP5PF, dtype: int64
#
#
# ATP5PO
# 0.0    143
# 1.0      1
# Name: ATP5PO, dtype: int64
#
#
# ATP5S
# 0.0    142
# 1.0      2
# Name: ATP5S, dtype: int64
#
#
# ATP6AP1
# 0.0    136
# 1.0      8
# Name: ATP6AP1, dtype: int64
#
#
# ATP6AP2
# 0.0    143
# 1.0      1
# Name: ATP6AP2, dtype: int64
#
#
# ATP6V0A1
# 0.0    139
# 1.0      5
# Name: ATP6V0A1, dtype: int64
#
#
# ATP6V0A2
# 0.0    137
# 1.0      7
# Name: ATP6V0A2, dtype: int64
#
#
# ATP6V0C
# 0.0    129
# 1.0      7
# Name: ATP6V0C, dtype: int64
#
#
# ATP6V0D2
# 0.0    130
# 1.0     14
# Name: ATP6V0D2, dtype: int64
#
#
# ATP6V1A
# 0.0    140
# 1.0      4
# Name: ATP6V1A, dtype: int64
#
#
# ATP6V1B1
# 0.0    113
# 1.0      5
# Name: ATP6V1B1, dtype: int64
#
#
# ATP6V1B2
# 0.0    137
# 1.0      7
# Name: ATP6V1B2, dtype: int64
#
#
# ATP6V1D
# 0.0    142
# 1.0      2
# Name: ATP6V1D, dtype: int64
#
#
# ATP6V1E2
# 0.0    8
# 1.0    1
# Name: ATP6V1E2, dtype: int64
#
#
# ATP6V1F
# 0.0    142
# 1.0      2
# Name: ATP6V1F, dtype: int64
#
#
# ATP6V1G1
# 0.0    142
# 1.0      2
# Name: ATP6V1G1, dtype: int64
#
#
# ATP6V1G2
# 0.0    133
# 1.0      3
# Name: ATP6V1G2, dtype: int64
#
#
# ATP6V1H
# 0.0    139
# 1.0      5
# Name: ATP6V1H, dtype: int64
#
#
# ATP7A
# 0.0    140
# 1.0      4
# Name: ATP7A, dtype: int64
#
#
# ATP8A1
# 0.0    138
# 1.0      6
# Name: ATP8A1, dtype: int64
#
#
# ATP9A
# 0.0    142
# 1.0      2
# Name: ATP9A, dtype: int64
#
#
# ATP9B
# 0.0    135
# 1.0      9
# Name: ATP9B, dtype: int64
#
#
# ATR
# 0.0    141
# 1.0      3
# Name: ATR, dtype: int64
#
#
# ATRAID
# 0.0    133
# 1.0      2
# Name: ATRAID, dtype: int64
#
#
# ATRIP
# 0.0    138
# 1.0      6
# Name: ATRIP, dtype: int64
#
#
# ATRN
# 0.0    143
# 1.0      1
# Name: ATRN, dtype: int64
#
#
# ATRX
# 0.0    136
# 1.0      8
# Name: ATRX, dtype: int64
#
#
# ATXN1
# 0.0    140
# 1.0      4
# Name: ATXN1, dtype: int64
#
#
# ATXN10
# 0.0    140
# 1.0      4
# Name: ATXN10, dtype: int64
#
#
# ATXN1L
# 0.0    141
# 1.0      3
# Name: ATXN1L, dtype: int64
#
#
# ATXN2
# 0.0    138
# 1.0      6
# Name: ATXN2, dtype: int64
#
#
# ATXN3
# 0.0    143
# 1.0      1
# Name: ATXN3, dtype: int64
#
#
# ATXN7
# 0.0    140
# 1.0      4
# Name: ATXN7, dtype: int64
#
#
# ATXN7L3
# 0.0    127
# 1.0      9
# Name: ATXN7L3, dtype: int64
#
#
# ATXN7L3B
# 0.0    140
# 1.0      4
# Name: ATXN7L3B, dtype: int64
#
#
# AUH
# 0.0    139
# 1.0      5
# Name: AUH, dtype: int64
#
#
# AUP1
# 0.0    139
# 1.0      5
# Name: AUP1, dtype: int64
#
#
# AURKA
# 0.0    85
# 1.0     7
# Name: AURKA, dtype: int64
#
#
# AUTS2
# 0.0    143
# 1.0      1
# Name: AUTS2, dtype: int64
#
#
# AVEN
# 0.0    135
# 1.0      9
# Name: AVEN, dtype: int64
#
#
# AXIN1
# 0.0    97
# 1.0     3
# Name: AXIN1, dtype: int64
#
#
# AZI2
# 0.0    124
# 1.0     11
# Name: AZI2, dtype: int64
#
#
# AZU1
# 0.0    142
# 1.0      2
# Name: AZU1, dtype: int64
#
#
# B3GALNT1
# 0.0    52
# 1.0     1
# Name: B3GALNT1, dtype: int64
#
#
# B3GALT6
# 0.0    130
# 1.0      5
# Name: B3GALT6, dtype: int64
#
#
# B3GAT3
# 0.0    142
# 1.0      2
# Name: B3GAT3, dtype: int64
#
#
# B3GLCT
# 0.0    143
# 1.0      1
# Name: B3GLCT, dtype: int64
#
#
# B3GNT2
# 0.0    129
# 1.0      6
# Name: B3GNT2, dtype: int64
#
#
# B3GNT7
# 0.0    94
# 1.0     1
# Name: B3GNT7, dtype: int64
#
#
# B3GNTL1
# 0.0    130
# 1.0      5
# Name: B3GNTL1, dtype: int64
#
#
# B4GALNT3
# 0.0    123
# 1.0      6
# Name: B4GALNT3, dtype: int64
#
#
# B4GALT1
# 0.0    142
# 1.0      2
# Name: B4GALT1, dtype: int64
#
#
# B4GALT3
# 0.0    115
# 1.0      2
# Name: B4GALT3, dtype: int64
#
#
# B4GALT5
# 0.0    139
# 1.0      5
# Name: B4GALT5, dtype: int64
#
#
# B4GALT7
# 0.0    95
# 1.0     4
# Name: B4GALT7, dtype: int64
#
#
# B4GAT1
# 0.0    85
# 1.0     1
# Name: B4GAT1, dtype: int64
#
#
# B9D1
# 0.0    132
# 1.0     12
# Name: B9D1, dtype: int64
#
#
# B9D2
# 0.0    129
# 1.0      6
# Name: B9D2, dtype: int64
#
#
# BABAM1
# 0.0    139
# 1.0      5
# Name: BABAM1, dtype: int64
#
#
# BABAM2
# 0.0    136
# 1.0      8
# Name: BABAM2, dtype: int64
#
#
# BACE2
# 0.0    117
# 1.0      2
# Name: BACE2, dtype: int64
#
#
# BACH1
# 0.0    141
# 1.0      3
# Name: BACH1, dtype: int64
#
#
# BAD
# 0.0    142
# 1.0      2
# Name: BAD, dtype: int64
#
#
# BAG1
# 0.0    137
# 1.0      7
# Name: BAG1, dtype: int64
#
#
# BAG2
# 0.0    142
# 1.0      2
# Name: BAG2, dtype: int64
#
#
# BAG3
# 0.0    142
# 1.0      2
# Name: BAG3, dtype: int64
#
#
# BAG4
# 0.0    139
# 1.0      5
# Name: BAG4, dtype: int64
#
#
# BAG5
# 0.0    141
# 1.0      3
# Name: BAG5, dtype: int64
#
#
# BAG6
# 0.0    142
# 1.0      2
# Name: BAG6, dtype: int64
#
#
# BAHD1
# 0.0    112
# 1.0      5
# Name: BAHD1, dtype: int64
#
#
# BAIAP2
# 0.0    139
# 1.0      5
# Name: BAIAP2, dtype: int64
#
#
# BAIAP2L2
# 0.0    100
# 1.0      1
# Name: BAIAP2L2, dtype: int64
#
#
# BAK1
# 0.0    139
# 1.0      5
# Name: BAK1, dtype: int64
#
#
# BANP
# 0.0    140
# 1.0      4
# Name: BANP, dtype: int64
#
#
# BAP1
# 0.0    142
# 1.0      2
# Name: BAP1, dtype: int64
#
#
# BASP1
# 0.0    141
# 1.0      3
# Name: BASP1, dtype: int64
#
#
# BAX
# 0.0    141
# 1.0      3
# Name: BAX, dtype: int64
#
#
# BAZ1A
# 0.0    143
# 1.0      1
# Name: BAZ1A, dtype: int64
#
#
# BAZ1B
# 0.0    137
# 1.0      7
# Name: BAZ1B, dtype: int64
#
#
# BAZ2A
# 0.0    141
# 1.0      3
# Name: BAZ2A, dtype: int64
#
#
# BAZ2B
# 0.0    143
# 1.0      1
# Name: BAZ2B, dtype: int64
#
#
# BBC3
# 0.0    49
# 1.0     2
# Name: BBC3, dtype: int64
#
#
# BBIP1
# 0.0    137
# 1.0      7
# Name: BBIP1, dtype: int64
#
#
# BBOX1
# 0.0    74
# 1.0     1
# Name: BBOX1, dtype: int64
#
#
# BBS1
# 0.0    138
# 1.0      6
# Name: BBS1, dtype: int64
#
#
# BBS2
# 0.0    139
# 1.0      5
# Name: BBS2, dtype: int64
#
#
# BBS4
# 0.0    131
# 1.0     13
# Name: BBS4, dtype: int64
#
#
# BBS5
# 0.0    129
# 1.0      7
# Name: BBS5, dtype: int64
#
#
# BBS7
# 0.0    140
# 1.0      4
# Name: BBS7, dtype: int64
#
#
# BBS9
# 0.0    140
# 1.0      4
# Name: BBS9, dtype: int64
#
#
# BBX
# 0.0    142
# 1.0      2
# Name: BBX, dtype: int64
#
#
# BCAM
# 0.0    138
# 1.0      6
# Name: BCAM, dtype: int64
#
#
# BCAP29
# 0.0    127
# 1.0     17
# Name: BCAP29, dtype: int64
#
#
# BCAP31
# 0.0    136
# 1.0      8
# Name: BCAP31, dtype: int64
#
#
# BCAR1
# 0.0    138
# 1.0      6
# Name: BCAR1, dtype: int64
#
#
# BCAR3
# 0.0    141
# 1.0      3
# Name: BCAR3, dtype: int64
#
#
# BCAS2
# 0.0    140
# 1.0      4
# Name: BCAS2, dtype: int64
#
#
# BCAS3
# 0.0    141
# 1.0      3
# Name: BCAS3, dtype: int64
#
#
# BCAT2
# 0.0    138
# 1.0      6
# Name: BCAT2, dtype: int64
#
#
# BCCIP
# 0.0    143
# 1.0      1
# Name: BCCIP, dtype: int64
#
#
# BCKDHA
# 0.0    140
# 1.0      4
# Name: BCKDHA, dtype: int64
#
#
# BCKDHB
# 0.0    138
# 1.0      6
# Name: BCKDHB, dtype: int64
#
#
# BCKDK
# 0.0    142
# 1.0      2
# Name: BCKDK, dtype: int64
#
#
# BCL10
# 0.0    132
# 1.0     12
# Name: BCL10, dtype: int64
#
#
# BCL11A
# 0.0    90
# 1.0     3
# Name: BCL11A, dtype: int64
#
#
# BCL2
# 0.0    123
# 1.0     13
# Name: BCL2, dtype: int64
#
#
# BCL2L1
# 0.0    135
# 1.0      9
# Name: BCL2L1, dtype: int64
#
#
# BCL2L11
# 0.0    106
# 1.0      5
# Name: BCL2L11, dtype: int64
#
#
# BCL2L12
# 0.0    80
# 1.0     1
# Name: BCL2L12, dtype: int64
#
#
# BCL2L13
# 0.0    143
# 1.0      1
# Name: BCL2L13, dtype: int64
#
#
# BCL2L14
# 0.0    111
# 1.0      1
# Name: BCL2L14, dtype: int64
#
#
# BCL2L15
# 0.0    143
# 1.0      1
# Name: BCL2L15, dtype: int64
#
#
# BCL2L2
# 0.0    122
# 1.0      4
# Name: BCL2L2, dtype: int64
#
#
# BCL3
# 0.0    140
# 1.0      4
# Name: BCL3, dtype: int64
#
#
# BCL6
# 0.0    100
# 1.0     10
# Name: BCL6, dtype: int64
#
#
# BCL7A
# 0.0    137
# 1.0      7
# Name: BCL7A, dtype: int64
#
#
# BCL7B
# 0.0    134
# 1.0     10
# Name: BCL7B, dtype: int64
#
#
# BCL7C
# 0.0    140
# 1.0      4
# Name: BCL7C, dtype: int64
#
#
# BCL9
# 0.0    138
# 1.0      6
# Name: BCL9, dtype: int64
#
#
# BCL9L
# 0.0    139
# 1.0      5
# Name: BCL9L, dtype: int64
#
#
# BCLAF1
# 0.0    135
# 1.0      9
# Name: BCLAF1, dtype: int64
#
#
# BCLAF3
# 0.0    142
# 1.0      2
# Name: BCLAF3, dtype: int64
#
#
# BCOR
# 0.0    137
# 1.0      7
# Name: BCOR, dtype: int64
#
#
# BCORL1
# 0.0    77
# 1.0    14
# Name: BCORL1, dtype: int64
#
#
# BCR
# 0.0    142
# 1.0      2
# Name: BCR, dtype: int64
#
#
# BCS1L
# 0.0    136
# 1.0      8
# Name: BCS1L, dtype: int64
#
#
# BDH1
# 0.0    143
# 1.0      1
# Name: BDH1, dtype: int64
#
#
# BDH2
# 0.0    138
# 1.0      6
# Name: BDH2, dtype: int64
#
#
# BECN1
# 0.0    140
# 1.0      4
# Name: BECN1, dtype: int64
#
#
# BEND3
# 0.0    142
# 1.0      2
# Name: BEND3, dtype: int64
#
#
# BEND5
# 0.0    25
# 1.0     1
# Name: BEND5, dtype: int64
#
#
# BEND7
# 0.0    22
# 1.0     3
# Name: BEND7, dtype: int64
#
#
# BET1
# 0.0    136
# 1.0      8
# Name: BET1, dtype: int64
#
#
# BET1L
# 0.0    143
# 1.0      1
# Name: BET1L, dtype: int64
#
#
# BHLHE40
# 0.0    87
# 1.0     3
# Name: BHLHE40, dtype: int64
#
#
# BHLHE41
# 0.0    41
# 1.0     3
# Name: BHLHE41, dtype: int64
#
#
# BICC1
# 0.0    137
# 1.0      6
# Name: BICC1, dtype: int64
#
#
# BICD1
# 0.0    139
# 1.0      5
# Name: BICD1, dtype: int64
#
#
# BICD2
# 0.0    140
# 1.0      4
# Name: BICD2, dtype: int64
#
#
# BICRA
# 0.0    139
# 1.0      5
# Name: BICRA, dtype: int64
#
#
# BICRAL
# 0.0    142
# 1.0      2
# Name: BICRAL, dtype: int64
#
#
# BID
# 0.0    143
# 1.0      1
# Name: BID, dtype: int64
#
#
# BIN1
# 0.0    143
# 1.0      1
# Name: BIN1, dtype: int64
#
#
# BIN2
# 0.0    142
# 1.0      2
# Name: BIN2, dtype: int64
#
#
# BIN3
# 0.0    141
# 1.0      3
# Name: BIN3, dtype: int64
#
#
# BIRC2
# 0.0    141
# 1.0      3
# Name: BIRC2, dtype: int64
#
#
# BIRC3
# 0.0    24
# 1.0     3
# Name: BIRC3, dtype: int64
#
#
# BIRC5
# 0.0    60
# 1.0     3
# Name: BIRC5, dtype: int64
#
#
# BIRC6
# 0.0    143
# 1.0      1
# Name: BIRC6, dtype: int64
#
#
# BLM
# 0.0    137
# 1.0      7
# Name: BLM, dtype: int64
#
#
# BLMH
# 0.0    134
# 1.0     10
# Name: BLMH, dtype: int64
#
#
# BLNK
# 0.0    143
# 1.0      1
# Name: BLNK, dtype: int64
#
#
# BLOC1S1
# 0.0    142
# 1.0      2
# Name: BLOC1S1, dtype: int64
#
#
# BLOC1S2
# 0.0    135
# 1.0      9
# Name: BLOC1S2, dtype: int64
#
#
# BLOC1S3
# 0.0    142
# 1.0      2
# Name: BLOC1S3, dtype: int64
#
#
# BLOC1S4
# 0.0    136
# 1.0      8
# Name: BLOC1S4, dtype: int64
#
#
# BLOC1S5
# 0.0    140
# 1.0      4
# Name: BLOC1S5, dtype: int64
#
#
# BLOC1S6
# 0.0    142
# 1.0      2
# Name: BLOC1S6, dtype: int64
#
#
# BLVRA
# 0.0    139
# 1.0      5
# Name: BLVRA, dtype: int64
#
#
# BLZF1
# 0.0    135
# 1.0      9
# Name: BLZF1, dtype: int64
#
#
# BMF
# 0.0    114
# 1.0      5
# Name: BMF, dtype: int64
#
#
# BMP1
# 0.0    132
# 1.0      3
# Name: BMP1, dtype: int64
#
#
# BMP2K
# 0.0    141
# 1.0      3
# Name: BMP2K, dtype: int64
#
#
# BMPR1B
# 0.0    83
# 1.0     1
# Name: BMPR1B, dtype: int64
#
#
# BMPR2
# 0.0    59
# 1.0     1
# Name: BMPR2, dtype: int64
#
#
# BMS1
# 0.0    137
# 1.0      7
# Name: BMS1, dtype: int64
#
#
# BMT2
# 0.0    45
# 1.0     3
# Name: BMT2, dtype: int64
#
#
# BMX
# 0.0    62
# 1.0     4
# Name: BMX, dtype: int64
#
#
# BNIP1
# 0.0    140
# 1.0      4
# Name: BNIP1, dtype: int64
#
#
# BNIP2
# 0.0    143
# 1.0      1
# Name: BNIP2, dtype: int64
#
#
# BNIP3
# 0.0    135
# 1.0      9
# Name: BNIP3, dtype: int64
#
#
# BNIP3L
# 0.0    106
# 1.0      3
# Name: BNIP3L, dtype: int64
#
#
# BOD1
# 0.0    142
# 1.0      2
# Name: BOD1, dtype: int64
#
#
# BOD1L1
# 0.0    141
# 1.0      3
# Name: BOD1L1, dtype: int64
#
#
# BOLA1
# 0.0    142
# 1.0      2
# Name: BOLA1, dtype: int64
#
#
# BOP1
# 0.0    138
# 1.0      6
# Name: BOP1, dtype: int64
#
#
# BORCS5
# 0.0    140
# 1.0      4
# Name: BORCS5, dtype: int64
#
#
# BORCS6
# 0.0    140
# 1.0      4
# Name: BORCS6, dtype: int64
#
#
# BORCS7
# 0.0    140
# 1.0      4
# Name: BORCS7, dtype: int64
#
#
# BORCS8
# 0.0    133
# 1.0     11
# Name: BORCS8, dtype: int64
#
#
# BPGM
# 0.0    143
# 1.0      1
# Name: BPGM, dtype: int64
#
#
# BPHL
# 0.0    140
# 1.0      4
# Name: BPHL, dtype: int64
#
#
# BPI
# 0.0    143
# 1.0      1
# Name: BPI, dtype: int64
#
#
# BPIFB1
# 0.0    132
# 1.0      5
# Name: BPIFB1, dtype: int64
#
#
# BPTF
# 0.0    132
# 1.0     12
# Name: BPTF, dtype: int64
#
#
# BRAF
# 0.0    132
# 1.0     12
# Name: BRAF, dtype: int64
#
#
# BRAP
# 0.0    139
# 1.0      5
# Name: BRAP, dtype: int64
#
#
# BRAT1
# 0.0    136
# ...
#
#
# YWHAZ
# 0.0    142
# 1.0      2
# Name: YWHAZ, dtype: int64
#
#
# YY1
# 0.0    142
# 1.0      2
# Name: YY1, dtype: int64
#
#
# YY1AP1
# 0.0    134
# 1.0      2
# Name: YY1AP1, dtype: int64
#
#
# YY2
# 0.0    140
# 1.0      4
# Name: YY2, dtype: int64
#
#
# ZADH2
# 0.0    136
# 1.0      8
# Name: ZADH2, dtype: int64
#
#
# ZAP70
# 0.0    139
# 1.0      5
# Name: ZAP70, dtype: int64
#
#
# ZBED1
# 0.0    135
# 1.0      9
# Name: ZBED1, dtype: int64
#
#
# ZBED3
# 0.0    139
# 1.0      5
# Name: ZBED3, dtype: int64
#
#
# ZBED5
# 0.0    109
# 1.0      2
# Name: ZBED5, dtype: int64
#
#
# ZBED8
# 0.0    132
# 1.0      3
# Name: ZBED8, dtype: int64
#
#
# ZBP1
# 0.0    76
# 1.0     1
# Name: ZBP1, dtype: int64
#
#
# ZBTB1
# 0.0    142
# 1.0      2
# Name: ZBTB1, dtype: int64
#
#
# ZBTB10
# 0.0    142
# 1.0      2
# Name: ZBTB10, dtype: int64
#
#
# ZBTB11
# 0.0    135
# 1.0      9
# Name: ZBTB11, dtype: int64
#
#
# ZBTB12
# 0.0    85
# 1.0     2
# Name: ZBTB12, dtype: int64
#
#
# ZBTB16
# 0.0    73
# 1.0     1
# Name: ZBTB16, dtype: int64
#
#
# ZBTB17
# 0.0    135
# 1.0      1
# Name: ZBTB17, dtype: int64
#
#
# ZBTB2
# 0.0    140
# 1.0      4
# Name: ZBTB2, dtype: int64
#
#
# ZBTB20
# 0.0    143
# 1.0      1
# Name: ZBTB20, dtype: int64
#
#
# ZBTB21
# 0.0    142
# 1.0      2
# Name: ZBTB21, dtype: int64
#
#
# ZBTB3
# 0.0    116
# 1.0      1
# Name: ZBTB3, dtype: int64
#
#
# ZBTB33
# 0.0    140
# 1.0      4
# Name: ZBTB33, dtype: int64
#
#
# ZBTB37
# 0.0    72
# 1.0     4
# Name: ZBTB37, dtype: int64
#
#
# ZBTB38
# 0.0    124
# 1.0      2
# Name: ZBTB38, dtype: int64
#
#
# ZBTB4
# 0.0    143
# 1.0      1
# Name: ZBTB4, dtype: int64
#
#
# ZBTB40
# 0.0    138
# 1.0      6
# Name: ZBTB40, dtype: int64
#
#
# ZBTB43
# 0.0    89
# 1.0     2
# Name: ZBTB43, dtype: int64
#
#
# ZBTB44
# 0.0    43
# 1.0     1
# Name: ZBTB44, dtype: int64
#
#
# ZBTB45
# 0.0    75
# 1.0     4
# Name: ZBTB45, dtype: int64
#
#
# ZBTB47
# 0.0    142
# 1.0      2
# Name: ZBTB47, dtype: int64
#
#
# ZBTB48
# 0.0    76
# 1.0     6
# Name: ZBTB48, dtype: int64
#
#
# ZBTB7A
# 0.0    133
# 1.0     11
# Name: ZBTB7A, dtype: int64
#
#
# ZBTB8A
# 0.0    109
# 1.0      5
# Name: ZBTB8A, dtype: int64
#
#
# ZBTB8OS
# 0.0    140
# 1.0      4
# Name: ZBTB8OS, dtype: int64
#
#
# ZBTB9
# 0.0    140
# 1.0      2
# Name: ZBTB9, dtype: int64
#
#
# ZC2HC1A
# 0.0    142
# 1.0      2
# Name: ZC2HC1A, dtype: int64
#
#
# ZC3H10
# 0.0    139
# 1.0      5
# Name: ZC3H10, dtype: int64
#
#
# ZC3H11A
# 0.0    142
# 1.0      2
# Name: ZC3H11A, dtype: int64
#
#
# ZC3H12A
# 0.0    131
# 1.0      4
# Name: ZC3H12A, dtype: int64
#
#
# ZC3H12C
# 0.0    66
# 1.0     1
# Name: ZC3H12C, dtype: int64
#
#
# ZC3H13
# 0.0    141
# 1.0      3
# Name: ZC3H13, dtype: int64
#
#
# ZC3H14
# 0.0    143
# 1.0      1
# Name: ZC3H14, dtype: int64
#
#
# ZC3H18
# 0.0    136
# 1.0      8
# Name: ZC3H18, dtype: int64
#
#
# ZC3H4
# 0.0    137
# 1.0      7
# Name: ZC3H4, dtype: int64
#
#
# ZC3H6
# 0.0    124
# 1.0      3
# Name: ZC3H6, dtype: int64
#
#
# ZC3H7A
# 0.0    139
# 1.0      5
# Name: ZC3H7A, dtype: int64
#
#
# ZC3H7B
# 0.0    133
# 1.0     11
# Name: ZC3H7B, dtype: int64
#
#
# ZC3H8
# 0.0    131
# 1.0      4
# Name: ZC3H8, dtype: int64
#
#
# ZC3HAV1
# 0.0    141
# 1.0      3
# Name: ZC3HAV1, dtype: int64
#
#
# ZC3HAV1L
# 0.0    141
# 1.0      3
# Name: ZC3HAV1L, dtype: int64
#
#
# ZC3HC1
# 0.0    141
# 1.0      3
# Name: ZC3HC1, dtype: int64
#
#
# ZCCHC10
# 0.0    88
# 1.0     7
# Name: ZCCHC10, dtype: int64
#
#
# ZCCHC12
# 0.0    107
# 1.0      4
# Name: ZCCHC12, dtype: int64
#
#
# ZCCHC17
# 0.0    141
# 1.0      3
# Name: ZCCHC17, dtype: int64
#
#
# ZCCHC24
# 0.0    143
# 1.0      1
# Name: ZCCHC24, dtype: int64
#
#
# ZCCHC3
# 0.0    143
# 1.0      1
# Name: ZCCHC3, dtype: int64
#
#
# ZCCHC4
# 0.0    80
# 1.0     5
# Name: ZCCHC4, dtype: int64
#
#
# ZCCHC7
# 0.0    142
# 1.0      2
# Name: ZCCHC7, dtype: int64
#
#
# ZCCHC8
# 0.0    138
# 1.0      6
# Name: ZCCHC8, dtype: int64
#
#
# ZCCHC9
# 0.0    137
# 1.0      7
# Name: ZCCHC9, dtype: int64
#
#
# ZDHHC13
# 0.0    141
# 1.0      3
# Name: ZDHHC13, dtype: int64
#
#
# ZDHHC17
# 0.0    138
# 1.0      5
# Name: ZDHHC17, dtype: int64
#
#
# ZDHHC18
# 0.0    76
# 1.0     2
# Name: ZDHHC18, dtype: int64
#
#
# ZDHHC2
# 0.0    33
# 1.0     1
# Name: ZDHHC2, dtype: int64
#
#
# ZDHHC20
# 0.0    137
# 1.0      7
# Name: ZDHHC20, dtype: int64
#
#
# ZDHHC21
# 0.0    105
# 1.0      3
# Name: ZDHHC21, dtype: int64
#
#
# ZDHHC3
# 0.0    137
# 1.0      7
# Name: ZDHHC3, dtype: int64
#
#
# ZDHHC4
# 0.0    86
# 1.0     8
# Name: ZDHHC4, dtype: int64
#
#
# ZDHHC5
# 0.0    141
# 1.0      3
# Name: ZDHHC5, dtype: int64
#
#
# ZDHHC7
# 0.0    100
# 1.0      4
# Name: ZDHHC7, dtype: int64
#
#
# ZER1
# 0.0    140
# 1.0      4
# Name: ZER1, dtype: int64
#
#
# ZFAND1
# 0.0    140
# 1.0      4
# Name: ZFAND1, dtype: int64
#
#
# ZFAND2B
# 0.0    142
# 1.0      2
# Name: ZFAND2B, dtype: int64
#
#
# ZFAND3
# 0.0    140
# 1.0      4
# Name: ZFAND3, dtype: int64
#
#
# ZFAND5
# 0.0    136
# 1.0      8
# Name: ZFAND5, dtype: int64
#
#
# ZFAND6
# 0.0    142
# 1.0      2
# Name: ZFAND6, dtype: int64
#
#
# ZFC3H1
# 0.0    141
# 1.0      3
# Name: ZFC3H1, dtype: int64
#
#
# ZFHX3
# 0.0    138
# 1.0      6
# Name: ZFHX3, dtype: int64
#
#
# ZFP1
# 0.0    100
# 1.0      2
# Name: ZFP1, dtype: int64
#
#
# ZFP3
# 0.0    111
# 1.0      9
# Name: ZFP3, dtype: int64
#
#
# ZFP36L1
# 0.0    138
# 1.0      6
# Name: ZFP36L1, dtype: int64
#
#
# ZFP36L2
# 0.0    140
# 1.0      4
# Name: ZFP36L2, dtype: int64
#
#
# ZFP37
# 0.0    47
# 1.0     4
# Name: ZFP37, dtype: int64
#
#
# ZFP62
# 0.0    51
# 1.0     2
# Name: ZFP62, dtype: int64
#
#
# ZFP90
# 0.0    139
# 1.0      5
# Name: ZFP90, dtype: int64
#
#
# ZFP91
# 0.0    132
# 1.0     12
# Name: ZFP91, dtype: int64
#
#
# ZFPL1
# 0.0    142
# 1.0      2
# Name: ZFPL1, dtype: int64
#
#
# ZFR
# 0.0    134
# 1.0     10
# Name: ZFR, dtype: int64
#
#
# ZFX
# 0.0    140
# 1.0      4
# Name: ZFX, dtype: int64
#
#
# ZFYVE1
# 0.0    135
# 1.0      9
# Name: ZFYVE1, dtype: int64
#
#
# ZFYVE16
# 0.0    138
# 1.0      6
# Name: ZFYVE16, dtype: int64
#
#
# ZFYVE19
# 0.0    136
# 1.0      8
# Name: ZFYVE19, dtype: int64
#
#
# ZFYVE26
# 0.0    138
# 1.0      6
# Name: ZFYVE26, dtype: int64
#
#
# ZFYVE27
# 0.0    143
# 1.0      1
# Name: ZFYVE27, dtype: int64
#
#
# ZFYVE9
# 0.0    141
# 1.0      3
# Name: ZFYVE9, dtype: int64
#
#
# ZG16B
# 0.0    59
# 1.0     1
# Name: ZG16B, dtype: int64
#
#
# ZGPAT
# 0.0    141
# 1.0      3
# Name: ZGPAT, dtype: int64
#
#
# ZHX1
# 0.0    139
# 1.0      5
# Name: ZHX1, dtype: int64
#
#
# ZHX2
# 0.0    137
# 1.0      7
# Name: ZHX2, dtype: int64
#
#
# ZKSCAN1
# 0.0    139
# 1.0      5
# Name: ZKSCAN1, dtype: int64
#
#
# ZKSCAN3
# 0.0    15
# 1.0     1
# Name: ZKSCAN3, dtype: int64
#
#
# ZKSCAN4
# 0.0    112
# 1.0      6
# Name: ZKSCAN4, dtype: int64
#
#
# ZKSCAN8
# 0.0    140
# 1.0      4
# Name: ZKSCAN8, dtype: int64
#
#
# ZMAT2
# 0.0    136
# 1.0      8
# Name: ZMAT2, dtype: int64
#
#
# ZMAT3
# 0.0    105
# 1.0      5
# Name: ZMAT3, dtype: int64
#
#
# ZMAT5
# 0.0    84
# 1.0     3
# Name: ZMAT5, dtype: int64
#
#
# ZMIZ1
# 0.0    140
# 1.0      4
# Name: ZMIZ1, dtype: int64
#
#
# ZMIZ2
# 0.0    143
# 1.0      1
# Name: ZMIZ2, dtype: int64
#
#
# ZMPSTE24
# 0.0    133
# 1.0     11
# Name: ZMPSTE24, dtype: int64
#
#
# ZMYM1
# 0.0    140
# 1.0      4
# Name: ZMYM1, dtype: int64
#
#
# ZMYM3
# 0.0    133
# 1.0     11
# Name: ZMYM3, dtype: int64
#
#
# ZMYM4
# 0.0    136
# 1.0      8
# Name: ZMYM4, dtype: int64
#
#
# ZMYND10
# 0.0    130
# 1.0      5
# Name: ZMYND10, dtype: int64
#
#
# ZMYND11
# 0.0    143
# 1.0      1
# Name: ZMYND11, dtype: int64
#
#
# ZMYND8
# 0.0    142
# 1.0      2
# Name: ZMYND8, dtype: int64
#
#
# ZNF106
# 0.0    121
# 1.0      5
# Name: ZNF106, dtype: int64
#
#
# ZNF121
# 0.0    115
# 1.0      3
# Name: ZNF121, dtype: int64
#
#
# ZNF131
# 0.0    142
# 1.0      2
# Name: ZNF131, dtype: int64
#
#
# ZNF134
# 0.0    8
# 1.0    1
# Name: ZNF134, dtype: int64
#
#
# ZNF140
# 0.0    16
# 1.0     1
# Name: ZNF140, dtype: int64
#
#
# ZNF143
# 0.0    139
# 1.0      5
# Name: ZNF143, dtype: int64
#
#
# ZNF146
# 0.0    137
# 1.0      7
# Name: ZNF146, dtype: int64
#
#
# ZNF148
# 0.0    139
# 1.0      5
# Name: ZNF148, dtype: int64
#
#
# ZNF157
# 0.0    5
# 1.0    1
# Name: ZNF157, dtype: int64
#
#
# ZNF16
# 0.0    42
# 1.0     5
# Name: ZNF16, dtype: int64
#
#
# ZNF184
# 0.0    108
# 1.0     14
# Name: ZNF184, dtype: int64
#
#
# ZNF195
# 0.0    66
# 1.0     6
# Name: ZNF195, dtype: int64
#
#
# ZNF2
# 0.0    35
# 1.0     1
# Name: ZNF2, dtype: int64
#
#
# ZNF207
# 0.0    137
# 1.0      7
# Name: ZNF207, dtype: int64
#
#
# ZNF217
# 0.0    143
# 1.0      1
# Name: ZNF217, dtype: int64
#
#
# ZNF219
# 0.0    142
# 1.0      2
# Name: ZNF219, dtype: int64
#
#
# ZNF22
# 0.0    140
# 1.0      4
# Name: ZNF22, dtype: int64
#
#
# ZNF224
# 0.0    23
# 1.0     4
# Name: ZNF224, dtype: int64
#
#
# ZNF250
# 0.0    96
# 1.0     4
# Name: ZNF250, dtype: int64
#
#
# ZNF253
# 0.0    66
# 1.0     2
# Name: ZNF253, dtype: int64
#
#
# ZNF260
# 0.0    96
# 1.0    11
# Name: ZNF260, dtype: int64
#
#
# ZNF263
# 0.0    57
# 1.0     3
# Name: ZNF263, dtype: int64
#
#
# ZNF264
# 0.0    94
# 1.0     1
# Name: ZNF264, dtype: int64
#
#
# ZNF268
# 0.0    31
# 1.0     4
# Name: ZNF268, dtype: int64
#
#
# ZNF275
# 0.0    42
# 1.0     1
# Name: ZNF275, dtype: int64
#
#
# ZNF276
# 0.0    136
# 1.0      8
# Name: ZNF276, dtype: int64
#
#
# ZNF277
# 0.0    64
# 1.0     5
# Name: ZNF277, dtype: int64
#
#
# ZNF280D
# 0.0    139
# 1.0      5
# Name: ZNF280D, dtype: int64
#
#
# ZNF281
# 0.0    141
# 1.0      3
# Name: ZNF281, dtype: int64
#
#
# ZNF282
# 0.0    132
# 1.0      4
# Name: ZNF282, dtype: int64
#
#
# ZNF286A
# 0.0    15
# 1.0     2
# Name: ZNF286A, dtype: int64
#
#
# ZNF292
# 0.0    138
# 1.0      6
# Name: ZNF292, dtype: int64
#
#
# ZNF3
# 0.0    106
# 1.0      2
# Name: ZNF3, dtype: int64
#
#
# ZNF304
# 0.0    24
# 1.0     2
# Name: ZNF304, dtype: int64
#
#
# ZNF316
# 0.0    140
# 1.0      4
# Name: ZNF316, dtype: int64
#
#
# ZNF318
# 0.0    142
# 1.0      2
# Name: ZNF318, dtype: int64
#
#
# ZNF320
# 0.0    72
# 1.0     2
# Name: ZNF320, dtype: int64
#
#
# ZNF324
# 0.0    83
# 1.0     3
# Name: ZNF324, dtype: int64
#
#
# ZNF326
# 0.0    138
# 1.0      6
# Name: ZNF326, dtype: int64
#
#
# ZNF329
# 0.0    92
# 1.0     6
# Name: ZNF329, dtype: int64
#
#
# ZNF330
# 0.0    135
# 1.0      9
# Name: ZNF330, dtype: int64
#
#
# ZNF331
# 0.0    132
# 1.0      4
# Name: ZNF331, dtype: int64
#
#
# ZNF33A
# 0.0    66
# 1.0     1
# Name: ZNF33A, dtype: int64
#
#
# ZNF346
# 0.0    136
# 1.0      8
# Name: ZNF346, dtype: int64
#
#
# ZNF358
# 0.0    140
# 1.0      4
# Name: ZNF358, dtype: int64
#
#
# ZNF362
# 0.0    137
# 1.0      7
# Name: ZNF362, dtype: int64
#
#
# ZNF384
# 0.0    138
# 1.0      6
# Name: ZNF384, dtype: int64
#
#
# ZNF385A
# 0.0    107
# 1.0      2
# Name: ZNF385A, dtype: int64
#
#
# ZNF391
# 0.0    89
# 1.0     4
# Name: ZNF391, dtype: int64
#
#
# ZNF395
# 0.0    108
# 1.0      1
# Name: ZNF395, dtype: int64
#
#
# ZNF397
# 0.0    122
# 1.0      4
# Name: ZNF397, dtype: int64
#
#
# ZNF407
# 0.0    127
# 1.0      2
# Name: ZNF407, dtype: int64
#
#
# ZNF408
# 0.0    82
# 1.0    13
# Name: ZNF408, dtype: int64
#
#
# ZNF410
# 0.0    133
# 1.0      2
# Name: ZNF410, dtype: int64
#
#
# ZNF414
# 0.0    134
# 1.0     10
# Name: ZNF414, dtype: int64
#
#
# ZNF418
# 0.0    24
# 1.0     1
# Name: ZNF418, dtype: int64
#
#
# ZNF423
# 0.0    123
# 1.0     12
# Name: ZNF423, dtype: int64
#
#
# ZNF428
# 0.0    140
# 1.0      4
# Name: ZNF428, dtype: int64
#
#
# ZNF430
# 0.0    27
# 1.0     4
# Name: ZNF430, dtype: int64
#
#
# ZNF431
# 0.0    68
# 1.0     2
# Name: ZNF431, dtype: int64
#
#
# ZNF432
# 0.0    29
# 1.0     3
# Name: ZNF432, dtype: int64
#
#
# ZNF436
# 0.0    138
# 1.0      6
# Name: ZNF436, dtype: int64
#
#
# ZNF444
# 0.0    127
# 1.0      1
# Name: ZNF444, dtype: int64
#
#
# ZNF446
# 0.0    129
# 1.0     15
# Name: ZNF446, dtype: int64
#
#
# ZNF451
# 0.0    136
# 1.0      8
# Name: ZNF451, dtype: int64
#
#
# ZNF460
# 0.0    140
# 1.0      4
# Name: ZNF460, dtype: int64
#
#
# ZNF462
# 0.0    133
# 1.0     11
# Name: ZNF462, dtype: int64
#
#
# ZNF467
# 0.0    78
# 1.0     6
# Name: ZNF467, dtype: int64
#
#
# ZNF48
# 0.0    123
# 1.0      3
# Name: ZNF48, dtype: int64
#
#
# ZNF480
# 0.0    29
# 1.0     2
# Name: ZNF480, dtype: int64
#
#
# ZNF501
# 0.0    60
# 1.0     1
# Name: ZNF501, dtype: int64
#
#
# ZNF502
# 0.0    8
# 1.0    1
# Name: ZNF502, dtype: int64
#
#
# ZNF507
# 0.0    55
# 1.0     2
# Name: ZNF507, dtype: int64
#
#
# ZNF511
# 0.0    140
# 1.0      4
# Name: ZNF511, dtype: int64
#
#
# ZNF512
# 0.0    143
# 1.0      1
# Name: ZNF512, dtype: int64
#
#
# ZNF512B
# 0.0    140
# 1.0      4
# Name: ZNF512B, dtype: int64
#
#
# ZNF516
# 0.0    140
# 1.0      4
# Name: ZNF516, dtype: int64
#
#
# ZNF526
# 0.0    135
# 1.0      8
# Name: ZNF526, dtype: int64
#
#
# ZNF532
# 0.0    138
# 1.0      6
# Name: ZNF532, dtype: int64
#
#
# ZNF543
# 0.0    16
# 1.0     1
# Name: ZNF543, dtype: int64
#
#
# ZNF548
# 0.0    16
# 1.0     2
# Name: ZNF548, dtype: int64
#
#
# ZNF551
# 0.0    22
# 1.0     3
# Name: ZNF551, dtype: int64
#
#
# ZNF552
# 0.0    125
# 1.0      1
# Name: ZNF552, dtype: int64
#
#
# ZNF561
# 0.0    23
# 1.0     1
# Name: ZNF561, dtype: int64
#
#
# ZNF565
# 0.0    78
# 1.0     5
# Name: ZNF565, dtype: int64
#
#
# ZNF568
# 0.0    16
# 1.0     2
# Name: ZNF568, dtype: int64
#
#
# ZNF570
# 0.0    24
# 1.0     3
# Name: ZNF570, dtype: int64
#
#
# ZNF574
# 0.0    138
# 1.0      6
# Name: ZNF574, dtype: int64
#
#
# ZNF579
# 0.0    134
# 1.0     10
# Name: ZNF579, dtype: int64
#
#
# ZNF580
# 0.0    80
# 1.0     7
# Name: ZNF580, dtype: int64
#
#
# ZNF581
# 0.0    130
# 1.0      5
# Name: ZNF581, dtype: int64
#
#
# ZNF589
# 0.0    80
# 1.0     7
# Name: ZNF589, dtype: int64
#
#
# ZNF592
# 0.0    138
# 1.0      6
# Name: ZNF592, dtype: int64
#
#
# ZNF593
# 0.0    138
# 1.0      6
# Name: ZNF593, dtype: int64
#
#
# ZNF597
# 0.0    89
# 1.0     4
# Name: ZNF597, dtype: int64
#
#
# ZNF598
# 0.0    143
# 1.0      1
# Name: ZNF598, dtype: int64
#
#
# ZNF609
# 0.0    135
# 1.0      9
# Name: ZNF609, dtype: int64
#
#
# ZNF618
# 0.0    140
# 1.0      4
# Name: ZNF618, dtype: int64
#
#
# ZNF622
# 0.0    140
# 1.0      4
# Name: ZNF622, dtype: int64
#
#
# ZNF623
# 0.0    49
# 1.0     1
# Name: ZNF623, dtype: int64
#
#
# ZNF627
# 0.0    98
# 1.0     4
# Name: ZNF627, dtype: int64
#
#
# ZNF629
# 0.0    142
# 1.0      2
# Name: ZNF629, dtype: int64
#
#
# ZNF638
# 0.0    141
# 1.0      3
# Name: ZNF638, dtype: int64
#
#
# ZNF639
# 0.0    120
# 1.0      6
# Name: ZNF639, dtype: int64
#
#
# ZNF644
# 0.0    137
# 1.0      7
# Name: ZNF644, dtype: int64
#
#
# ZNF649
# 0.0    102
# 1.0      8
# Name: ZNF649, dtype: int64
#
#
# ZNF652
# 0.0    140
# 1.0      4
# Name: ZNF652, dtype: int64
#
#
# ZNF654
# 0.0    131
# 1.0      4
# Name: ZNF654, dtype: int64
#
#
# ZNF655
# 0.0    105
# 1.0      6
# Name: ZNF655, dtype: int64
#
#
# ZNF658
# 0.0    35
# 1.0     3
# Name: ZNF658, dtype: int64
#
#
# ZNF660
# 0.0    25
# 1.0     1
# Name: ZNF660, dtype: int64
#
#
# ZNF664
# 0.0    109
# 1.0      3
# Name: ZNF664, dtype: int64
#
#
# ZNF668
# 0.0    122
# 1.0      7
# Name: ZNF668, dtype: int64
#
#
# ZNF672
# 0.0    100
# 1.0     10
# Name: ZNF672, dtype: int64
#
#
# ZNF687
# 0.0    142
# 1.0      2
# Name: ZNF687, dtype: int64
#
#
# ZNF688
# 0.0    134
# 1.0      1
# Name: ZNF688, dtype: int64
#
#
# ZNF691
# 0.0    141
# 1.0      3
# Name: ZNF691, dtype: int64
#
#
# ZNF7
# 0.0    46
# 1.0     5
# Name: ZNF7, dtype: int64
#
#
# ZNF703
# 0.0    137
# 1.0      7
# Name: ZNF703, dtype: int64
#
#
# ZNF704
# 0.0    143
# 1.0      1
# Name: ZNF704, dtype: int64
#
#
# ZNF706
# 0.0    139
# 1.0      5
# Name: ZNF706, dtype: int64
#
#
# ZNF713
# 0.0    80
# 1.0     6
# Name: ZNF713, dtype: int64
#
#
# ZNF740
# 0.0    142
# 1.0      2
# Name: ZNF740, dtype: int64
#
#
# ZNF746
# 0.0    128
# 1.0      6
# Name: ZNF746, dtype: int64
#
#
# ZNF76
# 0.0    129
# 1.0      6
# Name: ZNF76, dtype: int64
#
#
# ZNF768
# 0.0    141
# 1.0      3
# Name: ZNF768, dtype: int64
#
#
# ZNF771
# 0.0    132
# 1.0      4
# Name: ZNF771, dtype: int64
#
#
# ZNF773
# 0.0    34
# 1.0     1
# Name: ZNF773, dtype: int64
#
#
# ZNF777
# 0.0    100
# 1.0      1
# Name: ZNF777, dtype: int64
#
#
# ZNF780A
# 0.0    35
# 1.0     1
# Name: ZNF780A, dtype: int64
#
#
# ZNF787
# 0.0    137
# 1.0      7
# Name: ZNF787, dtype: int64
#
#
# ZNF8
# 0.0    136
# 1.0      8
# Name: ZNF8, dtype: int64
#
#
# ZNF800
# 0.0    143
# 1.0      1
# Name: ZNF800, dtype: int64
#
#
# ZNF816
# 0.0    26
# 1.0     1
# Name: ZNF816, dtype: int64
#
#
# ZNF827
# 0.0    137
# 1.0      7
# Name: ZNF827, dtype: int64
#
#
# ZNF830
# 0.0    142
# 1.0      2
# Name: ZNF830, dtype: int64
#
#
# ZNF837
# 0.0    56
# 1.0     2
# Name: ZNF837, dtype: int64
#
#
# ZNF84
# 0.0    92
# 1.0     1
# Name: ZNF84, dtype: int64
#
#
# ZNF845
# 0.0    55
# 1.0     3
# Name: ZNF845, dtype: int64
#
#
# ZNF852
# 0.0    52
# 1.0     7
# Name: ZNF852, dtype: int64
#
#
# ZNF888
# 0.0    41
# 1.0     2
# Name: ZNF888, dtype: int64
#
#
# ZNFX1
# 0.0    139
# 1.0      5
# Name: ZNFX1, dtype: int64
#
#
# ZNHIT1
# 0.0    136
# 1.0      8
# Name: ZNHIT1, dtype: int64
#
#
# ZNHIT2
# 0.0    140
# 1.0      4
# Name: ZNHIT2, dtype: int64
#
#
# ZNHIT3
# 0.0    126
# 1.0      1
# Name: ZNHIT3, dtype: int64
#
#
# ZNHIT6
# 0.0    143
# 1.0      1
# Name: ZNHIT6, dtype: int64
#
#
# ZNRD1
# 0.0    137
# 1.0      7
# Name: ZNRD1, dtype: int64
#
#
# ZNRF1
# 0.0    123
# 1.0      4
# Name: ZNRF1, dtype: int64
#
#
# ZNRF2
# 0.0    143
# 1.0      1
# Name: ZNRF2, dtype: int64
#
#
# ZPR1
# 0.0    142
# 1.0      2
# Name: ZPR1, dtype: int64
#
#
# ZRANB2
# 0.0    140
# 1.0      4
# Name: ZRANB2, dtype: int64
#
#
# ZRSR2
# 0.0    129
# 1.0      7
# Name: ZRSR2, dtype: int64
#
#
# ZSCAN18
# 0.0    142
# 1.0      2
# Name: ZSCAN18, dtype: int64
#
#
# ZSCAN21
# 0.0    130
# 1.0      7
# Name: ZSCAN21, dtype: int64
#
#
# ZSCAN26
# 0.0    142
# 1.0      2
# Name: ZSCAN26, dtype: int64
#
#
# ZSCAN31
# 0.0    106
# 1.0     11
# Name: ZSCAN31, dtype: int64
#
#
# ZSWIM8
# 0.0    139
# 1.0      5
# Name: ZSWIM8, dtype: int64
#
#
# ZSWIM9
# 0.0    99
# 1.0     1
# Name: ZSWIM9, dtype: int64
#
#
# ZW10
# 0.0    139
# 1.0      5
# Name: ZW10, dtype: int64
#
#
# ZWILCH
# 0.0    143
# 1.0      1
# Name: ZWILCH, dtype: int64
#
#
# ZWINT
# 0.0    112
# 1.0      6
# Name: ZWINT, dtype: int64
#
#
# ZXDC
# 0.0    139
# 1.0      5
# Name: ZXDC, dtype: int64
#
#
# ZYG11B
# 0.0    143
# 1.0      1
# Name: ZYG11B, dtype: int64
#
#
# ZZEF1
# 0.0    137
# 1.0      7
# Name: ZZEF1, dtype: int64
#
#
# ZZZ3
# 0.0    140
# 1.0      4
# Name: ZZZ3, dtype: int64

# %%
sum_outliers = just_outliers_copy.sum(skipna=True)

# %%
most_outliers = sum_outliers[high_count]
most_outliers.sort_values(ascending=False)[-12:].plot(kind='bar')
plt.show()

# %% [markdown]
# ## Step 4: Wrap your A/B test into the outliers analysis, and create a table

# %%
#Potentially show the the name of the dataset we're working with.
print("Testing for proteomics dataset:\n")
results_prot = blsh.compare_groups_outliers(outliers_prot, 
                                            annotations)

print("\nTesting for transcriptomics dataset:\n")
results_mRNA = blsh.compare_groups_outliers(outliers_mRNA, 
                                            annotations)
# Out:
# Testing for proteomics dataset:
#
# No rows had outliers in at least 0.3 of MSI_status MSS samples
# Testing 10 rows for enrichment in MSI_status MSI-H samples
#
# Testing for transcriptomics dataset:
#
# No rows had outliers in at least 0.3 of MSI_status MSS samples
# Testing 39 rows for enrichment in MSI_status MSI-H samples

# %% [markdown]
# Many of the return values from the compare_groups_outliers function are NaN, so we will drop the unnecessary values

# %%
results_prot = results_prot.dropna(axis=0, how='all')
results_mRNA = results_mRNA.dropna(axis=0, how='all')

# %% [markdown]
# ## Step 5: Visualize these enrichments

# %%
sns.heatmap(results_prot)
plt.show()

# %%
sns.heatmap(results_mRNA)
plt.show()

# %% [markdown]
# ## Step 6: Determine significant enrichments, and link with cancer drug database.

# %%
#Check for significant columns in proteomics
for col in results_prot.columns:
    bf.significantEnrichments(results_prot, col)

#Check for significant columns in proteomics
for col in results_mRNA.columns:
    bf.significantEnrichments(results_mRNA, col)
# Out:
# 10 significant protein enrichments in MSI_status_MSI-H
#
# 35 significant protein enrichments in MSI_status_MSI-H

# %%
#Store the dataframe of significant enrichments
column = 'MSI_status_MSI-H_enrichment_FDR'
sig_results_prot = bf.significantEnrichments(results_prot, column)
sig_results_mRNA = bf.significantEnrichments(results_mRNA, column)
# Out:
# 10 significant protein enrichments in MSI_status_MSI-H
#
# 35 significant protein enrichments in MSI_status_MSI-H

# %% [markdown]
# As mentioned in our paper, we see a significant down regulation in MLH1 and EPM2AIP1 in both protein and mRNA levels for patients with MSI-High status.

# %%
print('MLH1' in sig_results_prot.index)
print('EPM2AIP1' in sig_results_prot.index)
print('MLH1' in sig_results_mRNA.index)
print('EPM2AIP1' in sig_results_mRNA.index)
# Out:
# True
# True
# True
# True

# %% [markdown]
# Additionally, PMS1 and PMS2, which are two binding partners of MLH1, are downregulated at the protein level (not mRNA)

# %%
print('PMS1' in sig_results_prot.index)
print('PMS1' in sig_results_mRNA.index)
print('PMS2' in sig_results_prot.index)
print('PMS2' in sig_results_mRNA.index)
# Out:
# True
# False
# True
# False
