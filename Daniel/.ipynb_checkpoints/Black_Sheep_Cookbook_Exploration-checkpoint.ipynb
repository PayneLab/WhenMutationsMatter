# %% [markdown]
# ## BlackSheep Cookbook MSI Upregulation
#
# The Black Sheep Analysis allows researchers to find trends in abnormal protein enrichment among patients in CPTAC datasets. In this Cookbook, we will go through the steps needed to perform a full Black Sheep Analysis.

# %% [markdown]
# ### Step 1a: Import Dependencies
# First, import the necessary dependencies and load cptac data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cptac
import binarization_functions as bf
import blackSheepCPTACmoduleCopy as blsh
en = cptac.Endometrial()
# Out:
# Checking that data files are up-to-date...
# 100% [..................................................................................] 649 / 649
# Data check complete.
# endometrial data version: 2.1
#
# Loading acetylproteomics data...
# Loading clinical data...
# Loading CNA data...
# Loading definitions data...
# Loading miRNA data...
# Loading phosphoproteomics_gene data...
# Loading phosphoproteomics_site data...
# Loading proteomics data...
# Loading somatic data...
# Loading somatic_binary data...
# Loading transcriptomics_circular data...
# Loading transcriptomics_linear data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but analysis may not be
# published until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter cptac.embargo() to open the webpage for more details.

# %% [markdown]
# ## Step 1b: Load Data and Choose Omics Table

# %%
en = cptac.Endometrial()
proteomics = en.get_proteomics()
mRNA = en.get_transcriptomics()
clinical = en.get_clinical()
# Out:
# Checking that data files are up-to-date...
# 100% [..................................................................................] 649 / 649
# Data check complete.
# endometrial data version: 2.1
#
# Loading acetylproteomics data...
# Loading clinical data...
# Loading CNA data...
# Loading definitions data...
# Loading miRNA data...
# Loading phosphoproteomics_gene data...
# Loading phosphoproteomics_site data...
# Loading proteomics data...
# Loading somatic data...
# Loading somatic_binary data...
# Loading transcriptomics_circular data...
# Loading transcriptomics_linear data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but analysis may not be
# published until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter cptac.embargo() to open the webpage for more details.

# %%
#Append Genomics_subtype and MSI_status to en.get_clinical()
df= en.get_derived_molecular()
clinical['MSI_status'] = df['MSI_status']
clinical['Genomics_subtype'] = df['Genomics_subtype']

# %% [markdown]
# ## Step 2: Determine what attributes you would like to A/B test.
# For this analysis, we will iteratively go through the various columns in the clinical dataset, to determine if any of them have trends within them for protein enrichment.

# %%
#Create a copy of the original Clinical DataFrame and drop irrelevant columns.
'''
IRRELEVANT COLUMNS:
Patient_ID, Treatment_naive, Tumor_purity, Gender, 
Tumor_Site_Other(not irrelevant, but too many things to binarize),
'''

annotations = pd.DataFrame(clinical.copy())
annotations = annotations.drop(['Patient_ID', 
                                'Treatment_naive', 
                                'Tumor_purity', 
                                'Gender', 
                                'Tumor_Site_Other'], axis=1)

# %% [markdown]
# ## Step 2a: Binarize column values

# %%
tumor_map = {'Tumor':'Normal_Tumor', 
             'Adjacent_normal':'Other_tumor', 
             'Enriched_normal':'Other_tumor', 
             'Myometrium_normal':'Other_tumor'}

annotations['Proteomics_Tumor_Normal'] = bf.binarizeCategorical(clinical, 
                                                                'Proteomics_Tumor_Normal', 
                                                                tumor_map)

country_map = {'United States':'US', 
               'Ukraine':'Other', 
               'Other_specify':'Other', 
               'Poland':'Other'}

annotations['Country'] = bf.binarizeCategorical(clinical, 
                                                'Country', 
                                                country_map)

annotations['BMI'] = bf.binarizeRange(clinical, 'BMI', 18, 25, 
                                      'Healthy', 'Unhealthy')

annotations['Age'] = bf.binarizeCutOff(clinical, 'Age', 
                                       60.0, 'Old', 'Young')
FIGO_map = {'FIGO grade 1':'Low_grade', 
            'FIGO grade 2':'High_grade', 
            'FIGO grade 3':'High_grade'}

annotations['Histologic_Grade_FIGO'] = bf.binarizeCategorical(clinical, 
                                                              'Histologic_Grade_FIGO', 
                                                              FIGO_map)
Myo_map = {'under 50 %':'under 50 %', 
           '50 % or more': '50 % or more', 
           'Not identified': 'under 50 %'}

annotations['Myometrial_invasion_Specify'] = bf.binarizeCategorical(clinical, 
                                                                    'Myometrial_invasion_Specify', 
                                                                    Myo_map)
path_tumor_map = {'pT1a (FIGO IA)':'Not_FIGO_III', 
            'pT1b (FIGO IB)':'Not_FIGO_III', 
            'pT2 (FIGO II)':'Not_FIGO_III', 
            'pT1 (FIGO I)':'Not_FIGO_III', 
            'pT3a (FIGO IIIA)':'FIGO_III', 
            'pT3b (FIGO IIIB)':'FIGO_III'}

annotations['Path_Stage_Primary_Tumor-pT'] = bf.binarizeCategorical(clinical, 
                                                                    'Path_Stage_Primary_Tumor-pT', 
                                                                    path_tumor_map)

path_lymph_map = {'pN0':'Not_FIGO_III', 
                  'pNX':'Not_FIGO_III', 
                  'pN1 (FIGO IIIC1)':'FIGO_III', 
                  'pN2 (FIGO IIIC2)':'FIGO_III'}

annotations['Path_Stage_Reg_Lymph_Nodes-pN'] = bf.binarizeCategorical(clinical, 
                                                                      'Path_Stage_Reg_Lymph_Nodes-pN', 
                                                                      path_lymph_map)
clin_stage_map = {'cM0':'cM0_or_cM1', 
                  'cM1':'cM0_or_cM1', 
                  'Staging_Incomplete':'Staging_Incomplete'}

annotations['Clin_Stage_Dist_Mets-cM'] = bf.binarizeCategorical(clinical, 
                                                                'Clin_Stage_Dist_Mets-cM', 
                                                                clin_stage_map)

path_stage_map = {'Staging Incomplete': 'No distant metastasis', 
                  'No pathologic evidence of distant metastasis':'No distant metastasis', 
                  'pM1':'Distant Metastasis'}

annotations['Path_Stage_Dist_Mets-pM'] = bf.binarizeCategorical(clinical, 
                                                                'Path_Stage_Dist_Mets-pM', 
                                                                path_stage_map)

tumor_stage_map = {'Stage I':'Stage I or II', 
                   'Stage II':'Stage I or II', 
                   'Stage III':'Stage III or IV', 
                   'Stage IV':'Stage III or IV'}

annotations['tumor_Stage-Pathological'] = bf.binarizeCategorical(clinical, 
                                                               'tumor_Stage-Pathological', 
                                                               tumor_stage_map)
FIGO_stage_map = {'IA':'I or II', 
                  'IB':'I or II', 
                  'II':'I or II', 
                  'IIIA':'III or IV', 
                  'IIIC1':'III or IV', 
                  'IVB':'III or IV', 
                  'IIIC2':'III or IV', 
                  'IIIB':'III or IV'}

annotations['FIGO_stage'] = bf.binarizeCategorical(clinical, 
                                                   'FIGO_stage', 
                                                   FIGO_stage_map)
diabetes_map = {'No':'No', 
                'Yes':'Yes', 
                'Unknown':'No'}

annotations['Diabetes'] = bf.binarizeCategorical(clinical, 
                                                 'Diabetes', 
                                                 diabetes_map)

race_map = {'White':'White', 
            'Black or African American':'Not_White', 
            'Asian':'Not_White', 
            'Not Reported':'Not_White'}

annotations['Race'] = bf.binarizeCategorical(clinical, 
                                             'Race', 
                                             race_map)

ethnicity_map = {'Not-Hispanic or Latino':'Not_Hispanic', 
                 'Not reported':'Not_Hispanic', 
                 'Hispanic or Latino':'Hispanic'}

annotations['Ethnicity'] = bf.binarizeCategorical(clinical, 
                                                  'Ethnicity', 
                                                  ethnicity_map)

tumor_site_map = {'Other, specify':'Not_Anterior', 
                  'Anterior endometrium':'Anterior', 
                  'Posterior endometrium':'Not_Anterior'}

annotations['Tumor_Site'] = bf.binarizeCategorical(clinical, 
                                                   'Tumor_Site', 
                                                   tumor_site_map)

annotations['Tumor_Size_cm'] = bf.binarizeCutOff(clinical, 
                                                'Tumor_Size_cm', 4.0, 
                                                'Large_tumor', 
                                                'Small_tumor')

num_pregnancies_map = {2:'Less_than_3', 
                       1:'Less_than_3', 
                       'None':'Less_than_3', 
                       None:'Less_than_3', 
                       3:'3_or_more', 
                       '4 or more':'3_or_more'}

annotations['Num_full_term_pregnancies'] = bf.binarizeCategorical(clinical, 
                                                                  'Num_full_term_pregnancies', 
                                                                  num_pregnancies_map)

genomics_map = {'MSI-H':'MSI-H', 
                'CNV_low':'Other_subtype', 
                'CNV_high':'Other_subtype', 
                'POLE':'Other_subtype'}

annotations['Genomics_subtype'] = bf.binarizeCategorical(clinical, 
                                                         'Genomics_subtype', 
                                                         genomics_map)

# %%
annotations
# Out:
#           Proteomics_Tumor_Normal Country Histologic_Grade_FIGO  \
# Sample_ID
# S001                 Normal_Tumor      US             Low_grade
# S002                 Normal_Tumor      US             Low_grade
# S003                 Normal_Tumor      US            High_grade
# S005                 Normal_Tumor      US            High_grade
# S006                 Normal_Tumor      US                   NaN
# S007                 Normal_Tumor      US             Low_grade
# S008                 Normal_Tumor   Other            High_grade
# S009                 Normal_Tumor      US                   NaN
# S010                 Normal_Tumor      US             Low_grade
# S011                 Normal_Tumor      US             Low_grade
# S012                 Normal_Tumor      US             Low_grade
# S014                 Normal_Tumor      US            High_grade
# S016                 Normal_Tumor      US                   NaN
# S017                 Normal_Tumor      US             Low_grade
# S018                 Normal_Tumor      US             Low_grade
# S019                 Normal_Tumor      US             Low_grade
# S020                 Normal_Tumor      US            High_grade
# S021                 Normal_Tumor   Other             Low_grade
# S022                 Normal_Tumor      US             Low_grade
# S023                 Normal_Tumor      US             Low_grade
# S024                 Normal_Tumor      US            High_grade
# S025                 Normal_Tumor   Other             Low_grade
# S026                 Normal_Tumor   Other            High_grade
# S027                 Normal_Tumor   Other             Low_grade
# S028                 Normal_Tumor   Other            High_grade
# S029                 Normal_Tumor   Other            High_grade
# S030                 Normal_Tumor   Other            High_grade
# S031                 Normal_Tumor      US            High_grade
# S032                 Normal_Tumor   Other             Low_grade
# S033                 Normal_Tumor      US            High_grade
# ...                           ...     ...                   ...
# S124                  Other_tumor     NaN                   NaN
# S125                  Other_tumor     NaN                   NaN
# S126                  Other_tumor     NaN                   NaN
# S127                  Other_tumor     NaN                   NaN
# S128                  Other_tumor     NaN                   NaN
# S129                  Other_tumor     NaN                   NaN
# S130                  Other_tumor     NaN                   NaN
# S131                  Other_tumor     NaN                   NaN
# S132                  Other_tumor     NaN                   NaN
# S133                  Other_tumor     NaN                   NaN
# S134                  Other_tumor     NaN                   NaN
# S135                  Other_tumor     NaN                   NaN
# S136                  Other_tumor     NaN                   NaN
# S137                  Other_tumor     NaN                   NaN
# S138                  Other_tumor     NaN                   NaN
# S139                  Other_tumor     NaN                   NaN
# S140                  Other_tumor     NaN                   NaN
# S141                  Other_tumor     NaN                   NaN
# S142                  Other_tumor     NaN                   NaN
# S143                  Other_tumor     NaN                   NaN
# S144                  Other_tumor     NaN                   NaN
# S145                  Other_tumor     NaN                   NaN
# S146                  Other_tumor     NaN                   NaN
# S147                  Other_tumor     NaN                   NaN
# S148                  Other_tumor     NaN                   NaN
# S149                  Other_tumor     NaN                   NaN
# S150                  Other_tumor     NaN                   NaN
# S151                  Other_tumor     NaN                   NaN
# S152                  Other_tumor     NaN                   NaN
# S153                  Other_tumor     NaN                   NaN
#
#           Myometrial_invasion_Specify Histologic_type  \
# Sample_ID
# S001                       under 50 %    Endometrioid
# S002                       under 50 %    Endometrioid
# S003                       under 50 %    Endometrioid
# S005                       under 50 %    Endometrioid
# S006                       under 50 %          Serous
# S007                       under 50 %    Endometrioid
# S008                       under 50 %    Endometrioid
# S009                     50 % or more          Serous
# S010                       under 50 %    Endometrioid
# S011                       under 50 %    Endometrioid
# S012                       under 50 %    Endometrioid
# S014                     50 % or more    Endometrioid
# S016                     50 % or more          Serous
# S017                       under 50 %    Endometrioid
# S018                       under 50 %    Endometrioid
# S019                       under 50 %    Endometrioid
# S020                       under 50 %    Endometrioid
# S021                       under 50 %    Endometrioid
# S022                       under 50 %    Endometrioid
# S023                       under 50 %    Endometrioid
# S024                       under 50 %    Endometrioid
# S025                       under 50 %    Endometrioid
# S026                     50 % or more    Endometrioid
# S027                       under 50 %    Endometrioid
# S028                     50 % or more    Endometrioid
# S029                       under 50 %    Endometrioid
# S030                     50 % or more    Endometrioid
# S031                     50 % or more    Endometrioid
# S032                       under 50 %    Endometrioid
# S033                     50 % or more    Endometrioid
# ...                               ...             ...
# S124                              NaN             NaN
# S125                              NaN             NaN
# S126                              NaN             NaN
# S127                              NaN             NaN
# S128                              NaN             NaN
# S129                              NaN             NaN
# S130                              NaN             NaN
# S131                              NaN             NaN
# S132                              NaN             NaN
# S133                              NaN             NaN
# S134                              NaN             NaN
# S135                              NaN             NaN
# S136                              NaN             NaN
# S137                              NaN             NaN
# S138                              NaN             NaN
# S139                              NaN             NaN
# S140                              NaN             NaN
# S141                              NaN             NaN
# S142                              NaN             NaN
# S143                              NaN             NaN
# S144                              NaN             NaN
# S145                              NaN             NaN
# S146                              NaN             NaN
# S147                              NaN             NaN
# S148                              NaN             NaN
# S149                              NaN             NaN
# S150                              NaN             NaN
# S151                              NaN             NaN
# S152                              NaN             NaN
# S153                              NaN             NaN
#
#           Path_Stage_Primary_Tumor-pT Path_Stage_Reg_Lymph_Nodes-pN  \
# Sample_ID
# S001                     Not_FIGO_III                  Not_FIGO_III
# S002                     Not_FIGO_III                  Not_FIGO_III
# S003                     Not_FIGO_III                  Not_FIGO_III
# S005                     Not_FIGO_III                  Not_FIGO_III
# S006                     Not_FIGO_III                  Not_FIGO_III
# S007                     Not_FIGO_III                  Not_FIGO_III
# S008                     Not_FIGO_III                  Not_FIGO_III
# S009                         FIGO_III                  Not_FIGO_III
# S010                     Not_FIGO_III                  Not_FIGO_III
# S011                     Not_FIGO_III                  Not_FIGO_III
# S012                     Not_FIGO_III                  Not_FIGO_III
# S014                     Not_FIGO_III                  Not_FIGO_III
# S016                     Not_FIGO_III                  Not_FIGO_III
# S017                     Not_FIGO_III                  Not_FIGO_III
# S018                     Not_FIGO_III                  Not_FIGO_III
# S019                     Not_FIGO_III                  Not_FIGO_III
# S020                     Not_FIGO_III                  Not_FIGO_III
# S021                     Not_FIGO_III                  Not_FIGO_III
# S022                     Not_FIGO_III                      FIGO_III
# S023                     Not_FIGO_III                  Not_FIGO_III
# S024                     Not_FIGO_III                  Not_FIGO_III
# S025                     Not_FIGO_III                  Not_FIGO_III
# S026                     Not_FIGO_III                  Not_FIGO_III
# S027                     Not_FIGO_III                  Not_FIGO_III
# S028                         FIGO_III                  Not_FIGO_III
# S029                     Not_FIGO_III                  Not_FIGO_III
# S030                     Not_FIGO_III                  Not_FIGO_III
# S031                     Not_FIGO_III                      FIGO_III
# S032                     Not_FIGO_III                  Not_FIGO_III
# S033                     Not_FIGO_III                  Not_FIGO_III
# ...                               ...                           ...
# S124                              NaN                           NaN
# S125                              NaN                           NaN
# S126                              NaN                           NaN
# S127                              NaN                           NaN
# S128                              NaN                           NaN
# S129                              NaN                           NaN
# S130                              NaN                           NaN
# S131                              NaN                           NaN
# S132                              NaN                           NaN
# S133                              NaN                           NaN
# S134                              NaN                           NaN
# S135                              NaN                           NaN
# S136                              NaN                           NaN
# S137                              NaN                           NaN
# S138                              NaN                           NaN
# S139                              NaN                           NaN
# S140                              NaN                           NaN
# S141                              NaN                           NaN
# S142                              NaN                           NaN
# S143                              NaN                           NaN
# S144                              NaN                           NaN
# S145                              NaN                           NaN
# S146                              NaN                           NaN
# S147                              NaN                           NaN
# S148                              NaN                           NaN
# S149                              NaN                           NaN
# S150                              NaN                           NaN
# S151                              NaN                           NaN
# S152                              NaN                           NaN
# S153                              NaN                           NaN
#
#           Clin_Stage_Dist_Mets-cM Path_Stage_Dist_Mets-pM  \
# Sample_ID
# S001                   cM0_or_cM1   No distant metastasis
# S002                   cM0_or_cM1   No distant metastasis
# S003                   cM0_or_cM1   No distant metastasis
# S005                   cM0_or_cM1   No distant metastasis
# S006                   cM0_or_cM1   No distant metastasis
# S007                   cM0_or_cM1   No distant metastasis
# S008                   cM0_or_cM1   No distant metastasis
# S009                   cM0_or_cM1   No distant metastasis
# S010                   cM0_or_cM1   No distant metastasis
# S011                          NaN   No distant metastasis
# S012                   cM0_or_cM1   No distant metastasis
# S014                          NaN   No distant metastasis
# S016                   cM0_or_cM1   No distant metastasis
# S017                   cM0_or_cM1   No distant metastasis
# S018                   cM0_or_cM1   No distant metastasis
# S019                   cM0_or_cM1   No distant metastasis
# S020                   cM0_or_cM1   No distant metastasis
# S021                   cM0_or_cM1   No distant metastasis
# S022                   cM0_or_cM1   No distant metastasis
# S023                   cM0_or_cM1   No distant metastasis
# S024                   cM0_or_cM1   No distant metastasis
# S025                   cM0_or_cM1   No distant metastasis
# S026                   cM0_or_cM1   No distant metastasis
# S027                   cM0_or_cM1   No distant metastasis
# S028                   cM0_or_cM1   No distant metastasis
# S029                   cM0_or_cM1   No distant metastasis
# S030                   cM0_or_cM1   No distant metastasis
# S031                          NaN   No distant metastasis
# S032                   cM0_or_cM1   No distant metastasis
# S033                   cM0_or_cM1   No distant metastasis
# ...                           ...                     ...
# S124                          NaN                     NaN
# S125                          NaN                     NaN
# S126                          NaN                     NaN
# S127                          NaN                     NaN
# S128                          NaN                     NaN
# S129                          NaN                     NaN
# S130                          NaN                     NaN
# S131                          NaN                     NaN
# S132                          NaN                     NaN
# S133                          NaN                     NaN
# S134                          NaN                     NaN
# S135                          NaN                     NaN
# S136                          NaN                     NaN
# S137                          NaN                     NaN
# S138                          NaN                     NaN
# S139                          NaN                     NaN
# S140                          NaN                     NaN
# S141                          NaN                     NaN
# S142                          NaN                     NaN
# S143                          NaN                     NaN
# S144                          NaN                     NaN
# S145                          NaN                     NaN
# S146                          NaN                     NaN
# S147                          NaN                     NaN
# S148                          NaN                     NaN
# S149                          NaN                     NaN
# S150                          NaN                     NaN
# S151                          NaN                     NaN
# S152                          NaN                     NaN
# S153                          NaN                     NaN
#
#           tumor_Stage-Pathological  ...    Age  Diabetes       Race  \
# Sample_ID                           ...
# S001                 Stage I or II  ...    Old        No      White
# S002               Stage III or IV  ...  Young        No      White
# S003                 Stage I or II  ...  Young       Yes      White
# S005                 Stage I or II  ...    Old        No      White
# S006                 Stage I or II  ...    Old        No      White
# S007                 Stage I or II  ...  Young        No      White
# S008                 Stage I or II  ...    Old        No      White
# S009               Stage III or IV  ...    Old        No      White
# S010                 Stage I or II  ...    Old       Yes      White
# S011                 Stage I or II  ...  Young       Yes      White
# S012                 Stage I or II  ...  Young       Yes      White
# S014                 Stage I or II  ...  Young        No      White
# S016                 Stage I or II  ...    Old        No      White
# S017                 Stage I or II  ...    Old       Yes      White
# S018                 Stage I or II  ...  Young       Yes      White
# S019                 Stage I or II  ...    Old        No      White
# S020                 Stage I or II  ...  Young        No      White
# S021                 Stage I or II  ...    Old       Yes  Not_White
# S022               Stage III or IV  ...  Young        No      White
# S023                 Stage I or II  ...  Young        No      White
# S024                 Stage I or II  ...    Old        No      White
# S025                 Stage I or II  ...  Young        No      White
# S026                 Stage I or II  ...  Young        No      White
# S027                 Stage I or II  ...    Old       Yes      White
# S028               Stage III or IV  ...    Old        No      White
# S029                 Stage I or II  ...    Old       Yes      White
# S030                 Stage I or II  ...  Young        No      White
# S031               Stage III or IV  ...    Old        No      White
# S032                 Stage I or II  ...    Old       Yes      White
# S033                 Stage I or II  ...    Old        No      White
# ...                            ...  ...    ...       ...        ...
# S124                           NaN  ...    NaN       NaN        NaN
# S125                           NaN  ...    NaN       NaN        NaN
# S126                           NaN  ...    NaN       NaN        NaN
# S127                           NaN  ...    NaN       NaN        NaN
# S128                           NaN  ...    NaN       NaN        NaN
# S129                           NaN  ...    NaN       NaN        NaN
# S130                           NaN  ...    NaN       NaN        NaN
# S131                           NaN  ...    NaN       NaN        NaN
# S132                           NaN  ...    NaN       NaN        NaN
# S133                           NaN  ...    NaN       NaN        NaN
# S134                           NaN  ...    NaN       NaN        NaN
# S135                           NaN  ...    NaN       NaN        NaN
# S136                           NaN  ...    NaN       NaN        NaN
# S137                           NaN  ...    NaN       NaN        NaN
# S138                           NaN  ...    NaN       NaN        NaN
# S139                           NaN  ...    NaN       NaN        NaN
# S140                           NaN  ...    NaN       NaN        NaN
# S141                           NaN  ...    NaN       NaN        NaN
# S142                           NaN  ...    NaN       NaN        NaN
# S143                           NaN  ...    NaN       NaN        NaN
# S144                           NaN  ...    NaN       NaN        NaN
# S145                           NaN  ...    NaN       NaN        NaN
# S146                           NaN  ...    NaN       NaN        NaN
# S147                           NaN  ...    NaN       NaN        NaN
# S148                           NaN  ...    NaN       NaN        NaN
# S149                           NaN  ...    NaN       NaN        NaN
# S150                           NaN  ...    NaN       NaN        NaN
# S151                           NaN  ...    NaN       NaN        NaN
# S152                           NaN  ...    NaN       NaN        NaN
# S153                           NaN  ...    NaN       NaN        NaN
#
#               Ethnicity    Tumor_Site Tumor_Focality Tumor_Size_cm  \
# Sample_ID
# S001       Not_Hispanic      Anterior       Unifocal   Small_tumor
# S002       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S003       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S005       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S006       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S007       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S008       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S009       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S010       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S011       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S012       Not_Hispanic      Anterior       Unifocal   Small_tumor
# S014           Hispanic  Not_Anterior       Unifocal   Large_tumor
# S016       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S017       Not_Hispanic      Anterior       Unifocal   Small_tumor
# S018       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S019       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S020       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S021       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S022       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S023       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S024       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S025       Not_Hispanic      Anterior     Multifocal   Small_tumor
# S026       Not_Hispanic      Anterior     Multifocal   Large_tumor
# S027       Not_Hispanic      Anterior     Multifocal   Small_tumor
# S028       Not_Hispanic  Not_Anterior     Multifocal   Large_tumor
# S029           Hispanic  Not_Anterior       Unifocal   Small_tumor
# S030           Hispanic  Not_Anterior       Unifocal   Large_tumor
# S031       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# S032       Not_Hispanic  Not_Anterior       Unifocal   Small_tumor
# S033       Not_Hispanic  Not_Anterior       Unifocal   Large_tumor
# ...                 ...           ...            ...           ...
# S124                NaN           NaN            NaN           NaN
# S125                NaN           NaN            NaN           NaN
# S126                NaN           NaN            NaN           NaN
# S127                NaN           NaN            NaN           NaN
# S128                NaN           NaN            NaN           NaN
# S129                NaN           NaN            NaN           NaN
# S130                NaN           NaN            NaN           NaN
# S131                NaN           NaN            NaN           NaN
# S132                NaN           NaN            NaN           NaN
# S133                NaN           NaN            NaN           NaN
# S134                NaN           NaN            NaN           NaN
# S135                NaN           NaN            NaN           NaN
# S136                NaN           NaN            NaN           NaN
# S137                NaN           NaN            NaN           NaN
# S138                NaN           NaN            NaN           NaN
# S139                NaN           NaN            NaN           NaN
# S140                NaN           NaN            NaN           NaN
# S141                NaN           NaN            NaN           NaN
# S142                NaN           NaN            NaN           NaN
# S143                NaN           NaN            NaN           NaN
# S144                NaN           NaN            NaN           NaN
# S145                NaN           NaN            NaN           NaN
# S146                NaN           NaN            NaN           NaN
# S147                NaN           NaN            NaN           NaN
# S148                NaN           NaN            NaN           NaN
# S149                NaN           NaN            NaN           NaN
# S150                NaN           NaN            NaN           NaN
# S151                NaN           NaN            NaN           NaN
# S152                NaN           NaN            NaN           NaN
# S153                NaN           NaN            NaN           NaN
#
#           Num_full_term_pregnancies MSI_status Genomics_subtype
# Sample_ID
# S001                            NaN      MSI-H            MSI-H
# S002                            NaN      MSI-H            MSI-H
# S003                      3_or_more        MSS    Other_subtype
# S005                      3_or_more        MSS    Other_subtype
# S006                            NaN        MSS    Other_subtype
# S007                            NaN        MSS    Other_subtype
# S008                            NaN        MSS    Other_subtype
# S009                      3_or_more        MSS    Other_subtype
# S010                            NaN      MSI-H            MSI-H
# S011                            NaN        MSS    Other_subtype
# S012                            NaN        MSS    Other_subtype
# S014                            NaN      MSI-H            MSI-H
# S016                            NaN        MSS    Other_subtype
# S017                    Less_than_3      MSI-H            MSI-H
# S018                    Less_than_3        MSS    Other_subtype
# S019                            NaN        MSS    Other_subtype
# S020                    Less_than_3        MSS    Other_subtype
# S021                            NaN        MSS    Other_subtype
# S022                            NaN        MSS    Other_subtype
# S023                            NaN        MSS    Other_subtype
# S024                            NaN        MSS    Other_subtype
# S025                      3_or_more        MSS    Other_subtype
# S026                            NaN        MSS    Other_subtype
# S027                      3_or_more        MSS    Other_subtype
# S028                            NaN        MSS    Other_subtype
# S029                            NaN        MSS    Other_subtype
# S030                      3_or_more      MSI-H            MSI-H
# S031                            NaN        MSS    Other_subtype
# S032                            NaN      MSI-H            MSI-H
# S033                            NaN        MSS    Other_subtype
# ...                             ...        ...              ...
# S124                            NaN        NaN              NaN
# S125                            NaN        NaN              NaN
# S126                            NaN        NaN              NaN
# S127                            NaN        NaN              NaN
# S128                            NaN        NaN              NaN
# S129                            NaN        NaN              NaN
# S130                            NaN        NaN              NaN
# S131                            NaN        NaN              NaN
# S132                            NaN        NaN              NaN
# S133                            NaN        NaN              NaN
# S134                            NaN        NaN              NaN
# S135                            NaN        NaN              NaN
# S136                            NaN        NaN              NaN
# S137                            NaN        NaN              NaN
# S138                            NaN        NaN              NaN
# S139                            NaN        NaN              NaN
# S140                            NaN        NaN              NaN
# S141                            NaN        NaN              NaN
# S142                            NaN        NaN              NaN
# S143                            NaN        NaN              NaN
# S144                            NaN        NaN              NaN
# S145                            NaN        NaN              NaN
# S146                            NaN        NaN              NaN
# S147                            NaN        NaN              NaN
# S148                            NaN        NaN              NaN
# S149                            NaN        NaN              NaN
# S150                            NaN        NaN              NaN
# S151                            NaN        NaN              NaN
# S152                            NaN        NaN              NaN
# S153                            NaN        NaN              NaN
#
# [144 rows x 23 columns]

# %% [markdown]
# ## Step 3: Perform outliers analysis

# %%
outliers_prot = blsh.make_outliers_table(proteomics, iqrs=1.5, 
                                         up_or_down='up', 
                                         aggregate=False, 
                                         frac_table=False)

outliers_mRNA = blsh.make_outliers_table(mRNA, iqrs=1.5, 
                                         up_or_down='up', 
                                         aggregate=False, 
                                         frac_table=False)
# Out:
# C:\Users\Daniel\AppData\Local\conda\conda\envs\Research\lib\site-packages\numpy\lib\nanfunctions.py:1354: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)

# %% [markdown]
# ## Step 4: Wrap your A/B test into the outliers analysis, and create a table

# %%
results_prot = blsh.compare_groups_outliers(outliers_prot, 
                                            annotations)

results_mRNA = blsh.compare_groups_outliers(outliers_mRNA, 
                                            annotations)
# Out:
# No rows had outliers in at least 0.3 of Proteomics_Tumor_Normal Normal_Tumor samples
# Testing 14 rows for enrichment in Proteomics_Tumor_Normal Other_tumor samples
# No rows had outliers in at least 0.3 of Country Other samples
# No rows had outliers in at least 0.3 of Country US samples
# Testing 2 rows for enrichment in Histologic_Grade_FIGO High_grade samples
# Testing 1 rows for enrichment in Histologic_Grade_FIGO Low_grade samples
# No rows had outliers in at least 0.3 of Myometrial_invasion_Specify under 50 % samples
# Testing 7 rows for enrichment in Myometrial_invasion_Specify 50 % or more samples
# No rows had outliers in at least 0.3 of Histologic_type Endometrioid samples
# Testing 626 rows for enrichment in Histologic_type Serous samples
# No rows had outliers in at least 0.3 of Path_Stage_Primary_Tumor-pT Not_FIGO_III samples
# Testing 241 rows for enrichment in Path_Stage_Primary_Tumor-pT FIGO_III samples
# No rows had outliers in at least 0.3 of Path_Stage_Reg_Lymph_Nodes-pN Not_FIGO_III samples
# Testing 136 rows for enrichment in Path_Stage_Reg_Lymph_Nodes-pN FIGO_III samples
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-14e9ee378858> in <module>()
#       1 results_prot = blsh.compare_groups_outliers(outliers_prot,
# ----> 2                                             annotations)
#       3
#       4 results_mRNA = blsh.compare_groups_outliers(outliers_mRNA,
#       5                                             annotations)
#
# ~\Documents\GitHub\WhenMutationsMatter\Daniel\blackSheepCPTACmoduleCopy.py in compare_groups_outliers(outliers, annotations, frac_filter)
#     177     results_df = pd.DataFrame(index=outliers.index)
#     178     for comp in annotations.columns:
# --> 179         group0_label, group0, group1_label, group1 = getSampleLists(annotations, comp)
#     180         label0 = '%s_%s_enrichment_FDR' %(comp, group0_label)
#     181         df = filterOutliers(outliers, group0, group1, frac_filter)
#
# ~\Documents\GitHub\WhenMutationsMatter\Daniel\blackSheepCPTACmoduleCopy.py in getSampleLists(annotations, col)
#     126
#     127     group0 = list(annotations.loc[annotations[col]==groups[0], :].index)
# --> 128     group1 = list(annotations.loc[annotations[col]==groups[1], :].index)
#     129     return groups[0], group0, groups[1], group1
#     130
#
# IndexError: list index out of range

# %%
clinical.columns
'''
NEED TO BINARIZE:
Proteomics_Tumor_Normal, Country, Histologic_Grade_FIGO, 
Myometrial_invasion_Specify, Path_Stage_Reg_Lymph_Nodes-pN,
Path_Stage_Primary_Tumor-pT, Clin_Stage_Dist_Mets-cM,
tumor_Stage-Pathological, FIGO_stage, BMI, Age, Diabetes,
Race, Ethnicity, Tumor_Site, Tumor_Size_cm, Num_full_term_pregnancies,
Genomics_subtype
'''
# Out:
# Index(['Patient_ID', 'Proteomics_Tumor_Normal', 'Country',
#        'Histologic_Grade_FIGO', 'Myometrial_invasion_Specify',
#        'Histologic_type', 'Treatment_naive', 'Tumor_purity',
#        'Path_Stage_Primary_Tumor-pT', 'Path_Stage_Reg_Lymph_Nodes-pN',
#        'Clin_Stage_Dist_Mets-cM', 'Path_Stage_Dist_Mets-pM',
#        'tumor_Stage-Pathological', 'FIGO_stage', 'LVSI', 'BMI', 'Age',
#        'Diabetes', 'Race', 'Ethnicity', 'Gender', 'Tumor_Site',
#        'Tumor_Site_Other', 'Tumor_Focality', 'Tumor_Size_cm',
#        'Num_full_term_pregnancies', 'MSI_status', 'Genomics_subtype'],
#       dtype='object')

# %%
for col in annotations.columns:
    print (annotations[col].value_counts())
    print('\n')
# Out:
# Tumor                95
# Adjacent_normal      25
# Enriched_normal      18
# Myometrium_normal     6
# Name: Proteomics_Tumor_Normal, dtype: int64
#
#
# United States    34
# Ukraine          32
# Other_specify    24
# Poland            5
# Name: Country, dtype: int64
#
#
# FIGO grade 2    38
# FIGO grade 1    37
# FIGO grade 3     8
# Name: Histologic_Grade_FIGO, dtype: int64
#
#
# under 50 %        56
# 50 % or more      30
# Not identified     9
# Name: Myometrial_invasion_Specify, dtype: int64
#
#
# Endometrioid    83
# Serous          12
# Name: Histologic_type, dtype: int64
#
#
# pT1a (FIGO IA)      56
# pT1b (FIGO IB)      18
# pT2 (FIGO II)       10
# pT3a (FIGO IIIA)     7
# pT3b (FIGO IIIB)     3
# pT1 (FIGO I)         1
# Name: Path_Stage_Primary_Tumor-pT, dtype: int64
#
#
# pN0                 45
# pNX                 43
# pN1 (FIGO IIIC1)     5
# pN2 (FIGO IIIC2)     2
# Name: Path_Stage_Reg_Lymph_Nodes-pN, dtype: int64
#
#
# cM0                   70
# Staging Incomplete    22
# cM1                    3
# Name: Clin_Stage_Dist_Mets-cM, dtype: int64
#
#
# Staging Incomplete                              72
# No pathologic evidence of distant metastasis    20
# pM1                                              3
# Name: Path_Stage_Dist_Mets-pM, dtype: int64
#
#
# Stage I      68
# Stage III    13
# Stage II     10
# Stage IV      4
# Name: tumor_Stage-Pathological, dtype: int64
#
#
# IA       56
# IB       15
# II        8
# IIIA      6
# IIIC1     4
# IVB       3
# IIIC2     2
# IIIB      1
# Name: FIGO_stage, dtype: int64
#
#
# 0.0    65
# 1.0    28
# Name: LVSI, dtype: int64
#
#
# 31.00    4
# 27.00    3
# 31.96    2
# 35.00    2
# 34.00    2
# 35.42    1
# 27.66    1
# 26.22    1
# 24.32    1
# 65.71    1
# 39.76    1
# 29.62    1
# 34.72    1
# 25.03    1
# 34.06    1
# 32.06    1
# 21.83    1
# 23.88    1
# 17.64    1
# 28.84    1
# 36.57    1
# 30.47    1
# 46.45    1
# 36.84    1
# 38.88    1
# 27.83    1
# 34.37    1
# 46.64    1
# 28.50    1
# 26.00    1
#         ..
# 68.39    1
# 40.72    1
# 34.53    1
# 31.63    1
# 44.81    1
# 46.41    1
# 32.83    1
# 22.86    1
# 46.85    1
# 32.69    1
# 17.85    1
# 27.10    1
# 32.32    1
# 29.52    1
# 31.22    1
# 38.97    1
# 30.48    1
# 42.98    1
# 39.14    1
# 51.19    1
# 21.45    1
# 26.14    1
# 29.37    1
# 34.26    1
# 20.28    1
# 59.78    1
# 36.81    1
# 25.68    1
# 21.57    1
# 43.00    1
# Name: BMI, Length: 87, dtype: int64
#
#
# 64.0    9
# 65.0    7
# 59.0    6
# 62.0    5
# 75.0    4
# 60.0    4
# 56.0    4
# 66.0    3
# 58.0    3
# 50.0    3
# 63.0    3
# 69.0    3
# 57.0    3
# 73.0    3
# 68.0    3
# 53.0    3
# 71.0    2
# 70.0    2
# 77.0    2
# 86.0    2
# 61.0    2
# 74.0    2
# 45.0    2
# 67.0    2
# 44.0    1
# 41.0    1
# 83.0    1
# 78.0    1
# 46.0    1
# 72.0    1
# 90.0    1
# 38.0    1
# 55.0    1
# 76.0    1
# 48.0    1
# 42.0    1
# 85.0    1
# Name: Age, dtype: int64
#
#
# No         67
# Yes        26
# Unknown     1
# Name: Diabetes, dtype: int64
#
#
# White                        53
# Black or African American     3
# Asian                         1
# Not Reported                  1
# Name: Race, dtype: int64
#
#
# Not-Hispanic or Latino    40
# Not reported              15
# Hispanic or Latino         3
# Name: Ethnicity, dtype: int64
#
#
# Other, specify           70
# Anterior endometrium     18
# Posterior endometrium     7
# Name: Tumor_Site, dtype: int64
#
#
# Unifocal      55
# Multifocal    40
# Name: Tumor_Focality, dtype: int64
#
#
# 4.5     8
# 4.0     8
# 3.0     8
# 3.5     6
# 1.0     6
# 5.0     5
# 1.5     4
# 2.3     4
# 2.7     3
# 6.0     3
# 2.5     3
# 1.3     3
# 7.0     2
# 5.5     2
# 1.4     2
# 2.2     2
# 3.2     2
# 2.6     2
# 4.3     2
# 3.8     1
# 0.9     1
# 1.8     1
# 1.2     1
# 0.8     1
# 13.5    1
# 6.3     1
# 4.7     1
# 3.9     1
# 6.5     1
# 8.0     1
# 9.0     1
# 1.7     1
# 11.0    1
# 8.5     1
# 5.2     1
# 2.9     1
# 3.7     1
# 4.2     1
# Name: Tumor_Size_cm, dtype: int64
#
#
# 2            27
# 1            22
# Unknown      13
# 4 or more    13
# None         11
# 3             9
# Name: Num_full_term_pregnancies, dtype: int64
#
#
# MSS      70
# MSI-H    25
# Name: MSI_status, dtype: int64
#
#
# CNV_low     43
# MSI-H       25
# CNV_high    20
# POLE         7
# Name: Genomics_subtype, dtype: int64

# %%
for val in annotations['Tumor_Size_cm'].values:
    print(type(val))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %% [markdown]
# Many of the output values from compare_group_outliers are NaN, so here we will get rid of the NaN values for visualization purposes.

# %%
results_prot = results_prot.dropna(axis=0, how='all')
results_mRNA = results_mRNA.dropna(axis=0, how='all')

# %% [markdown]
# ## Step 5: Visualize these enrichments

# %%
sns.heatmap(results_prot)
plt.show()

# %%
sns.heatmap(results_mRNA)
plt.show()

# %% [markdown]
# ## Step 6: Determine significant enrichments, and link with cancer drug database.

# %%
#Check for significant columns in proteomics
print("Testing for proteomics")
for col in results_prot.columns:
    bf.significantEnrichments(results_prot, col)

#Check for significant columns in mRNA.
print("Testing for mRNA")
for col in results_mRNA.columns:
    bf.significantEnrichments(results_mRNA, col)
# Out:
# Testing for proteomics
# 9 significant protein enrichments in MSI_status_MSI-H
#
# Testing for mRNA
# 5 significant protein enrichments in MSI_status_MSS
#
# 16 significant protein enrichments in MSI_status_MSI-H

# %%
#Store the dataframe of significant enrichments
column_MSI = 'MSI_status_MSI-H_enrichment_FDR'
column_MSS = 'MSI_status_MSS_enrichment_FDR'

sig_results_prot = bf.significantEnrichments(results_prot, 
                                             column_MSI)
sig_results_mRNA_MSI = bf.significantEnrichments(results_mRNA, 
                                                 column_MSI)
sig_results_mRNA_MSS = bf.significantEnrichments(results_mRNA, 
                                                 column_MSS)
# Out:
# 9 significant protein enrichments in MSI_status_MSI-H
#
# 16 significant protein enrichments in MSI_status_MSI-H
#
# 5 significant protein enrichments in MSI_status_MSS

# %% [markdown]
# As mentioned in our paper, we see a significant upregulation in RPL22L1 within the proteomics dataset for patients with MSI-H status, however there is an inconsistency in our analysis when it comes to mRNA data **Look into this**.

# %%
print('RPL22L1' in sig_results_prot.index)
print('RPL22L1' in sig_results_mRNA_MSI.index) #Actual inconsistency
# Out:
# True
# False
