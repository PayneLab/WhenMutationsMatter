# %% [markdown]
# # PIK3CA trans effects on known interacting proteins

# %% [markdown]
# We investigated the effects of PIK3CA mutation on the proteomics and phosphoproteomic of known interacting proteins. This list primarily included proteins in the PI3K/AKT/MTOR signaling cascade that plays a key role in cell survival and cell proliferation.
#
# We compare the proteomics and phosphoproteomics of patients with mutations in the PIK3CA hotspot with cancer patients with no PIK3CA mutation (cancer wildtype) and also all patients with any PIK3CA mutation with cancer wildtype.

# %% [markdown]
# ## Standard Imports

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import json
import operator

#import the Endometrial data from CPTAC package
import CPTAC.Endometrial as CPTAC

# %% [markdown]
# # 1. Set up initial dataframes and variables

# %%
gene = 'PIK3CA'

# Get the dataframes 
clinical = CPTAC.get_clinical()
somatic = CPTAC.get_somatic()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()

#A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.E545A', 'p.E545K', 'p.E545V', 'p.Q546P', 'p.Q546R', 'p.E542K']

#Create a list of patients who have hotspot mutations
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations)) & (somatic['Gene'] == gene)]
hotspot_patients = mutated_hotspot['Clinical_Patient_Key']

hotspot_patients_both_keys = mutated_hotspot[['Clinical_Patient_Key', 'Patient_Id']]
hotspot_patients = hotspot_patients_both_keys['Clinical_Patient_Key']
print('Patients with PIK3CA hotspot mutations (by Patient ID)\n')
print(hotspot_patients)
# Out:
# Patients with PIK3CA hotspot mutations (by Patient ID)
#
# 160      S001
# 1147     S003
# 1357     S009
# 4630     S021
# 16486    S023
# 19061    S024
# 21259    S032
# 21516    S033
# 22497    S038
# 37421    S061
# 38155    S063
# 39522    S066
# 43391    S067
# 43490    S068
# 46662    S084
# 47360    S088
# 47857    S090
# 49362    S097
# 49475    S098
# Name: Clinical_Patient_Key, dtype: object

# %% [markdown]
# # 2. Find number of patients with PIK3CA mutations in/outside of the hotspot

# %%
print('{}' '{}'.format("Patients with mutations inside hotspot: ", len(hotspot_patients)))
#note: the gene PIK3CA encodes for the protein p110α, hence the variable 'p110_mutated'
p110_mutated = somatic.loc[somatic['Gene'] == 'PIK3CA']


# This naturally includes a value that is 'NA' so we subtract 1
# Some people have more than one mutation so we need to grab the unique values
num_mutated = len(set(p110_mutated['Clinical_Patient_Key'])) - 1
print('{}''{}'.format("Total number of patients with mutations: ", str(num_mutated)))
# Out:
# Patients with mutations inside hotspot: 19
# Total number of patients with mutations: 46

# %% [markdown]
# # 3. List proteins that interact with PIK3CA  (according to Uniprot and STRING)

# %% [markdown]
# UniProt: https://www.uniprot.org/uniprot/P42336,    October 25, 2018

# %% [markdown]
# STRING: https://string-db.org/network/9606.ENSP00000263967,    November 1, 2018

# %%
#Build the protein list; this may have only a single protein if desired
protList = ['IRS1', 'IRS2', 'RRAS', 'AKT2', 'NRAS', 'PTEN', 'AKT1', 'MRAS', 'HRAS', 'RPS6KB1', 'PIK3R1', 'PKC', 'MTOR', 'S6K', 'ERBB3', 'P85A', 'P55G', 'CDK5']

# %% [markdown]
# # 4. Proteomic Abundance

# %% [markdown]
# ## 4a. Hotspot mutations vs cancer wildtype

# %%
print('{}' '{}'.format('Mutations inside hotspot: ', len(hotspot_patients)))

# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)
print('{}' '{}' '{}'.format('\nAdjusted p-value: ', pcutoff, '\n'))


# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each interacting protein to test for whether mutations in PIK3CA effect the interacting protein's abundance
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Set up a new column for mutations that are within the hotspot
        p110_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p110_mutations['Within_Hotspot'] = 'Outside Hotspot'
        p110_mutations.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
        p110_mutations.loc[p110_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype_Tumor'
       
        # 5. Take out the data for normal cancer samples 
        p110_mutations = p110_mutations.loc[p110_mutations['PIK3CA_Sample_Status'] == 'Tumor'].dropna(axis=0)

        # 6. Create two dataframes - one for patients with hotspot mutations and another for cacner wildtype patients (no PIK3CA mutation)
        in_hotspot = p110_mutations.loc[p110_mutations['Within_Hotspot'] == 'Within Hotspot']
        wt = p110_mutations.loc[p110_mutations['Within_Hotspot'] == 'Wildtype_Tumor']
        
        # 7. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        tstat, pvalue = scipy.stats.ttest_ind(in_hotspot['{}' '{}'.format(protein, '_omics')], wt['{}' '{}'.format(protein, '_omics')])
        
        # Loop through each pvalue to find those that are lower than the pcutoff
        if pvalue < pcutoff:
            sigResults[protein] = pvalue
        else:
            unsigResults[protein] = pvalue

# 8. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 1))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 1))
# Out:
# Mutations inside hotspot: 19
#
# Adjusted p-value: 0.002777777777777778
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#  "IRS1": 0.4787731478620394,
#  "IRS2": 0.07272070779690445,
#  "RRAS": 0.03446351747840539,
#  "AKT2": 0.020333606070791856,
#  "NRAS": 0.5450399807872786,
#  "PTEN": 0.021379145894699855,
#  "AKT1": 0.20010278193153005,
#  "MRAS": 0.5051068858399758,
#  "HRAS": 0.50534001501834,
#  "RPS6KB1": 0.273972971692615,
#  "PIK3R1": 0.12070633963762907,
#  "MTOR": 0.053330426551103975,
#  "ERBB3": 0.07354678014678877,
#  "CDK5": 0.058536471320093056
# }

# %% [markdown]
# ## 4b. Plot the data for the most significant result

# %% [markdown]
# <b> Note: </b> This result did not pass the Bonferroni correction of significance. This is the lowest p-value found in our list of unsignificant results.

# %%
# Get the protein with the lowest p-value
protein = min(unsigResults.keys(), key=(lambda k: unsigResults[k]))
 
# Get the ttest results computed from the previous step, using protein with the lowest p-value as the protein of interest
p110_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
p110_mutations['Within_Hotspot'] = 'Outside Hotspot'
p110_mutations.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
p110_mutations.loc[p110_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype_Tumor'
p110_mutations = p110_mutations.loc[p110_mutations['PIK3CA_Sample_Status'] == 'Tumor'].dropna(axis=0)
p110_mutations = p110_mutations.loc[p110_mutations['Within_Hotspot'] != 'Outside Hotspot']

# Create a dataframe for hotspot mutated patients and another for cancer wildtype patients
in_hotspot = p110_mutations.loc[p110_mutations['Within_Hotspot'] == 'Within Hotspot']
wt = p110_mutations.loc[p110_mutations['Within_Hotspot'] == 'Wildtype_Tumor']
 
# Perform a ttest to get the resulting pvalue
ttest = scipy.stats.ttest_ind(in_hotspot['{}' '{}'.format(protein, '_omics')], wt['{}' '{}'.format(protein, '_omics')])

# Set the plot dimensions
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)

# Create the plot and add styling
boxplt = sns.boxplot(data = p110_mutations, x = 'Within_Hotspot', y = '{}' '{}'.format(protein, '_omics'), ax = ax)
boxplt = sns.stripplot(data = p110_mutations, x = 'Within_Hotspot', y = '{}' '{}'.format(protein, '_omics'), jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Location', fontsize='20')
boxplt.set_ylabel('Protein Expression', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " proteomics" + '\nP-value = ' + str(round(ttest[1],  6)), fontsize='22')
plt.show()

# %% [markdown]
# ## 4c. All mutations vs cancer wildtype

# %%
# 1. Use the Bonferonni correction to adjust the p-value by dividing alpha (0.05) by the number of tests. 
#   Because we are analyzing 19 proteins, we will have 19 tests. 
pcutoff = 0.05/len(protList)
print('Adjusted P-value: ', pcutoff, '\n')

# 2. Create a dictionary for significant proteins with their prespective pvalues
#    Create another dictionary for unsignificant results

sigResults = {}
unsigResults = {}

# 3. Loop through each interacting protein to test for whether mutations in PIK3CA effect the interacting protein's abundance
for protein in protList: 
    
    #Check to make sure that the protein is in the proteomics dataframe that we are reading from
    if protein in proteomics.columns:
        # 4. Create two data frames for mutated patients and cancer wildtype patients
        p110_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
        p110_mutations = p110_mutations.loc[p110_mutations['PIK3CA_Sample_Status'] == 'Tumor'].dropna(axis=0)
        all_mut = p110_mutations.loc[p110_mutations['PIK3CA_Mutation'] != 'Wildtype_Tumor']
        wt = p110_mutations.loc[p110_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor']
        
        # 5. Perform a two-sample ttest for mutations in hotspot vs mutations outside of the hotspot
        ttest = scipy.stats.ttest_ind(all_mut['{}' '{}'.format(protein, '_omics')], wt['{}' '{}'.format(protein, '_omics')])
        
        if ttest[1] < pcutoff:
            sigResults[protein] = ttest[1]
            
        else:
            unsigResults[protein] = ttest[1]
            
# 5. Print the results
print('SIGNIFICANT RESULTS:')
# Json is a nice package that allows you to print items in the dictionary line by line
print(json.dumps(sigResults, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigResults, indent = 2))
# Out:
# Adjusted P-value:  0.002777777777777778
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1": 0.3589749294393514,
#   "IRS2": 0.22216155850981723,
#   "RRAS": 0.2786340157791247,
#   "AKT2": 0.026902041515640015,
#   "NRAS": 0.6924641618069217,
#   "PTEN": 0.29705786646798127,
#   "AKT1": 0.26274510752451385,
#   "MRAS": 0.9632485924650018,
#   "HRAS": 0.6099405429572754,
#   "RPS6KB1": 0.03640034709316176,
#   "PIK3R1": 0.024327730118996492,
#   "MTOR": 0.2487999191492049,
#   "ERBB3": 0.1362646413913762,
#   "CDK5": 0.06276730967236842
# }

# %% [markdown]
# ## 4d. Plot the data for the most significant result

# %% [markdown]
# <b> Note: </b> This result did not pass the Bonferroni correction of significance. This is the lowest p-value found in our list of unsignificant results.

# %%
#Get the protein with the lowest p-value
protein = min(unsigResults.keys(), key=(lambda k: unsigResults[k]))


#Get the ttest results computed from the previous step, using AKT2 as the protein of interest
p110_mutations = CPTAC.compare_mutations(proteomics, protein, gene)
#Remove the Normal patient control
p110_mutations = p110_mutations.loc[p110_mutations['PIK3CA_Sample_Status'] == 'Tumor'].dropna(axis=0)
#p110_mutations = p110_mutations.loc[p110_mutations['']]
p110_mutations['Status'] = 'Cancer Wildtype'
p110_mutations.loc[p110_mutations['PIK3CA_Mutation'] != 'Wildtype_Tumor', 'Status'] = 'Mutated'

# Create a dataframe for mutated cancer patients and another for cancer wildtype patients 
mutated = p110_mutations.loc[p110_mutations['Status'] != 'Cancer Wildtype']
wt = p110_mutations.loc[p110_mutations['Status'] == 'Cancer Wildtype']

#perform a ttest to get the resulting pvalue      
ttest = scipy.stats.ttest_ind(mutated['{}' '{}'.format(protein, '_omics')], wt['{}' '{}'.format(protein, '_omics')])

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p110_mutations, x = 'Status', y = '{}' '{}'.format(protein, '_omics'), ax = ax)
boxplt = sns.stripplot(data = p110_mutations, x = 'Status', y = '{}' '{}'.format(protein, '_omics'), jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Type', fontsize='20')
boxplt.set_ylabel('Protein Expression', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " proteomics" + '\nP-value = ' + str(round(ttest[1],  6)), fontsize='22')
plt.show()

# %% [markdown]
# # 5. Phosphoproteomic Abundance

# %% [markdown]
# ## 5a. Hotspot mutation vs cancer wildtype

# %%
#1. Create two corresponding lists for sites and their respective pvalues to calculate the Bonferroni correction when all of the sites have been analyzed
sites = []
pvalues = []


# 2. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 3. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 4. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        phos_mutations['Within_Hotspot'] = 'Outside Hotspot'
        phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
        phos_mutations.loc[phos_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype_Tumor'
        
        # 5. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['PIK3CA_Sample_Status'] == 'Tumor']
       
        # 6. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'PIK3CA_Mutation', 'PIK3CA_Sample_Status', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]
        
        # 7. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 8. Check if the site is in both dataframes. That column may have been deleted in step 4
            #if site in hotspot_mut.columns and site in wt.columns:
                
            # 9. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
            #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
            hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Within Hotspot'][['PIK3CA_Mutation', site]].dropna(axis = 0)
            wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype_Tumor'][['PIK3CA_Mutation', site]].dropna(axis = 0)

            # 10. Perform a two-sample ttest for mutations in hotspot vs cancer wildtype
            ttest = scipy.stats.ttest_ind(hotspot_mut[site], wt[site])

            # 11. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
            sites.append(site)
            pvalues.append(ttest[1])
            
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 12. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)
print('\nAdjusted p-value: ', pcutoff, '\n')

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:  
        unsigSites[sites[i]] = pvalues[i]


# 13. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
#
# Adjusted p-value:  0.00013262599469496023
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.26931394809355025,
#   "IRS1-S1078": 0.2953861160384293,
#   "IRS1-S1100": 0.14426804680276514,
#   "IRS1-S1101": 0.5070849608397894,
#   "IRS1-S1131": NaN,
#   "IRS1-S1132": 0.17037324260160489,
#   "IRS1-S1133": 0.33073057288454144,
#   "IRS1-S1134": 0.05344794304063461,
#   "IRS1-S1135": 0.990309068267633,
#   "IRS1-S1143": 0.6689195641811675,
#   "IRS1-S1145": 0.6689195641811675,
#   "IRS1-S1222": 0.9357339247191957,
#   "IRS1-S1223": 0.6458078911759092,
#   "IRS1-S1227": NaN,
#   "IRS1-S270": 0.5782405783020121,
#   "IRS1-S274": 0.9014682287993983,
#   "IRS1-S303": 0.768079857200236,
#   "IRS1-S307": 0.7009275058671687,
#   "IRS1-S312": 0.45874598768836583,
#   "IRS1-S315": 0.6467628701564236,
#   "IRS1-S323": 0.4403571822383826,
#   "IRS1-S330": 0.4408767372886866,
#   "IRS1-S337": 0.8486227747583235,
#   "IRS1-S341": 0.27571679770593344,
#   "IRS1-S345": 0.5009976301983918,
#   "IRS1-S348": 0.49128675195425486,
#   "IRS1-S374": 0.5548955317654796,
#   "IRS1-S413": 0.7517306805146714,
#   "IRS1-S415": 0.5552433687516581,
#   "IRS1-S417": 0.18581025431604703,
#   "IRS1-S419": 0.8285564245908299,
#   "IRS1-S421": 0.45979256479981057,
#   "IRS1-S427": 0.3426597929013283,
#   "IRS1-S428": 0.9753408241421412,
#   "IRS1-S434": 0.9972289830160352,
#   "IRS1-S444": 0.5578835038635978,
#   "IRS1-S449": 0.8021668412940606,
#   "IRS1-S463": 0.48363447153705663,
#   "IRS1-S503": 0.9483183189061601,
#   "IRS1-S513": NaN,
#   "IRS1-S527": 0.9269092713778896,
#   "IRS1-S531": 0.7722507998208423,
#   "IRS1-S541": 0.17329733968492975,
#   "IRS1-S543": 0.15210637491666013,
#   "IRS1-S544": 0.32607112817025397,
#   "IRS1-S547": 0.10676776203434002,
#   "IRS1-S574": NaN,
#   "IRS1-S581": 0.18329689830093068,
#   "IRS1-S629": 0.7095098036276762,
#   "IRS1-S636": 0.8135607582692506,
#   "IRS1-S641": NaN,
#   "IRS1-S668": 0.09410152234660249,
#   "IRS1-S672": 0.18935436852418902,
#   "IRS1-S736": 0.6265576189803933,
#   "IRS1-S741": 0.4387461588143545,
#   "IRS1-S744": NaN,
#   "IRS1-S745": 0.5841238032001899,
#   "IRS1-S766": 0.30415724005212685,
#   "IRS1-S925": 0.4182825433347475,
#   "IRS1-T1103": NaN,
#   "IRS1-T305": 0.6958331105709918,
#   "IRS1-T309": 0.05886201547656899,
#   "IRS1-T311": 0.21983285604640837,
#   "IRS1-T335": 0.2554105729866518,
#   "IRS1-T446": 0.4056125100641559,
#   "IRS1-T453": 0.2957645435615431,
#   "IRS1-T525": NaN,
#   "IRS1-T530": 0.5751935635007304,
#   "IRS1-T533": 0.8201641563615527,
#   "IRS1-T552": 0.4393503658931358,
#   "IRS1-T579": NaN,
#   "IRS1-T859": 0.7389445422259172,
#   "IRS1-Y465": NaN,
#   "IRS1-Y551": 0.946238840447673,
#   "IRS1-Y582": 0.6049161357447033,
#   "IRS1-Y632": 0.15023966385989895,
#   "IRS1-Y662": 0.15551094210743863,
#   "IRS1-Y750": 0.5853577614150564,
#   "IRS2-S1100": 0.7710237774126867,
#   "IRS2-S1148": NaN,
#   "IRS2-S1149": 0.2947118115829299,
#   "IRS2-S1162": 0.3119999762551662,
#   "IRS2-S1174": 0.34094269479638983,
#   "IRS2-S1176": 0.3568846561175224,
#   "IRS2-S1181": 0.8426215836605389,
#   "IRS2-S1186": 0.7668361199245708,
#   "IRS2-S1203": 0.9056629833996219,
#   "IRS2-S1237": 0.1540604697808015,
#   "IRS2-S166": 0.8742374224789676,
#   "IRS2-S174": NaN,
#   "IRS2-S306": 0.9830581169413644,
#   "IRS2-S342": NaN,
#   "IRS2-S346": 0.7762090967856945,
#   "IRS2-S365": 0.16327515590460467,
#   "IRS2-S384": 0.3137499234270844,
#   "IRS2-S388": 0.8373057102343344,
#   "IRS2-S391": 0.053755908985604006,
#   "IRS2-S406": NaN,
#   "IRS2-S560": 0.6618145637539328,
#   "IRS2-S577": 0.3019749557241244,
#   "IRS2-S591": 0.3216909405724162,
#   "IRS2-S592": NaN,
#   "IRS2-S594": 0.8934876503185741,
#   "IRS2-S606": NaN,
#   "IRS2-S608": NaN,
#   "IRS2-S615": NaN,
#   "IRS2-S619": NaN,
#   "IRS2-S620": 0.7937662721704561,
#   "IRS2-S643": 0.3098484900275924,
#   "IRS2-S672": NaN,
#   "IRS2-S679": 0.5405653942290306,
#   "IRS2-S731": 0.16966194926120304,
#   "IRS2-S735": NaN,
#   "IRS2-S736": 0.06496082499980216,
#   "IRS2-S752": 0.44837948466420874,
#   "IRS2-S772": NaN,
#   "IRS2-S805": 0.6554176639068738,
#   "IRS2-S827": 0.4886927999572611,
#   "IRS2-S828": NaN,
#   "IRS2-S915": 0.2923294936363075,
#   "IRS2-S932": NaN,
#   "IRS2-S947": NaN,
#   "IRS2-S973": 0.2714074448626737,
#   "IRS2-S984": 0.5621940667786733,
#   "IRS2-S985": NaN,
#   "IRS2-T1151": 0.2947118115829299,
#   "IRS2-T1157": 0.47090012949641835,
#   "IRS2-T1159": 0.47090012949641835,
#   "IRS2-T1202": 0.21137866288011553,
#   "IRS2-T1221": NaN,
#   "IRS2-T350": NaN,
#   "IRS2-T363": 0.7271996726663306,
#   "IRS2-T404": NaN,
#   "IRS2-T520": 0.567367472572546,
#   "IRS2-T527": 0.9342416738891232,
#   "IRS2-T575": 0.4880809922540924,
#   "IRS2-T776": 0.2599386914773997,
#   "IRS2-T779": 0.9184560560471349,
#   "IRS2-T962": 0.935066111606012,
#   "IRS2-Y653": 0.3820979127738877,
#   "IRS2-Y675": 0.4467170178454103,
#   "IRS2-Y823": 0.2881385164796118,
#   "IRS2-Y919": 0.9210979766546947,
#   "RRAS-S201": NaN,
#   "RRAS2-S186": 0.0551543639911008,
#   "RRAS2-T190": 0.1302742025545708,
#   "AKT2-S126": 0.7329195223832671,
#   "AKT2-S128": 0.9881086451105111,
#   "AKT2-S302": NaN,
#   "AKT2-S34": 0.8047276144815851,
#   "AKT2-S474": NaN,
#   "AKT2-T133": NaN,
#   "AKT2-T449": 0.317295642743204,
#   "AKT2-T451": 0.1503621529199437,
#   "NRAS-T122": NaN,
#   "PTEN-S467": 0.3267240874150995,
#   "PTEN-S475": 0.30390787126732133,
#   "PTEN-S478": 0.21051175227314356,
#   "PTEN-S537": 0.4367682363641005,
#   "PTEN-S543": 0.9567091504739313,
#   "PTEN-S558": 0.025313577596704495,
#   "PTEN-T539": 0.055798081538692014,
#   "PTEN-T555": NaN,
#   "PTEN-T556": 0.057778788136978766,
#   "AKT1-S122": 0.5498126464601633,
#   "AKT1-S124": 0.5028956625755319,
#   "AKT1-S126": 0.7932295056776111,
#   "AKT1-S129": 0.5945276831730633,
#   "AKT1-T450": 0.9945749870515903,
#   "AKT1S1-S108": 0.31906217468502845,
#   "AKT1S1-S112": 0.7257557519339899,
#   "AKT1S1-S203": 0.5194923723774871,
#   "AKT1S1-S222": 0.3303939003710594,
#   "AKT1S1-S223": 0.6506499967719732,
#   "AKT1S1-S231": 0.16431160539965756,
#   "AKT1S1-S232": 0.8906719340111492,
#   "AKT1S1-S241": NaN,
#   "AKT1S1-S267": 0.0695148813015217,
#   "AKT1S1-T110": 0.18780145678886653,
#   "AKT1S1-T117": 0.1852361417249206,
#   "AKT1S1-T218": NaN,
#   "AKT1S1-T266": 0.6757877980485181,
#   "AKT1S1-T93": 0.27347459781823735,
#   "RPS6KB1-S441": 0.11211565897866389,
#   "RPS6KB1-S447": 0.03139802941588384,
#   "RPS6KB1-S452": 0.896683916153959,
#   "RPS6KB1-T444": 0.1513360347630714,
#   "PIK3R1-S154": 0.9860718519434779,
#   "PIK3R1-S690": NaN,
#   "PIK3R1-S83": NaN,
#   "PIK3R1-T86": NaN,
#   "PIK3R1-Y452": 0.29439583615826015,
#   "PIK3R1-Y556": 0.06632802935731183,
#   "PIK3R1-Y580": 0.20004764475823264,
#   "ITPKC-S222": 0.9610386240980799,
#   "ITPKC-S322": 0.41293284437954125,
#   "ITPKC-S362": NaN,
#   "ITPKC-S378": NaN,
#   "ITPKC-S548": NaN,
#   "ITPKC-S84": 0.6822623270445016,
#   "ITPKC-S9": 0.9154649706648078,
#   "ITPKC-T333": 0.9061037048888709,
#   "ITPKC-T336": 0.6849525298769139,
#   "ITPKC-T547": NaN,
#   "ITPKC-T549": NaN,
#   "ITPKC-T91": 0.04358534779152733,
#   "LAMTOR1-S27": 0.9016286798538741,
#   "LAMTOR1-S42": 0.009405902840346413,
#   "LAMTOR1-S45": NaN,
#   "LAMTOR1-S56": NaN,
#   "LAMTOR1-S63": 0.9344554280020234,
#   "LAMTOR1-S98": 0.8538480102696511,
#   "LAMTOR1-T48": 0.8528912522075862,
#   "LAMTOR1-T61": 0.14952549382388144,
#   "LAMTOR5-S108": 0.5454357774556415,
#   "LAMTOR5-S99": 0.8728541134232,
#   "MTOR-S1261": 0.3058476916270859,
#   "MTOR-S1821": 0.40571814343275714,
#   "MTOR-S1849": 0.9859515035037951,
#   "MTOR-S1851": 0.35393133201593713,
#   "MTOR-S2069": NaN,
#   "MTOR-S2450": 0.3800395157763883,
#   "MTOR-S2454": NaN,
#   "MTOR-S2478": 0.5188210679073968,
#   "MTOR-S2481": 0.3957400294802549,
#   "MTOR-T1826": 0.4710050798805524,
#   "MTOR-T1829": NaN,
#   "MTOR-T1834": 0.5929325336821898,
#   "MTOR-T1837": NaN,
#   "MTOR-T1844": NaN,
#   "MTOR-T2471": 0.5100282026814915,
#   "MTOR-T2473": 0.900562734063054,
#   "MTOR-T2474": 0.900562734063054,
#   "MTOR-Y2449": 0.9063054591979903,
#   "RPS6KA1-S230": 0.10849500667173836,
#   "RPS6KA1-S31": NaN,
#   "RPS6KA1-S316": 0.3784902403919025,
#   "RPS6KA1-S372": 0.42337341673252593,
#   "RPS6KA1-S378": 0.6744013678547671,
#   "RPS6KA1-S389": 0.8859783534328982,
#   "RPS6KA1-S437": 0.3893355263738157,
#   "RPS6KA1-S522": NaN,
#   "RPS6KA1-S54": NaN,
#   "RPS6KA1-S646": NaN,
#   "RPS6KA1-S696": 0.3332447993485439,
#   "RPS6KA1-T234": 0.15676820249709994,
#   "RPS6KA1-T30": NaN,
#   "RPS6KA1-T368": 0.7942485451389538,
#   "RPS6KA1-T56": 0.6361542072630806,
#   "RPS6KA1-Y237": NaN,
#   "RPS6KA2-S243": 0.6961525210382433,
#   "RPS6KA2-S402": NaN,
#   "RPS6KA2-S704": 0.7900044075604559,
#   "RPS6KA2-T247": 0.4306457714253348,
#   "RPS6KA2-T595": 0.4171963419999043,
#   "RPS6KA2-T599": 0.37589031956741986,
#   "RPS6KA2-Y250": 0.674720546763184,
#   "RPS6KA3-S17": NaN,
#   "RPS6KA3-S19": 0.6413517434120712,
#   "RPS6KA3-S21": NaN,
#   "RPS6KA3-S369": 0.7918150334114176,
#   "RPS6KA3-S375": 0.4674091546313657,
#   "RPS6KA3-S386": 0.33880042902040536,
#   "RPS6KA3-S415": 0.6394910329634181,
#   "RPS6KA3-S639": NaN,
#   "RPS6KA3-S715": 0.326491783646785,
#   "RPS6KA3-S724": NaN,
#   "RPS6KA3-T365": 0.8935186470900249,
#   "RPS6KA3-T725": NaN,
#   "RPS6KA3-Y644": NaN,
#   "RPS6KA4-S343": 0.2553513180810706,
#   "RPS6KA4-S347": 0.19864164293724842,
#   "RPS6KA4-S502": NaN,
#   "RPS6KA4-S634": 0.053523132881374384,
#   "RPS6KA4-S678": 0.7899466741530146,
#   "RPS6KA4-S681": 0.16306098691565887,
#   "RPS6KA4-S682": 0.09097546789734172,
#   "RPS6KA4-S721": 0.540257542152332,
#   "RPS6KA4-S737": 0.5177212502969969,
#   "RPS6KA4-S745": 0.887355610256318,
#   "RPS6KA4-T22": 0.7972034422411834,
#   "RPS6KA4-T542": 0.2181452063346941,
#   "RPS6KA4-T687": 0.5031164943913602,
#   "RPS6KA4-Y342": 0.33719612876915883,
#   "RPS6KA5-S212": 0.5884000647218017,
#   "RPS6KA5-S360": 0.6735838216093238,
#   "RPS6KA5-S376": 0.24175029180526036,
#   "RPS6KA5-S438": 0.687740105728047,
#   "RPS6KA5-S448": 0.5186336589506337,
#   "RPS6KA5-S517": 0.01188221094676727,
#   "RPS6KA5-S628": 0.08579435585401278,
#   "RPS6KA5-S695": 0.13051457709449305,
#   "RPS6KA5-S750": 0.46801464730744036,
#   "RPS6KA5-S752": 0.5143986169206259,
#   "RPS6KA5-T216": 0.6345701521285889,
#   "RPS6KA5-T38": 0.8420925839062485,
#   "RPS6KA5-T630": 0.4721864211806346,
#   "RPS6KA5-T700": NaN,
#   "RPS6KA5-T749": 0.5233742878066577,
#   "RPS6KA5-T751": 0.9658484931660463,
#   "RPS6KA5-T753": 0.8901315149024189,
#   "RPS6KA5-Y359": 0.7897928358978005,
#   "RPS6KA6-S389": 0.3377396472252062,
#   "RPS6KB2-S370": NaN,
#   "RPS6KB2-S416": 0.9761970765323627,
#   "RPS6KB2-S417": 0.9761970765323627,
#   "RPS6KB2-S423": 0.9781346954502214,
#   "RPS6KC1-S199": 0.3378913782419892,
#   "RPS6KC1-S201": NaN,
#   "RPS6KC1-S202": 0.45020417869211704,
#   "RPS6KC1-S209": NaN,
#   "RPS6KC1-S282": 0.790555905679404,
#   "RPS6KC1-S302": 0.7113668575556574,
#   "RPS6KC1-S304": 0.6647169651243634,
#   "RPS6KC1-S423": 0.02035693277371136,
#   "RPS6KC1-S427": 0.06746207379725772,
#   "RPS6KC1-S449": 0.24526351315581085,
#   "RPS6KC1-S453": NaN,
#   "RPS6KC1-S454": 0.13682690878150539,
#   "RPS6KC1-S455": 0.1614237500987813,
#   "RPS6KC1-S461": NaN,
#   "RPS6KC1-S475": NaN,
#   "RPS6KC1-S484": NaN,
#   "RPS6KC1-S528": 0.9840668236078579,
#   "RPS6KC1-S560": 0.17686663565700272,
#   "RPS6KC1-S582": 0.22890282194389186,
#   "RPS6KC1-S583": 0.906709994475363,
#   "RPS6KC1-S596": 0.9137083459802688,
#   "RPS6KC1-S605": 0.34183257402775136,
#   "RPS6KC1-S608": 0.42262954739782244,
#   "RPS6KC1-S610": NaN,
#   "RPS6KC1-S642": 0.24486582361502676,
#   "RPS6KC1-S644": 0.030634898149703948,
#   "RPS6KC1-S661": 0.18696169267496,
#   "RPS6KC1-S664": 0.8431765437027823,
#   "RPS6KC1-S667": 0.5389580401376453,
#   "RPS6KC1-S762": 0.5421845625996844,
#   "RPS6KC1-S823": 0.3838926916317099,
#   "RPS6KC1-S826": 0.4625333889709036,
#   "RPS6KC1-S834": 0.5519159433966421,
#   "RPS6KC1-S872": 0.8609844199733336,
#   "RPS6KC1-T284": NaN,
#   "RPS6KC1-T659": 0.5987155117884233,
#   "RPS6KC1-T684": NaN,
#   "RPS6KC1-Y307": 0.0728862531576904,
#   "ERBB3-S1044": 0.7679620692501472,
#   "ERBB3-S1049": NaN,
#   "ERBB3-S1096": NaN,
#   "ERBB3-S1097": NaN,
#   "ERBB3-S1315": 0.543255284415413,
#   "ERBB3-S686": 0.10533473885815298,
#   "ERBB3-S717": 0.2783043326811471,
#   "ERBB3-S846": 0.777718143494867,
#   "ERBB3-S982": 0.09676635858573435,
#   "CDK5-S229": 0.7699487312104698,
#   "CDK5-Y15": 0.3558912953808956,
#   "CDK5RAP2-S1020": 0.2550125868821355,
#   "CDK5RAP2-S1061": 0.1360547618396683,
#   "CDK5RAP2-S1064": 0.2207458407384304,
#   "CDK5RAP2-S1074": 0.026524157737168014,
#   "CDK5RAP2-S1102": 0.1252377078277082,
#   "CDK5RAP2-S1238": 0.92622116719948,
#   "CDK5RAP2-S1350": 0.9014248519642185,
#   "CDK5RAP2-S1356": NaN,
#   "CDK5RAP2-S1490": 0.20849529329022223,
#   "CDK5RAP2-S1666": 0.4756334482762579,
#   "CDK5RAP2-S1887": 0.5083582578104385,
#   "CDK5RAP2-S576": 0.46807341442898154,
#   "CDK5RAP2-S841": 0.6112091604493027,
#   "CDK5RAP2-S947": NaN,
#   "CDK5RAP2-T1076": 0.3096587170103758,
#   "CDK5RAP2-T1677": 0.7091817283539381
# }

# %% [markdown]
# ## 5b. Plot the data for the most significant result

# %% [markdown]
# <b> Note: </b> This result did not pass the Bonferroni correction of significance. This is the lowest p-value found in our list of unsignificant results.

# %%
#Get the site with the lowest p-value 
site = min(unsigSites.keys(), key=(lambda k: unsigSites[k]))

#Get the ttest results computed from the previous step, using RPS6KC1-S423 as the site of interest
phos_mutations = CPTAC.compare_mutations(phos, site, gene)
phos_mutations['Within_Hotspot'] = 'Outside Hotspot'
phos_mutations.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
phos_mutations.loc[phos_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype_Tumor'

# Select for tumor samples only 
phos_mutations = phos_mutations.loc[phos_mutations['PIK3CA_Sample_Status'] == 'Tumor']

# Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
#phos_sites = list(phos_mutations)
# Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
phos_sites = phos_sites[:(len(phos_sites) - 3)]

#  Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
#    Drop any columns that contain values of 'Nan' which means for 'Not a number'
hotspot_mut = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Within Hotspot'].dropna(axis = 0)
wt = phos_mutations.loc[phos_mutations['Within_Hotspot'] == 'Wildtype_Tumor'].dropna(axis = 0)

# Take out the patients with mutations outside of the hotspot
phos_mutations = phos_mutations.loc[phos_mutations['Within_Hotspot'] != 'Outside Hotspot']

# Perform a two-sample t-test on the two groups 
tstat, pvalue = scipy.stats.ttest_ind(hotspot_mut[site + '_omics'], wt[site + '_omics'])

# Set the plot dimensions
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)

# Create the plot and add styling
boxplt = sns.boxplot(data = phos_mutations, x = 'Within_Hotspot', y = site + '_omics', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Within_Hotspot', y = site + '_omics', jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Location', fontsize='20')
boxplt.set_ylabel('Protein Expression', fontsize='20')
boxplt.set_title("Effect of " + gene + " hotspot mutation on " + site + " proteomics" + '\nP-value = ' + str(round(pvalue,  6)), fontsize='22')
plt.show()

# %% [markdown]
# ## 5c. All mutations vs cancer wildtype

# %%
#1. Create two corresponding lists for sites and their respective pvalues to calculate the Bonferroni correction when all of the sites have been analyzed
sites = []
pvalues = []

# 1. Loop through each of the proteins in the list of interacting proteins
for protein in protList:
   # 2. Loop through each phosphorylation site in that protein to find any that show any significant changes in phosphorylation level
    #  Some proteins do not have recorded data in the phosphoproteomics data. If this is the case, we move on to the next protein in the list
    try:
        
        # 3. Set up a new column for mutations that are within the hotspot
        phos_mutations = CPTAC.compare_mutations(phos, protein, gene)
        
        # 4. Select for tumor samples only 
        phos_mutations = phos_mutations.loc[phos_mutations['PIK3CA_Sample_Status'] == 'Tumor']
       
        #5. Create a list of the phosphosites by selecting all the columns in the dataframe, excluding the last three which are categorical variables
        phos_sites = list(phos_mutations)
        # Take out the categorical variables, which are 'Mutation', 'Patient_Type', and 'Within_Hotspot'
        phos_sites = phos_sites[:(len(phos_sites) - 3)]

        # 6. Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
        #    Drop any columns that contain values of 'Nan' which means for 'Not a number'
        all_mut = phos_mutations.loc[phos_mutations['PIK3CA_Mutation'] != 'Wildtype_Tumor'].dropna(axis = 1)
        wt = phos_mutations.loc[phos_mutations['PIK3CA_Mutation'] == 'Wildtype_Tumor'].dropna(axis = 1)

        # 7. Loop through each site to test for significant difference in phosphorylation levels between the two tested cases
        for site in phos_sites:

        # 8. Check if the site is in both dataframes. That column may have been deleted in step 4
            if site in all_mut.columns and site in wt.columns:
                
                # 9. Perform a two-sample ttest for all mutations vs cancer wildtype
                tstat, pvalue = scipy.stats.ttest_ind(all_mut[site], wt[site])
                
                # 10. Append site name and pvalue in two separate lists that will be used to calculate the pvalue adjustment using Bonferroni correction
                sites.append(site)
                pvalues.append(pvalue)
    #Error caught in the case that the protein had no data in the phosproteomics data
    except:
        print('')
        
        
# 11. After looping through all of the phosphorylation sites of each protein, filter the list of pvalues with respective sites to find those with significant results
#     Create a dictionary to pair the significant sites with their significant pvalues 
#     Create another dictionary for unsignificant results
sigSites = {}
unsigSites = {}

#     The Bonferroni correction is alpha/number of sites tested
alpha = 0.05
pcutoff = alpha/len(sites)
print('\nAdjusted p-value: ', pcutoff, '\n')

#     Loop through each pvalue to find those that are lower than the pcutoff
for i in range(0, len(sites) - 1):
    if pvalues[i] < pcutoff:
        sigSites[sites[i]] = pvalues[i]
    else:
        unsigSites[sites[i]] = pvalues[i]

# 12. Print your results
print('SIGNIFICANT RESULTS:')
print(json.dumps(sigSites, indent = 2))
print(' ')
print('UNSIGNIFICANT RESULTS:')
print(json.dumps(unsigSites, indent = 2))
# Out:
# Gene MRAS not found in phosphoproteomics data
#
# Gene HRAS not found in phosphoproteomics data
#
# Gene P85A not found in phosphoproteomics data
#
# Gene P55G not found in phosphoproteomics data
#
#
# Adjusted p-value:  0.0020833333333333333
#
# SIGNIFICANT RESULTS:
# {}
#
# UNSIGNIFICANT RESULTS:
# {
#   "IRS1-S1005": 0.8582155333277856,
#   "IRS1-S270": 0.5455081062631899,
#   "IRS1-S527": 0.9335053890879129,
#   "IRS2-S1100": 0.5089515383376189,
#   "IRS2-S365": 0.1488315807160331,
#   "RRAS2-S186": 0.08195973735412895,
#   "PTEN-S467": 0.21441699534567685,
#   "AKT1-S126": 0.9320586620240865,
#   "AKT1-S129": 0.6923635694791075,
#   "AKT1S1-S222": 0.6138456554941203,
#   "AKT1S1-S223": 0.7757002685589837,
#   "AKT1S1-S232": 0.9976098942994294,
#   "LAMTOR1-S27": 0.3495941573977167,
#   "RPS6KA1-S372": 0.499583945388996,
#   "RPS6KA3-S369": 0.6802063291345009,
#   "RPS6KA3-S415": 0.7722514441199118,
#   "RPS6KA3-T365": 0.586597390585479,
#   "RPS6KA4-S343": 0.2917774575134804,
#   "RPS6KA4-S347": 0.11141036495244633,
#   "RPS6KA4-S682": 0.0813941233707406,
#   "RPS6KA4-S745": 0.6612399490255205,
#   "RPS6KC1-S423": 0.3118126638887184,
#   "RPS6KC1-S667": 0.8488746978568008
# }

# %% [markdown]
# ## 5d. Plot the data for the most significant results

# %%
# Get the site with the lowest p-value 
site = min(unsigSites.keys(), key=(lambda k: unsigSites[k]))

# Get the dataframe for the site of interest
phos_mutations = CPTAC.compare_mutations(phos, site, gene)

# Select for tumor samples only 
phos_mutations = phos_mutations.loc[phos_mutations['PIK3CA_Sample_Status'] == 'Tumor']

# Drop any columns that contain values of 'Nan' which means for 'Not a number'
phos_mutations['Status'] = 'Cancer Wildtype'
phos_mutations.loc[phos_mutations['PIK3CA_Mutation'] != 'Wildtype_Tumor', 'Status'] = 'Mutated'

# Create two dataframes to test the two cases: one for phosphorylation levels when PIK3CA is mutated at a hotspot, the other when PIK3CA is mutated outside the hotspot
hotspot_mut = phos_mutations.loc[phos_mutations['Status'] == 'Mutated'].dropna(axis = 1)
wt = phos_mutations.loc[phos_mutations['Status'] == 'Cancer Wildtype'].dropna(axis = 1)

# Perform a two-sample t-test on the two groups 
ttest = scipy.stats.ttest_ind(hotspot_mut[site + '_omics'], wt[site + '_omics'])

# Add plot dimensions
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)

# Create the plot and add styling
boxplt = sns.boxplot(data = phos_mutations, x = 'Status', y = site + '_omics', ax = ax)
boxplt = sns.stripplot(data = phos_mutations, x = 'Status', y = site + '_omics', jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Type', fontsize='20')
boxplt.set_ylabel('Protein Expression', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + site + " phosphoproteomics" + '\nP-value = ' + str(round(ttest[1],  6)), fontsize='22')
plt.show()

# %% [markdown]
# ### We can conclude from these results that PIK3CA mutation, neither hotspot no non-hotspot mutations, do not have a significant effect on the proteomics or phosproteomics of its interacting proteins
