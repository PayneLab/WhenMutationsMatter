# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections
import re

import CPTAC.Endometrial as en
import CPTAC.Algorithms as al
# Out:
# Welcome to the CPTAC data service package. Available datasets may be
# viewed using CPTAC.list_data(). In order to access a specific data
# set, import a CPTAC subfolder using either 'import CPTAC.Dataset' or
# 'from CPTAC import Dataset'.
# ******
# Version: 0.3.1
# ******
# Loading Endometrial CPTAC data:
# Loading Dictionary...
# Loading Clinical Data...
# Loading Acetylation Proteomics Data...
# Loading Proteomics Data...
# Loading Transcriptomics Data...
# Loading CNA Data...
# Loading Phosphoproteomics Data...
# Loading Somatic Mutation Data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until July 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until July 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# ...

# %%
somatic = en.get_mutations()
clinical = en.get_clinical()
prot = en.get_proteomics()
gene = 'PTEN'
omics_mutations = en.append_mutations_to_omics(mutation_genes=gene, omics_df=prot, omics_genes=gene)
omics_mutations = omics_mutations.loc[omics_mutations['Sample_Status'] == 'Tumor']

fm = al.get_frequently_mutated(somatic, omics_mutations, .2, show_percentage=True)
print(fm)
# Out:
# ovarian

# %%
omics_mutations.tail()
# Out:
#       PTEN_proteomics      PTEN_Mutation  PTEN_Location Sample_Status
# S149            0.357  [Wildtype_Normal]  [No_mutation]        Normal
# S150            0.469  [Wildtype_Normal]  [No_mutation]        Normal
# S151            0.424  [Wildtype_Normal]  [No_mutation]        Normal
# S152            0.290  [Wildtype_Normal]  [No_mutation]        Normal
# S153            0.530  [Wildtype_Normal]  [No_mutation]        Normal

# %%
print(omics_mutations)
# Out:
#       PTEN_proteomics                                      PTEN_Mutation  \
# S001          -0.5260             [Missense_Mutation, Nonsense_Mutation]
# S002          -0.8300                                [Missense_Mutation]
# S003          -0.9410                                [Nonsense_Mutation]
# S005           0.7300                                [Missense_Mutation]
# S006          -0.3790                                   [Wildtype_Tumor]
# S007           0.0293             [Missense_Mutation, Missense_Mutation]
# S008          -1.0100               [Frame_Shift_Ins, Nonsense_Mutation]
# S009           0.1300                                   [Wildtype_Tumor]
# S010           0.3900                                [Missense_Mutation]
# S011           0.0301               [Missense_Mutation, Frame_Shift_Ins]
# S012          -1.5900  [Nonsense_Mutation, Missense_Mutation, Missens...
# S014          -1.0400                 [Frame_Shift_Del, Frame_Shift_Del]
# ...

# %%
selection = ['Wildtype_Tumor']
mask = omics_mutations.PTEN_Mutation.apply(lambda x: any(item for item in selection if item in x))
wtdf = omics_mutations[mask]
wtdf.head()
# Out:
#       PTEN_proteomics     PTEN_Mutation  PTEN_Location Sample_Status
# S006           -0.379  [Wildtype_Tumor]  [No_mutation]         Tumor
# S009            0.130  [Wildtype_Tumor]  [No_mutation]         Tumor
# S016           -0.539  [Wildtype_Tumor]  [No_mutation]         Tumor
# S017            0.457  [Wildtype_Tumor]  [No_mutation]         Tumor
# S018            0.109  [Wildtype_Tumor]  [No_mutation]         Tumor

# %%
mutmask = omics_mutations.PTEN_Mutation.apply(lambda x: any(item for item in selection if item not in x))
mutdf = omics_mutations[mutmask]
print(mutdf)
# Out:
#       PTEN_proteomics                                      PTEN_Mutation  \
# S001          -0.5260             [Missense_Mutation, Nonsense_Mutation]
# S002          -0.8300                                [Missense_Mutation]
# S003          -0.9410                                [Nonsense_Mutation]
# S005           0.7300                                [Missense_Mutation]
# S007           0.0293             [Missense_Mutation, Missense_Mutation]
# S008          -1.0100               [Frame_Shift_Ins, Nonsense_Mutation]
# S010           0.3900                                [Missense_Mutation]
# S011           0.0301               [Missense_Mutation, Frame_Shift_Ins]
# S012          -1.5900  [Nonsense_Mutation, Missense_Mutation, Missens...
# S014          -1.0400                 [Frame_Shift_Del, Frame_Shift_Del]
# S019          -1.7000                                  [Frame_Shift_Del]
# S020           0.6170                                [Missense_Mutation]
# ...

# %%
print(len(wtdf))
print(len(mutdf))

print((len(mutdf)/(len(mutdf)+len(wtdf))))
# Out:
# 20
# 124
# 0.8611111111111112
