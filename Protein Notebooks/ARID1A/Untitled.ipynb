# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

import cptac
import cptac.algorithms as al

# %%
# omics and mut, tumors, gene

def get_missence_truncation_comparison(cancer_object, specific_omics, gene):
    #get omics data and tumors
    omics_and_mutations = cancer_object.append_mutations_to_omics(
            mutation_genes = gene, omics_df_name = specific_omics.name, omics_genes = gene)
    tumors = omics_and_mutations.loc[omics_and_mutations['Sample_Status'] == 'Tumor']
    
    #data for mutation comparison
    somatic_mutations = cancer_object.get_mutations().reset_index()
    gene_df = somatic_mutations.loc[somatic_mutations['Gene'] == gene]
    
    if cancer_object.get_cancer_type() == 'colon':
        missence_truncation_groups = {'frameshift substitution': 'T', 
            'frameshift deletion': 'T', 'frameshift insertion': 'T', 
            'stopgain': 'T', 'stoploss': 'T', 'nonsynonymous SNV': 'M',
            'nonframeshift insertion': 'M','nonframeshift deletion': 'M', 
            'nonframeshift substitution': 'M'}
    else: 
        missence_truncation_groups = {'In_Frame_Del': 'M', 'In_Frame_Ins': 'M',
            'Missense_Mutation': 'M', 'Frame_Shift_Del': 'T','Nonsense_Mutation': 'T', 
            'Splice_Site': 'T', 'Frame_Shift_Ins': 'T','Nonstop_Mutation':'T'}
        
    mutations_replaced_M_T = gene_df.replace(missence_truncation_groups)
    
    # group mutation categories
    miss = mutations_replaced_M_T.loc[mutations_replaced_M_T['Mutation'] == 'M']
    trunc = mutations_replaced_M_T.loc[mutations_replaced_M_T['Mutation'] == 'T']
    
    #get lists of unique samples for missence and trucation categories
    miss_unique_samples = list(miss['Sample_ID'].unique())
    trunc_unique_samples = list(trunc['Sample_ID'].unique())
    
    # Get mutation catagories with omics data
    missence_omics = tumors.loc[tumors.index.isin(miss_unique_samples)]
    truncation_omics = tumors.loc[tumors.index.isin(trunc_unique_samples)]
    
    
  
    return truncation_omics

# %%
en_object = cptac.Endometrial()
desired_cutoff = .1

endometrial_freq_mut = al.get_frequently_mutated(en_object, cutoff=desired_cutoff)
print('\n\nNumber of Frequently Mutated Genes:', len(endometrial_freq_mut), '\n', endometrial_freq_mut.head())
# Out:
# matting dataframes...linear data.....
#
# Number of Frequently Mutated Genes: 232
#       Gene  Unique_Samples_Mut  Missence_Mut  Truncation_Mut
# 0  ABCA12            0.147368      0.094737        0.073684
# 1  ABCA13            0.115789      0.105263        0.042105
# 2  ACVR2A            0.105263      0.010526        0.094737
# 3  ADGRG4            0.136842      0.126316        0.021053
# 4  ADGRV1            0.115789      0.094737        0.052632

# %%
omics = en_object.get_proteomics()
#omics = en_object.get_transcriptomics()
#omics = en_object.get_phosphoproteomics()
#omics = en_object.get_acetylproteomics()

# %%
mutation_type_comparison = get_missence_truncation_comparison(en_object, omics, 'ARID1A')
mutation_type_comparison
# Out:
#            ARID1A_proteomics  \
# Sample_ID
# S002                -1.41000
# S008                 0.06220
# S012                -1.61000
# S014                -1.54000
# S018                 0.19500
# S019                -0.20900
# S023                 0.14900
# S024                -0.99200
# S026                -0.11300
# S030                -1.19000
# S036                -0.15800
# S037                -0.01320
# S038                -0.07990
# S040                -0.14400
# S049                -0.09070
# S050                -0.63900
# S051                -0.06790
# S053                -0.34400
# S057                -0.74600
# S064                -0.69800
# S068                -1.17000
# S069                -1.00000
# S073                -1.14000
# S077                -1.46000
# S078                -0.35600
# S080                -0.24000
# S083                -2.12000
# S084                -0.01280
# S085                 0.26900
# S087                -1.43000
# S090                -0.00658
# S091                -0.84000
# S092                -0.79300
# S093                -0.06580
# S094                -1.10000
# S098                -0.65100
# S099                -0.42800
# S100                -1.65000
#
#                                              ARID1A_Mutation  \
# Sample_ID
# S002                    [Nonsense_Mutation, Frame_Shift_Del]
# S008                                       [Frame_Shift_Del]
# S012                                     [Nonsense_Mutation]
# S014                  [Nonsense_Mutation, Missense_Mutation]
# S018                                     [Nonsense_Mutation]
# S019                                       [Frame_Shift_Ins]
# S023                  [Nonsense_Mutation, Nonsense_Mutation]
# S024       [Nonsense_Mutation, Frame_Shift_Ins, Missense_...
# S026                                     [Nonsense_Mutation]
# S030                                       [Frame_Shift_Del]
# S036                                       [Frame_Shift_Del]
# S037                    [Missense_Mutation, Frame_Shift_Ins]
# S038                                     [Nonsense_Mutation]
# S040                                     [Nonsense_Mutation]
# S049                                       [Frame_Shift_Del]
# S050                    [Nonsense_Mutation, Frame_Shift_Ins]
# S051                      [Frame_Shift_Del, Frame_Shift_Del]
# S053                                       [Frame_Shift_Del]
# S057                    [Nonsense_Mutation, Frame_Shift_Del]
# S064                       [Nonsense_Mutation, In_Frame_Del]
# S068                                       [Frame_Shift_Ins]
# S069                      [Frame_Shift_Ins, Frame_Shift_Del]
# S073       [Frame_Shift_Del, Missense_Mutation, Frame_Shi...
# S077                                       [Frame_Shift_Del]
# S078                      [Frame_Shift_Ins, Frame_Shift_Del]
# S080                                       [Frame_Shift_Del]
# S083                                       [Frame_Shift_Del]
# S084                                       [Frame_Shift_Del]
# S085                    [Frame_Shift_Del, Missense_Mutation]
# S087                                     [Nonsense_Mutation]
# S090                                       [Frame_Shift_Del]
# S091                      [Frame_Shift_Del, Frame_Shift_Ins]
# S092                      [Frame_Shift_Del, Frame_Shift_Del]
# S093                                       [Frame_Shift_Del]
# S094       [Frame_Shift_Del, Nonsense_Mutation, Missense_...
# S098                    [Nonsense_Mutation, Frame_Shift_Ins]
# S099                  [Missense_Mutation, Nonsense_Mutation]
# S100                                       [Frame_Shift_Ins]
#
#                                    ARID1A_Location ARID1A_Mutation_Status  \
# Sample_ID
# S002                      [p.Q403*, p.D1850Tfs*33]      Multiple_mutation
# S008                                [p.T541Pfs*77]        Single_mutation
# S012                                    [p.R1989*]        Single_mutation
# S014                           [p.Q557*, p.I1117F]      Multiple_mutation
# S018                                    [p.R1989*]        Single_mutation
# S019                                [p.D1850Gfs*4]        Single_mutation
# S023                          [p.C1827*, p.R1989*]      Multiple_mutation
# S024            [p.Y471*, p.H1581Qfs*22, p.G2087R]      Multiple_mutation
# S026                                     [p.R750*]        Single_mutation
# S030                                [p.A339Lfs*24]        Single_mutation
# S036                                [p.V1561Hfs*8]        Single_mutation
# S037                       [p.P687H, p.D1850Gfs*4]      Multiple_mutation
# S038                                    [p.R1276*]        Single_mutation
# S040                                    [p.R1989*]        Single_mutation
# S049                               [p.K2045Sfs*53]        Single_mutation
# S050                      [p.Q543*, p.Q1327Afs*11]      Multiple_mutation
# S051                 [p.G276Efs*87, p.D1850Tfs*33]      Multiple_mutation
# S053                                [p.Q521Rfs*98]        Single_mutation
# S057                     [p.R1276*, p.F2141Sfs*59]      Multiple_mutation
# S064                   [p.R693*, p.G2012_I2015del]      Multiple_mutation
# S068                                [p.D1850Gfs*4]        Single_mutation
# S069                 [p.Q355Tfs*45, p.D1850Tfs*33]      Multiple_mutation
# S073       [p.L1160Kfs*32, p.R1918W, p.F2141Lfs*9]      Multiple_mutation
# S077                                [p.Q372Sfs*19]        Single_mutation
# S078                    [p.A6Gfs*109, p.P427Rfs*6]      Multiple_mutation
# S080                                [p.Y551Tfs*68]        Single_mutation
# S083                               [p.G248Afs*148]        Single_mutation
# S084                               [p.I1855Tfs*28]        Single_mutation
# S085                     [p.K1072Nfs*21, p.S2126N]      Multiple_mutation
# S087                                     [p.S607*]        Single_mutation
# S090                               [p.L1967Cfs*48]        Single_mutation
# S091                 [p.Q1452Rfs*29, p.D1850Gfs*4]      Multiple_mutation
# S092                 [p.Y551Tfs*68, p.F2141Sfs*59]      Multiple_mutation
# S093                               [p.M2231Rfs*41]        Single_mutation
# S094            [p.G276Efs*87, p.Q1947*, p.W1973R]      Multiple_mutation
# S098                      [p.R693*, p.Q1537Pfs*31]      Multiple_mutation
# S099                           [p.P819S, p.R2158*]      Multiple_mutation
# S100                               [p.L1176Ifs*17]        Single_mutation
#
#           Sample_Status
# Sample_ID
# S002              Tumor
# S008              Tumor
# S012              Tumor
# S014              Tumor
# S018              Tumor
# S019              Tumor
# S023              Tumor
# S024              Tumor
# S026              Tumor
# S030              Tumor
# S036              Tumor
# S037              Tumor
# S038              Tumor
# S040              Tumor
# S049              Tumor
# S050              Tumor
# S051              Tumor
# S053              Tumor
# S057              Tumor
# S064              Tumor
# S068              Tumor
# S069              Tumor
# S073              Tumor
# S077              Tumor
# S078              Tumor
# S080              Tumor
# S083              Tumor
# S084              Tumor
# S085              Tumor
# S087              Tumor
# S090              Tumor
# S091              Tumor
# S092              Tumor
# S093              Tumor
# S094              Tumor
# S098              Tumor
# S099              Tumor
# S100              Tumor
