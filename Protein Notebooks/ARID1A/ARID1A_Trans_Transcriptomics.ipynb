# %% [markdown]
# # ARID1A Mutation Trans Effect on Transcriptomics

# %% [markdown]
# This notebook analyzes the trans effect of ARID1A mutation on interacting and other proteins Transcriptomics, in Endometrial, Colon, and Ovarian cancer.

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections

import warnings
warnings.filterwarnings("ignore")

import cptac
import cptac.algorithms as al

en = cptac.Endometrial()
co = cptac.Colon()
ov = cptac.Ovarian()

# %% [markdown]
# ### Select Gene

# %%
gene = "ARID1A"

# %% [markdown]
# ### Investigate Proteomics, Phosphoproteomics, Acetylproteomics, or Transcriptomics

# %%
#omics = "proteomics"
omics = "transcriptomics"
#omics = "phosphoproteomics"
#omics = "acetylproteomics"

# %% [markdown]
# ### Track all significant comparisons in Dataframe

# %%
all_significant_comparisons = pd.DataFrame(columns=['Cancer_Type', 'Gene', 'Comparison','Interacting_Protein','P_Value'])

# %%
def add_to_all_significant_comparisons(df, cancer, interacting, all_sig_comp):
    expanded = df
    expanded['Gene'] = gene
    expanded['Cancer_Type'] = cancer
    expanded['Interacting_Protein'] = interacting
    
    updated_all_comparisons = pd.concat([all_sig_comp, expanded], sort=False)
    
    return updated_all_comparisons

# %% [markdown]
# # Interacting Proteins: Transcriptomics

# %% [markdown]
# ### Generate interacting protein list

# %% [markdown]
# Make a call to the cptac.algorithms get interacting proteins method, which interacts with the uniprot and string databases to generate a list of known interacting partners with the given gene

# %%
'''Use get interacting proteins method to generate list of interacting proteins'''
interacting_proteins = al.get_interacting_proteins(gene)

'''Show interacting protein list'''
print("Interacting Proteins:")
for interacting_protein in interacting_proteins:
    print(interacting_protein)
# Out:
# Interacting Proteins:
# SMARCC1
# SUPT16H
# CCND1
# SMARCD3
# CREBBP
# SMARCB1
# KAT2B
# DNMT3A
# SMARCA2
# SMARCC2
# KMT2D
# ARID1A
# SMARCE1
# PHF10
# BAZ1B
# ARID1B
# NF1
# CDC5L
# SMARCD1
# SMARCD2
# SMARCA4
# ACTL6A
# BCL7B
# SS18
# DPF2
# DPF3
# KLF1
# GATA1
# ING1
# PGR
# BCL7C
# HIC1

# %% [markdown]
# ## Endometrial

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)


'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Endometrial", True, all_significant_comparisons)
# Out:
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Colon

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Colon", True, all_significant_comparisons)
# Out:
# DPF3 did not match any columns in transcriptomics dataframe. DPF3_transcriptomics column inserted, but filled with NaN.
# KLF1 did not match any columns in transcriptomics dataframe. KLF1_transcriptomics column inserted, but filled with NaN.
# GATA1 did not match any columns in transcriptomics dataframe. GATA1_transcriptomics column inserted, but filled with NaN.
# PGR did not match any columns in transcriptomics dataframe. PGR_transcriptomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Ovarian

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Ovarian", True, all_significant_comparisons)
# Out:
# BCL7C did not match any columns in transcriptomics dataframe. BCL7C_transcriptomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
#             Comparison       P_Value
# 0  PGR_transcriptomics  6.009689e-08

# %% [markdown]
# # All Proteins: Transcriptomics

# %% [markdown]
# Expand our search for significant comparisons to all proteins in our dataset

# %% [markdown]
# ## Endometrial

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")
            
            all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Endometrial", False, all_significant_comparisons)


except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  ARID1A
# Doing t-test comparisons
#
#                  Comparison       P_Value
# 0      PRNP_transcriptomics  7.546881e-09
# 1    SAPCD2_transcriptomics  7.544245e-08
# 2      CDH1_transcriptomics  1.324795e-07
# 3      EYA4_transcriptomics  1.683441e-07
# 4    FAM57A_transcriptomics  3.737113e-07
# 5     PCLAF_transcriptomics  3.860434e-07
# 6      LRBA_transcriptomics  8.352878e-07
# 7    TDRD10_transcriptomics  9.668603e-07
# 8     WDR34_transcriptomics  1.308609e-06
# 9     LHCGR_transcriptomics  1.368058e-06
# 10  FAM110B_transcriptomics  1.567902e-06

# %% [markdown]
# ## Colon

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")
            
            all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Colon", False, all_significant_comparisons)


except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  ARID1A
# Doing t-test comparisons
#
#                 Comparison       P_Value
# 0    TDGF1_transcriptomics  3.068549e-08
# 1    AXIN2_transcriptomics  6.590190e-07
# 2    APOL2_transcriptomics  6.897007e-07
# 3    RNF43_transcriptomics  1.216561e-06
# 4  POU5F1B_transcriptomics  1.400440e-06
# 5     IL15_transcriptomics  1.529432e-06
# 6  FAM71E1_transcriptomics  2.573590e-06
# 7    ROCK2_transcriptomics  3.370621e-06

# %% [markdown]
# ## Ovarian

# %%
print("\nGene: ", gene)

'''Use all proteins'''

'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
protdf = protdf.loc[:,~protdf.columns.duplicated()]

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the datafram correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Ovarian", False, all_significant_comparisons)
# Out:
# Gene:  ARID1A
# Doing t-test comparisons
#
#                        Comparison       P_Value
# 0          MTNR1B_transcriptomics  4.806922e-16
# 1           CDK20_transcriptomics  2.998791e-15
# 2            HMX3_transcriptomics  2.826724e-14
# 3           RXFP1_transcriptomics  4.168296e-13
# 4           GPR97_transcriptomics  5.061682e-13
# 5           TUNAR_transcriptomics  5.713628e-13
# 6         SLC26A2_transcriptomics  1.865577e-12
# 7           PGAP2_transcriptomics  3.420800e-12
# 8     ANKRD20A12P_transcriptomics  9.261376e-12
# 9        TNFRSF18_transcriptomics  9.514260e-12
# 10            HGD_transcriptomics  1.070983e-11
# 11       C10orf71_transcriptomics  3.187757e-11
# 12   LOC100506526_transcriptomics  3.325323e-11
# 13         C2CD4B_transcriptomics  3.860608e-11
# 14         MFAP3L_transcriptomics  1.417773e-10
# 15      LINC00645_transcriptomics  2.321706e-10
# 16          OLFM4_transcriptomics  2.840319e-10
# 17           HES2_transcriptomics  3.318104e-10
# 18         RNF186_transcriptomics  3.846150e-10
# 19         SLC5A9_transcriptomics  4.499720e-10
# 20          CCAT1_transcriptomics  4.591002e-10
# 21          FGF14_transcriptomics  5.719453e-10
# 22      LOC158434_transcriptomics  6.466856e-10
# 23          GABRP_transcriptomics  8.434191e-10
# 24           ERMN_transcriptomics  9.957977e-10
# 25        SCGB2A1_transcriptomics  1.085246e-09
# 26        SERINC2_transcriptomics  1.192787e-09
# 27           HMX2_transcriptomics  2.306227e-09
# 28          CAPN6_transcriptomics  2.674776e-09
# 29           ELP3_transcriptomics  2.962609e-09
# ..                            ...           ...
# 179          FUT6_transcriptomics  6.739185e-07
# 180       HSD17B2_transcriptomics  7.309743e-07
# 181         TPRX1_transcriptomics  7.323498e-07
# 182        TFAP2B_transcriptomics  7.441152e-07
# 183      MTRNR2L6_transcriptomics  7.453821e-07
# 184            F3_transcriptomics  8.296980e-07
# 185       TRIM43B_transcriptomics  8.299754e-07
# 186       PPP1R3B_transcriptomics  8.330275e-07
# 187         RFPL1_transcriptomics  8.986442e-07
# 188         GDF15_transcriptomics  9.257919e-07
# 189       CEACAM1_transcriptomics  9.589350e-07
# 190     MTUS2-AS1_transcriptomics  1.063140e-06
# 191         MFSD4_transcriptomics  1.078302e-06
# 192         NCALD_transcriptomics  1.286969e-06
# 193        AVPR1A_transcriptomics  1.313588e-06
# 194         MESP2_transcriptomics  1.353499e-06
# 195       SLC43A1_transcriptomics  1.403135e-06
# 196           PZP_transcriptomics  1.422187e-06
# 197  LOC100505817_transcriptomics  1.437350e-06
# 198     LOC643486_transcriptomics  1.446004e-06
# 199     LINC01245_transcriptomics  1.531206e-06
# 200         INSM1_transcriptomics  1.536219e-06
# 201  LOC102724484_transcriptomics  1.648421e-06
# 202        KIF13B_transcriptomics  1.650590e-06
# 203         KCNH4_transcriptomics  1.666373e-06
# 204        KHDC1L_transcriptomics  1.673755e-06
# 205        HS3ST1_transcriptomics  1.696851e-06
# 206     LINC00462_transcriptomics  1.753059e-06
# 207        SEMA3G_transcriptomics  2.101998e-06
# 208          ANO1_transcriptomics  2.154795e-06
#
# [209 rows x 2 columns]

# %% [markdown]
# ### Print All Signififant Comparisons

# %%
if len(all_significant_comparisons) == 0:
    print('No Significant Comparisons!')
    
else:
    display(all_significant_comparisons)
# Out:
#      Cancer_Type    Gene                    Comparison Interacting_Protein  \
# 0        Ovarian  ARID1A           PGR_transcriptomics                True
# 0    Endometrial  ARID1A          PRNP_transcriptomics               False
# 1    Endometrial  ARID1A        SAPCD2_transcriptomics               False
# 2    Endometrial  ARID1A          CDH1_transcriptomics               False
# 3    Endometrial  ARID1A          EYA4_transcriptomics               False
# 4    Endometrial  ARID1A        FAM57A_transcriptomics               False
# 5    Endometrial  ARID1A         PCLAF_transcriptomics               False
# 6    Endometrial  ARID1A          LRBA_transcriptomics               False
# 7    Endometrial  ARID1A        TDRD10_transcriptomics               False
# 8    Endometrial  ARID1A         WDR34_transcriptomics               False
# 9    Endometrial  ARID1A         LHCGR_transcriptomics               False
# 10   Endometrial  ARID1A       FAM110B_transcriptomics               False
# 0          Colon  ARID1A         TDGF1_transcriptomics               False
# 1          Colon  ARID1A         AXIN2_transcriptomics               False
# 2          Colon  ARID1A         APOL2_transcriptomics               False
# 3          Colon  ARID1A         RNF43_transcriptomics               False
# 4          Colon  ARID1A       POU5F1B_transcriptomics               False
# 5          Colon  ARID1A          IL15_transcriptomics               False
# 6          Colon  ARID1A       FAM71E1_transcriptomics               False
# 7          Colon  ARID1A         ROCK2_transcriptomics               False
# 0        Ovarian  ARID1A        MTNR1B_transcriptomics               False
# 1        Ovarian  ARID1A         CDK20_transcriptomics               False
# 2        Ovarian  ARID1A          HMX3_transcriptomics               False
# 3        Ovarian  ARID1A         RXFP1_transcriptomics               False
# 4        Ovarian  ARID1A         GPR97_transcriptomics               False
# 5        Ovarian  ARID1A         TUNAR_transcriptomics               False
# 6        Ovarian  ARID1A       SLC26A2_transcriptomics               False
# 7        Ovarian  ARID1A         PGAP2_transcriptomics               False
# 8        Ovarian  ARID1A   ANKRD20A12P_transcriptomics               False
# 9        Ovarian  ARID1A      TNFRSF18_transcriptomics               False
# ..           ...     ...                           ...                 ...
# 179      Ovarian  ARID1A          FUT6_transcriptomics               False
# 180      Ovarian  ARID1A       HSD17B2_transcriptomics               False
# 181      Ovarian  ARID1A         TPRX1_transcriptomics               False
# 182      Ovarian  ARID1A        TFAP2B_transcriptomics               False
# 183      Ovarian  ARID1A      MTRNR2L6_transcriptomics               False
# 184      Ovarian  ARID1A            F3_transcriptomics               False
# 185      Ovarian  ARID1A       TRIM43B_transcriptomics               False
# 186      Ovarian  ARID1A       PPP1R3B_transcriptomics               False
# 187      Ovarian  ARID1A         RFPL1_transcriptomics               False
# 188      Ovarian  ARID1A         GDF15_transcriptomics               False
# 189      Ovarian  ARID1A       CEACAM1_transcriptomics               False
# 190      Ovarian  ARID1A     MTUS2-AS1_transcriptomics               False
# 191      Ovarian  ARID1A         MFSD4_transcriptomics               False
# 192      Ovarian  ARID1A         NCALD_transcriptomics               False
# 193      Ovarian  ARID1A        AVPR1A_transcriptomics               False
# 194      Ovarian  ARID1A         MESP2_transcriptomics               False
# 195      Ovarian  ARID1A       SLC43A1_transcriptomics               False
# 196      Ovarian  ARID1A           PZP_transcriptomics               False
# 197      Ovarian  ARID1A  LOC100505817_transcriptomics               False
# 198      Ovarian  ARID1A     LOC643486_transcriptomics               False
# 199      Ovarian  ARID1A     LINC01245_transcriptomics               False
# 200      Ovarian  ARID1A         INSM1_transcriptomics               False
# 201      Ovarian  ARID1A  LOC102724484_transcriptomics               False
# 202      Ovarian  ARID1A        KIF13B_transcriptomics               False
# 203      Ovarian  ARID1A         KCNH4_transcriptomics               False
# 204      Ovarian  ARID1A        KHDC1L_transcriptomics               False
# 205      Ovarian  ARID1A        HS3ST1_transcriptomics               False
# 206      Ovarian  ARID1A     LINC00462_transcriptomics               False
# 207      Ovarian  ARID1A        SEMA3G_transcriptomics               False
# 208      Ovarian  ARID1A          ANO1_transcriptomics               False
#
#           P_Value
# 0    6.009689e-08
# 0    7.546881e-09
# 1    7.544245e-08
# 2    1.324795e-07
# 3    1.683441e-07
# 4    3.737113e-07
# 5    3.860434e-07
# 6    8.352878e-07
# 7    9.668603e-07
# 8    1.308609e-06
# 9    1.368058e-06
# 10   1.567902e-06
# 0    3.068549e-08
# 1    6.590190e-07
# 2    6.897007e-07
# 3    1.216561e-06
# 4    1.400440e-06
# 5    1.529432e-06
# 6    2.573590e-06
# 7    3.370621e-06
# 0    4.806922e-16
# 1    2.998791e-15
# 2    2.826724e-14
# 3    4.168296e-13
# 4    5.061682e-13
# 5    5.713628e-13
# 6    1.865577e-12
# 7    3.420800e-12
# 8    9.261376e-12
# 9    9.514260e-12
# ..            ...
# 179  6.739185e-07
# 180  7.309743e-07
# 181  7.323498e-07
# 182  7.441152e-07
# 183  7.453821e-07
# 184  8.296980e-07
# 185  8.299754e-07
# 186  8.330275e-07
# 187  8.986442e-07
# 188  9.257919e-07
# 189  9.589350e-07
# 190  1.063140e-06
# 191  1.078302e-06
# 192  1.286969e-06
# 193  1.313588e-06
# 194  1.353499e-06
# 195  1.403135e-06
# 196  1.422187e-06
# 197  1.437350e-06
# 198  1.446004e-06
# 199  1.531206e-06
# 200  1.536219e-06
# 201  1.648421e-06
# 202  1.650590e-06
# 203  1.666373e-06
# 204  1.673755e-06
# 205  1.696851e-06
# 206  1.753059e-06
# 207  2.101998e-06
# 208  2.154795e-06
#
# [229 rows x 5 columns]

# %% [markdown]
# ### Write Significant Comparisons (if any) to Shared CSV file

# %%
existing_results = pd.read_csv(gene+'_Trans_Results.csv')

updated_results = pd.concat([existing_results, all_significant_comparisons], sort=False)

updated_results.to_csv(path_or_buf = gene + '_Trans_Results.csv', index=False)
