# %% [markdown]
# # Examine trans effect of TP53 Hotspot mutation in Colon Cancer

# %% [markdown]
# ### Specifically examine Phosphorylation of TP53, AURKA, CDK1, XPO1, and STK11

# %% [markdown]
# #### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats

import cptac
import cptac.utils as ut

import seaborn as sns
import matplotlib.pyplot as plt

#Use Colon cancer object
co = cptac.Colon()
# Out:
# Warning: Your version of cptac (0.6.0) is out-of-date. Latest is 0.6.4. Please run 'pip install cptac --upgrade' to update it. (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 5)

# %% [markdown]
# ### Use parse hotspot utility to analyze TP53 hotspot mutation in Colon cancer

# %% [markdown]
# #### Get somatic mutation data from cptac

# %%
somatic_mutations = co.get_somatic_mutation()

# %% [markdown]
# #### Use parse hotspot utility

# %%
vis, binary, detailed, dictionary = ut.parse_hotspot('../../HotspotClusterFiles/DanHeader_MyData.maf.3D_Proximity.pairwise.recurrence.l0.r10.clusters', somatic_mutations)

# %%
vis
# Out:
#     hotspot_id  patients_within
# 0          A2M              6.0
# 1        ABCB6              6.0
# 2        ACAA1             11.0
# 3        ACACB              2.0
# 4       ACADSB              5.0
# ..         ...              ...
# 308       WAPL              3.0
# 309       WDR5              4.0
# 310       YARS              2.0
# 311   ZMPSTE24              4.0
# 312      ZMYM5             13.0
#
# [313 rows x 2 columns]

# %% [markdown]
# As we can see, TP53 has 2 hotspots in Colon cancer

# %% [markdown]
# #### Select only TP53 Hotspots

# %%
#There are 2 TP53 hotspots
TP53_Hotspots = detailed[['TP53','TP53_1']]
TP53_Hotspots
# Out:
#           TP53 TP53_1
# sample_id
# S001        No     No
# S002        No     No
# S003        No     No
# S004        No     No
# S005        No     No
# ...        ...    ...
# S106        No     No
# S107        No     No
# S108        No     No
# S109        No     No
# S110        No     No
#
# [106 rows x 2 columns]

# %% [markdown]
# #### Make binary column for samples that have a TP53 Hotspot Mutation

# %%
TP53_Hotspots['Hotspot_Mutation'] = ''
for ind, row in TP53_Hotspots.iterrows():
    for col in TP53_Hotspots.columns:
        if row[col] == 'Yes_HS':
            TP53_Hotspots.loc[ind,'Hotspot_Mutation'] = 'TP53_Hotspot_Mutation'
        if row[col] == 'Yes':
            TP53_Hotspots.loc[ind,'Hotspot_Mutation'] = 'TP53_Hotspot_Mutation'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# #### Grab only the binary yes/no hotspot mutation

# %%
binary_hotspots = TP53_Hotspots['Hotspot_Mutation']

# %%
TP53_Hotspots
# Out:
#           TP53 TP53_1 Hotspot_Mutation
# sample_id
# S001        No     No
# S002        No     No
# S003        No     No
# S004        No     No
# S005        No     No
# ...        ...    ...              ...
# S106        No     No
# S107        No     No
# S108        No     No
# S109        No     No
# S110        No     No
#
# [106 rows x 3 columns]

# %% [markdown]
# #### Get Proteomic data, append Binary hotspot mutation column

# %%
#Use join omics to mutations
proteomics_df = co.join_omics_to_mutations(omics_genes=['TP53','AURKA','CDK1','XPO1','STK11'], omics_df_name='phosphoproteomics', mutations_genes='TP53')

#Reduce multi-index to include phospho site in primary index
proteomics_df = co.reduce_multiindex(proteomics_df, flatten=True)

#Remove Non-Tumor Samples
proteomics_df = proteomics_df.loc[proteomics_df['Sample_Status'] == 'Tumor']

#Remove columns that are not needed
proteomics_df = proteomics_df.drop(['TP53_Location','Sample_Status'],axis=1)
proteomics_df['TP53_Hotspot_Mutation'] = binary_hotspots

#Show df
proteomics_df.head()
# Out:
# Warning: The following columns were not found in the phosphoproteomics dataframe, so they were inserted into joined table, but filled with NaN: AURKA (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 151 samples for the TP53 gene (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Warning: phosphoproteomics data was not found for the following samples, so phosphoproteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Name        AURKA_phosphoproteomics  CDK1_phosphoproteomics_T161_P06493  \
# Patient_ID
# S001                            NaN                                 NaN
# S002                            NaN                              -0.774
# S003                            NaN                              -0.364
# S004                            NaN                                 NaN
# S005                            NaN                               0.335
#
# Name        STK11_phosphoproteomics_S31_Q15831  \
# Patient_ID
# S001                                       NaN
# S002                                    -0.665
# S003                                     0.177
# S004                                     0.027
# S005                                    -0.332
#
# Name        TP53_phosphoproteomics_S314_P04637  \
# Patient_ID
# S001                                       NaN
# S002                                       NaN
# S003                                       NaN
# S004                                       NaN
# S005                                       NaN
#
# Name        TP53_phosphoproteomics_S315_P04637  \
# Patient_ID
# S001                                       NaN
# S002                                    -1.280
# S003                                    -0.996
# S004                                       NaN
# S005                                       NaN
#
# Name        XPO1_phosphoproteomics_S1055_O14980  \
# Patient_ID
# S001                                        NaN
# S002                                     -0.569
# S003                                     -0.243
# S004                                        NaN
# S005                                     -0.258
#
# Name        XPO1_phosphoproteomics_S391_O14980  \
# Patient_ID
# S001                                       NaN
# S002                                       NaN
# S003                                       NaN
# S004                                       NaN
# S005                                       NaN
#
# Name        XPO1_phosphoproteomics_S397_O14980  \
# Patient_ID
# S001                                       NaN
# S002                                       NaN
# S003                                       NaN
# S004                                       NaN
# S005                                       NaN
#
# Name                                            TP53_Mutation  \
# Patient_ID
# S001        [nonsynonymous SNV, nonsynonymous SNV, nonsyno...
# S002        [frameshift insertion, frameshift insertion, f...
# S003                                         [Wildtype_Tumor]
# S004                                         [Wildtype_Tumor]
# S005        [nonsynonymous SNV, nonsynonymous SNV, nonsyno...
#
# Name       TP53_Mutation_Status TP53_Hotspot_Mutation
# Patient_ID
# S001          Multiple_mutation
# S002          Multiple_mutation
# S003             Wildtype_Tumor
# S004             Wildtype_Tumor
# S005          Multiple_mutation

# %% [markdown]
# #### Classify every sample according to TP53 Mutation Status. Use: Wildtype, Hotspot_Missense, Other_Missense, Truncation

# %% [markdown]
# Which should take precedence? If there is a hotspot mutation, and is also a truncating mutation in the same sample?

# %% [markdown]
# There are 9 samples with a mutation in the hotspot. 4 of these also have truncating mutations, however, leaving only 5 hotspot missense samples.

# %%
for ind, row in proteomics_df.iterrows():
    if row['TP53_Mutation_Status'] == 'Wildtype_Tumor':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Wildtype'
    
    if row['TP53_Hotspot_Mutation'] != 'TP53_Hotspot_Mutation':
        if 'nonsynonymous SNV' in row['TP53_Mutation'] or 'nonframeshift deletion' in row['TP53_Mutation'] or 'nonframeshift insertion' in row['TP53_Mutation']:
            proteomics_df.loc[ind, 'TP53_Categorical'] = 'Other_Missense'
            
    if row['TP53_Hotspot_Mutation'] == 'TP53_Hotspot_Mutation':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Hotspot_Missense'
        
    if 'frameshift insertion' in row['TP53_Mutation'] or 'frameshift deletion' in row['TP53_Mutation'] or 'stopgain' in row['TP53_Mutation']:
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Truncation'
        
        
        
proteomics_df = proteomics_df.drop(['TP53_Mutation', 'TP53_Mutation_Status', 'TP53_Hotspot_Mutation', 'AURKA_phosphoproteomics','TP53_phosphoproteomics_S314_P04637','XPO1_phosphoproteomics_S391_O14980',], axis = 1)
proteomics_df
# Out:
# Name        CDK1_phosphoproteomics_T161_P06493  \
# Patient_ID
# S001                                       NaN
# S002                                    -0.774
# S003                                    -0.364
# S004                                       NaN
# S005                                     0.335
# ...                                        ...
# S106                                     0.533
# S107                                     0.054
# S108                                       NaN
# S109                                       NaN
# S110                                     0.147
#
# Name        STK11_phosphoproteomics_S31_Q15831  \
# Patient_ID
# S001                                       NaN
# S002                                    -0.665
# S003                                     0.177
# S004                                     0.027
# S005                                    -0.332
# ...                                        ...
# S106                                       NaN
# S107                                     0.378
# S108                                    -0.199
# S109                                       NaN
# S110                                    -0.066
#
# Name        TP53_phosphoproteomics_S315_P04637  \
# Patient_ID
# S001                                       NaN
# S002                                    -1.280
# S003                                    -0.996
# S004                                       NaN
# S005                                       NaN
# ...                                        ...
# S106                                     0.353
# S107                                       NaN
# S108                                       NaN
# S109                                       NaN
# S110                                       NaN
#
# Name        XPO1_phosphoproteomics_S1055_O14980  \
# Patient_ID
# S001                                        NaN
# S002                                     -0.569
# S003                                     -0.243
# S004                                        NaN
# S005                                     -0.258
# ...                                         ...
# S106                                      0.399
# S107                                     -0.418
# S108                                        NaN
# S109                                        NaN
# S110                                     -0.319
#
# Name        XPO1_phosphoproteomics_S397_O14980 TP53_Categorical
# Patient_ID
# S001                                       NaN   Other_Missense
# S002                                       NaN       Truncation
# S003                                       NaN         Wildtype
# S004                                       NaN         Wildtype
# S005                                       NaN       Truncation
# ...                                        ...              ...
# S106                                       NaN         Wildtype
# S107                                       NaN         Wildtype
# S108                                       NaN   Other_Missense
# S109                                       NaN   Other_Missense
# S110                                       NaN         Wildtype
#
# [107 rows x 6 columns]

# %% [markdown]
# ### Note:

# %% [markdown]
# Note that there are 9 samples with a missense mutation in the hotspot, however, 4 of these samples also have a truncating mutation present. These are classified as truncation, not hotspot missense samples.

# %% [markdown]
# ### Perform t-tests on each protein, comparing Hotspot-Wildtype, Hotspot-Truncation, and Hotspot-Other Missense Mutations

# %%
for col in proteomics_df:
    if col != 'TP53_Categorical':
        hotspot_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Hotspot_Missense'][col].dropna()
        truncation_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Truncation'][col].dropna()
        other_missense_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Other_Missense'][col].dropna()
        wt_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Wildtype'][col]
        
        #Hotspot-WT comparison
        stat, pval = scipy.stats.ttest_ind(hotspot_df, wt_df)
        print("Omics: ", col, "\nComparison: Hotspot vs. Wildtype \nP-Value: ", str(pval))
        
        #Hotspot-Truncation comparison
        stat, pval = scipy.stats.ttest_ind(hotspot_df, truncation_df)
        print("\nOmics: ", col, "\nComparison: Hotspot vs. Truncation \nP-Value: ", str(pval))
        
        #Hotspot-Other Missense comparison
        stat, pval = scipy.stats.ttest_ind(hotspot_df, other_missense_df)
        print("\nOmics: ", col, "\nComparison: Hotspot vs. Other Missense \nP-Value: ", str(pval))
        print("\n\n")
# Out:
# Omics:  CDK1_phosphoproteomics_T161_P06493
# Comparison: Hotspot vs. Wildtype
# P-Value:  nan
#
# Omics:  CDK1_phosphoproteomics_T161_P06493
# Comparison: Hotspot vs. Truncation
# P-Value:  0.0826503419667283
#
# Omics:  CDK1_phosphoproteomics_T161_P06493
# Comparison: Hotspot vs. Other Missense
# P-Value:  0.023224666624773425
#
#
#
# Omics:  STK11_phosphoproteomics_S31_Q15831
# Comparison: Hotspot vs. Wildtype
# P-Value:  nan
#
# Omics:  STK11_phosphoproteomics_S31_Q15831
# Comparison: Hotspot vs. Truncation
# P-Value:  0.6198449683492468
#
# Omics:  STK11_phosphoproteomics_S31_Q15831
# Comparison: Hotspot vs. Other Missense
# P-Value:  0.8648823731630544
#
#
#
# Omics:  TP53_phosphoproteomics_S315_P04637
# Comparison: Hotspot vs. Wildtype
# P-Value:  nan
#
# Omics:  TP53_phosphoproteomics_S315_P04637
# Comparison: Hotspot vs. Truncation
# P-Value:  0.5918646867972396
#
# Omics:  TP53_phosphoproteomics_S315_P04637
# Comparison: Hotspot vs. Other Missense
# P-Value:  0.2565226451084708
#
#
#
# Omics:  XPO1_phosphoproteomics_S1055_O14980
# Comparison: Hotspot vs. Wildtype
# P-Value:  nan
#
# Omics:  XPO1_phosphoproteomics_S1055_O14980
# Comparison: Hotspot vs. Truncation
# P-Value:  0.6229161971188857
#
# Omics:  XPO1_phosphoproteomics_S1055_O14980
# Comparison: Hotspot vs. Other Missense
# P-Value:  0.853994978233288
#
#
#
# Omics:  XPO1_phosphoproteomics_S397_O14980
# Comparison: Hotspot vs. Wildtype
# P-Value:  nan
#
# Omics:  XPO1_phosphoproteomics_S397_O14980
# Comparison: Hotspot vs. Truncation
# P-Value:  0.29322771866292924
#
# Omics:  XPO1_phosphoproteomics_S397_O14980
# Comparison: Hotspot vs. Other Missense
# P-Value:  0.04270327790360768

# %% [markdown]
# #### Reformat dataframe for plot

# %%
plotdf = pd.melt(proteomics_df, id_vars='TP53_Categorical', var_name='Site', value_name='Phosphorylation')
#plotdf = plotdf.replace({'AURKA_proteomics':'AURKA','XPO1_proteomics':'XPO1','TP53_proteomics':'TP53','CDK1_proteomics':'CDK1','STK11_proteomics':'STK11'})
plotdf = plotdf.replace({'Hotspot_Missense':'Hotspot Missense','Other_Missense':'Other Missense'})
plotdf = plotdf.replace({'CDK1_phosphoproteomics_T161_P06493':'CDK1_T161','STK11_phosphoproteomics_S31_Q15831':'STK11_S31','TP53_phosphoproteomics_S315_P04637':'TP53_S315','XPO1_phosphoproteomics_S1055_O14980':'XPO1_S1055','XPO1_phosphoproteomics_S397_O14980':'XPO1_S397'})

# %%
proteomics_df
# Out:
# Name        CDK1_phosphoproteomics_T161_P06493  \
# Patient_ID
# S001                                       NaN
# S002                                    -0.774
# S003                                    -0.364
# S004                                       NaN
# S005                                     0.335
# ...                                        ...
# S106                                     0.533
# S107                                     0.054
# S108                                       NaN
# S109                                       NaN
# S110                                     0.147
#
# Name        STK11_phosphoproteomics_S31_Q15831  \
# Patient_ID
# S001                                       NaN
# S002                                    -0.665
# S003                                     0.177
# S004                                     0.027
# S005                                    -0.332
# ...                                        ...
# S106                                       NaN
# S107                                     0.378
# S108                                    -0.199
# S109                                       NaN
# S110                                    -0.066
#
# Name        TP53_phosphoproteomics_S315_P04637  \
# Patient_ID
# S001                                       NaN
# S002                                    -1.280
# S003                                    -0.996
# S004                                       NaN
# S005                                       NaN
# ...                                        ...
# S106                                     0.353
# S107                                       NaN
# S108                                       NaN
# S109                                       NaN
# S110                                       NaN
#
# Name        XPO1_phosphoproteomics_S1055_O14980  \
# Patient_ID
# S001                                        NaN
# S002                                     -0.569
# S003                                     -0.243
# S004                                        NaN
# S005                                     -0.258
# ...                                         ...
# S106                                      0.399
# S107                                     -0.418
# S108                                        NaN
# S109                                        NaN
# S110                                     -0.319
#
# Name        XPO1_phosphoproteomics_S397_O14980 TP53_Categorical
# Patient_ID
# S001                                       NaN   Other_Missense
# S002                                       NaN       Truncation
# S003                                       NaN         Wildtype
# S004                                       NaN         Wildtype
# S005                                       NaN       Truncation
# ...                                        ...              ...
# S106                                       NaN         Wildtype
# S107                                       NaN         Wildtype
# S108                                       NaN   Other_Missense
# S109                                       NaN   Other_Missense
# S110                                       NaN         Wildtype
#
# [107 rows x 6 columns]

# %% [markdown]
# ### Make plot illustrating proteomic abundance

# %%
#Set dimensions and Colors
a4_dims = (30, 16)
fig, ax = plt.subplots(figsize=a4_dims)
my_pal = {"Wildtype": "blue", "Hotspot Missense": "orange", "Other Missense":"green","Truncation":"red"}

#Make Boxplot
plot = sns.boxplot(data=plotdf, y = 'Phosphorylation', x='Site', hue='TP53_Categorical', palette=my_pal, hue_order=['Wildtype','Hotspot Missense','Other Missense','Truncation'])

#Overlay Striplot
plot = sns.stripplot(data=plotdf, y = 'Phosphorylation', x='Site', hue='TP53_Categorical', color='.3', jitter=True, dodge=True, hue_order=['Wildtype','Hotspot Missense','Other Missense','Truncation'])

#Change Style and label sizes
plot.tick_params(labelsize=20)
plot.set_xlabel('')
plot.set_ylabel('Phosphorylation', fontsize='20')
plot.set_title('Phosphorylation of CDK1, STK11, TP53, XPO1 vs TP53 Mutation Status in Colon Cancer', fontsize = '35')
sns.set_style("white")

#Adjust the Legend
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:4],['Wildtype','Hotspot Missense','Other Missense','Truncation'], title='TP53 Status', fontsize='20', frameon=True)
plot.get_legend().get_title().set_fontsize('25')

# %% [markdown]
# # Hotspot debug:

# %%
#Use join omics to mutations
proteomics_df = co.join_omics_to_mutations(omics_genes=['TP53','AURKA','CDK1','XPO1','STK11'], omics_df_name='proteomics', mutations_genes='TP53')

#Remove Non-Tumor Samples
proteomics_df = proteomics_df.loc[proteomics_df['Sample_Status'] == 'Tumor']

#Remove columns that are not needed
proteomics_df = proteomics_df.drop(['Sample_Status'],axis=1)
proteomics_df['TP53_Hotspot_Mutation'] = binary_hotspots

#Show df
#proteomics_df.head()
for ind, row in proteomics_df.iterrows():
    if row['TP53_Mutation_Status'] == 'Wildtype_Tumor':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Wildtype'
    
    if row['TP53_Hotspot_Mutation'] != 'TP53_Hotspot_Mutation':
        if 'nonsynonymous SNV' in row['TP53_Mutation'] or 'nonframeshift deletion' in row['TP53_Mutation'] or 'nonframeshift insertion' in row['TP53_Mutation']:
            proteomics_df.loc[ind, 'TP53_Categorical'] = 'Other_Missense'
            
    if row['TP53_Hotspot_Mutation'] == 'TP53_Hotspot_Mutation':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Hotspot_Missense'
        
    if 'frameshift insertion' in row['TP53_Mutation'] or 'frameshift deletion' in row['TP53_Mutation'] or 'stopgain' in row['TP53_Mutation']:
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Truncation'
        
        
        
proteomics_df = proteomics_df.drop(['TP53_Mutation', 'TP53_Mutation_Status'], axis = 1)
proteomics_df.head(55)
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 151 samples for the TP53 gene (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Name        TP53_proteomics  AURKA_proteomics  CDK1_proteomics  \
# Patient_ID
# S001                    NaN               NaN              NaN
# S002                -0.4890            -0.311          -0.5690
# S003                -0.7960               NaN          -0.5570
# S004                    NaN               NaN          -0.2220
# S005                -1.3900               NaN           0.4860
# S006                    NaN               NaN           0.5330
# S007                    NaN               NaN           0.0605
# S008                    NaN               NaN           0.2400
# S009                -0.2630               NaN           1.2000
# S010                    NaN               NaN           1.0600
# S011                    NaN               NaN           0.1540
# S013                    NaN               NaN              NaN
# S014                    NaN               NaN           0.3670
# S015                    NaN               NaN              NaN
# S016                    NaN               NaN          -0.5610
# S017                    NaN               NaN              NaN
# S018                -0.2530               NaN           0.7560
# S019                    NaN               NaN           0.8930
# S020                    NaN               NaN           1.1800
# S021                -0.4840            -0.295           0.1360
# S022                -0.8050               NaN           0.0280
# S023                    NaN               NaN           0.0501
# S024                    NaN               NaN          -0.3080
# S025                    NaN               NaN          -0.0880
# S026                 0.3360               NaN           0.3300
# S027                    NaN               NaN          -0.0713
# S028                    NaN               NaN           0.7760
# S029                    NaN               NaN           1.0500
# S030                -0.4720               NaN           0.3150
# S031                -0.1340               NaN           0.5770
# S032                 1.4800               NaN           0.1960
# S033                    NaN               NaN           0.5730
# S034                    NaN               NaN           0.1430
# S035                -1.0500               NaN           1.1900
# S036                -1.0500               NaN           0.2670
# S037                -0.4630               NaN           0.4100
# S038                    NaN               NaN              NaN
# S039                -1.3700               NaN           0.3630
# S040                    NaN               NaN          -0.5740
# S041                    NaN               NaN          -0.5220
# S042                    NaN               NaN          -0.2570
# S043                    NaN               NaN           0.2680
# S044                -0.7280               NaN           0.1060
# S045                 0.9300               NaN           0.3590
# S046                 0.8430               NaN           0.0524
# S047                -0.6100             0.465           0.4840
# S048                 0.4230               NaN           0.8590
# S049                 0.0611               NaN           0.1330
# S050                -0.2770               NaN           1.1400
# S051                 0.1540               NaN          -1.0100
# S052                -0.0178               NaN           0.8970
# S053                 0.4400               NaN           0.6430
# S054                 0.5090               NaN           0.1810
# S055                -0.5810               NaN           0.2210
# S056                 0.0283               NaN          -0.0796
#
# Name        XPO1_proteomics  STK11_proteomics  \
# Patient_ID
# S001                    NaN               NaN
# S002                 0.1610               NaN
# S003                 0.0062               NaN
# S004                 0.1490            -0.607
# S005                 0.3410               NaN
# S006                 0.0259               NaN
# S007                 0.2520               NaN
# S008                 0.0469            -0.171
# S009                 0.0196               NaN
# S010                 0.0760            -0.516
# S011                 0.2420               NaN
# S013                    NaN               NaN
# S014                 0.1680               NaN
# S015                    NaN               NaN
# S016                 0.3940               NaN
# S017                    NaN               NaN
# S018                 0.1600               NaN
# S019                 0.4470               NaN
# S020                 0.3660            -0.590
# S021                -0.1190               NaN
# S022                 0.0632               NaN
# S023                -0.0227               NaN
# S024                -0.1300               NaN
# S025                 0.0967               NaN
# S026                 0.0421               NaN
# S027                 0.2460               NaN
# S028                 0.1920               NaN
# S029                 0.3690               NaN
# S030                 0.5370               NaN
# S031                 0.0696               NaN
# S032                 0.1170               NaN
# S033                 0.0743               NaN
# S034                 0.0064               NaN
# S035                 0.4250               NaN
# S036                 0.0248               NaN
# S037                -0.0071               NaN
# S038                    NaN               NaN
# S039                 0.5290               NaN
# S040                 0.0106               NaN
# S041                 0.1370            -0.440
# S042                -0.0869               NaN
# S043                 0.1270               NaN
# S044                -0.0014               NaN
# S045                 0.5290               NaN
# S046                 0.4140               NaN
# S047                -0.0035               NaN
# S048                 0.4360               NaN
# S049                 0.1580               NaN
# S050                 0.0800               NaN
# S051                 0.1420               NaN
# S052                 0.2790             0.104
# S053                 0.2670               NaN
# S054                 0.5420               NaN
# S055                -0.0026               NaN
# S056                 0.1480               NaN
#
# Name                                            TP53_Location  \
# Patient_ID
# S001        [G113S, G113S, G113S, G206S, G206S, G206S, G20...
# S002        [E287Wfs*10, E194Wfs*11, E194Wfs*10, E167Wfs*2...
# S003                                            [No_mutation]
# S004                                            [No_mutation]
# S005        [C143Y, C143Y, C116Y, C116Y, C116Y, S260Qfs*29...
# S006        [R273C, R273C, R273C, R273C, R234C, R234C, R23...
# S007                                            [No_mutation]
# S008        [V164L, V164L, V203L, V164L, V164L, V203L, V20...
# S009                                            [No_mutation]
# S010        [P239S, P239S, P239S, P239S, P239S, P278S, P27...
# S011                                            [No_mutation]
# S013                                            [No_mutation]
# S014                                 [V31I, V31I, V31I, V31I]
# S015                                            [No_mutation]
# S016        [N200fs*0, N200fs*0, N200fs*0, N80fs*0, N239fs...
# S017                                            [No_mutation]
# S018                                            [No_mutation]
# S019                                            [No_mutation]
# S020                                            [No_mutation]
# S021        [R273C, R273C, R273C, R273C, R234C, R234C, R14...
# S022        [Q52X, Q52X, Q52X, Q52X, Q13X, Q13X, Q13X, Q13...
# S023        [E255Sfs*47, E255Sfs*50, E255Sfs*50, E255Sfs*5...
# S024                                            [No_mutation]
# S025        [R210X, R183X, R303X, R303X, R303X, R342X, R342X]
# S026        [S215N, S215N, S215N, S215N, S176N, S176N, S17...
# S027                                            [No_mutation]
# S028                                            [No_mutation]
# S029        [V34Wfs*49, V73Wfs*49, V73Wfs*49, V73Wfs*49, V...
# S030        [S51Pfs*32, R136H, R136H, R136H, S51Pfs*32, S5...
# S031        [P152L, P113L, P113L, P113L, P152L, P20L, P20L...
# S032        [R273H, R273H, R114H, R114H, R114H, R273H, R27...
# S033        [E92D, E92D, E65D, E92D, E224D, E224D, E224D, ...
# S034        [R110L, R110L, R110L, R110L, R71L, R71L, R71L,...
# S035                                            [No_mutation]
# S036                                            [No_mutation]
# S037        [R157X, R37X, R37X, R64X, R64X, R64X, R37X, R1...
# S038                                            [No_mutation]
# S039        [R114C, R273C, R273C, R273C, R273C, R114C, R23...
# S040        [E185D, E185D, E185D, E185D, E92D, E92D, E65D,...
# S041                                            [No_mutation]
# S042                                            [No_mutation]
# S043        [L72Q, L72Q, L111Q, L111Q, L111Q, L111Q, L72Q,...
# S044                                            [No_mutation]
# S045                                            [No_mutation]
# S046        [R273C, R273C, R273C, R273C, R234C, R234C, R23...
# S047        [R147X, R147X, R147X, R174X, R174X, R174X, R30...
# S048                                            [No_mutation]
# S049        [C96F, C96F, C96F, C96F, C96F, C3F, C3F, C3F, ...
# S050        [Y124H, Y124H, Y124H, Y124H, Y124H, Y4H, Y4H, ...
# S051                                            [No_mutation]
# S052                                            [No_mutation]
# S053        [W14X, W53X, W14X, W53X, W53X, W53X, W14X, W14...
# S054        [G86S, G113S, G86S, G86S, G206S, G206S, G206S,...
# S055                                            [No_mutation]
# S056        [G262V, G262V, G262V, G262V, G223V, G103V, G10...
#
# Name        TP53_Hotspot_Mutation  TP53_Categorical
# Patient_ID
# S001                                 Other_Missense
# S002                                     Truncation
# S003                                       Wildtype
# S004                                       Wildtype
# S005                                     Truncation
# S006        TP53_Hotspot_Mutation  Hotspot_Missense
# S007                                       Wildtype
# S008                                 Other_Missense
# S009                                       Wildtype
# S010                                 Other_Missense
# S011                                       Wildtype
# S013                                       Wildtype
# S014        TP53_Hotspot_Mutation  Hotspot_Missense
# S015                                       Wildtype
# S016                                     Truncation
# S017                                       Wildtype
# S018                                       Wildtype
# S019                                       Wildtype
# S020                                       Wildtype
# S021                                 Other_Missense
# S022        TP53_Hotspot_Mutation        Truncation
# S023                                     Truncation
# S024                                       Wildtype
# S025                                     Truncation
# S026                                 Other_Missense
# S027                                       Wildtype
# S028                                       Wildtype
# S029                                     Truncation
# S030        TP53_Hotspot_Mutation        Truncation
# S031        TP53_Hotspot_Mutation  Hotspot_Missense
# S032                                 Other_Missense
# S033                                 Other_Missense
# S034                                 Other_Missense
# S035                                       Wildtype
# S036                                       Wildtype
# S037                                     Truncation
# S038                                       Wildtype
# S039                                 Other_Missense
# S040                                 Other_Missense
# S041                                       Wildtype
# S042                                       Wildtype
# S043                                 Other_Missense
# S044                                       Wildtype
# S045                                       Wildtype
# S046                                 Other_Missense
# S047                                     Truncation
# S048                                       Wildtype
# S049                                 Other_Missense
# S050                                 Other_Missense
# S051                                       Wildtype
# S052                                       Wildtype
# S053        TP53_Hotspot_Mutation        Truncation
# S054        TP53_Hotspot_Mutation  Hotspot_Missense
# S055                                       Wildtype
# S056                                 Other_Missense

# %%
hotspot_muts = []
for ind, row in proteomics_df.iterrows():
    if row['TP53_Hotspot_Mutation'] == 'TP53_Hotspot_Mutation':
        sample_muts = []
        for mut in row['TP53_Location']:
            sample_muts.append(mut)
        hotspot_muts.append(sample_muts)
            
for s in hotspot_muts:
    print(s, "\n")
# Out:
# ['R273C', 'R273C', 'R273C', 'R273C', 'R234C', 'R234C', 'R234C', 'R114C', 'R114C', 'R114C', 'R141C', 'R141C', 'R141C', 'R234C', 'R234C']
#
# ['V31I', 'V31I', 'V31I', 'V31I']
#
# ['Q52X', 'Q52X', 'Q52X', 'Q52X', 'Q13X', 'Q13X', 'Q13X', 'Q13X', 'Q13X']
#
# ['S51Pfs*32', 'R136H', 'R136H', 'R136H', 'S51Pfs*32', 'S51Pfs*32', 'S51Pfs*32', 'S90Pfs*32', 'S90Pfs*32', 'S90Pfs*32', 'S90Pfs*32', 'R136H', 'S51Pfs*32', 'R136H', 'R43H', 'R43H', 'R43H', 'R16H', 'R16H', 'R175H', 'R175H', 'R175H', 'R175H', 'R16H']
#
# ['P152L', 'P113L', 'P113L', 'P113L', 'P152L', 'P20L', 'P20L', 'P20L', 'P113L', 'P113L', 'P152L', 'P152L']
#
# ['W14X', 'W53X', 'W14X', 'W53X', 'W53X', 'W53X', 'W14X', 'W14X', 'W14X']
#
# ['G86S', 'G113S', 'G86S', 'G86S', 'G206S', 'G206S', 'G206S', 'G206S', 'G206S', 'G245S', 'G245S', 'G245S', 'G245S', 'G113S', 'G113S']
#
# ['S33Ffs*7', 'S33Ffs*7', 'S33Ffs*7', 'S33Ffs*7']
#
# ['P31L', 'P31L', 'P31L', 'P58L', 'P58L', 'P58L', 'P190L', 'P190L', 'P190L', 'P190L', 'P151L', 'P151L', 'P151L', 'P151L', 'P151L']

# %%
hs = []
for ind, row in proteomics_df.iterrows():
    for loc in row['TP53_Location']:
        if '52' in loc or '53' in loc:
            if ind not in hs:
                hs.append(ind)
            #print(row['TP53_Location'])
            
hs
# Out:
# ['S005', 'S022', 'S031', 'S053', 'S073', 'S108']

# %%
binary[['TP53','TP53_1']]
# Out:
#             TP53  TP53_1
# sample_id
# S001       False   False
# S002       False   False
# S003       False   False
# S004       False   False
# S005       False   False
# ...          ...     ...
# S106       False   False
# S107       False   False
# S108       False   False
# S109       False   False
# S110       False   False
#
# [106 rows x 2 columns]

# %% [markdown]
# vis, binary, detailed, dictionary

# %%
dictionary['TP53_1']
# Out:
# ['p.S33Ffs*7', 'p.V31I']

# %%
dictionary['TP53']
# Out:
# ['p.Q52X', 'p.W53X']

# %% [markdown]
# Hotspot mutations are 'p.S33Ffs*7', 'p.V31I', 'p.Q52X', 'p.W53X' <br>
# According to detailed, hotspot samples are: 006, 014, 022, 030, 031, 053, 054, 075, 076 <br>
# According to binary, hotspot samples are: 006, 014, 022, 030, 053, 075

# %%
hs = []
for ind, row in proteomics_df.iterrows():
    #print(row['TP53_Location'])
    if 'S33Ffs*7' in row['TP53_Location'] or 'V31I' in row['TP53_Location'] or 'Q52X' in row['TP53_Location'] or 'W53X' in row['TP53_Location']:
        hs.append(ind)
        
        
hs
# Out:
# ['S014', 'S022', 'S053', 'S075']

# %%
t = proteomics_df.loc['S022']
t['TP53_Location']
# Out:
# ['Q52X', 'Q52X', 'Q52X', 'Q52X', 'Q13X', 'Q13X', 'Q13X', 'Q13X', 'Q13X']

# %%
for ind, row in proteomics_df.iterrows():
    for mut in row['TP53_Location']:
        if '273' in mut:
            print(ind, ": ", mut)
# Out:
# S006 :  R273C
# S006 :  R273C
# S006 :  R273C
# S006 :  R273C
# S021 :  R273C
# S021 :  R273C
# S021 :  R273C
# S021 :  R273C
# S032 :  R273H
# S032 :  R273H
# S032 :  R273H
# S032 :  R273H
# S039 :  R273C
# S039 :  R273C
# S039 :  R273C
# S039 :  R273C
# S046 :  R273C
# S046 :  R273C
# S046 :  R273C
# S046 :  R273C
# S067 :  R273H
# S067 :  R273H
# S067 :  R273H
# S067 :  R273H
# S087 :  R273C
# S087 :  R273C
# S087 :  R273C
# S087 :  R273C
