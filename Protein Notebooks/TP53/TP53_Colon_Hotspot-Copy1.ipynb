# %% [markdown]
# See figure 2 E in email from sam, for listed proteins, compare hotspot/wt, non-hotspot/wt, and truncation/wt in each other cancer type.

# %% [markdown]
# # Examine trans effect of TP53 Hotspot mutation in Ovarian Cancer

# %% [markdown]
# #### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats

import cptac
import cptac.utils as ut

co = cptac.Colon()
# Out:
# /anaconda3/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Use parse hotspot utility to analyze TP53 hotspot mutation in Ovarian cancer

# %% [markdown]
# #### Get somatic mutation data from cptac

# %%
somatic_mutations = co.get_somatic_mutation()

# %% [markdown]
# #### Use parse hotspot utility

# %%
vis, binary, detailed, dictionary = ut.parse_hotspot('../../HotspotClusterFiles/DanHeader_MyData.maf.3D_Proximity.pairwise.recurrence.l0.r10.clusters', somatic_mutations)

# %% [markdown]
# #### Select only TP53 Hotspots

# %%
TP53_Hotspots = detailed[['TP53','TP53_1']]
TP53_Hotspots.head()
# Out:
#           TP53 TP53_1
# sample_id
# S001        No     No
# S002        No     No
# S003        No     No
# S004        No     No
# S005        No     No

# %% [markdown]
# #### Make binary column for samples that have a TP53 Hotspot Mutation

# %%
TP53_Hotspots['Hotspot_Mutation'] = False
for ind, row in TP53_Hotspots.iterrows():
    for col in TP53_Hotspots.columns:
        if row[col] == 'Yes_HS':
            TP53_Hotspots.loc[ind,'Hotspot_Mutation'] = True
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:480: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
binary_hotspots = TP53_Hotspots['Hotspot_Mutation']

# %% [markdown]
# #### Get Proteomic data, append Binary hotspot mutation column

# %%
proteomics_df = co.join_omics_to_mutations(omics_df_name='proteomics', mutations_genes='TP53')
proteomics_df
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 151 samples for the TP53 gene (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 1)
# Warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 1)
# Name        A1BG_proteomics  A1CF_proteomics  A2M_proteomics  AAAS_proteomics  \
# Patient_ID
# S001                    NaN              NaN             NaN              NaN
# S002                -1.1000            0.318          -0.487           0.0995
# S003                -1.1200           -0.441          -0.347          -0.0029
# S004                -1.2000            0.160          -1.850           0.1190
# S005                -1.8900            0.112          -0.329           0.6700
# ...                     ...              ...             ...              ...
# S206                -0.5950            0.430           0.727           0.0141
# S207                 0.9770           -0.379           0.661          -0.2120
# S208                 0.0542            0.406           1.070          -0.0312
# S209                 0.5840           -0.691          -0.266          -0.1850
# S210                 0.9620           -0.171           0.533           0.1370
#
# Name        AACS_proteomics  AAGAB_proteomics  AAK1_proteomics  \
# Patient_ID
# S001                    NaN               NaN              NaN
# S002                 0.1550            0.1690           0.0653
# S003                 0.0957            0.3960          -0.0363
# S004                -0.0924            0.0187          -0.2140
# S005                 0.1160            0.3130          -0.2380
# ...                     ...               ...              ...
# S206                 0.2820            0.0105           0.2780
# S207                 0.1320           -0.5090           0.4290
# S208                 0.0870            0.0428          -0.0950
# S209                -0.8500           -0.2930           0.5470
# S210                -0.1840           -0.1670           0.1610
#
# Name        AAMDC_proteomics  AAMP_proteomics  AAR2_proteomics  ...  \
# Patient_ID                                                      ...
# S001                     NaN              NaN              NaN  ...
# S002                  -0.147           0.1140           0.3410  ...
# S003                  -0.549           0.2200           0.2480  ...
# S004                   0.328          -0.2820          -0.3480  ...
# S005                  -0.274          -0.5540           0.2700  ...
# ...                      ...              ...              ...  ...
# S206                  -0.293           0.0320           0.0128  ...
# S207                   1.210          -0.2360           0.4620  ...
# S208                   0.447           0.0081          -0.0947  ...
# S209                   0.174           0.0202           0.3160  ...
# S210                   0.636          -0.1800          -0.0453  ...
#
# Name        ZRANB2_proteomics  ZW10_proteomics  ZWILCH_proteomics  \
# Patient_ID
# S001                      NaN              NaN                NaN
# S002                   0.2500           0.0869             0.0331
# S003                   0.0846           0.0010            -0.3450
# S004                   0.3570          -0.3250             0.3490
# S005                  -0.2950           0.4630            -0.4480
# ...                       ...              ...                ...
# S206                  -0.0206          -0.2410                NaN
# S207                  -0.2020           0.2860            -0.1820
# S208                  -0.1660          -0.1310            -0.7450
# S209                   0.1810          -0.0940                NaN
# S210                   0.2070          -0.2680                NaN
#
# Name        ZWINT_proteomics  ZYX_proteomics  ZZEF1_proteomics  \
# Patient_ID
# S001                     NaN             NaN               NaN
# S002                     NaN         -0.7330           -0.2650
# S003                     NaN         -0.6580            0.0052
# S004                     NaN         -0.8210            0.2000
# S005                  0.0493         -0.9040           -0.1580
# ...                      ...             ...               ...
# S206                     NaN         -0.4490            0.3200
# S207                     NaN          1.6200            0.0584
# S208                     NaN         -0.0342            0.3270
# S209                     NaN          1.2000            0.1550
# S210                     NaN          0.5170            0.1370
#
# Name                                            TP53_Mutation  \
# Patient_ID
# S001        [nonsynonymous SNV, nonsynonymous SNV, nonsyno...
# S002        [frameshift insertion, frameshift insertion, f...
# S003                                         [Wildtype_Tumor]
# S004                                         [Wildtype_Tumor]
# S005        [nonsynonymous SNV, nonsynonymous SNV, nonsyno...
# ...                                                       ...
# S206                                        [Wildtype_Normal]
# S207                                        [Wildtype_Normal]
# S208                                        [Wildtype_Normal]
# S209                                        [Wildtype_Normal]
# S210                                        [Wildtype_Normal]
#
# Name                                            TP53_Location  \
# Patient_ID
# S001        [G113S, G113S, G113S, G206S, G206S, G206S, G20...
# S002        [E287Wfs*10, E194Wfs*11, E194Wfs*10, E167Wfs*2...
# S003                                            [No_mutation]
# S004                                            [No_mutation]
# S005        [C143Y, C143Y, C116Y, C116Y, C116Y, S260Qfs*29...
# ...                                                       ...
# S206                                            [No_mutation]
# S207                                            [No_mutation]
# S208                                            [No_mutation]
# S209                                            [No_mutation]
# S210                                            [No_mutation]
#
# Name        TP53_Mutation_Status  Sample_Status
# Patient_ID
# S001           Multiple_mutation          Tumor
# S002           Multiple_mutation          Tumor
# S003              Wildtype_Tumor          Tumor
# S004              Wildtype_Tumor          Tumor
# S005           Multiple_mutation          Tumor
# ...                          ...            ...
# S206             Wildtype_Normal         Normal
# S207             Wildtype_Normal         Normal
# S208             Wildtype_Normal         Normal
# S209             Wildtype_Normal         Normal
# S210             Wildtype_Normal         Normal
#
# [207 rows x 8071 columns]

# %%
proteomics_df = co.join_omics_to_mutations(omics_df_name='proteomics', mutations_genes='TP53')

#Remove Non-Tumor Samples
proteomics_df = proteomics_df.loc[proteomics_df['Sample_Status'] == 'Tumor']

#Remove columns that are not needed
proteomics_df = proteomics_df.drop(['TP53_Mutation','TP53_Location','TP53_Mutation_Status','Sample_Status'],axis=1)
proteomics_df['TP53_Hotspot_Mutation'] = binary_hotspots

#drop nan from tp53 hotspot col
proteomics_df = proteomics_df[pd.notnull(proteomics_df['TP53_Hotspot_Mutation'])]

proteomics_df
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 151 samples for the TP53 gene (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 1)
# Warning: proteomics data was not found for the following samples, so proteomics data columns were filled with NaN for these samples: S001, S013, S015, S017, S038, S080, S081, S090, S099, S109 (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 1)
# Name        A1BG_proteomics  A1CF_proteomics  A2M_proteomics  AAAS_proteomics  \
# Patient_ID
# S001                    NaN              NaN             NaN              NaN
# S002                 -1.100           0.3180         -0.4870           0.0995
# S003                 -1.120          -0.4410         -0.3470          -0.0029
# S004                 -1.200           0.1600         -1.8500           0.1190
# S005                 -1.890           0.1120         -0.3290           0.6700
# ...                     ...              ...             ...              ...
# S106                 -0.975           0.3980         -1.1500           0.5730
# S107                 -1.280           0.5180         -0.8720           0.2580
# S108                  0.515          -1.2100         -0.0283           0.1780
# S109                    NaN              NaN             NaN              NaN
# S110                 -1.640          -0.0693         -0.2540           0.0520
#
# Name        AACS_proteomics  AAGAB_proteomics  AAK1_proteomics  \
# Patient_ID
# S001                    NaN               NaN              NaN
# S002                 0.1550            0.1690           0.0653
# S003                 0.0957            0.3960          -0.0363
# S004                -0.0924            0.0187          -0.2140
# S005                 0.1160            0.3130          -0.2380
# ...                     ...               ...              ...
# S106                -0.1280            0.0600          -0.0559
# S107                 0.4240            0.2980          -0.1500
# S108                -0.3030            0.1500           0.3990
# S109                    NaN               NaN              NaN
# S110                -0.1370            0.1450           0.1100
#
# Name        AAMDC_proteomics  AAMP_proteomics  AAR2_proteomics  ...  \
# Patient_ID                                                      ...
# S001                     NaN              NaN              NaN  ...
# S002                  -0.147           0.1140           0.3410  ...
# S003                  -0.549           0.2200           0.2480  ...
# S004                   0.328          -0.2820          -0.3480  ...
# S005                  -0.274          -0.5540           0.2700  ...
# ...                      ...              ...              ...  ...
# S106                  -1.330          -0.3650           0.2920  ...
# S107                  -0.658           0.0066          -0.0378  ...
# S108                  -1.000           0.2060          -0.2970  ...
# S109                     NaN              NaN              NaN  ...
# S110                   0.140          -0.5690           0.3270  ...
#
# Name        ZNRD1_proteomics  ZNRF2_proteomics  ZPR1_proteomics  \
# Patient_ID
# S001                     NaN               NaN              NaN
# S002                     NaN            0.0384           0.0221
# S003                   0.324               NaN          -0.3940
# S004                     NaN           -0.3840          -0.1680
# S005                     NaN               NaN          -0.0656
# ...                      ...               ...              ...
# S106                     NaN            0.2460           0.0047
# S107                     NaN            0.4490          -0.0616
# S108                     NaN           -0.5610           0.4740
# S109                     NaN               NaN              NaN
# S110                     NaN               NaN           0.1270
#
# Name        ZRANB2_proteomics  ZW10_proteomics  ZWILCH_proteomics  \
# Patient_ID
# S001                      NaN              NaN                NaN
# S002                   0.2500           0.0869             0.0331
# S003                   0.0846           0.0010            -0.3450
# S004                   0.3570          -0.3250             0.3490
# S005                  -0.2950           0.4630            -0.4480
# ...                       ...              ...                ...
# S106                   0.1650           0.1030                NaN
# S107                   0.3850           0.1160            -0.0437
# S108                   0.0836          -0.2510             0.1760
# S109                      NaN              NaN                NaN
# S110                  -0.0992           0.1900            -0.2080
#
# Name        ZWINT_proteomics  ZYX_proteomics  ZZEF1_proteomics  \
# Patient_ID
# S001                     NaN             NaN               NaN
# S002                     NaN         -0.7330           -0.2650
# S003                     NaN         -0.6580            0.0052
# S004                     NaN         -0.8210            0.2000
# S005                  0.0493         -0.9040           -0.1580
# ...                      ...             ...               ...
# S106                     NaN         -0.7520           -0.2410
# S107                     NaN         -0.8840            0.0088
# S108                     NaN          0.0584           -0.3010
# S109                     NaN             NaN               NaN
# S110                 -0.1980         -0.2110            0.0487
#
# Name        TP53_Hotspot_Mutation
# Patient_ID
# S001                        False
# S002                        False
# S003                        False
# S004                        False
# S005                        False
# ...                           ...
# S106                        False
# S107                        False
# S108                        False
# S109                        False
# S110                        False
#
# [106 rows x 8068 columns]

# %% [markdown]
# #### Use wrap_ttest to do a comparison on each proteomics value, comparing samples with a hotspot mutation to those without a hotspot mutation

# %%
compar_cols = list(proteomics_df.columns)
compar_cols.remove('TP53_Hotspot_Mutation')
wrap_results = ut.wrap_ttest(proteomics_df, comparison_columns=compar_cols, label_column='TP53_Hotspot_Mutation')
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3506: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
wrap_results
# Out:
#          Comparison   P_Value
# 0  PPP4C_proteomics  0.000003
