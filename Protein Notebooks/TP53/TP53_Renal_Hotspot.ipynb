# %%
import pandas as pd
import numpy as np
import scipy.stats

import cptac
import cptac.utils as ut

ccrcc = cptac.Ccrcc()
# Out:
# /anaconda3/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
somatic_mutations = ccrcc.get_somatic_mutation()

# %%
somatic_mutations
# Out:
# Name           Gene           Mutation     Location
# Patient_ID
# S001          ACACA  Nonsense_Mutation      p.R662*
# S001          ACSL5  Missense_Mutation      p.L699I
# S001         AMBRA1  Missense_Mutation      p.Q677L
# S001        ARFGEF2  Missense_Mutation      p.E209Q
# S001           ASPM  Missense_Mutation     p.R2665P
# ...             ...                ...          ...
# S137        TMEM63C  Missense_Mutation      p.R213W
# S137           TP73             Silent      p.P491P
# S137          TTC38  Missense_Mutation      p.N219I
# S137            UBC    Frame_Shift_Del  p.Q49Rfs*33
# S137           ZIC1             Silent      p.G139G
#
# [8350 rows x 3 columns]

# %%
vis, binary, detailed, dictionary = ut.parse_hotspot('../../HotspotClusterFiles/ccrcc.somatic.consensus.gdc.umichigan.wu.112918.maf.3D_Proximity.pairwise.recurrence.l0.r10.clusters', somatic_mutations)

# %%
vis
# Out:
#   hotspot_id  patients_within
# 0      AMY2A              2.0
# 1      DUSP2              2.0
# 2      KIF22              2.0
# 3      PBRM1              2.0
# 4     PIK3CA              3.0
# 5      SMAD2              2.0
# 6        VHL             14.0
# 7      VHL_1              3.0
