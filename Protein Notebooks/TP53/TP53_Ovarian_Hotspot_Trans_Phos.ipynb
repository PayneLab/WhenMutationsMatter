# %% [markdown]
# # Examine trans effect of TP53 Hotspot mutation in Ovarian Cancer on Phosphoproteomics

# %% [markdown]
# ### Specifically examine Phosphorylation

# %% [markdown]
# #### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats

import cptac
import cptac.utils as ut

import seaborn as sns
import matplotlib.pyplot as plt

#Use Ovarian cancer object
co = cptac.Ovarian()
# Out:
# Warning: Your version of cptac (0.6.0) is out-of-date. Latest is 0.6.3. Please run 'pip install cptac --upgrade' to update it. (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 5)

# %% [markdown]
# ## Use parse hotspot utility to analyze TP53 hotspot mutation in Ovarian cancer

# %% [markdown]
# #### Get somatic mutation data from cptac

# %%
somatic_mutations = co.get_somatic_mutation()

# %% [markdown]
# #### Use parse hotspot utility

# %%
vis, binary, detailed, dictionary = ut.parse_hotspot('../../HotspotClusterFiles/ovarian_somatic_38.maf.3D_Proximity.pairwise.recurrence.l0.r10.clusters', somatic_mutations)

# %%
vis
# Out:
#    hotspot_id  patients_within
# 0       ADH1A              2.0
# 1       CDCA2              3.0
# 2        CPS1              2.0
# 3      EIF4A1              3.0
# 4       FGF18              3.0
# 5         GCA              2.0
# 6        GOT1              2.0
# 7      HNRNPM              3.0
# 8       KDM2A              2.0
# 9         KHK              2.0
# 10      NTRK1              2.0
# 11     PFKFB1              4.0
# 12       POLI              2.0
# 13    PPP2R1A              3.0
# 14     RANBP2              3.0
# 15      RPS11              6.0
# 16      SP100              2.0
# 17       TP53              5.0
# 18     TP53_1              9.0
# 19     TP53_2              7.0
# 20     TP53_3              3.0
# 21     TP53_4              2.0
# 22     ZNF484              2.0

# %% [markdown]
# As we can see, TP53 has 5 hotspots in Ovarian cancer

# %% [markdown]
# #### Select only TP53 Hotspots

# %%
#There are 5 TP53 hotspots
TP53_Hotspots = detailed[['TP53','TP53_1','TP53_2','TP53_3','TP53_4']]
TP53_Hotspots.head()
# Out:
#           TP53  TP53_1 TP53_2 TP53_3 TP53_4
# sample_id
# S002        No      No     No     No     No
# S006        No      No     No     No     No
# S007        No  Yes_HS     No     No     No
# S009        No     Yes     No     No     No
# S011        No     Yes     No     No     No

# %% [markdown]
# #### Make binary column for samples that have a TP53 Hotspot Mutation

# %%
TP53_Hotspots['Hotspot_Mutation'] = ''
for ind, row in TP53_Hotspots.iterrows():
    for col in TP53_Hotspots.columns:
        if row[col] == 'Yes_HS':
            TP53_Hotspots.loc[ind,'Hotspot_Mutation'] = 'TP53_Hotspot_Mutation'
        if row[col] == 'Yes':
            TP53_Hotspots.loc[ind,'Hotspot_Mutation'] = 'TP53_Hotspot_Mutation'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %% [markdown]
# #### Grab only the binary yes/no hotspot mutation

# %%
binary_hotspots = TP53_Hotspots['Hotspot_Mutation']

# %% [markdown]
# #### Get Proteomic data, append Binary hotspot mutation column

# %%
#Use join omics to mutations
proteomics_df = co.join_omics_to_mutations(omics_df_name='phosphoproteomics', mutations_genes='TP53')

#Remove multiindex from df
proteomics_df = co.reduce_multiindex(proteomics_df, flatten=True)

#Remove Non-Tumor Samples
proteomics_df = proteomics_df.loc[proteomics_df['Sample_Status'] == 'Tumor']

#Remove columns that are not needed
proteomics_df = proteomics_df.drop(['TP53_Location','Sample_Status'],axis=1)
proteomics_df['TP53_Hotspot_Mutation'] = binary_hotspots

#Show df
proteomics_df.head()
# Out:
# Warning: In joining the somatic_mutation table, no mutations were found for the following samples, so they were filled with Wildtype_Tumor or Wildtype_Normal: 26 samples for the TP53 gene (/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py, line 2)
# Name        AAAS_phosphoproteomics_S495_R.FS*PVLGR.A_NP_001166937  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                   -1.137
# S011                                                   -0.987
#
# Name        AAAS_phosphoproteomics_S495_R.FS*PVLGR.A_NP_056480  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                   -1.137
# S011                                                   -0.987
#
# Name        AAGAB_phosphoproteomics_S311_K.AFWMAIGGDRDEIEGLSS*DEEH.-_NP_001258815  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        AAGAB_phosphoproteomics_S311_K.AFWMAIGGDRDEIEGLSS*DEEH.-_NP_078942  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        AAK1_phosphoproteomics_S18_R.REQGGSGLGS*GSSGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        AAK1_phosphoproteomics_S20_R.EQGGSGLGSGS*SGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        AAK1_phosphoproteomics_S20_R.REQGGSGLGSGS*SGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        AAK1_phosphoproteomics_S21_R.EQGGSGLGSGSS*GGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                   -2.269
#
# Name        AAK1_phosphoproteomics_S624_K.VGSLTPPSS*PK.T_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                   -3.363
#
# Name        AAK1_phosphoproteomics_S637_R.ILS*DVTHSAV.F_NP_055726  ...  \
# Patient_ID                                                         ...
# S002                                                      NaN      ...
# S006                                                      NaN      ...
# S007                                                      NaN      ...
# S009                                                      NaN      ...
# S011                                                      NaN      ...
#
# Name        ZZZ3_phosphoproteomics_S113_R.RQTEPVS*PVLKR.I_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S135_R.SEAPNSSEEDS*PIKSDK.E_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S314_F.SETQSSLRDS*EEEVDVVGDSSASK.E_NP_056349  \
# Patient_ID
# S002                                                   -2.533
# S006                                                   -3.276
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S391_R.AAPTRGS*PTK.N_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                   -0.847
# S009                                                   -0.455
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S89_R.GLS*SSEKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S90_R.GLSS*SEKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S91_R.GLSSS*EKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                   -1.320
# S006                                                   -0.264
# S007                                                      NaN
# S009                                                   -1.129
# S011                                                   -1.301
#
# Name              TP53_Mutation  TP53_Mutation_Status  TP53_Hotspot_Mutation
# Patient_ID
# S002          [Frame_Shift_Del]       Single_mutation
# S006          [Frame_Shift_Del]       Single_mutation
# S007        [Missense_Mutation]       Single_mutation  TP53_Hotspot_Mutation
# S009        [Missense_Mutation]       Single_mutation  TP53_Hotspot_Mutation
# S011          [Frame_Shift_Ins]       Single_mutation  TP53_Hotspot_Mutation
#
# [5 rows x 110956 columns]

# %% [markdown]
# #### Classify every sample according to TP53 Mutation Status. Use: Wildtype, Hotspot_Missense, Other_Missense, Truncation

# %%
for ind, row in proteomics_df.iterrows():
    #Classify Hotspot Missense Mutations
    if row['TP53_Hotspot_Mutation'] == 'TP53_Hotspot_Mutation':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Hotspot_Missense'
        
    #Classify Truncation Mutations
    if 'Frame_Shift_Ins' in row['TP53_Mutation'] or 'Frame_Shift_Del' in row['TP53_Mutation'] or 'Nonsense_Mutation' in row['TP53_Mutation']:
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Truncation'
        
    #Classify Wildtype
    if row['TP53_Mutation_Status'] == 'Wildtype_Tumor':
        proteomics_df.loc[ind, 'TP53_Categorical'] = 'Wildtype'
        
    #Classify Other Missense Mutations
    if row['TP53_Hotspot_Mutation'] != 'TP53_Hotspot_Mutation':
        if 'Missense_Mutation' in row['TP53_Mutation'] or 'In_Frame_Del' in row['TP53_Mutation'] or 'In_Frame_Ins' in row['TP53_Mutation'] or 'Splice_Site' in row['TP53_Mutation']:
            proteomics_df.loc[ind, 'TP53_Categorical'] = 'Other_Missense'

#Drop columns we no longer need, display df
proteomics_df = proteomics_df.drop(['TP53_Mutation', 'TP53_Mutation_Status', 'TP53_Hotspot_Mutation'], axis = 1)
proteomics_df
# Out:
# Name        AAAS_phosphoproteomics_S495_R.FS*PVLGR.A_NP_001166937  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                   -1.137
# S011                                                   -0.987
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                   -0.742
# S111                                                      NaN
#
# Name        AAAS_phosphoproteomics_S495_R.FS*PVLGR.A_NP_056480  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                   -1.137
# S011                                                   -0.987
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                   -0.742
# S111                                                      NaN
#
# Name        AAGAB_phosphoproteomics_S311_K.AFWMAIGGDRDEIEGLSS*DEEH.-_NP_001258815  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        AAGAB_phosphoproteomics_S311_K.AFWMAIGGDRDEIEGLSS*DEEH.-_NP_078942  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        AAK1_phosphoproteomics_S18_R.REQGGSGLGS*GSSGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                   -3.038
#
# Name        AAK1_phosphoproteomics_S20_R.EQGGSGLGSGS*SGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        AAK1_phosphoproteomics_S20_R.REQGGSGLGSGS*SGGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                   -1.080
# S108                                                   -2.771
# S110                                                      NaN
# S111                                                   -3.016
#
# Name        AAK1_phosphoproteomics_S21_R.EQGGSGLGSGSS*GGGGSTSGLGSGYIGR.V_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                   -2.269
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                   -1.704
# S111                                                   -2.519
#
# Name        AAK1_phosphoproteomics_S624_K.VGSLTPPSS*PK.T_NP_055726  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                   -3.363
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                   -2.075
# S111                                                      NaN
#
# Name        AAK1_phosphoproteomics_S637_R.ILS*DVTHSAV.F_NP_055726  ...  \
# Patient_ID                                                         ...
# S002                                                      NaN      ...
# S006                                                      NaN      ...
# S007                                                      NaN      ...
# S009                                                      NaN      ...
# S011                                                      NaN      ...
# ...                                                       ...      ...
# S106                                                      NaN      ...
# S107                                                      NaN      ...
# S108                                                      NaN      ...
# S110                                                      NaN      ...
# S111                                                      NaN      ...
#
# Name        ZZZ3_phosphoproteomics_S113_R.QTEPVS*PVLKR.I_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                   -0.336
# S011                                                   -0.770
# ...                                                       ...
# S106                                                   -1.637
# S107                                                      NaN
# S108                                                      NaN
# S110                                                   -0.306
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S113_R.RQTEPVS*PVLK.R_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S113_R.RQTEPVS*PVLKR.I_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                   -2.219
# S108                                                   -1.612
# S110                                                      NaN
# S111                                                   -1.175
#
# Name        ZZZ3_phosphoproteomics_S135_R.SEAPNSSEEDS*PIKSDK.E_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S314_F.SETQSSLRDS*EEEVDVVGDSSASK.E_NP_056349  \
# Patient_ID
# S002                                                   -2.533
# S006                                                   -3.276
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S391_R.AAPTRGS*PTK.N_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                   -0.847
# S009                                                   -0.455
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S89_R.GLS*SSEKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                      NaN
# S108                                                      NaN
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S90_R.GLSS*SEKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                      NaN
# S006                                                      NaN
# S007                                                      NaN
# S009                                                      NaN
# S011                                                      NaN
# ...                                                       ...
# S106                                                      NaN
# S107                                                   -2.134
# S108                                                   -2.503
# S110                                                      NaN
# S111                                                      NaN
#
# Name        ZZZ3_phosphoproteomics_S91_R.GLSSS*EKDNIER.Q_NP_056349  \
# Patient_ID
# S002                                                   -1.320
# S006                                                   -0.264
# S007                                                      NaN
# S009                                                   -1.129
# S011                                                   -1.301
# ...                                                       ...
# S106                                                   -1.232
# S107                                                      NaN
# S108                                                      NaN
# S110                                                    0.713
# S111                                                      NaN
#
# Name        TP53_Categorical
# Patient_ID
# S002              Truncation
# S006              Truncation
# S007        Hotspot_Missense
# S009        Hotspot_Missense
# S011              Truncation
# ...                      ...
# S106        Hotspot_Missense
# S107              Truncation
# S108        Hotspot_Missense
# S110        Hotspot_Missense
# S111        Hotspot_Missense
#
# [83 rows x 110954 columns]

# %% [markdown]
# #### Split dataframe into 4 categorical dataframes

# %%
hotspot_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Hotspot_Missense']
truncation_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Truncation']
other_missense_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Other_Missense']
wt_df = proteomics_df.loc[proteomics_df['TP53_Categorical'] == 'Wildtype']

# %% [markdown]
# #### Use wrap t-test to compare Hotspot_Missense with Truncation

# %%
hotspot_missense_truncation_df = pd.concat([hotspot_df, truncation_df])
comp_cols = list(hotspot_missense_truncation_df.columns)
comp_cols.remove('TP53_Categorical')
results = ut.wrap_ttest(hotspot_missense_truncation_df, comparison_columns=comp_cols, label_column='TP53_Categorical')
results
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3506: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                                           Comparison       P_Value
# 0  HOXA5_phosphoproteomics_S95_R.YSQPATSTHS*PQPDP...  4.649234e-08

# %% [markdown]
# #### Use wrap t-test to compare Hotspot_Missense with Wildtype

# %%
hotspot_missense_wildtype_df = pd.concat([hotspot_df, wt_df])
comp_cols = list(hotspot_missense_wildtype_df.columns)
comp_cols.remove('TP53_Categorical')
results = ut.wrap_ttest(hotspot_missense_wildtype_df, comparison_columns=comp_cols, label_column='TP53_Categorical')
results
# Out:
# No significant comparisons.

# %% [markdown]
# #### Use wrap t-test to compare Hotspot_Missense with Other Missense

# %%
hotspot_missense_other_missense_df = pd.concat([hotspot_df, other_missense_df])
comp_cols = list(hotspot_missense_other_missense_df.columns)
comp_cols.remove('TP53_Categorical')
results = ut.wrap_ttest(hotspot_missense_other_missense_df, comparison_columns=comp_cols, label_column='TP53_Categorical')
results
# Out:
# No significant comparisons.

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# There were not significant comparisons, after adjusting for multiple testing using a bonferroni correction.
