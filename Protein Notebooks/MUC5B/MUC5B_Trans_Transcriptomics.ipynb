# %% [markdown]
# # MUC5B Mutation Trans Effect on Transcriptomics

# %% [markdown]
# This notebook analyzes the trans effect of MUC5B mutation on interacting and other proteins Transcriptomics, in Endometrial, Colon, and Ovarian cancer.

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections

import warnings
warnings.filterwarnings("ignore")

import cptac
import cptac.algorithms as al

en = cptac.Endometrial()
co = cptac.Colon()
ov = cptac.Ovarian()

# %% [markdown]
# ### Select Gene

# %%
gene = "MUC5B"

# %% [markdown]
# ### Investigate Proteomics, Phosphoproteomics, Acetylproteomics, or Transcriptomics

# %%
#omics = "proteomics"
omics = "transcriptomics"
#omics = "phosphoproteomics"
#omics = "acetylproteomics"

# %% [markdown]
# ### Track all significant comparisons in Dataframe

# %%
all_significant_comparisons = pd.DataFrame(columns=['Cancer_Type', 'Gene', 'Comparison','Interacting_Protein','P_Value'])

# %%
def add_to_all_significant_comparisons(df, cancer, interacting, all_sig_comp):
    expanded = df
    expanded['Gene'] = gene
    expanded['Cancer_Type'] = cancer
    expanded['Interacting_Protein'] = interacting
    
    updated_all_comparisons = pd.concat([all_sig_comp, expanded], sort=False)
    
    return updated_all_comparisons

# %% [markdown]
# # Interacting Proteins: Transcriptomics

# %% [markdown]
# ### Generate interacting protein list

# %% [markdown]
# Make a call to the cptac.algorithms get interacting proteins method, which interacts with the uniprot and string databases to generate a list of known interacting partners with the given gene

# %%
'''Use get interacting proteins method to generate list of interacting proteins'''
interacting_proteins = al.get_interacting_proteins(gene)

'''Show interacting protein list'''
print("Interacting Proteins:")
for interacting_protein in interacting_proteins:
    print(interacting_protein)
# Out:
# Interacting Proteins:
# GALNT8
# ST6GAL1
# ST6GALNAC2
# ST3GAL3
# MUC17
# GALNT16
# GALNT12
# MUC21
# MUC3A
# ST3GAL2
# GCNT3
# MUC16
# C1GALT1
# MUC6
# MUC7
# MUC20
# MUC15
# MUC4
# GALNTL6
# ST3GAL4
# MUC5B
# MUC12
# B3GNT6
# MUC1
# MUC13
# MUC5AC
# UBC
# KIR2DS2
# C7orf25
# ICE2
# FRMD1
# PCK2
# HBM
# ARHGAP12
# TIMM50
# DDX31
# ESR2
# AGR2

# %% [markdown]
# ## Endometrial

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)


'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Endometrial", True, all_significant_comparisons)
# Out:
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Colon

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Colon", True, all_significant_comparisons)
# Out:
# MUC17 did not match any columns in transcriptomics dataframe. MUC17_transcriptomics column inserted, but filled with NaN.
# GALNT16 did not match any columns in transcriptomics dataframe. GALNT16_transcriptomics column inserted, but filled with NaN.
# MUC21 did not match any columns in transcriptomics dataframe. MUC21_transcriptomics column inserted, but filled with NaN.
# MUC16 did not match any columns in transcriptomics dataframe. MUC16_transcriptomics column inserted, but filled with NaN.
# MUC6 did not match any columns in transcriptomics dataframe. MUC6_transcriptomics column inserted, but filled with NaN.
# MUC7 did not match any columns in transcriptomics dataframe. MUC7_transcriptomics column inserted, but filled with NaN.
# MUC15 did not match any columns in transcriptomics dataframe. MUC15_transcriptomics column inserted, but filled with NaN.
# GALNTL6 did not match any columns in transcriptomics dataframe. GALNTL6_transcriptomics column inserted, but filled with NaN.
# MUC5B did not match any columns in transcriptomics dataframe. MUC5B_transcriptomics column inserted, but filled with NaN.
# MUC5AC did not match any columns in transcriptomics dataframe. MUC5AC_transcriptomics column inserted, but filled with NaN.
# KIR2DS2 did not match any columns in transcriptomics dataframe. KIR2DS2_transcriptomics column inserted, but filled with NaN.
# HBM did not match any columns in transcriptomics dataframe. HBM_transcriptomics column inserted, but filled with NaN.
# ESR2 did not match any columns in transcriptomics dataframe. ESR2_transcriptomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
#                    Comparison   P_Value
# 0       MUC20_transcriptomics  0.000004
# 1       FRMD1_transcriptomics  0.000013
# 2     ST6GAL1_transcriptomics  0.000067
# 3       MUC12_transcriptomics  0.000111
# 4  ST6GALNAC2_transcriptomics  0.000615

# %% [markdown]
# ## Ovarian

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Ovarian", True, all_significant_comparisons)
# Out:
# GALNT8 did not match any columns in transcriptomics dataframe. GALNT8_transcriptomics column inserted, but filled with NaN.
# C1GALT1 did not match any columns in transcriptomics dataframe. C1GALT1_transcriptomics column inserted, but filled with NaN.
# MUC20 did not match any columns in transcriptomics dataframe. MUC20_transcriptomics column inserted, but filled with NaN.
# MUC1 did not match any columns in transcriptomics dataframe. MUC1_transcriptomics column inserted, but filled with NaN.
# MUC5AC did not match any columns in transcriptomics dataframe. MUC5AC_transcriptomics column inserted, but filled with NaN.
# ICE2 did not match any columns in transcriptomics dataframe. ICE2_transcriptomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# # All Proteins: Transcriptomics

# %% [markdown]
# Expand our search for significant comparisons to all proteins in our dataset

# %% [markdown]
# ## Endometrial

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")
            
            all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Endometrial", False, all_significant_comparisons)


except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  MUC5B
# Doing t-test comparisons
#
#                 Comparison   P_Value
# 0  FAM86HP_transcriptomics  0.000001

# %% [markdown]
# ## Colon

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")
            
            all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Colon", False, all_significant_comparisons)


except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  MUC5B
# Doing t-test comparisons
#
#                      Comparison       P_Value
# 0          GPX2_transcriptomics  1.758001e-10
# 1       POU5F1B_transcriptomics  4.688794e-10
# 2        RUBCNL_transcriptomics  1.541604e-09
# 3        ATP10B_transcriptomics  3.068562e-09
# 4         NUBPL_transcriptomics  3.884908e-09
# 5       CEACAM5_transcriptomics  6.870982e-09
# 6       CEACAM6_transcriptomics  9.942373e-09
# 7         ADNP2_transcriptomics  1.155737e-08
# 8    DLGAP1-AS2_transcriptomics  1.221313e-08
# 9      TOR1AIP2_transcriptomics  1.275600e-08
# 10         GRM8_transcriptomics  1.851409e-08
# 11       LY6G6D_transcriptomics  2.788723e-08
# 12        CCSAP_transcriptomics  3.180643e-08
# 13        EPDR1_transcriptomics  3.808045e-08
# 14         ACE2_transcriptomics  4.376884e-08
# 15        NR1I2_transcriptomics  4.771506e-08
# 16       MAPK12_transcriptomics  5.517810e-08
# 17       CASC21_transcriptomics  5.951666e-08
# 18    LINC00513_transcriptomics  9.176024e-08
# 19       GPR143_transcriptomics  1.071900e-07
# 20        PIAS2_transcriptomics  1.264160e-07
# 21    LINC01560_transcriptomics  1.514142e-07
# 22  THUMPD3-AS1_transcriptomics  1.689576e-07
# 23     SLC25A13_transcriptomics  1.864544e-07
# 24        CXXC1_transcriptomics  2.088444e-07
# 25        TNNC2_transcriptomics  2.443947e-07
# 26        TDGF1_transcriptomics  2.727111e-07
# 27         CFTR_transcriptomics  2.870300e-07
# 28      CTTNBP2_transcriptomics  3.082151e-07
# 29       TSPAN6_transcriptomics  3.718990e-07
# ..                          ...           ...
# 47        MRE11_transcriptomics  1.403404e-06
# 48         PIGX_transcriptomics  1.418377e-06
# 49          MBP_transcriptomics  1.546044e-06
# 50        MYZAP_transcriptomics  1.561001e-06
# 51        PRAP1_transcriptomics  1.692921e-06
# 52       SEMA5A_transcriptomics  1.824961e-06
# 53       THRAP3_transcriptomics  2.186983e-06
# 54         MLH1_transcriptomics  2.270186e-06
# 55        DDX27_transcriptomics  2.290637e-06
# 56         LMNA_transcriptomics  2.326658e-06
# 57       SLC3A1_transcriptomics  2.421983e-06
# 58        LIN54_transcriptomics  2.553519e-06
# 59         IER5_transcriptomics  2.572737e-06
# 60         RAC3_transcriptomics  2.702800e-06
# 61        KIF14_transcriptomics  2.727888e-06
# 62       GUCY2C_transcriptomics  2.736175e-06
# 63        SOCS6_transcriptomics  2.843641e-06
# 64         VAPB_transcriptomics  2.907669e-06
# 65         QPRT_transcriptomics  2.953795e-06
# 66        ATP9A_transcriptomics  2.977994e-06
# 67        CRAT8_transcriptomics  3.196294e-06
# 68         TYMS_transcriptomics  3.330010e-06
# 69      CXorf23_transcriptomics  3.369104e-06
# 70      SPATA25_transcriptomics  3.383985e-06
# 71       POFUT1_transcriptomics  3.506052e-06
# 72         AAR2_transcriptomics  3.522057e-06
# 73       ZNF737_transcriptomics  3.535392e-06
# 74    LINC01006_transcriptomics  3.607070e-06
# 75        RNF43_transcriptomics  3.665086e-06
# 76        GSPT2_transcriptomics  3.699970e-06
#
# [77 rows x 2 columns]

# %% [markdown]
# ## Ovarian

# %%
print("\nGene: ", gene)

'''Use all proteins'''

'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
protdf = protdf.loc[:,~protdf.columns.duplicated()]

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the datafram correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
        
        all_significant_comparisons = add_to_all_significant_comparisons(wrap_results, "Ovarian", False, all_significant_comparisons)
# Out:
# Gene:  MUC5B
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ### Print All Signififant Comparisons

# %%
if len(all_significant_comparisons) == 0:
    print('No Significant Comparisons!')
    
else:
    display(all_significant_comparisons)
# Out:
#     Cancer_Type   Gene                   Comparison Interacting_Protein  \
# 0         Colon  MUC5B        MUC20_transcriptomics                True
# 1         Colon  MUC5B        FRMD1_transcriptomics                True
# 2         Colon  MUC5B      ST6GAL1_transcriptomics                True
# 3         Colon  MUC5B        MUC12_transcriptomics                True
# 4         Colon  MUC5B   ST6GALNAC2_transcriptomics                True
# 0   Endometrial  MUC5B      FAM86HP_transcriptomics               False
# 0         Colon  MUC5B         GPX2_transcriptomics               False
# 1         Colon  MUC5B      POU5F1B_transcriptomics               False
# 2         Colon  MUC5B       RUBCNL_transcriptomics               False
# 3         Colon  MUC5B       ATP10B_transcriptomics               False
# 4         Colon  MUC5B        NUBPL_transcriptomics               False
# 5         Colon  MUC5B      CEACAM5_transcriptomics               False
# 6         Colon  MUC5B      CEACAM6_transcriptomics               False
# 7         Colon  MUC5B        ADNP2_transcriptomics               False
# 8         Colon  MUC5B   DLGAP1-AS2_transcriptomics               False
# 9         Colon  MUC5B     TOR1AIP2_transcriptomics               False
# 10        Colon  MUC5B         GRM8_transcriptomics               False
# 11        Colon  MUC5B       LY6G6D_transcriptomics               False
# 12        Colon  MUC5B        CCSAP_transcriptomics               False
# 13        Colon  MUC5B        EPDR1_transcriptomics               False
# 14        Colon  MUC5B         ACE2_transcriptomics               False
# 15        Colon  MUC5B        NR1I2_transcriptomics               False
# 16        Colon  MUC5B       MAPK12_transcriptomics               False
# 17        Colon  MUC5B       CASC21_transcriptomics               False
# 18        Colon  MUC5B    LINC00513_transcriptomics               False
# 19        Colon  MUC5B       GPR143_transcriptomics               False
# 20        Colon  MUC5B        PIAS2_transcriptomics               False
# 21        Colon  MUC5B    LINC01560_transcriptomics               False
# 22        Colon  MUC5B  THUMPD3-AS1_transcriptomics               False
# 23        Colon  MUC5B     SLC25A13_transcriptomics               False
# ..          ...    ...                          ...                 ...
# 47        Colon  MUC5B        MRE11_transcriptomics               False
# 48        Colon  MUC5B         PIGX_transcriptomics               False
# 49        Colon  MUC5B          MBP_transcriptomics               False
# 50        Colon  MUC5B        MYZAP_transcriptomics               False
# 51        Colon  MUC5B        PRAP1_transcriptomics               False
# 52        Colon  MUC5B       SEMA5A_transcriptomics               False
# 53        Colon  MUC5B       THRAP3_transcriptomics               False
# 54        Colon  MUC5B         MLH1_transcriptomics               False
# 55        Colon  MUC5B        DDX27_transcriptomics               False
# 56        Colon  MUC5B         LMNA_transcriptomics               False
# 57        Colon  MUC5B       SLC3A1_transcriptomics               False
# 58        Colon  MUC5B        LIN54_transcriptomics               False
# 59        Colon  MUC5B         IER5_transcriptomics               False
# 60        Colon  MUC5B         RAC3_transcriptomics               False
# 61        Colon  MUC5B        KIF14_transcriptomics               False
# 62        Colon  MUC5B       GUCY2C_transcriptomics               False
# 63        Colon  MUC5B        SOCS6_transcriptomics               False
# 64        Colon  MUC5B         VAPB_transcriptomics               False
# 65        Colon  MUC5B         QPRT_transcriptomics               False
# 66        Colon  MUC5B        ATP9A_transcriptomics               False
# 67        Colon  MUC5B        CRAT8_transcriptomics               False
# 68        Colon  MUC5B         TYMS_transcriptomics               False
# 69        Colon  MUC5B      CXorf23_transcriptomics               False
# 70        Colon  MUC5B      SPATA25_transcriptomics               False
# 71        Colon  MUC5B       POFUT1_transcriptomics               False
# 72        Colon  MUC5B         AAR2_transcriptomics               False
# 73        Colon  MUC5B       ZNF737_transcriptomics               False
# 74        Colon  MUC5B    LINC01006_transcriptomics               False
# 75        Colon  MUC5B        RNF43_transcriptomics               False
# 76        Colon  MUC5B        GSPT2_transcriptomics               False
#
#          P_Value
# 0   4.319530e-06
# 1   1.340157e-05
# 2   6.725471e-05
# 3   1.108167e-04
# 4   6.152779e-04
# 0   1.094390e-06
# 0   1.758001e-10
# 1   4.688794e-10
# 2   1.541604e-09
# 3   3.068562e-09
# 4   3.884908e-09
# 5   6.870982e-09
# 6   9.942373e-09
# 7   1.155737e-08
# 8   1.221313e-08
# 9   1.275600e-08
# 10  1.851409e-08
# 11  2.788723e-08
# 12  3.180643e-08
# 13  3.808045e-08
# 14  4.376884e-08
# 15  4.771506e-08
# 16  5.517810e-08
# 17  5.951666e-08
# 18  9.176024e-08
# 19  1.071900e-07
# 20  1.264160e-07
# 21  1.514142e-07
# 22  1.689576e-07
# 23  1.864544e-07
# ..           ...
# 47  1.403404e-06
# 48  1.418377e-06
# 49  1.546044e-06
# 50  1.561001e-06
# 51  1.692921e-06
# 52  1.824961e-06
# 53  2.186983e-06
# 54  2.270186e-06
# 55  2.290637e-06
# 56  2.326658e-06
# 57  2.421983e-06
# 58  2.553519e-06
# 59  2.572737e-06
# 60  2.702800e-06
# 61  2.727888e-06
# 62  2.736175e-06
# 63  2.843641e-06
# 64  2.907669e-06
# 65  2.953795e-06
# 66  2.977994e-06
# 67  3.196294e-06
# 68  3.330010e-06
# 69  3.369104e-06
# 70  3.383985e-06
# 71  3.506052e-06
# 72  3.522057e-06
# 73  3.535392e-06
# 74  3.607070e-06
# 75  3.665086e-06
# 76  3.699970e-06
#
# [83 rows x 5 columns]

# %% [markdown]
# ### Write Significant Comparisons (if any) to Shared CSV file

# %%
existing_results = pd.read_csv(gene+'_Trans_Results.csv')

updated_results = pd.concat([existing_results, all_significant_comparisons], sort=False)

updated_results.to_csv(path_or_buf = gene + '_Trans_Results.csv', index=False)
