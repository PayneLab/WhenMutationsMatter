# %% [markdown]
# # Examine Relation of Altered Transcriptomics and Proteomics when ARID1A is mutated in Ovarian Cancer

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections
import re
import gseapy as gp
from gseapy.plot import barplot, dotplot
import matplotlib.pyplot as plt
import seaborn as sns

import cptac
import cptac.algorithms as al

ov = cptac.Ovarian()

# %% [markdown]
# ### Load Results of Trans Analysis

# %%
Trans_Results = pd.read_csv("Formatted_Trans_Results.csv")

# %% [markdown]
# ### Filter for only Ovarian Cancer Type, ARID1A Mutation, and Transcript or Proteomic Comparison

# %%
Ovarian = Trans_Results.loc[Trans_Results['Cancer_Type'] == 'Ovarian']
ARID = Ovarian.loc[Ovarian['Mutation_Gene'] == 'ARID1A']

transcript = ARID.loc[ARID['Omics'] == 'transcriptomics']
proteomic = ARID.loc[ARID['Omics'] == 'proteomics']

transcript_proteins = list(transcript['Protein'])
proteomic_proteins = list(proteomic['Protein'])

# %% [markdown]
# ### Print proteins whose proteomic levels are significantly altered when ARID1A is Mutated

# %%
proteomic_proteins
# Out:
# ['ING1', 'OLFM4', 'TIMP1', 'PAXIP1', 'ING1', 'ZBTB40', 'PIGR', 'TMEM63A']

# %% [markdown]
# ### Print proteins whose transcript levels are significantly altered when ARID1A is Mutated

# %%
transcript_proteins
# Out:
# ['PGR',
#  'MTNR1B',
#  'CDK20',
#  'HMX3',
#  'RXFP1',
#  'GPR97',
#  'TUNAR',
#  'SLC26A2',
#  'PGAP2',
#  'ANKRD20A12P',
#  'TNFRSF18',
#  'HGD',
#  'C10orf71',
#  'LOC100506526',
#  'C2CD4B',
#  'MFAP3L',
#  'LINC00645',
#  'OLFM4',
#  'HES2',
#  'RNF186',
#  'SLC5A9',
#  'CCAT1',
#  'FGF14',
#  'LOC158434',
#  'GABRP',
#  'ERMN',
#  'SCGB2A1',
#  'SERINC2',
#  'HMX2',
#  'CAPN6',
#  'ELP3',
#  'GUCA1C',
#  'GJD3',
#  'RCAN1',
#  'PIGR',
#  'LOC102723769',
#  'ARSA',
#  'LINC00485',
#  'KLHDC7B',
#  'C2orf16',
#  'GDA',
#  'LRRC26',
#  'MOGAT1',
#  'CRELD2',
#  'NCMAP',
#  'MSX1',
#  'SCNN1B',
#  'AGR2',
#  'LINC01207',
#  'TCN1',
#  'LEFTY1',
#  'MTRNR2L1',
#  'SPATA21',
#  'CSF3',
#  'GNRHR',
#  'RASD1',
#  'SLC46A2',
#  'SPRR2D',
#  'ANKS4B',
#  'BAIAP2L2',
#  'SERPINA4',
#  'PHYHIPL',
#  'ANAPC4',
#  'TFF3',
#  'PEBP4',
#  'C1orf64',
#  'PGR',
#  'OR8D4',
#  'PRR15',
#  'FAM150B',
#  'UBTFL1',
#  'FGL1',
#  'CCAT2',
#  'SERPINA3',
#  'ZBTB25',
#  'DUXA',
#  'STX18',
#  'MICALCL',
#  'CREB3L1',
#  'MSS51',
#  'CLCA1',
#  'SPDEF',
#  'PLIN3',
#  'FBXW10',
#  'SCGB1D2',
#  'PRAMEF12',
#  'MMP26',
#  'KRT24',
#  'FAM149A',
#  'MBD3L3',
#  'SERPINA1',
#  'MBD3L5',
#  'MBD3L4',
#  'PTGS2',
#  'GP2',
#  'MBD3L2',
#  'SFTPB',
#  'HAVCR1',
#  'PRAMEF17',
#  'SLC6A1-AS1',
#  'AQP2',
#  'IRGC',
#  'OR10G7',
#  'OR1L6',
#  'OR2T34',
#  'OR9G4',
#  'SLC22A7',
#  'SNAR-A13',
#  'C10orf111',
#  'C18orf64',
#  'CREB3L4',
#  'DEFB106B',
#  'HNF1A',
#  'LINC00690',
#  'LL22NC01-81G9.3',
#  'MIR23B',
#  'MIR2682',
#  'MIR320A',
#  'MIR378D2',
#  'MIR4292',
#  'MIR4768',
#  'OR5M1',
#  'SLC7A13',
#  'OR2G6',
#  'SCGB1D4',
#  'TINAG',
#  'TRIM49B',
#  'SCUBE2',
#  'AMBRA1',
#  'KLK12',
#  'SLC47A1',
#  'TRIM53AP',
#  'TUBB8',
#  'TRIM48',
#  'SULT2B1',
#  'TRIM51',
#  'TRIM64',
#  'PRAMEF7',
#  'LOC339593',
#  'TRIM64B',
#  'SERPINA11',
#  'MUC7',
#  'MC3R',
#  'C15orf43',
#  'C5orf27',
#  'KDM4E',
#  'CRYL1',
#  'SPRR2A',
#  'OPN5',
#  'LOC649324',
#  'LOC645354',
#  'AGTR2',
#  'TMED6',
#  'FAM83E',
#  'TOX3',
#  'LOC100505811',
#  'DLGAP1-AS3',
#  'MC2R',
#  'SPRR3',
#  'ARRDC5',
#  'TRIM51HP',
#  'ADAMTS8',
#  'GPHB5',
#  'CPD',
#  'LOC400553',
#  'FAM155A',
#  'ENPP3',
#  'LEUTX',
#  'TMPRSS11D',
#  'LOC100506085',
#  'FAM169B',
#  'SIAE',
#  'EPS8L3',
#  'G6PC2',
#  'UTS2',
#  'MAP2K6',
#  'PTHLH',
#  'PIP',
#  'LCN15',
#  'SULF2',
#  'FUT6',
#  'HSD17B2',
#  'TPRX1',
#  'TFAP2B',
#  'MTRNR2L6',
#  'F3',
#  'TRIM43B',
#  'PPP1R3B',
#  'RFPL1',
#  'GDF15',
#  'CEACAM1',
#  'MTUS2-AS1',
#  'MFSD4',
#  'NCALD',
#  'AVPR1A',
#  'MESP2',
#  'SLC43A1',
#  'PZP',
#  'LOC100505817',
#  'LOC643486',
#  'LINC01245',
#  'INSM1',
#  'LOC102724484',
#  'KIF13B',
#  'KCNH4',
#  'KHDC1L',
#  'HS3ST1',
#  'LINC00462',
#  'SEMA3G',
#  'ANO1']

# %% [markdown]
# ### Find proteins in both lists

# %%
in_both = []
for pp in proteomic_proteins:
    if pp in transcript_proteins:
        print(pp)
        in_both.append(pp)
# Out:
# OLFM4
# PIGR

# %% [markdown]
# <b>OLFM4</b> and <b>PIGR</b> are the only proteins showing significant change in both proteomic expression and transcript expression when ARID1A is mutated in Ovarian Cancer

# %%
transcript_df = ov.join_omics_to_mutations(mutations_genes='ARID1A', omics_df_name='transcriptomics', omics_genes=in_both)
proteomic_df = ov.join_omics_to_mutations(mutations_genes='ARID1A', omics_df_name='proteomics', omics_genes=in_both)

#joint_df = pd.concat([transcript_df, proteomic_df])

#joint_df

transcript_df
# Out:
#            OLFM4_transcriptomics  PIGR_transcriptomics  \
# Sample_ID
# S001                    2.062720            147.178000
# S002                    0.072102              0.041317
# S003                    0.000000              0.027524
# S004                    0.174432             10.052100
# S005                    0.165579              0.325556
# S006                    0.118844             10.660800
# S007                    0.065489              0.593011
# S008                    0.000000              0.579682
# S009                    0.010962              0.942334
# S011                    0.082004              0.015715
# S013                    0.068949              0.015438
# S015                    0.000000              0.007778
# S016                    0.000000              0.028310
# S017                    0.011715              0.039253
# S018                    0.819868              0.207399
# S019                    0.000000              0.029344
# S020                    0.000000              0.217293
# S022                    0.000000              0.804908
# S023                    0.352374              0.354289
# S024                    0.021807              7.575030
# S025                    5.414140              0.021876
# S026                    0.187611             71.281600
# S027                    0.011277              1.097780
# S028                    0.116578              1.742060
# S029                    0.000000              0.506987
# S030                    5.222320              0.082821
# S031                    0.000000              0.447581
# S032                    0.023805              0.135741
# S033                    0.011569              0.131928
# S034                    0.000000             12.123300
# ...                          ...                   ...
# S078                   34.268400             25.117600
# S079                    6.372260             28.745400
# S080                  174.078000            224.109000
# S084                    0.175997              0.169824
# S085                    0.150643              0.050452
# S087                    0.085550              0.417614
# S088                    0.049689              0.720769
# S089                    0.110703              0.057818
# S090                    0.038577              0.293150
# S091                    0.023564              0.118521
# S092                    0.011336              1.137240
# S093                    0.058908              1.129940
# S094                    0.000000              0.062962
# S095                    0.000000              0.014837
# S096                    0.000000              0.213016
# S097                    0.037106             14.089900
# S098                    0.000000              0.434437
# S099                    0.023062              2.651570
# S100                    0.093953              0.228420
# S101                    0.011633              0.171606
# S102                    0.011004              0.346230
# S103                    0.021935              0.007358
# S104                    0.024657              0.437015
# S105                    0.000000              1.190910
# S106                    0.078023              0.017439
# S107                    1.020740              0.007600
# S108                    0.000000              0.000000
# S109                    0.045690             12.584000
# S110                    0.883919              0.866740
# S111                    0.060930              0.024526
#
#                                   ARID1A_Mutation  \
# Sample_ID
# S001                             [Wildtype_Tumor]
# S002                             [Wildtype_Tumor]
# S003                             [Wildtype_Tumor]
# S004                             [Wildtype_Tumor]
# S005                             [Wildtype_Tumor]
# S006                             [Wildtype_Tumor]
# S007                             [Wildtype_Tumor]
# S008                             [Wildtype_Tumor]
# S009                             [Wildtype_Tumor]
# S011                             [Wildtype_Tumor]
# S013                             [Wildtype_Tumor]
# S015                             [Wildtype_Tumor]
# S016                             [Wildtype_Tumor]
# S017                             [Wildtype_Tumor]
# S018                             [Wildtype_Tumor]
# S019                             [Wildtype_Tumor]
# S020                             [Wildtype_Tumor]
# S022                             [Wildtype_Tumor]
# S023                             [Wildtype_Tumor]
# S024                             [Wildtype_Tumor]
# S025                             [Wildtype_Tumor]
# S026                          [Missense_Mutation]
# S027                             [Wildtype_Tumor]
# S028                             [Wildtype_Tumor]
# S029                             [Wildtype_Tumor]
# S030                             [Wildtype_Tumor]
# S031                             [Wildtype_Tumor]
# S032                             [Wildtype_Tumor]
# S033                             [Wildtype_Tumor]
# S034                             [Wildtype_Tumor]
# ...                                           ...
# S078           [Frame_Shift_Del, Frame_Shift_Del]
# S079                             [Wildtype_Tumor]
# S080       [Missense_Mutation, Nonsense_Mutation]
# S084                             [Wildtype_Tumor]
# S085                             [Wildtype_Tumor]
# S087                             [Wildtype_Tumor]
# S088                             [Wildtype_Tumor]
# S089                             [Wildtype_Tumor]
# S090                             [Wildtype_Tumor]
# S091                             [Wildtype_Tumor]
# S092                             [Wildtype_Tumor]
# S093                             [Wildtype_Tumor]
# S094                             [Wildtype_Tumor]
# S095                             [Wildtype_Tumor]
# S096                             [Wildtype_Tumor]
# S097                             [Wildtype_Tumor]
# S098                             [Wildtype_Tumor]
# S099                             [Wildtype_Tumor]
# S100                             [Wildtype_Tumor]
# S101                             [Wildtype_Tumor]
# S102                             [Wildtype_Tumor]
# S103                             [Wildtype_Tumor]
# S104                             [Wildtype_Tumor]
# S105                             [Wildtype_Tumor]
# S106                             [Wildtype_Tumor]
# S107                             [Wildtype_Tumor]
# S108                             [Wildtype_Tumor]
# S109                             [Wildtype_Tumor]
# S110                             [Wildtype_Tumor]
# S111                             [Wildtype_Tumor]
#
#                          ARID1A_Location ARID1A_Mutation_Status Sample_Status
# Sample_ID
# S001                       [No_mutation]         Wildtype_Tumor         Tumor
# S002                       [No_mutation]         Wildtype_Tumor         Tumor
# S003                       [No_mutation]         Wildtype_Tumor         Tumor
# S004                       [No_mutation]         Wildtype_Tumor         Tumor
# S005                       [No_mutation]         Wildtype_Tumor         Tumor
# S006                       [No_mutation]         Wildtype_Tumor         Tumor
# S007                       [No_mutation]         Wildtype_Tumor         Tumor
# S008                       [No_mutation]         Wildtype_Tumor         Tumor
# S009                       [No_mutation]         Wildtype_Tumor         Tumor
# S011                       [No_mutation]         Wildtype_Tumor         Tumor
# S013                       [No_mutation]         Wildtype_Tumor         Tumor
# S015                       [No_mutation]         Wildtype_Tumor         Tumor
# S016                       [No_mutation]         Wildtype_Tumor         Tumor
# S017                       [No_mutation]         Wildtype_Tumor         Tumor
# S018                       [No_mutation]         Wildtype_Tumor         Tumor
# S019                       [No_mutation]         Wildtype_Tumor         Tumor
# S020                       [No_mutation]         Wildtype_Tumor         Tumor
# S022                       [No_mutation]         Wildtype_Tumor         Tumor
# S023                       [No_mutation]         Wildtype_Tumor         Tumor
# S024                       [No_mutation]         Wildtype_Tumor         Tumor
# S025                       [No_mutation]         Wildtype_Tumor         Tumor
# S026                          [p.I1625T]        Single_mutation         Tumor
# S027                       [No_mutation]         Wildtype_Tumor         Tumor
# S028                       [No_mutation]         Wildtype_Tumor         Tumor
# S029                       [No_mutation]         Wildtype_Tumor         Tumor
# S030                       [No_mutation]         Wildtype_Tumor         Tumor
# S031                       [No_mutation]         Wildtype_Tumor         Tumor
# S032                       [No_mutation]         Wildtype_Tumor         Tumor
# S033                       [No_mutation]         Wildtype_Tumor         Tumor
# S034                       [No_mutation]         Wildtype_Tumor         Tumor
# ...                                  ...                    ...           ...
# S078       [p.Q1519Rfs*8, p.F2141Sfs*59]      Multiple_mutation         Tumor
# S079                       [No_mutation]         Wildtype_Tumor         Tumor
# S080                  [p.S202Y, p.E992*]      Multiple_mutation         Tumor
# S084                       [No_mutation]         Wildtype_Tumor         Tumor
# S085                       [No_mutation]         Wildtype_Tumor         Tumor
# S087                       [No_mutation]         Wildtype_Tumor         Tumor
# S088                       [No_mutation]         Wildtype_Tumor         Tumor
# S089                       [No_mutation]         Wildtype_Tumor         Tumor
# S090                       [No_mutation]         Wildtype_Tumor         Tumor
# S091                       [No_mutation]         Wildtype_Tumor         Tumor
# S092                       [No_mutation]         Wildtype_Tumor         Tumor
# S093                       [No_mutation]         Wildtype_Tumor         Tumor
# S094                       [No_mutation]         Wildtype_Tumor         Tumor
# S095                       [No_mutation]         Wildtype_Tumor         Tumor
# S096                       [No_mutation]         Wildtype_Tumor         Tumor
# S097                       [No_mutation]         Wildtype_Tumor         Tumor
# S098                       [No_mutation]         Wildtype_Tumor         Tumor
# S099                       [No_mutation]         Wildtype_Tumor         Tumor
# S100                       [No_mutation]         Wildtype_Tumor         Tumor
# S101                       [No_mutation]         Wildtype_Tumor         Tumor
# S102                       [No_mutation]         Wildtype_Tumor         Tumor
# S103                       [No_mutation]         Wildtype_Tumor         Tumor
# S104                       [No_mutation]         Wildtype_Tumor         Tumor
# S105                       [No_mutation]         Wildtype_Tumor         Tumor
# S106                       [No_mutation]         Wildtype_Tumor         Tumor
# S107                       [No_mutation]         Wildtype_Tumor         Tumor
# S108                       [No_mutation]         Wildtype_Tumor         Tumor
# S109                       [No_mutation]         Wildtype_Tumor         Tumor
# S110                       [No_mutation]         Wildtype_Tumor         Tumor
# S111                       [No_mutation]         Wildtype_Tumor         Tumor
#
# [101 rows x 6 columns]

# %%
mutateddf = transcript_df.loc[transcript_df['ARID1A_Mutation_Status'] != 'Wildtype_Tumor']
mutateddf
# Out:
#            OLFM4_transcriptomics  PIGR_transcriptomics  \
# Sample_ID
# S026                    0.187611             71.281600
# S044                    0.142194              0.286387
# S078                   34.268400             25.117600
# S080                  174.078000            224.109000
#
#                                   ARID1A_Mutation  \
# Sample_ID
# S026                          [Missense_Mutation]
# S044                          [Missense_Mutation]
# S078           [Frame_Shift_Del, Frame_Shift_Del]
# S080       [Missense_Mutation, Nonsense_Mutation]
#
#                          ARID1A_Location ARID1A_Mutation_Status Sample_Status
# Sample_ID
# S026                          [p.I1625T]        Single_mutation         Tumor
# S044                          [p.A1946P]        Single_mutation         Tumor
# S078       [p.Q1519Rfs*8, p.F2141Sfs*59]      Multiple_mutation         Tumor
# S080                  [p.S202Y, p.E992*]      Multiple_mutation         Tumor

# %% [markdown]
# Very few ARID1A Mutation in Ovarian Cancer (But seems to have a large effect)?
