# %% [markdown]
# # Comparing effect of MUC5B Mutation in Colon cancer on Transcriptomics and Proteomics

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections
import re
import gseapy as gp
from gseapy.plot import barplot, dotplot
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

import cptac
import cptac.algorithms as al

co = cptac.Colon()

# %% [markdown]
# ### Specify Mutation Gene

# %%
mutation_gene = 'MUC5B'

# %% [markdown]
# ### Read in Trans Results and filter for Colon cancer and MUC5B Mutation

# %%
#Read in Results of Trans Analysis
Trans_Results = pd.read_csv("Formatted_Trans_Results.csv")

#Filter for only Colon cancer, and only MUC5B Mutation
Colon = Trans_Results.loc[Trans_Results['Cancer_Type'] == 'Colon']
MUC5B_Colon = Colon.loc[Colon['Mutation_Gene'] == mutation_gene]

# %% [markdown]
# ### Split proteomics and transcriptomics

# %%
MUC5B_Colon_Prot = MUC5B_Colon.loc[MUC5B_Colon['Omics'] == 'proteomics']
MUC5B_Colon_Trans = MUC5B_Colon.loc[MUC5B_Colon['Omics'] == 'transcriptomics']

# %% [markdown]
# ### Display proteomics

# %%
print(len(MUC5B_Colon_Prot))
MUC5B_Colon_Prot
# Out:
# 38
#     Cancer_Type Mutation_Gene  Protein Site       Omics  Interacting_Protein  \
# 617       Colon         MUC5B     PCK2  NaN  proteomics                 True
# 618       Colon         MUC5B    MRE11  NaN  proteomics                False
# 619       Colon         MUC5B     GPX2  NaN  proteomics                False
# 620       Colon         MUC5B   ANP32E  NaN  proteomics                False
# 621       Colon         MUC5B    KRT20  NaN  proteomics                False
# 622       Colon         MUC5B    RAD50  NaN  proteomics                False
# 623       Colon         MUC5B    PRDX5  NaN  proteomics                False
# 624       Colon         MUC5B  ARHGEF2  NaN  proteomics                False
# 625       Colon         MUC5B    NFKB2  NaN  proteomics                False
# 626       Colon         MUC5B   MRPS31  NaN  proteomics                False
# 627       Colon         MUC5B    PCSK9  NaN  proteomics                False
# 628       Colon         MUC5B    HNF4A  NaN  proteomics                False
# 629       Colon         MUC5B      VTN  NaN  proteomics                False
# 630       Colon         MUC5B   MYO15B  NaN  proteomics                False
# 631       Colon         MUC5B    NUBPL  NaN  proteomics                False
# 632       Colon         MUC5B   FUNDC1  NaN  proteomics                False
# 633       Colon         MUC5B    ACSL5  NaN  proteomics                False
# 634       Colon         MUC5B     ACE2  NaN  proteomics                False
# 635       Colon         MUC5B   GALNT1  NaN  proteomics                False
# 636       Colon         MUC5B     A1CF  NaN  proteomics                False
# 637       Colon         MUC5B  TFCP2L1  NaN  proteomics                False
# 638       Colon         MUC5B  SLC16A3  NaN  proteomics                False
# 639       Colon         MUC5B  PLA2G4A  NaN  proteomics                False
# 640       Colon         MUC5B    AIFM1  NaN  proteomics                False
# 641       Colon         MUC5B     GYS1  NaN  proteomics                False
# 642       Colon         MUC5B   ENGASE  NaN  proteomics                False
# 643       Colon         MUC5B      PKM  NaN  proteomics                False
# 644       Colon         MUC5B   SMCHD1  NaN  proteomics                False
# 645       Colon         MUC5B  ARHGEF1  NaN  proteomics                False
# 646       Colon         MUC5B      C8A  NaN  proteomics                False
# 647       Colon         MUC5B    ALDH2  NaN  proteomics                False
# 648       Colon         MUC5B       F9  NaN  proteomics                False
# 649       Colon         MUC5B     VAPB  NaN  proteomics                False
# 650       Colon         MUC5B    SSFA2  NaN  proteomics                False
# 651       Colon         MUC5B    MMS19  NaN  proteomics                False
# 652       Colon         MUC5B    CFHR5  NaN  proteomics                False
# 653       Colon         MUC5B       C7  NaN  proteomics                False
# 654       Colon         MUC5B     RIDA  NaN  proteomics                False
#
#           P_Value
# 617  1.136850e-05
# 618  1.144045e-10
# 619  5.988006e-10
# 620  3.042503e-09
# 621  3.969811e-09
# 622  9.817991e-09
# 623  5.077905e-08
# 624  7.919124e-08
# 625  1.471187e-07
# 626  3.790579e-07
# 627  4.405533e-07
# 628  6.761123e-07
# 629  8.848484e-07
# 630  9.027894e-07
# 631  9.960365e-07
# 632  1.025502e-06
# 633  1.289272e-06
# 634  1.332648e-06
# 635  1.374055e-06
# 636  1.503580e-06
# 637  1.666901e-06
# 638  2.262895e-06
# 639  2.320262e-06
# 640  2.482703e-06
# 641  2.763100e-06
# 642  2.794402e-06
# 643  3.085404e-06
# 644  3.179521e-06
# 645  3.802987e-06
# 646  4.031319e-06
# 647  4.510004e-06
# 648  4.895850e-06
# 649  4.916239e-06
# 650  4.989103e-06
# 651  5.148296e-06
# 652  5.171754e-06
# 653  5.632118e-06
# 654  6.171126e-06

# %% [markdown]
# ### Display transcriptomics

# %%
print(len(MUC5B_Colon_Trans))
MUC5B_Colon_Trans
# Out:
# 82
#     Cancer_Type Mutation_Gene      Protein Site            Omics  \
# 655       Colon         MUC5B        MUC20  NaN  transcriptomics
# 656       Colon         MUC5B        FRMD1  NaN  transcriptomics
# 657       Colon         MUC5B      ST6GAL1  NaN  transcriptomics
# 658       Colon         MUC5B        MUC12  NaN  transcriptomics
# 659       Colon         MUC5B   ST6GALNAC2  NaN  transcriptomics
# 661       Colon         MUC5B         GPX2  NaN  transcriptomics
# 662       Colon         MUC5B      POU5F1B  NaN  transcriptomics
# 663       Colon         MUC5B       RUBCNL  NaN  transcriptomics
# 664       Colon         MUC5B       ATP10B  NaN  transcriptomics
# 665       Colon         MUC5B        NUBPL  NaN  transcriptomics
# 666       Colon         MUC5B      CEACAM5  NaN  transcriptomics
# 667       Colon         MUC5B      CEACAM6  NaN  transcriptomics
# 668       Colon         MUC5B        ADNP2  NaN  transcriptomics
# 669       Colon         MUC5B   DLGAP1-AS2  NaN  transcriptomics
# 670       Colon         MUC5B     TOR1AIP2  NaN  transcriptomics
# 671       Colon         MUC5B         GRM8  NaN  transcriptomics
# 672       Colon         MUC5B       LY6G6D  NaN  transcriptomics
# 673       Colon         MUC5B        CCSAP  NaN  transcriptomics
# 674       Colon         MUC5B        EPDR1  NaN  transcriptomics
# 675       Colon         MUC5B         ACE2  NaN  transcriptomics
# 676       Colon         MUC5B        NR1I2  NaN  transcriptomics
# 677       Colon         MUC5B       MAPK12  NaN  transcriptomics
# 678       Colon         MUC5B       CASC21  NaN  transcriptomics
# 679       Colon         MUC5B    LINC00513  NaN  transcriptomics
# 680       Colon         MUC5B       GPR143  NaN  transcriptomics
# 681       Colon         MUC5B        PIAS2  NaN  transcriptomics
# 682       Colon         MUC5B    LINC01560  NaN  transcriptomics
# 683       Colon         MUC5B  THUMPD3-AS1  NaN  transcriptomics
# 684       Colon         MUC5B     SLC25A13  NaN  transcriptomics
# 685       Colon         MUC5B        CXXC1  NaN  transcriptomics
# ..          ...           ...          ...  ...              ...
# 708       Colon         MUC5B        MRE11  NaN  transcriptomics
# 709       Colon         MUC5B         PIGX  NaN  transcriptomics
# 710       Colon         MUC5B          MBP  NaN  transcriptomics
# 711       Colon         MUC5B        MYZAP  NaN  transcriptomics
# 712       Colon         MUC5B        PRAP1  NaN  transcriptomics
# 713       Colon         MUC5B       SEMA5A  NaN  transcriptomics
# 714       Colon         MUC5B       THRAP3  NaN  transcriptomics
# 715       Colon         MUC5B         MLH1  NaN  transcriptomics
# 716       Colon         MUC5B        DDX27  NaN  transcriptomics
# 717       Colon         MUC5B         LMNA  NaN  transcriptomics
# 718       Colon         MUC5B       SLC3A1  NaN  transcriptomics
# 719       Colon         MUC5B        LIN54  NaN  transcriptomics
# 720       Colon         MUC5B         IER5  NaN  transcriptomics
# 721       Colon         MUC5B         RAC3  NaN  transcriptomics
# 722       Colon         MUC5B        KIF14  NaN  transcriptomics
# 723       Colon         MUC5B       GUCY2C  NaN  transcriptomics
# 724       Colon         MUC5B        SOCS6  NaN  transcriptomics
# 725       Colon         MUC5B         VAPB  NaN  transcriptomics
# 726       Colon         MUC5B         QPRT  NaN  transcriptomics
# 727       Colon         MUC5B        ATP9A  NaN  transcriptomics
# 728       Colon         MUC5B        CRAT8  NaN  transcriptomics
# 729       Colon         MUC5B         TYMS  NaN  transcriptomics
# 730       Colon         MUC5B      CXorf23  NaN  transcriptomics
# 731       Colon         MUC5B      SPATA25  NaN  transcriptomics
# 732       Colon         MUC5B       POFUT1  NaN  transcriptomics
# 733       Colon         MUC5B         AAR2  NaN  transcriptomics
# 734       Colon         MUC5B       ZNF737  NaN  transcriptomics
# 735       Colon         MUC5B    LINC01006  NaN  transcriptomics
# 736       Colon         MUC5B        RNF43  NaN  transcriptomics
# 737       Colon         MUC5B        GSPT2  NaN  transcriptomics
#
#      Interacting_Protein       P_Value
# 655                 True  4.319530e-06
# 656                 True  1.340157e-05
# 657                 True  6.725471e-05
# 658                 True  1.108167e-04
# 659                 True  6.152779e-04
# 661                False  1.758001e-10
# 662                False  4.688794e-10
# 663                False  1.541604e-09
# 664                False  3.068562e-09
# 665                False  3.884908e-09
# 666                False  6.870982e-09
# 667                False  9.942373e-09
# 668                False  1.155737e-08
# 669                False  1.221313e-08
# 670                False  1.275600e-08
# 671                False  1.851409e-08
# 672                False  2.788723e-08
# 673                False  3.180643e-08
# 674                False  3.808045e-08
# 675                False  4.376884e-08
# 676                False  4.771506e-08
# 677                False  5.517810e-08
# 678                False  5.951666e-08
# 679                False  9.176024e-08
# 680                False  1.071900e-07
# 681                False  1.264160e-07
# 682                False  1.514142e-07
# 683                False  1.689576e-07
# 684                False  1.864544e-07
# 685                False  2.088444e-07
# ..                   ...           ...
# 708                False  1.403404e-06
# 709                False  1.418377e-06
# 710                False  1.546044e-06
# 711                False  1.561001e-06
# 712                False  1.692921e-06
# 713                False  1.824961e-06
# 714                False  2.186983e-06
# 715                False  2.270186e-06
# 716                False  2.290637e-06
# 717                False  2.326658e-06
# 718                False  2.421983e-06
# 719                False  2.553519e-06
# 720                False  2.572737e-06
# 721                False  2.702800e-06
# 722                False  2.727888e-06
# 723                False  2.736175e-06
# 724                False  2.843641e-06
# 725                False  2.907669e-06
# 726                False  2.953795e-06
# 727                False  2.977994e-06
# 728                False  3.196294e-06
# 729                False  3.330010e-06
# 730                False  3.369104e-06
# 731                False  3.383985e-06
# 732                False  3.506052e-06
# 733                False  3.522057e-06
# 734                False  3.535392e-06
# 735                False  3.607070e-06
# 736                False  3.665086e-06
# 737                False  3.699970e-06
#
# [82 rows x 7 columns]

# %% [markdown]
# <br><br>When MUC5B is mutated in colon cancer, 82 transcripts are significantly altered, yet only 38 proteomics <br><br>

# %% [markdown]
# ### Generate lists of proteins significantly altered in proteomic expression and transcript expression when MUC5B mutated

# %%
prots_MUC5B_Colon = list(MUC5B_Colon_Prot['Protein'])
rna_MUC5B_Colon = list(MUC5B_Colon_Trans['Protein'])

# %% [markdown]
# ### Determine which proteins are present in both lists

# %%
both_proteomic_and_transcriptomic = []

#List proteins in both 
for pro in prots_MUC5B_Colon:
    if pro in rna_MUC5B_Colon:
        both_proteomic_and_transcriptomic.append(pro)
        print(pro)
# Out:
# MRE11
# GPX2
# ANP32E
# KRT20
# NUBPL
# ACE2
# PLA2G4A
# VAPB

# %% [markdown]
# ### Make plot illustrating $Δ$ transcriptomics and  $Δ$ proteomics in the above genes when MUC5B is mutated

# %% [markdown]
# ### Compute $Δ$ proteomics for above proteins

# %%
delta_proteomics = {}

#Loop through proteins found in both lists
for prot in both_proteomic_and_transcriptomic:
    #Use join omics to mutations to compare proteomic levels when mutation gene is mutated
    proteomic_df = co.join_omics_to_mutations(mutations_genes=mutation_gene, omics_df_name='proteomics',omics_genes=prot)
    
    #Use only Tumor samples
    proteomic_df = proteomic_df.loc[proteomic_df['Sample_Status'] == 'Tumor']
    
    #Split into mutated and wildtype groups
    mutated_df = proteomic_df.loc[proteomic_df[mutation_gene + '_Mutation_Status'] != 'Wildtype_Tumor']
    wt_df = proteomic_df.loc[proteomic_df[mutation_gene + '_Mutation_Status'] == 'Wildtype_Tumor']
    
    #Compute mean proteomic values for both mutated and wildtype groups
    mutated_mean = np.mean(mutated_df[prot + '_proteomics'])
    wt_mean = np.mean(wt_df[prot + '_proteomics'])
    
    #Compute Delta (mutated mean - wildtype mean) proteomic value
    delta = mutated_mean - wt_mean
    
    #Store values in Dictionary
    delta_proteomics[prot] = delta

# %% [markdown]
# ### Print $Δ$ proteomics

# %%
delta_proteomics
# Out:
# {'MRE11': -0.49227150595882985,
#  'GPX2': -0.9922851029252437,
#  'ANP32E': 0.49580552546045514,
#  'KRT20': -1.12995872156013,
#  'NUBPL': -0.6704825027085591,
#  'ACE2': -1.087971111111111,
#  'PLA2G4A': 0.7175556818181816,
#  'VAPB': -0.3720879739978331}

# %% [markdown]
# ### Compute $Δ$ transcriptomics for above proteins

# %%
delta_transcriptomics = {}

#Loop through proteins found in both lists
for prot in both_proteomic_and_transcriptomic:
    #Use join omics to mutations to compare transcript levels when mutation gene is mutated
    transcript_df = co.join_omics_to_mutations(mutations_genes=mutation_gene, omics_df_name='transcriptomics',omics_genes=prot)
    
    #Use only Tumor samples
    transcript_df = transcript_df.loc[transcript_df['Sample_Status'] == 'Tumor']
    
    #Split into mutated and wildtype groups
    mutated_df = transcript_df.loc[transcript_df[mutation_gene + '_Mutation_Status'] != 'Wildtype_Tumor']
    wt_df = transcript_df.loc[transcript_df[mutation_gene + '_Mutation_Status'] == 'Wildtype_Tumor']
    
    #Compute mean transcriptomic values for both mutated and wildtype groups
    mutated_mean = np.mean(mutated_df[prot + '_transcriptomics'])
    wt_mean = np.mean(wt_df[prot + '_transcriptomics'])
    
    #Compute Delta (mutated mean - wildtype mean) transcriptomics value
    delta = mutated_mean - wt_mean
    
    #Store values in Dictionary
    delta_transcriptomics[prot] = delta

# %% [markdown]
# ### Print $Δ$ transcriptomics

# %%
delta_transcriptomics
# Out:
# {'MRE11': -0.46507224566338756,
#  'GPX2': -1.3991120956399463,
#  'ANP32E': 0.7669377871542409,
#  'KRT20': -1.5011769807782471,
#  'NUBPL': -0.7866076887013591,
#  'ACE2': -2.4860568682606665,
#  'PLA2G4A': 1.7358417252695784,
#  'VAPB': -0.5147527894983579}

# %% [markdown]
# ## Illustrate $Δ$ proteomics and $Δ$ transcriptomics in a plot

# %% [markdown]
# ### Format data in dataframe

# %%
#Make Pandas Dataframe
delta_proteomic_transcriptomic_df = pd.DataFrame(columns=['Protein','Delta_Proteomics','Delta_Transcriptomics'])

#Fill with values from delta proteomics and delta transcriptomics dictionaries
for key, val in delta_proteomics.items():
    delta_proteomic_transcriptomic_df = delta_proteomic_transcriptomic_df.append({'Protein':key, 'Delta_Proteomics':val,'Delta_Transcriptomics':delta_transcriptomics[key]}, ignore_index = True)

# %%
delta_proteomic_transcriptomic_df
# Out:
#    Protein  Delta_Proteomics  Delta_Transcriptomics
# 0    MRE11         -0.492272              -0.465072
# 1     GPX2         -0.992285              -1.399112
# 2   ANP32E          0.495806               0.766938
# 3    KRT20         -1.129959              -1.501177
# 4    NUBPL         -0.670483              -0.786608
# 5     ACE2         -1.087971              -2.486057
# 6  PLA2G4A          0.717556               1.735842
# 7     VAPB         -0.372088              -0.514753

# %% [markdown]
# ### Plot $Δ$ proteomics and $Δ$ transcriptomics in a scatter plot, along with line $ y = x $

# %%
scatter_plot = sns.scatterplot(data=delta_proteomic_transcriptomic_df, x='Delta_Transcriptomics', y='Delta_Proteomics')
plt.plot([-3, 3], [-3, 3], linewidth=1, color='red')
