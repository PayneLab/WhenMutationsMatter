# %% [markdown]
# # PIK3CA Mutation Trans Effect on Phosphoproteomics

# %% [markdown]
# This notebook analyzes the trans effect of PIK3CA mutation on interacting and other proteins Phosphoproteomics, in Endometrial, Colon, and Ovarian cancer.

# %% [markdown]
# ### Library Imports

# %%
import pandas as pd
import numpy as np
import scipy.stats
import collections
import re
import gseapy as gp
from gseapy.plot import barplot, dotplot
import matplotlib.pyplot as plt
import seaborn as sns

import cptac
import cptac.algorithms as al

en = cptac.Endometrial()
co = cptac.Colon()
ov = cptac.Ovarian()

# %% [markdown]
# ### Select Gene

# %%
gene = "PIK3CA"

# %% [markdown]
# ### Investigate Proteomics, Phosphoproteomics, Acetylproteomics, or Transcriptomics

# %%
#omics = "proteomics"
#omics = "transcriptomics"
omics = "phosphoproteomics"
#omics = "acetylproteomics"

# %% [markdown]
# # Interacting Proteins: Transcriptomics

# %% [markdown]
# ## Endometrial

# %% [markdown]
# ### Generate interacting protein list

# %%
'''Use get interacting proteins method to generate list of interacting proteins'''
interacting_proteins = al.get_interacting_proteins(gene)

omics_object = en.get_phosphoproteomics()

print("Generating interacting protein list")
interacting_proteins_in_omics_df = []

'''Only do comparisons on proteins in the omics dataframe'''
for ip in interacting_proteins:
    if omics == 'phosphoproteomics' or omics == 'acetylproteomics':
        col_regex = ip + "-.*" # Build a regex to get all columns that match the gene
    else:
        col_regex = '^{}$'.format(ip)

    selected = omics_object.filter(regex=col_regex)

    if len(selected.columns) > 0:
        interacting_proteins_in_omics_df.append(ip)

print("Interacting Proteins:")
for interacting_protein in interacting_proteins_in_omics_df:
    print(interacting_protein)
# Out:
# Generating interacting protein list
# Interacting Proteins:
# PIK3R2
# TNS1
# RPS6KB1
# KRAS
# PDGFRA
# AKT3
# PIK3CA
# ERBB3
# IGF1R
# ERBB2
# EGFR
# KIT
# IRS1
# CTNNB1
# NRAS
# PTEN
# IRS2
# AKT2
# ESR1
# PIK3R1
# AKT1
# ATR
# LCK
# NOTCH1
# DGKZ
# ARHGEF1
# GSN
# YWHAH
# UBTF

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins_in_omics_df)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)


'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
# Out:
# Doing t-test comparisons
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# No significant comparisons.

# %% [markdown]
# ## Colon

# %% [markdown]
# ### Generate interacting protein list

# %%
'''Use get interacting proteins method to generate list of interacting proteins'''
interacting_proteins = al.get_interacting_proteins(gene)

omics_object = co.get_phosphoproteomics()

print("Generating interacting protein list")
interacting_proteins_in_omics_df = []

'''Only do comparisons on proteins in the omics dataframe'''
for ip in interacting_proteins:
    if omics == 'phosphoproteomics' or omics == 'acetylproteomics':
        col_regex = ip + "_.*" # Build a regex to get all columns that match the gene
    else:
        col_regex = '^{}$'.format(ip)

    selected = omics_object.filter(regex=col_regex)

    if len(selected.columns) > 0:
        interacting_proteins_in_omics_df.append(ip)

print("Interacting Proteins:")
for interacting_protein in interacting_proteins_in_omics_df:
    print(interacting_protein)
# Out:
# Generating interacting protein list
# Interacting Proteins:
# PIK3R2
# TNS1
# RPS6KB1
# PDGFRA
# AKT3
# ERBB3
# ERBB2
# EGFR
# KIT
# IRS1
# CTNNB1
# PTEN
# IRS2
# AKT2
# PIK3R1
# AKT1
# ATR
# LCK
# NOTCH1
# DGKZ
# ARHGEF1
# GSN
# UBTF

# %% [markdown]
# ### Test for significant comparisons in any of interacting proteins

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins_in_omics_df)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
# Out:
# Warning: PIK3R2 did not match any columns in phosphoproteomics dataframe. PIK3R2_phosphoproteomics column inserted, but filled with NaN.
# Warning: TNS1 did not match any columns in phosphoproteomics dataframe. TNS1_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPS6KB1 did not match any columns in phosphoproteomics dataframe. RPS6KB1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PDGFRA did not match any columns in phosphoproteomics dataframe. PDGFRA_phosphoproteomics column inserted, but filled with NaN.
# Warning: AKT3 did not match any columns in phosphoproteomics dataframe. AKT3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ERBB3 did not match any columns in phosphoproteomics dataframe. ERBB3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ERBB2 did not match any columns in phosphoproteomics dataframe. ERBB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: EGFR did not match any columns in phosphoproteomics dataframe. EGFR_phosphoproteomics column inserted, but filled with NaN.
# Warning: KIT did not match any columns in phosphoproteomics dataframe. KIT_phosphoproteomics column inserted, but filled with NaN.
# Warning: IRS1 did not match any columns in phosphoproteomics dataframe. IRS1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CTNNB1 did not match any columns in phosphoproteomics dataframe. CTNNB1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTEN did not match any columns in phosphoproteomics dataframe. PTEN_phosphoproteomics column inserted, but filled with NaN.
# Warning: IRS2 did not match any columns in phosphoproteomics dataframe. IRS2_phosphoproteomics column inserted, but filled with NaN.
# Warning: AKT2 did not match any columns in phosphoproteomics dataframe. AKT2_phosphoproteomics column inserted, but filled with NaN.
# Warning: PIK3R1 did not match any columns in phosphoproteomics dataframe. PIK3R1_phosphoproteomics column inserted, but filled with NaN.
# Warning: AKT1 did not match any columns in phosphoproteomics dataframe. AKT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATR did not match any columns in phosphoproteomics dataframe. ATR_phosphoproteomics column inserted, but filled with NaN.
# Warning: LCK did not match any columns in phosphoproteomics dataframe. LCK_phosphoproteomics column inserted, but filled with NaN.
# Warning: NOTCH1 did not match any columns in phosphoproteomics dataframe. NOTCH1_phosphoproteomics column inserted, but filled with NaN.
# Warning: DGKZ did not match any columns in phosphoproteomics dataframe. DGKZ_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARHGEF1 did not match any columns in phosphoproteomics dataframe. ARHGEF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GSN did not match any columns in phosphoproteomics dataframe. GSN_phosphoproteomics column inserted, but filled with NaN.
# Warning: UBTF did not match any columns in phosphoproteomics dataframe. UBTF_phosphoproteomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Ovarian

# %% [markdown]
# ### Generate interacting protein list

# %%
'''Use get interacting proteins method to generate list of interacting proteins'''
interacting_proteins = al.get_interacting_proteins(gene)

omics_object = ov.get_phosphoproteomics()

print("Generating interacting protein list")
interacting_proteins_in_omics_df = []

'''Only do comparisons on proteins in the omics dataframe'''
for ip in interacting_proteins:
    if omics == 'phosphoproteomics' or omics == 'acetylproteomics':
        col_regex = ip + "-.*" # Build a regex to get all columns that match the gene
    else:
        col_regex = '^{}$'.format(ip)

    selected = omics_object.filter(regex=col_regex)

    if len(selected.columns) > 0:
        interacting_proteins_in_omics_df.append(ip)

print("Interacting Proteins:")
for interacting_protein in interacting_proteins_in_omics_df:
    print(interacting_protein)
# Out:
# Generating interacting protein list
# Interacting Proteins:
# PIK3R2
# TNS1
# RPS6KB1
# PDGFRA
# PIK3R3
# AKT3
# PIK3CA
# ERBB3
# IGF1R
# ERBB2
# EGFR
# KIT
# IRS1
# CTNNB1
# PTEN
# IRS2
# AKT2
# ESR1
# PIK3R1
# AKT1
# ATR
# LCK
# DGKZ
# ARHGEF1
# GSN
# YWHAH
# UBTF

# %%
'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=interacting_proteins_in_omics_df) 
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.loc[ind,'Label'] = 'Mutated'
    else:
        protdf.loc[ind,'Label'] = 'Wildtype'

'''Format the dataframe correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)
protdf = protdf.loc[:,~protdf.columns.duplicated()]

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
# Out:
# Doing t-test comparisons
#
# No significant comparisons.
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\fromnumeric.py:3367: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\brittany henderson\Anaconda3\envs\Research\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %% [markdown]
# # All Proteins: Phosphoproteomics

# %% [markdown]
# ## Endometrial

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''
    proteomics = en.get_proteomics()
    all_proteins = proteomics.columns
    #all_proteins = all_proteins[:100]

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = en.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=all_proteins)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")

except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  PIK3CA
# Warning: A1BG did not match any columns in phosphoproteomics dataframe. A1BG_phosphoproteomics column inserted, but filled with NaN.
# Warning: A2M did not match any columns in phosphoproteomics dataframe. A2M_phosphoproteomics column inserted, but filled with NaN.
# Warning: A2ML1 did not match any columns in phosphoproteomics dataframe. A2ML1_phosphoproteomics column inserted, but filled with NaN.
# Warning: A4GALT did not match any columns in phosphoproteomics dataframe. A4GALT_phosphoproteomics column inserted, but filled with NaN.
# Warning: AADAT did not match any columns in phosphoproteomics dataframe. AADAT_phosphoproteomics column inserted, but filled with NaN.
# Warning: AAMP did not match any columns in phosphoproteomics dataframe. AAMP_phosphoproteomics column inserted, but filled with NaN.
# Warning: AAR2 did not match any columns in phosphoproteomics dataframe. AAR2_phosphoproteomics column inserted, but filled with NaN.
# Warning: AARS2 did not match any columns in phosphoproteomics dataframe. AARS2_phosphoproteomics column inserted, but filled with NaN.
# Warning: AARSD1 did not match any columns in phosphoproteomics dataframe. AARSD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: AASDHPPT did not match any columns in phosphoproteomics dataframe. AASDHPPT_phosphoproteomics column inserted, but filled with NaN.
# Warning: AASS did not match any columns in phosphoproteomics dataframe. AASS_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABAT did not match any columns in phosphoproteomics dataframe. ABAT_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCA8 did not match any columns in phosphoproteomics dataframe. ABCA8_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCB10 did not match any columns in phosphoproteomics dataframe. ABCB10_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCB7 did not match any columns in phosphoproteomics dataframe. ABCB7_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCB8 did not match any columns in phosphoproteomics dataframe. ABCB8_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCC10 did not match any columns in phosphoproteomics dataframe. ABCC10_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCD1 did not match any columns in phosphoproteomics dataframe. ABCD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCD4 did not match any columns in phosphoproteomics dataframe. ABCD4_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCG1 did not match any columns in phosphoproteomics dataframe. ABCG1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD10 did not match any columns in phosphoproteomics dataframe. ABHD10_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD11 did not match any columns in phosphoproteomics dataframe. ABHD11_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD13 did not match any columns in phosphoproteomics dataframe. ABHD13_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD14A did not match any columns in phosphoproteomics dataframe. ABHD14A_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD14A-ACY1 did not match any columns in phosphoproteomics dataframe. ABHD14A-ACY1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD14B did not match any columns in phosphoproteomics dataframe. ABHD14B_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD17A did not match any columns in phosphoproteomics dataframe. ABHD17A_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD17B did not match any columns in phosphoproteomics dataframe. ABHD17B_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD17C did not match any columns in phosphoproteomics dataframe. ABHD17C_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD2 did not match any columns in phosphoproteomics dataframe. ABHD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD3 did not match any columns in phosphoproteomics dataframe. ABHD3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD4 did not match any columns in phosphoproteomics dataframe. ABHD4_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD5 did not match any columns in phosphoproteomics dataframe. ABHD5_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD6 did not match any columns in phosphoproteomics dataframe. ABHD6_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABO did not match any columns in phosphoproteomics dataframe. ABO_phosphoproteomics column inserted, but filled with NaN.
# Warning: 
phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF662 did not match any columns in phosphoproteomics dataframe. ZNF662_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF664 did not match any columns in phosphoproteomics dataframe. ZNF664_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF664-RFLNA did not match any columns in phosphoproteomics dataframe. ZNF664-RFLNA_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF688 did not match any columns in phosphoproteomics dataframe. ZNF688_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF69 did not match any columns in phosphoproteomics dataframe. ZNF69_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF7 did not match any columns in phosphoproteomics dataframe. ZNF7_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF701 did not match any columns in phosphoproteomics dataframe. ZNF701_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF706 did not match any columns in phosphoproteomics dataframe. ZNF706_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF713 did not match any columns in phosphoproteomics dataframe. ZNF713_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF737 did not match any columns in phosphoproteomics dataframe. ZNF737_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF76 did not match any columns in phosphoproteomics dataframe. ZNF76_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF771 did not match any columns in phosphoproteomics dataframe. ZNF771_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF772 did not match any columns in phosphoproteomics dataframe. ZNF772_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF773 did not match any columns in phosphoproteomics dataframe. ZNF773_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF776 did not match any columns in phosphoproteomics dataframe. ZNF776_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF79 did not match any columns in phosphoproteomics dataframe. ZNF79_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF805 did not match any columns in phosphoproteomics dataframe. ZNF805_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF813 did not match any columns in phosphoproteomics dataframe. ZNF813_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF816 did not match any columns in phosphoproteomics dataframe. ZNF816_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF845 did not match any columns in phosphoproteomics dataframe. ZNF845_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF888 did not match any columns in phosphoproteomics dataframe. ZNF888_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNRD1 did not match any columns in phosphoproteomics dataframe. ZNRD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZSCAN12 did not match any columns in phosphoproteomics dataframe. ZSCAN12_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZSCAN26 did not match any columns in phosphoproteomics dataframe. ZSCAN26_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZSWIM9 did not match any columns in phosphoproteomics dataframe. ZSWIM9_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZWILCH did not match any columns in phosphoproteomics dataframe. ZWILCH_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZWINT did not match any columns in phosphoproteomics dataframe. ZWINT_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZYG11B did not match any columns in phosphoproteomics dataframe. ZYG11B_phosphoproteomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Colon

# %%
try:
    print("\nGene: ", gene)

    '''Use all proteins'''
    proteomics = co.get_proteomics()
    all_proteins = proteomics.columns
    #all_proteins = all_proteins[:100]

    '''Create dataframe in order to do comparisons with wrap_ttest'''
    protdf = co.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=all_proteins)
    protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
    
    '''Create the binary valued column needed to do the comparison'''
    for ind, row in protdf.iterrows():
        if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
            protdf.at[ind,'Label'] = 'Mutated'
        else:
            protdf.at[ind,'Label'] = 'Wildtype'

    '''Format the datafram correctly'''
    protdf = protdf.drop(gene+"_Mutation",axis=1)
    protdf = protdf.drop(gene+"_Location",axis=1)
    protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
    protdf = protdf.drop("Sample_Status",axis=1)

    '''Make list of columns to be compared using t-tests'''
    col_list = list(protdf.columns)
    col_list.remove('Label')

    print("Doing t-test comparisons\n")
    
    '''Call wrap_ttest, pass in formatted dataframe'''
    wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

    '''Print results, if anything significant was found'''
    if wrap_results is not None:
            print(wrap_results)
            print("\n\n")

except Exception as e:
    print("Error in Comparison")
    print(e)
# Out:
# Gene:  PIK3CA
# Warning: A1BG did not match any columns in phosphoproteomics dataframe. A1BG_phosphoproteomics column inserted, but filled with NaN.
# Warning: A1CF did not match any columns in phosphoproteomics dataframe. A1CF_phosphoproteomics column inserted, but filled with NaN.
# Warning: A2M did not match any columns in phosphoproteomics dataframe. A2M_phosphoproteomics column inserted, but filled with NaN.
# Warning: A
2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZPR1 did not match any columns in phosphoproteomics dataframe. ZPR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZRANB2 did not match any columns in phosphoproteomics dataframe. ZRANB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZW10 did not match any columns in phosphoproteomics dataframe. ZW10_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZWILCH did not match any columns in phosphoproteomics dataframe. ZWILCH_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZWINT did not match any columns in phosphoproteomics dataframe. ZWINT_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZYX did not match any columns in phosphoproteomics dataframe. ZYX_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZZEF1 did not match any columns in phosphoproteomics dataframe. ZZEF1_phosphoproteomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Ovarian

# %%
print("\nGene: ", gene)

'''Use all proteins'''
proteomics = ov.get_proteomics()
all_proteins = list(set(proteomics.columns))

'''Create dataframe in order to do comparisons with wrap_ttest'''
protdf = ov.join_omics_to_mutations(mutations_genes=[gene], omics_df_name=omics, omics_genes=all_proteins)
protdf = protdf.loc[protdf['Sample_Status'] == 'Tumor']
protdf = protdf.loc[:,~protdf.columns.duplicated()]

'''Create the binary valued column needed to do the comparison'''
for ind, row in protdf.iterrows():
    if row[gene+"_Mutation_Status"] != 'Wildtype_Tumor':
        protdf.at[ind,'Label'] = 'Mutated'
    else:
        protdf.at[ind,'Label'] = 'Wildtype'

'''Format the datafram correctly'''
protdf = protdf.drop(gene+"_Mutation",axis=1)
protdf = protdf.drop(gene+"_Location",axis=1)
protdf = protdf.drop(gene+"_Mutation_Status", axis=1)
protdf = protdf.drop("Sample_Status",axis=1)

'''Make list of columns to be compared using t-tests'''
col_list = list(protdf.columns)
col_list.remove('Label')

print("Doing t-test comparisons\n")

'''Call wrap_ttest, pass in formatted dataframe'''
wrap_results = al.wrap_ttest(protdf, 'Label', col_list)

'''Print results, if anything significant was found'''
if wrap_results is not None:
        print(wrap_results)
        print("\n\n")
# Out:
# Gene:  PIK3CA
# Warning: POP4 did not match any columns in phosphoproteomics dataframe. POP4_phosphoproteomics column inserted, but filled with NaN.
# Warning: MSRB3 did not match any columns in phosphoproteomics dataframe. MSRB3_phosphoproteomics column inserted, but filled with NaN.
# Warning: GAA did not match any columns in phosphoproteomics dataframe. GAA_phosphoproteomics column inserted, but filled with NaN.
# Warning: HBM did not match any columns in phosphoproteomics dataframe. HBM_phosphoproteomics column inserted, but filled with NaN.
# Warning: NINJ2 did not match any columns in phosphoproteomics dataframe. NINJ2_phosphoproteomics column inserted, but filled with NaN.
# Warning: SH3YL1 did not match any columns in phosphoproteomics dataframe. SH3YL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: SPACA9 did not match any columns in phosphoproteomics dataframe. SPACA9_phosphoproteomics column inserted, but filled with NaN.
# Warning: DNA2 did not match any columns in phosphoproteomics dataframe. DNA2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPLP1 did not match any columns in phosphoproteomics dataframe. RPLP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ELANE did not match any columns in phosphoproteomics dataframe. ELANE_phosphoproteomics column inserted, but filled with NaN.
# Warning: CNPY3 did not match any columns in phosphoproteomics dataframe. CNPY3_phosphoproteomics column inserted, but filled with NaN.
# Warning: SFRP5 did not match any columns in phosphoproteomics dataframe. SFRP5_phosphoproteomics column inserted, but filled with NaN.
# Warning: N4BP2L1 did not match any columns in phosphoproteomics dataframe. N4BP2L1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PRIM1 did not match any columns in phosphoproteomics dataframe. PRIM1_phosphoproteomics column inserted, but filled with NaN.
# Warning: IGSF3 did not match any columns in phosphoproteomics dataframe. IGSF3_phosphoproteomics column inserted, but filled with NaN.
# Warning: GSTM3 did not match any columns in phosphoproteomics dataframe. GSTM3_phosphoproteomics column inserted, but filled with NaN.
# Warning: C16orf62 did not match any columns in phosphoproteomics dataframe. C16orf62_phosphoproteomics column inserted, but filled with NaN.
# Warning: FAAH did not match any columns in phosphoproteomics dataframe. FAAH_phosphoproteomics column inserted, but filled with NaN.
# Warning: INPP1 did not match any columns in phosphoproteomics dataframe. INPP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: YIF1A did not match any columns in phosphoproteomics dataframe. YIF1A_phosphoproteomics column inserted, but filled with NaN.
# Warning: MCU did not match any columns in phosphoproteomics dataframe. MCU_phosphoproteomics column inserted, but filled with NaN.
# Warning: LSM6 did not match any columns in phosphoproteomics dataframe. LSM6_phosphoproteomics column inserted, but filled with NaN.
# Warning: SS18L1 did not match any columns in phosphoproteomics dataframe. SS18L1_phosphoproteomics column inserted, but filled with NaN.
# Warning: HMX3 did not match any columns in phosphoproteomics dataframe. HMX3_phosphoproteomics column inserted, but filled with NaN.
# Warning: MMP10 did not match any columns in phosphoproteomics dataframe. MMP10_phosphoproteomics column inserted, but filled with NaN.
# Warning: CROT did not match any columns in phosphoproteomics dataframe. CROT_phosphoproteomics column inserted, but filled with NaN.
# Warning: RABGGTB did not match any columns in phosphoproteomics dataframe. RABGGTB_phosphoproteomics column inserted, but filled with NaN.
# Warning: VPS26A did not match any columns in phosphoproteomics dataframe. VPS26A_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZWINT did not match any columns in phosphoproteomics dataframe. ZWINT_phosphoproteomics column inserted, but filled with NaN.
# Warning: BSPRY did not match any columns in phosphoproteomics dataframe. BSPRY_phosphoproteomics column inserted, but filled with NaN.
# Warning: PRKRIP1 did not match any columns in phosphoproteomics dataframe. PRKRIP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MTHFD2 did not match any columns in phosphoproteomics dataframe. MTHFD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: WNT2B did not match any columns in phosphoproteomics dataframe. WNT2B_phosphoproteomics column inserted, but filled with NaN.
# Warning: RCBTB2 did not match any columns in phosphoproteomics dataframe. RCBTB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ALCAM did not match any columns in phosphoproteomics dataframe. ALCAM_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARF1 did not match any columns in phosphoproteomics dataframe. ARF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: IL4I1 did not match any columns in phosphoproteomics dataframe. IL4I1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CXCL12 did not match any columns in phosphoproteomics dataframe. CXCL12_phosphoproteomics column inserted, but filled with NaN.
# Warning: PCSK5 did not match any columns in phosphoproteomics dataframe. PCSK5_phosphoproteomics column inserted, but filled with NaN.
# Warning: HLTF did not match any columns in phosphoproteomics dataframe. HLTF_phosphoproteomics column inserted, but filled with NaN.
# Warning: LAMA3 did not match any columns in phosphoproteomics dataframe. LAMA3_phosphoproteomics column inserted, but filled with NaN.
# Warning: PINX1 did not match any columns in phosphoproteomics dataframe. PINX1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GORAB did not match any columns in phosphoproteomics dataframe. GORAB_phosphoproteomics column inserted, but filled with NaN.
# Warning: PAMR1 did not match any columns in phosphoproteomics dataframe. PAMR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMBIM6 did not match any columns in phosphoproteomics dataframe. TMBIM6_phosphoproteomics column inserted, but filled with NaN.
# Warning: PLCB1 did not match any columns in phosphoproteomics dataframe. PLCB1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZDHHC24 did not match any columns in phosphoproteomics dataframe. ZDHHC24_phosphoproteomics column inserted, but filled with NaN.
# Warning: HPSE2 did not match any columns in phosphoproteomics dataframe. HPSE2_phosphoproteomics column inserted, but filled with NaN.
# Warning: LY75-CD302 did not match any columns in phosphoproteomics dataframe. LY75-CD302_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARMC6 did not match any columns in phosphoproteomics dataframe. ARMC6_phosphoproteomics column inserted, but filled with NaN.
# Warning: CHRAC1 did not match any columns in phosphoproteomics dataframe. CHRAC1_phosphoproteomics column inserted, but filled with NaN.
# Warning: UBE2A did not match any columns in phosphoproteomics dataframe. UBE2A_phosphoproteomics column inserted, but filled with NaN.
# Warning: PPP5C did not match any columns in phosphoproteomics dataframe. PPP5C_phosphoproteomics column inserted, but filled with NaN.
# Warning: DHRS1 did not match any columns in phosphoproteomics dataframe. DHRS1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TNPO2 did not match any columns in phosphoproteomics dataframe. TNPO2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CTBS did not match any columns in phosphoproteomics dataframe. CTBS_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMEM19 did not match any columns in phosphoproteomics dataframe. TMEM19_phosphoproteomics column inserted, but filled with NaN.
# Warning: EFEMP1 did not match any columns in phosphoproteomics dataframe. EFEMP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: A1BG did not match any columns in phosphoproteomics dataframe. A1BG_phosphoproteomics column inserted, but filled with NaN.
# Warning: CRAT did not match any columns in phosphoproteomics dataframe. CRAT_phosphoproteomics column inserted, but filled with NaN.
# Warning: EXOSC10 did not match any columns in phosphoproteomics dataframe. EXOSC10_phosphoproteomics column inserted, but filled with NaN.
# Warning: FKBP10 did not match any columns in phosphoproteomics dataframe. FKBP10_phosphoproteomics column inserted, but filled with NaN.
# Warning: LRRC20 did not match any columns in phosphoproteomics dataframe. LRRC20_phosphoproteomics column inserted, but filled with NaN.
# Warning: KIF3A did not match any columns in phosphoproteomics dataframe. KIF3A_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF322 did not match any columns in phosphoproteomics dataframe. ZNF322_phosphoproteomics column inserted, but filled with NaN.
# Warning: PSMG4 did not match any columns in phosphoproteomics dataframe. PSMG4_phosphoproteomics column inserted, but filled with NaN.
# Warning: DPEP1 did not match any columns in phosphoproteomics dataframe. DPEP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: LANCL1 did not match any columns in phosphoproteomics dataframe. LANCL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: STAC3 did not match any columns in phosphoproteomics dataframe. STAC3_phosphoproteomics column inserted, but filled with NaN.
# Warning: EMC9 did not match any columns in phosphoproteomics dataframe. EMC9_phosphoproteomics column inserted, but filled with NaN.
# Warning: MAOA did not match any columns in phosphoproteomics dataframe. MAOA_phosphoproteomics column inserted, but filled with NaN.
# Warning: AMT did not match any columns in phosphoproteomics dataframe. AMT_phosphoproteomics column inserted, but filled with NaN.
# Warning: INTS4 did not match any columns in phosphoproteomics dataframe. INTS4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPL37A did not match any columns in phosphoproteomics dataframe. RPL37A_phosphoproteomics column inserted, but filled with NaN.
# Warning: RUFY3 did not match any columns in phosphoproteomics dataframe. RUFY3_phosphoproteomics column inserted, but filled with NaN.
# Warning: NIF3L1 did not match any columns in phosphoproteomics dataframe. NIF3L1_phosphoproteomics column inserted, but filled with NaN.
# Warning: RFWD2 did not match any columns in phosphoproteomics dataframe. RFWD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: DNAH5 did not match any columns in phosphoproteomics dataframe. DNAH5_phosphoproteomics column inserted, but filled with NaN.
# Warning: SHMT1 did not match any columns in phosphoproteomics dataframe. SHMT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: FER did not match any columns in phosphoproteomics dataframe. FER_phosphoproteomics column inserted, but filled with NaN.
# Warning: MTAP did not match any columns in phosphoproteomics dataframe. MTAP_phosphoproteomics column inserted, but filled with NaN.
# Warning: VBP1 did not match any columns in phosphoproteomics dataframe. VBP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ENOPH1 did not match any columns in phosphoproteomics dataframe. ENOPH1_phosphoproteomics column inserted, but filled with NaN.
# Warning: VPS18 did not match any columns in phosphoproteomics dataframe. VPS18_phosphoproteomics column inserted, but filled with NaN.
# Warning: FKBP1B did not match any columns in phosphoproteomics dataframe. FKBP1B_phosphoproteomics column inserted, but filled with NaN.
# Warning: RTCA did not match any columns in phosphoproteomics dataframe. RTCA_phosphoproteomics column inserted, but filled with NaN.
# Warning: IGSF8 did not match any columns in phosphoproteomics dataframe. IGSF8_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMTC1 did not match any columns in phosphoproteomics dataframe. TMTC1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ECHS1 did not match any columns in phosphoproteomics dataframe. ECHS1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TSEN15 did not match any columns in phosphoproteomics dataframe. TSEN15_phosphoproteomics column inserted, but filled with NaN.
# Warning: RFC5 did not match any columns in phosphoproteomics dataframe. RFC5_phosphoproteomics column inserted, but filled with NaN.
# Warning: GM2A did not match any columns in phosphoproteomics dataframe. GM2A_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZSCAN32 did not match any columns in phosphoproteomics dataframe. ZSCAN32_phosphoproteomics column inserted, but filled with NaN.
# Warning: PSMA3 did not match any columns in phosphoproteomics dataframe. PSMA3_phosphoproteomics column inserted, but filled with NaN.
# Warning: RNASE6 did not match any columns in phosphoproteomics dataframe. RNASE6_phosphoproteomics column inserted, but filled with NaN.
# Warning: SEZ6L2 did not match any columns in phosphoproteomics dataframe. SEZ6L2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF630 did not match any columns in phosphoproteomics dataframe. ZNF630_phosphoproteomics column inserted, but filled with NaN.
# Warning: F7 did not match any columns in phosphoproteomics dataframe. F7_phosphoproteomics column inserted, but filled with NaN.
# Warning: EIF4A1 did not match any columns in phosphoproteomics dataframe. EIF4A1_phosphoproteomics column inserted, but filled with NaN.
# Warning: LYPLAL1 did not match any columns in phosphoproteomics dataframe. LYPLAL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: SFXN2 did not match any columns in phosphoproteomics dataframe. SFXN2_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTBP2 did not match any columns in phosphoproteomics dataframe. PTBP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ING3 did not match any columns in phosphoproteomics dataframe. ING3_phosphoproteomics column inserted, but filled with NaN.
# Warning: LMBR1 did not match any columns in phosphoproteomics dataframe. LMBR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: BCHE did not match any columns in phosphoproteomics dataframe. BCHE_phosphoproteomics column inserted, but filled with NaN.
# Warning: PRSS33 did not match any columns in phosphoproteomics dataframe. PRSS33_phosphoproteomics column inserted, but filled with NaN.
# Warning: ALG1 did not match any columns in phosphoproteomics dataframe. ALG1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GSTK1 did not match any columns in phosphoproteomics dataframe. GSTK1_phosphoproteomics column inserted, but filled with NaN.
# Warning: LRP8 did not match any columns in phosphoproteomics dataframe. LRP8_phosphoproteomics column inserted, but filled with NaN.
# Warning: CCNDBP1 did not match any columns in phosphoproteomics dataframe. CCNDBP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TYW3 did not match any columns in phosphoproteomics dataframe. TYW3_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMPRSS3 did not match any columns in phosphoproteomics dataframe. TMPRSS3_phosphoproteomics column inserted, but filled with NaN.
# Warning: INPP5A did not match any columns in phosphoproteomics dataframe. INPP5A_phosphoproteomics column inserted, but filled with NaN.
# Warning: UBXN2A did not match any columns in phosphoproteomics dataframe. UBXN2A_phosphoproteomics column inserted, but filled with NaN.
# Warning: CACUL1 did not match any columns in phosphoproteomics dataframe. CACUL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TTC26 did not match any columns in phosphoproteomics dataframe. TTC26_phosphoproteomics column inserted, but filled with NaN.
# Warning: DTYMK did not match any columns in phosphoproteomics dataframe. DTYMK_phosphoproteomics column inserted, but filled with NaN.
# Warning: MT1G did not match any columns in phosphoproteomics dataframe. MT1G_phosphoproteomics column inserted, but filled with NaN.
# Warning: OAT did not match any columns in phosphoproteomics dataframe. OAT_phosphoproteomics column inserted, but filled with NaN.
# Warning: TM2D1 did not match any columns in phosphoproteomics dataframe. TM2D1_phosphoproteomics column inserted, but filled with NaN.
# Warning: EMC10 did not match any columns in phosphoproteomics dataframe. EMC10_phosphoproteomics column inserted, but filled with NaN.
# Warning: NDUFS5 did not match any columns in phosphoproteomics dataframe. NDUFS5_phosphoproteomics column inserted, but filled with NaN.
# Warning: USP30 did not match any columns in phosphoproteomics dataframe. USP30_phosphoproteomics column inserted, but filled with NaN.
# Warning: MLEC did not match any columns in phosphoproteomics dataframe. MLEC_phosphoproteomics column inserted, but filled with NaN.
# Warning: NQO1 did not match any columns in phosphoproteomics dataframe. NQO1_phosphoproteomics column inserted, but filled with NaN.
# Warning: SUPT4H1 did not match any columns in phosphoproteomics dataframe. SUPT4H1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PNMA3 did not match any columns in phosphoproteomics dataframe. PNMA3_phosphoproteomics column inserted, but filled with NaN.
# Warning: RINT1 did not match any columns in phosphoproteomics dataframe. RINT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MT-CO3 did not match any columns in phosphoproteomics dataframe. MT-CO3_phosphoproteomics column inserted, but filled with NaN.
# Warning: GALC did not match any columns in phosphoproteomics dataframe. GALC_phosphoproteomics column inserted, but filled with NaN.
# Warning: PADI4 did not match any columns in phosphoproteomics dataframe. PADI4_phosphoproteomics column inserted, but filled with NaN.
# Warning: SUMF1 did not match any columns in phosphoproteomics dataframe. SUMF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CTSA did not match any columns in phosphoproteomics dataframe. CTSA_phosphoproteomics column inserted, but filled with NaN.
# Warning: GSTT2B did not match any columns in phosphoproteomics dataframe. GSTT2B_phosphoproteomics column inserted, but filled with NaN.
# Warning: SORD did not match any columns in phosphoproteomics dataframe. SORD_phosphoproteomics column inserted, but filled with NaN.
# Warning: POLE3 did not match any columns in phosphoproteomics dataframe. POLE3_phosphoproteomics column inserted, but filled with NaN.
# Warning: GPRASP1 did not match any columns in phosphoproteomics dataframe. GPRASP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GLS2 did not match any columns in phosphoproteomics dataframe. GLS2_phosphoproteomics column inserted, but filled with NaN.
# Warning: NDUFV2 did not match any columns in phosphoproteomics dataframe. NDUFV2_phosphoproteomics column inserted, but filled with NaN.
# Warning: GDPGP1 did not match any columns in phosphoproteomics dataframe. GDPGP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: KLHL7 did not match any columns in phosphoproteomics dataframe. KLHL7_phosphoproteomics column inserted, but filled with NaN.
# Warning: CYP4B1 did not match any columns in phosphoproteomics dataframe. CYP4B1_phosphoproteomics column inserted, but filled with NaN.
# Warning: URGCP did not match any columns in phosphoproteomics dataframe. URGCP_phosphoproteomics column inserted, but filled with NaN.
# Warning: EIF5A did not match any columns in phosphoproteomics dataframe. EIF5A_phosphoproteomics column inserted, but filled with NaN.
# Warning: CTSZ did not match any columns in phosphoproteomics dataframe. CTSZ_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATP6V1D did not match any columns in phosphoproteomics dataframe. ATP6V1D_phosphoproteomics column inserted, but filled with NaN.
# Warning: RNLS did not match any columns in phosphoproteomics dataframe. RNLS_phosphoproteomics column inserted, but filled with NaN.
# Warning: DHRS4L2 did not match any columns in phosphoproteomics dataframe. DHRS4L2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATP13A2 did not match any columns in phosphoproteomics dataframe. ATP13A2_phosphoproteomics column inserted, but filled with NaN.
# Warning: KRT78 did not match any columns in phosphoproteomics dataframe. KRT78_phosphoproteomics column inserted, but filled with NaN.
# Warning: SCO2 did not match any columns in phosphoproteomics dataframe. SCO2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACY3 did not match any columns in phosphoproteomics dataframe. ACY3_phosphoproteomics column inserted, but filled with NaN.
# Warning: PSMG2 did not match any columns in phosphoproteomics dataframe. PSMG2_phosphoproteomics column inserted, but filled with NaN.
# Warning: METTL17 did not match any columns in phosphoproteomics dataframe. METTL17_phosphoproteomics column inserted, but filled with NaN.
# Warning: KIAA0907 did not match any columns in phosphoproteomics dataframe. KIAA0907_phosphoproteomics column inserted, but filled with NaN.
# Warning: B3GALT6 did not match any columns in phosphoproteomics dataframe. B3GALT6_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACOX3 did not match any columns in phosphoproteomics dataframe. ACOX3_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL14 did not match any columns in phosphoproteomics dataframe. MRPL14_phosphoproteomics column inserted, but filled with NaN.
# Warning: IFI44 did not match any columns in phosphoproteomics dataframe. IFI44_phosphoproteomics column inserted, but filled with NaN.
# Warning: CMA1 did not match any columns in phosphoproteomics dataframe. CMA1_phosphoproteomics column inserted, but filled with NaN.
# Warning: SDHB did not match any columns in phosphoproteomics dataframe. SDHB_phosphoproteomics column inserted, but filled with NaN.
# Warning: SCFD2 did not match any columns in phosphoproteomics dataframe. SCFD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARL5B did not match any columns in phosphoproteomics dataframe. ARL5B_phosphoproteomics column inserted, but filled with NaN.
# Warning: MMP19 did not match any columns in phosphoproteomics dataframe. MMP19_phosphoproteomics column inserted, but filled with NaN.
# Warning: OSGEPL1 did not match any columns in phosphoproteomics dataframe. OSGEPL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL23 did not match any columns in phosphoproteomics dataframe. MRPL23_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATG4C did not match any columns in phosphoproteomics dataframe. ATG4C_phosphoproteomics column inserted, but filled with NaN.
# Warning: MARCH5 did not match any columns in phosphoproteomics dataframe. MARCH5_phosphoproteomics column inserted, but filled with NaN.
# Warning: TYW5 did not match any columns in phosphoproteomics dataframe. TYW5_phosphoproteomics column inserted, but filled with NaN.
# Warning: SLC15A3 did not match any columns in phosphoproteomics dataframe. SLC15A3_phosphoproteomics column inserted, but filled with NaN.
# Warning: PGGT1B did not match any columns in phosphoproteomics dataframe. PGGT1B_phosphoproteomics column inserted, but filled with NaN.
# Warning: PBLD did not match any columns in phosphoproteomics dataframe. PBLD_phosphoproteomics column inserted, but filled with NaN.
# Warning: ADAM12 did not match any columns in phosphoproteomics dataframe. ADAM12_phosphoproteomics column inserted, but filled with NaN.
# Warning: C12orf57 did not match any columns in phosphoproteomics dataframe. C12orf57_phosphoproteomics column inserted, but filled with NaN.
# Warning: IDE did not match any columns in phosphoproteomics dataframe. IDE_phosphoproteomics column inserted, but filled with NaN.
# Warning: WDR45 did not match any columns in phosphoproteomics dataframe. WDR45_phosphoproteomics column inserted, but filled with NaN.
# Warning: MPP2 did not match any columns in phosphoproteomics dataframe. MPP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: GFOD2 did not match any columns in phosphoproteomics dataframe. GFOD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL48 did not match any columns in phosphoproteomics dataframe. MRPL48_phosphoproteomics column inserted, but filled with NaN.
# Warning: EPHA7 did not match any columns in phosphoproteomics dataframe. EPHA7_phosphoproteomics column inserted, but filled with NaN.
# Warning: C4orf33 did not match any columns in phosphoproteomics dataframe. C4orf33_phosphoproteomics column inserted, but filled with NaN.
# Warning: NSUN6 did not match any columns in phosphoproteomics dataframe. NSUN6_phosphoproteomics column inserted, but filled with NaN.
# Warning: AMN1 did not match any columns in phosphoproteomics dataframe. AMN1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CARD16 did not match any columns in phosphoproteomics dataframe. CARD16_phosphoproteomics column inserted, but filled with NaN.
# Warning: HPGD did not match any columns in phosphoproteomics dataframe. HPGD_phosphoproteomics column inserted, but filled with NaN.
# Warning: MGAT4B did not match any columns in phosphoproteomics dataframe. MGAT4B_phosphoproteomics column inserted, but filled with NaN.
# Warning: EPHX4 did not match any columns in phosphoproteomics dataframe. EPHX4_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARFRP1 did not match any columns in phosphoproteomics dataframe. ARFRP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: RHOT1 did not match any columns in phosphoproteomics dataframe. RHOT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ERP29 did not match any columns in phosphoproteomics dataframe. ERP29_phosphoproteomics column inserted, but filled with NaN.
# Warning: FXN did not match any columns in phosphoproteomics dataframe. FXN_phosphoproteomics column inserted, but filled with NaN.
# Warning: THSD7A did not match any columns in phosphoproteomics dataframe. THSD7A_phosphoproteomics column inserted, but filled with NaN.
# Warning: PPP1R21 did not match any columns in phosphoproteomics dataframe. PPP1R21_phosphoproteomics column inserted, but filled with NaN.
# Warning: ALG2 did not match any columns in phosphoproteomics dataframe. ALG2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RAP2A did not match any columns in phosphoproteomics dataframe. RAP2A_phosphoproteomics column inserted, but filled with NaN.
# Warning: C1QC did not match any columns in phosphoproteomics dataframe. C1QC_phosphoproteomics column inserted, but filled with NaN.
# Warning: BTBD2 did not match any columns in phosphoproteomics dataframe. BTBD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RHOF did not match any columns in phosphoproteomics dataframe. RHOF_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACAD9 did not match any columns in phosphoproteomics dataframe. ACAD9_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATPAF2 did not match any columns in phosphoproteomics dataframe. ATPAF2_phosphoproteomics column inserted, but filled with NaN.
# Warning: HAPLN1 did not match any columns in phosphoproteomics dataframe. HAPLN1_phosphoproteomics column inserted, but filled with NaN.
# Warning: OGFOD3 did not match any columns in phosphoproteomics dataframe. OGFOD3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ME1 did not match any columns in phosphoproteomics dataframe. ME1_phosphoproteomics column inserted, but filled with NaN.
# Warning: FBXO21 did not match any columns in phosphoproteomics dataframe. FBXO21_phosphoproteomics column inserted, but filled with NaN.
# Warning: SLC25A13 did not match any columns in phosphoproteomics dataframe. SLC25A13_phosphoproteomics column inserted, but filled with NaN.
# Warning: PXYLP1 did not match any columns in phosphoproteomics dataframe. PXYLP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTAR1 did not match any columns in phosphoproteomics dataframe. PTAR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: THBS3 did not match any columns in phosphoproteomics dataframe. THBS3_phosphoproteomics column inserted, but filled with NaN.
# Warning: SNF8 did not match any columns in phosphoproteomics dataframe. SNF8_phosphoproteomics column inserted, but filled with NaN.
# Warning: LYRM9 did not match any columns in phosphoproteomics dataframe. LYRM9_phosphoproteomics column inserted, but filled with NaN.
# Warning: FOXRED1 did not match any columns in phosphoproteomics dataframe. FOXRED1_phosphoproteomics column inserted, but filled with NaN.
# Warning: IGF1 did not match any columns in phosphoproteomics dataframe. IGF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: UCHL5 did not match any columns in phosphoproteomics dataframe. UCHL5_phosphoproteomics column inserted, but filled with NaN.
# Warning: PSMD5 did not match any columns in phosphoproteomics dataframe. PSMD5_phosphoproteomics column inserted, but filled with NaN.
# Warning: SYNE3 did not match any columns in phosphoproteomics dataframe. SYNE3_phosphoproteomics column inserted, but filled with NaN.
# Warning: C17orf58 did not match any columns in phosphoproteomics dataframe. C17orf58_phosphoproteomics column inserted, but filled with NaN.
# Warning: GTPBP2 did not match any columns in phosphoproteomics dataframe. GTPBP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MASP2 did not match any columns in phosphoproteomics dataframe. MASP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: NOXA1 did not match any columns in phosphoproteomics dataframe. NOXA1_phosphoproteomics column inserted, but filled with NaN.
# Warning: KATNB1 did not match any columns in phosphoproteomics dataframe. KATNB1_phosphoproteomics column inserted, but filled with NaN.
# Warning: OARD1 did not match any columns in phosphoproteomics dataframe. OARD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATXN10 did not match any columns in phosphoproteomics dataframe. ATXN10_phosphoproteomics column inserted, but filled with NaN.
# Warning: BCAT2 did not match any columns in phosphoproteomics dataframe. BCAT2_phosphoproteomics column inserted, but filled with NaN.
# Warning: SLC35D1 did not match any columns in phosphoproteomics dataframe. SLC35D1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MMRN1 did not match any columns in phosphoproteomics dataframe. MMRN1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZBTB2 did not match any columns in phosphoproteomics dataframe. ZBTB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: TIPIN did not match any columns in phosphoproteomics dataframe. TIPIN_phosphoproteomics column inserted, but filled with NaN.
# Warning: BRI3BP did not match any columns in phosphoproteomics dataframe. BRI3BP_phosphoproteomics column inserted, but filled with NaN.
# Warning: PCDHB8 did not match any columns in phosphoproteomics dataframe. PCDHB8_phosphoproteomics column inserted, but filled with NaN.
# Warning: GNPNAT1 did not match any columns in phosphoproteomics dataframe. GNPNAT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: INPP5K did not match any columns in phosphoproteomics dataframe. INPP5K_phosphoproteomics column inserted, but filled with NaN.
# Warning: NAPEPLD did not match any columns in phosphoproteomics dataframe. NAPEPLD_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACTR3B did not match any columns in phosphoproteomics dataframe. ACTR3B_phosphoproteomics column inserted, but filled with NaN.
# Warning: C1QTNF3 did not match any columns in phosphoproteomics dataframe. C1QTNF3_phosphoproteomics column inserted, but filled with NaN.
# Warning: MYOZ3 did not match any columns in phosphoproteomics dataframe. MYOZ3_phosphoproteomics column inserted, but filled with NaN.
# Warning: CD276 did not match any columns in phosphoproteomics dataframe. CD276_phosphoproteomics column inserted, but filled with NaN.
# Warning: CD36 did not match any columns in phosphoproteomics dataframe. CD36_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTGES did not match any columns in phosphoproteomics dataframe. PTGES_phosphoproteomics column inserted, but filled with NaN.
# Warning: RCC1L did not match any columns in phosphoproteomics dataframe. RCC1L_phosphoproteomics column inserted, but filled with NaN.
# Warning: ELP3 did not match any columns in phosphoproteomics dataframe. ELP3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ELMO3 did not match any columns in phosphoproteomics dataframe. ELMO3_phosphoproteomics column inserted, but filled with NaN.
# Warning: FSIP2 did not match any columns in phosphoproteomics dataframe. FSIP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CACYBP did not match any columns in phosphoproteomics dataframe. CACYBP_phosphoproteomics column inserted, but filled with NaN.
# Warning: AP3S1 did not match any columns in phosphoproteomics dataframe. AP3S1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GIMAP6 did not match any columns in phosphoproteomics dataframe. GIMAP6_phosphoproteomics column inserted, but filled with NaN.
# Warning: MED9 did not match any columns in phosphoproteomics dataframe. MED9_phosphoproteomics column inserted, but filled with NaN.
# Warning: EFCAB7 did not match any columns in phosphoproteomics dataframe. EFCAB7_phosphoproteomics column inserted, but filled with NaN.
# Warning: DPH5 did not match any columns in phosphoproteomics dataframe. DPH5_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABHD17C did not match any columns in phosphoproteomics dataframe. ABHD17C_phosphoproteomics column inserted, but filled with NaN.
# Warning: FIG4 did not match any columns in phosphoproteomics dataframe. FIG4_phosphoproteomics column inserted, but filled with NaN.
# Warning: TRMT11 did not match any columns in phosphoproteomics dataframe. TRMT11_phosphoproteomics column inserted, but filled with NaN.
# Warning: COX8A did not match any columns in phosphoproteomics dataframe. COX8A_phosphoproteomics column inserted, but filled with NaN.
# Warning: FUK did not match any columns in phosphoproteomics dataframe. FUK_phosphoproteomics column inserted, but filled with NaN.
# Warning: OTUD6B did not match any columns in phosphoproteomics dataframe. OTUD6B_phosphoproteomics column inserted, but filled with NaN.
# Warning: IGFBP4 did not match any columns in phosphoproteomics dataframe. IGFBP4_phosphoproteomics column inserted, but filled with NaN.
# Warning: AP1S2 did not match any columns in phosphoproteomics dataframe. AP1S2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CACNA2D1 did not match any columns in phosphoproteomics dataframe. CACNA2D1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MED16 did not match any columns in phosphoproteomics dataframe. MED16_phosphoproteomics column inserted, but filled with NaN.
# Warning: TNNC2 did not match any columns in phosphoproteomics dataframe. TNNC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTPA did not match any columns in phosphoproteomics dataframe. PTPA_phosphoproteomics column inserted, but filled with NaN.
# Warning: CFAP36 did not match any columns in phosphoproteomics dataframe. CFAP36_phosphoproteomics column inserted, but filled with NaN.
# Warning: DERL2 did not match any columns in phosphoproteomics dataframe. DERL2_phosphoproteomics column inserted, but filled with NaN.
# Warning: SPCS2 did not match any columns in phosphoproteomics dataframe. SPCS2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MST1R did not match any columns in phosphoproteomics dataframe. MST1R_phosphoproteomics column inserted, but filled with NaN.
# Warning: TLR1 did not match any columns in phosphoproteomics dataframe. TLR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: EPHX2 did not match any columns in phosphoproteomics dataframe. EPHX2_phosphoproteomics column inserted, but filled with NaN.
# Warning: FBXO11 did not match any columns in phosphoproteomics dataframe. FBXO11_phosphoproteomics column inserted, but filled with NaN.
# Warning: SETD3 did not match any columns in phosphoproteomics dataframe. SETD3_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPS31 did not match any columns in phosphoproteomics dataframe. MRPS31_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMED7-TICAM2 did not match any columns in phosphoproteomics dataframe. TMED7-TICAM2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CNTN1 did not match any columns in phosphoproteomics dataframe. CNTN1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PSAPL1 did not match any columns in phosphoproteomics dataframe. PSAPL1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CMC2 did not match any columns in phosphoproteomics dataframe. CMC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMED7 did not match any columns in phosphoproteomics dataframe. TMED7_phosphoproteomics column inserted, but filled with NaN.
# Warning: GSTM5 did not match any columns in phosphoproteomics dataframe. GSTM5_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMEM97 did not match any columns in phosphoproteomics dataframe. TMEM97_phosphoproteomics column inserted, but filled with NaN.
# Warning: SNAP25 did not match any columns in phosphoproteomics dataframe. SNAP25_phosphoproteomics column inserted, but filled with NaN.
# Warning: MTRF1L did not match any columns in phosphoproteomics dataframe. MTRF1L_phosphoproteomics column inserted, but filled with NaN.
# Warning: NIPSNAP2 did not match any columns in phosphoproteomics dataframe. NIPSNAP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: PGPEP1 did not match any columns in phosphoproteomics dataframe. PGPEP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: LGALS3 did not match any columns in phosphoproteomics dataframe. LGALS3_phosphoproteomics column inserted, but filled with NaN.
# Warning: NABP1 did not match any columns in phosphoproteomics dataframe. NABP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: AGPAT4 did not match any columns in phosphoproteomics dataframe. AGPAT4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPL31 did not match any columns in phosphoproteomics dataframe. RPL31_phosphoproteomics column inserted, but filled with NaN.
# Warning: IGFBP7 did not match any columns in phosphoproteomics dataframe. IGFBP7_phosphoproteomics column inserted, but filled with NaN.
# Warning: FKBP2 did not match any columns in phosphoproteomics dataframe. FKBP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RAD17 did not match any columns in phosphoproteomics dataframe. RAD17_phosphoproteomics column inserted, but filled with NaN.
# Warning: RAP1A did not match any columns in phosphoproteomics dataframe. RAP1A_phosphoproteomics column inserted, but filled with NaN.
# Warning: RARS did not match any columns in phosphoproteomics dataframe. RARS_phosphoproteomics column inserted, but filled with NaN.
# Warning: COL4A3 did not match any columns in phosphoproteomics dataframe. COL4A3_phosphoproteomics column inserted, but filled with NaN.
# Warning: HRAS did not match any columns in phosphoproteomics dataframe. HRAS_phosphoproteomics column inserted, but filled with NaN.
# Warning: ADAP2 did not match any columns in phosphoproteomics dataframe. ADAP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: FZD2 did not match any columns in phosphoproteomics dataframe. FZD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: GNB2 did not match any columns in phosphoproteomics dataframe. GNB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ANGPT2 did not match any columns in phosphoproteomics dataframe. ANGPT2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CXCL16 did not match any columns in phosphoproteomics dataframe. CXCL16_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATIC did not match any columns in phosphoproteomics dataframe. ATIC_phosphoproteomics column inserted, but filled with NaN.
# Warning: TGFB3 did not match any columns in phosphoproteomics dataframe. TGFB3_phosphoproteomics column inserted, but filled with NaN.
# Warning: NOVA2 did not match any columns in phosphoproteomics dataframe. NOVA2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RCHY1 did not match any columns in phosphoproteomics dataframe. RCHY1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CISD3 did not match any columns in phosphoproteomics dataframe. CISD3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ALDH1A2 did not match any columns in phosphoproteomics dataframe. ALDH1A2_phosphoproteomics column inserted, but filled with NaN.
# Warning: EXOG did not match any columns in phosphoproteomics dataframe. EXOG_phosphoproteomics column inserted, but filled with NaN.
# Warning: LOXL4 did not match any columns in phosphoproteomics dataframe. LOXL4_phosphoproteomics column inserted, but filled with NaN.
# Warning: MED6 did not match any columns in phosphoproteomics dataframe. MED6_phosphoproteomics column inserted, but filled with NaN.
# Warning: CCDC90B did not match any columns in phosphoproteomics dataframe. CCDC90B_phosphoproteomics column inserted, but filled with NaN.
# Warning: TRIM4 did not match any columns in phosphoproteomics dataframe. TRIM4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RNF121 did not match any columns in phosphoproteomics dataframe. RNF121_phosphoproteomics column inserted, but filled with NaN.
# Warning: TRMT112 did not match any columns in phosphoproteomics dataframe. TRMT112_phosphoproteomics column inserted, but filled with NaN.
# Warning: LRP1B did not match any columns in phosphoproteomics dataframe. LRP1B_phosphoproteomics column inserted, but filled with NaN.
# Warning: SARDH did not match any columns in phosphoproteomics dataframe. SARDH_phosphoproteomics column inserted, but filled with NaN.
# Warning: MBNL3 did not match any columns in phosphoproteomics dataframe. MBNL3_phosphoproteomics column inserted, but filled with NaN.
# Warning: TBCD did not match any columns in phosphoproteomics dataframe. TBCD_phosphoproteomics column inserted, but filled with NaN.
# Warning: MDK did not match any columns in phosphoproteomics dataframe. MDK_phosphoproteomics column inserted, but filled with NaN.
# Warning: RAPGEF4 did not match any columns in phosphoproteomics dataframe. RAPGEF4_phosphoproteomics column inserted, but filled with NaN.
# Warning: SURF1 did not match any columns in phosphoproteomics dataframe. SURF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPL10A did not match any columns in phosphoproteomics dataframe. RPL10A_phosphoproteomics column inserted, but filled with NaN.
# Warning: SMYD4 did not match any columns in phosphoproteomics dataframe. SMYD4_phosphoproteomics column inserted, but filled with NaN.
# Warning: APH1A did not match any columns in phosphoproteomics dataframe. APH1A_phosphoproteomics column inserted, but filled with NaN.
# Warning: RXRB did not match any columns in phosphoproteomics dataframe. RXRB_phosphoproteomics column inserted, but filled with NaN.
# Warning: KPTN did not match any columns in phosphoproteomics dataframe. KPTN_phosphoproteomics column inserted, but filled with NaN.
# Warning: TIMM10 did not match any columns in phosphoproteomics dataframe. TIMM10_phosphoproteomics column inserted, but filled with NaN.
# Warning: CMTM7 did not match any columns in phosphoproteomics dataframe. CMTM7_phosphoproteomics column inserted, but filled with NaN.
# Warning: GLDC did not match any columns in phosphoproteomics dataframe. GLDC_phosphoproteomics column inserted, but filled with NaN.
# Warning: OTULIN did not match any columns in phosphoproteomics dataframe. OTULIN_phosphoproteomics column inserted, but filled with NaN.
# Warning: KDM8 did not match any columns in phosphoproteomics dataframe. KDM8_phosphoproteomics column inserted, but filled with NaN.
# Warning: BANF1 did not match any columns in phosphoproteomics dataframe. BANF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: CSTF1 did not match any columns in phosphoproteomics dataframe. CSTF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ENPP4 did not match any columns in phosphoproteomics dataframe. ENPP4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RNF170 did not match any columns in phosphoproteomics dataframe. RNF170_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF143 did not match any columns in phosphoproteomics dataframe. ZNF143_phosphoproteomics column inserted, but filled with NaN.
# Warning: MARC2 did not match any columns in phosphoproteomics dataframe. MARC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: PRSS8 did not match any columns in phosphoproteomics dataframe. PRSS8_phosphoproteomics column inserted, but filled with NaN.
# Warning: C2 did not match any columns in phosphoproteomics dataframe. C2_phosphoproteomics column inserted, but filled with NaN.
# Warning: DPP3 did not match any columns in phosphoproteomics dataframe. DPP3_phosphoproteomics column inserted, but filled with NaN.
# Warning: RBM38 did not match any columns in phosphoproteomics dataframe. RBM38_phosphoproteomics column inserted, but filled with NaN.
# Warning: PAF1 did not match any columns in phosphoproteomics dataframe. PAF1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PEX10 did not match any columns in phosphoproteomics dataframe. PEX10_phosphoproteomics column inserted, but filled with NaN.
# Warning: GTPBP3 did not match any columns in phosphoproteomics dataframe. GTPBP3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ANGPTL4 did not match any columns in phosphoproteomics dataframe. ANGPTL4_phosphoproteomics column inserted, but filled with NaN.
# Warning: STX18 did not match any columns in phosphoproteomics dataframe. STX18_phosphoproteomics column inserted, but filled with NaN.
# Warning: RYR3 did not match any columns in phosphoproteomics dataframe. RYR3_phosphoproteomics column inserted, but filled with NaN.
# Warning: EIF3K did not match any columns in phosphoproteomics dataframe. EIF3K_phosphoproteomics column inserted, but filled with NaN.
# Warning: CARD6 did not match any columns in phosphoproteomics dataframe. CARD6_phosphoproteomics column inserted, but filled with NaN.
# Warning: SERPINB4 did not match any columns in phosphoproteomics dataframe. SERPINB4_phosphoproteomics column inserted, but filled with NaN.
# Warning: LCMT1 did not match any columns in phosphoproteomics dataframe. LCMT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: AURKA did not match any columns in phosphoproteomics dataframe. AURKA_phosphoproteomics column inserted, but filled with NaN.
# Warning: WDR36 did not match any columns in phosphoproteomics dataframe. WDR36_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZDHHC4 did not match any columns in phosphoproteomics dataframe. ZDHHC4_phosphoproteomics column inserted, but filled with NaN.
# Warning: IL1RN did not match any columns in phosphoproteomics dataframe. IL1RN_phosphoproteomics column inserted, but filled with NaN.
# Warning: LAMP1 did not match any columns in phosphoproteomics dataframe. LAMP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ERI3 did not match any columns in phosphoproteomics dataframe. ERI3_phosphoproteomics column inserted, but filled with NaN.
# Warning: TIMM21 did not match any columns in phosphoproteomics dataframe. TIMM21_phosphoproteomics column inserted, but filled with NaN.
# Warning: GALNT16 did not match any columns in phosphoproteomics dataframe. GALNT16_phosphoproteomics column inserted, but filled with NaN.
# ...
# Warning: WIPI1 did not match any columns in phosphoproteomics dataframe. WIPI1_phosphoproteomics column inserted, but filled with NaN.
# Warning: FCN2 did not match any columns in phosphoproteomics dataframe. FCN2_phosphoproteomics column inserted, but filled with NaN.
# Warning: TPSD1 did not match any columns in phosphoproteomics dataframe. TPSD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PAPPA did not match any columns in phosphoproteomics dataframe. PAPPA_phosphoproteomics column inserted, but filled with NaN.
# Warning: TPST1 did not match any columns in phosphoproteomics dataframe. TPST1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GKAP1 did not match any columns in phosphoproteomics dataframe. GKAP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PANK3 did not match any columns in phosphoproteomics dataframe. PANK3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ICAM2 did not match any columns in phosphoproteomics dataframe. ICAM2_phosphoproteomics column inserted, but filled with NaN.
# Warning: BTBD9 did not match any columns in phosphoproteomics dataframe. BTBD9_phosphoproteomics column inserted, but filled with NaN.
# Warning: ROMO1 did not match any columns in phosphoproteomics dataframe. ROMO1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ATP6AP2 did not match any columns in phosphoproteomics dataframe. ATP6AP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: IRAK4 did not match any columns in phosphoproteomics dataframe. IRAK4_phosphoproteomics column inserted, but filled with NaN.
# Warning: SLC3A2 did not match any columns in phosphoproteomics dataframe. SLC3A2_phosphoproteomics column inserted, but filled with NaN.
# Warning: FKBP9 did not match any columns in phosphoproteomics dataframe. FKBP9_phosphoproteomics column inserted, but filled with NaN.
# Warning: GUCY1A3 did not match any columns in phosphoproteomics dataframe. GUCY1A3_phosphoproteomics column inserted, but filled with NaN.
# Warning: TSPAN8 did not match any columns in phosphoproteomics dataframe. TSPAN8_phosphoproteomics column inserted, but filled with NaN.
# Warning: CTSF did not match any columns in phosphoproteomics dataframe. CTSF_phosphoproteomics column inserted, but filled with NaN.
# Warning: CD9 did not match any columns in phosphoproteomics dataframe. CD9_phosphoproteomics column inserted, but filled with NaN.
# Warning: CYB5R2 did not match any columns in phosphoproteomics dataframe. CYB5R2_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF16 did not match any columns in phosphoproteomics dataframe. ZNF16_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACAT1 did not match any columns in phosphoproteomics dataframe. ACAT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: C4BPB did not match any columns in phosphoproteomics dataframe. C4BPB_phosphoproteomics column inserted, but filled with NaN.
# Warning: LTN1 did not match any columns in phosphoproteomics dataframe. LTN1_phosphoproteomics column inserted, but filled with NaN.
# Warning: STAP1 did not match any columns in phosphoproteomics dataframe. STAP1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TRMU did not match any columns in phosphoproteomics dataframe. TRMU_phosphoproteomics column inserted, but filled with NaN.
# Warning: RBM45 did not match any columns in phosphoproteomics dataframe. RBM45_phosphoproteomics column inserted, but filled with NaN.
# Warning: TMPPE did not match any columns in phosphoproteomics dataframe. TMPPE_phosphoproteomics column inserted, but filled with NaN.
# Warning: MICAL2 did not match any columns in phosphoproteomics dataframe. MICAL2_phosphoproteomics column inserted, but filled with NaN.
# Warning: AGPAT3 did not match any columns in phosphoproteomics dataframe. AGPAT3_phosphoproteomics column inserted, but filled with NaN.
# Warning: B3GALNT1 did not match any columns in phosphoproteomics dataframe. B3GALNT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: DNAH6 did not match any columns in phosphoproteomics dataframe. DNAH6_phosphoproteomics column inserted, but filled with NaN.
# Warning: FDX2 did not match any columns in phosphoproteomics dataframe. FDX2_phosphoproteomics column inserted, but filled with NaN.
# Warning: SRP54 did not match any columns in phosphoproteomics dataframe. SRP54_phosphoproteomics column inserted, but filled with NaN.
# Warning: SPARC did not match any columns in phosphoproteomics dataframe. SPARC_phosphoproteomics column inserted, but filled with NaN.
# Warning: LRRC25 did not match any columns in phosphoproteomics dataframe. LRRC25_phosphoproteomics column inserted, but filled with NaN.
# Warning: AGL did not match any columns in phosphoproteomics dataframe. AGL_phosphoproteomics column inserted, but filled with NaN.
# Warning: GNB3 did not match any columns in phosphoproteomics dataframe. GNB3_phosphoproteomics column inserted, but filled with NaN.
# Warning: LYVE1 did not match any columns in phosphoproteomics dataframe. LYVE1_phosphoproteomics column inserted, but filled with NaN.
# Warning: HCFC2 did not match any columns in phosphoproteomics dataframe. HCFC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MBLAC2 did not match any columns in phosphoproteomics dataframe. MBLAC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: FCGR2B did not match any columns in phosphoproteomics dataframe. FCGR2B_phosphoproteomics column inserted, but filled with NaN.
# Warning: LSM2 did not match any columns in phosphoproteomics dataframe. LSM2_phosphoproteomics column inserted, but filled with NaN.
# Warning: FLVCR1 did not match any columns in phosphoproteomics dataframe. FLVCR1_phosphoproteomics column inserted, but filled with NaN.
# Warning: ITPA did not match any columns in phosphoproteomics dataframe. ITPA_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF135 did not match any columns in phosphoproteomics dataframe. ZNF135_phosphoproteomics column inserted, but filled with NaN.
# Warning: PCDHB3 did not match any columns in phosphoproteomics dataframe. PCDHB3_phosphoproteomics column inserted, but filled with NaN.
# Warning: STAM2 did not match any columns in phosphoproteomics dataframe. STAM2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MT-CO2 did not match any columns in phosphoproteomics dataframe. MT-CO2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MED20 did not match any columns in phosphoproteomics dataframe. MED20_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF706 did not match any columns in phosphoproteomics dataframe. ZNF706_phosphoproteomics column inserted, but filled with NaN.
# Warning: CORO6 did not match any columns in phosphoproteomics dataframe. CORO6_phosphoproteomics column inserted, but filled with NaN.
# Warning: GPX2 did not match any columns in phosphoproteomics dataframe. GPX2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL33 did not match any columns in phosphoproteomics dataframe. MRPL33_phosphoproteomics column inserted, but filled with NaN.
# Warning: COPS2 did not match any columns in phosphoproteomics dataframe. COPS2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MYO7A did not match any columns in phosphoproteomics dataframe. MYO7A_phosphoproteomics column inserted, but filled with NaN.
# Warning: GNLY did not match any columns in phosphoproteomics dataframe. GNLY_phosphoproteomics column inserted, but filled with NaN.
# Warning: GTF2H5 did not match any columns in phosphoproteomics dataframe. GTF2H5_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL55 did not match any columns in phosphoproteomics dataframe. MRPL55_phosphoproteomics column inserted, but filled with NaN.
# Warning: GOSR2 did not match any columns in phosphoproteomics dataframe. GOSR2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPS9 did not match any columns in phosphoproteomics dataframe. MRPS9_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZDHHC6 did not match any columns in phosphoproteomics dataframe. ZDHHC6_phosphoproteomics column inserted, but filled with NaN.
# Warning: ISG20 did not match any columns in phosphoproteomics dataframe. ISG20_phosphoproteomics column inserted, but filled with NaN.
# Warning: CCDC32 did not match any columns in phosphoproteomics dataframe. CCDC32_phosphoproteomics column inserted, but filled with NaN.
# Warning: PMM2 did not match any columns in phosphoproteomics dataframe. PMM2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CPZ did not match any columns in phosphoproteomics dataframe. CPZ_phosphoproteomics column inserted, but filled with NaN.
# Warning: HMGB2 did not match any columns in phosphoproteomics dataframe. HMGB2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPS34 did not match any columns in phosphoproteomics dataframe. MRPS34_phosphoproteomics column inserted, but filled with NaN.
# Warning: EMC2 did not match any columns in phosphoproteomics dataframe. EMC2_phosphoproteomics column inserted, but filled with NaN.
# Warning: SOD1 did not match any columns in phosphoproteomics dataframe. SOD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: VPS16 did not match any columns in phosphoproteomics dataframe. VPS16_phosphoproteomics column inserted, but filled with NaN.
# Warning: ERCC4 did not match any columns in phosphoproteomics dataframe. ERCC4_phosphoproteomics column inserted, but filled with NaN.
# Warning: TNNT1 did not match any columns in phosphoproteomics dataframe. TNNT1_phosphoproteomics column inserted, but filled with NaN.
# Warning: RTN2 did not match any columns in phosphoproteomics dataframe. RTN2_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPL22 did not match any columns in phosphoproteomics dataframe. RPL22_phosphoproteomics column inserted, but filled with NaN.
# Warning: CRELD1 did not match any columns in phosphoproteomics dataframe. CRELD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: TST did not match any columns in phosphoproteomics dataframe. TST_phosphoproteomics column inserted, but filled with NaN.
# Warning: HAVCR2 did not match any columns in phosphoproteomics dataframe. HAVCR2_phosphoproteomics column inserted, but filled with NaN.
# Warning: IFI44L did not match any columns in phosphoproteomics dataframe. IFI44L_phosphoproteomics column inserted, but filled with NaN.
# Warning: PTPRO did not match any columns in phosphoproteomics dataframe. PTPRO_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZNF823 did not match any columns in phosphoproteomics dataframe. ZNF823_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABRACL did not match any columns in phosphoproteomics dataframe. ABRACL_phosphoproteomics column inserted, but filled with NaN.
# Warning: CRIM1 did not match any columns in phosphoproteomics dataframe. CRIM1_phosphoproteomics column inserted, but filled with NaN.
# Warning: OASL did not match any columns in phosphoproteomics dataframe. OASL_phosphoproteomics column inserted, but filled with NaN.
# Warning: SNRPB did not match any columns in phosphoproteomics dataframe. SNRPB_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPL26L1 did not match any columns in phosphoproteomics dataframe. RPL26L1_phosphoproteomics column inserted, but filled with NaN.
# Warning: MRPL57 did not match any columns in phosphoproteomics dataframe. MRPL57_phosphoproteomics column inserted, but filled with NaN.
# Warning: MED27 did not match any columns in phosphoproteomics dataframe. MED27_phosphoproteomics column inserted, but filled with NaN.
# Warning: GPX8 did not match any columns in phosphoproteomics dataframe. GPX8_phosphoproteomics column inserted, but filled with NaN.
# Warning: CALB1 did not match any columns in phosphoproteomics dataframe. CALB1_phosphoproteomics column inserted, but filled with NaN.
# Warning: GBP2 did not match any columns in phosphoproteomics dataframe. GBP2_phosphoproteomics column inserted, but filled with NaN.
# Warning: MTERF4 did not match any columns in phosphoproteomics dataframe. MTERF4_phosphoproteomics column inserted, but filled with NaN.
# Warning: ACOT4 did not match any columns in phosphoproteomics dataframe. ACOT4_phosphoproteomics column inserted, but filled with NaN.
# Warning: PRUNE1 did not match any columns in phosphoproteomics dataframe. PRUNE1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PPWD1 did not match any columns in phosphoproteomics dataframe. PPWD1_phosphoproteomics column inserted, but filled with NaN.
# Warning: PCGF2 did not match any columns in phosphoproteomics dataframe. PCGF2_phosphoproteomics column inserted, but filled with NaN.
# Warning: CHCHD5 did not match any columns in phosphoproteomics dataframe. CHCHD5_phosphoproteomics column inserted, but filled with NaN.
# Warning: BTN3A3 did not match any columns in phosphoproteomics dataframe. BTN3A3_phosphoproteomics column inserted, but filled with NaN.
# Warning: ZBED8 did not match any columns in phosphoproteomics dataframe. ZBED8_phosphoproteomics column inserted, but filled with NaN.
# Warning: SMPD2 did not match any columns in phosphoproteomics dataframe. SMPD2_phosphoproteomics column inserted, but filled with NaN.
# Warning: LY6H did not match any columns in phosphoproteomics dataframe. LY6H_phosphoproteomics column inserted, but filled with NaN.
# Warning: NDUFA12 did not match any columns in phosphoproteomics dataframe. NDUFA12_phosphoproteomics column inserted, but filled with NaN.
# Warning: CCDC57 did not match any columns in phosphoproteomics dataframe. CCDC57_phosphoproteomics column inserted, but filled with NaN.
# Warning: PMS1 did not match any columns in phosphoproteomics dataframe. PMS1_phosphoproteomics column inserted, but filled with NaN.
# Warning: KLK13 did not match any columns in phosphoproteomics dataframe. KLK13_phosphoproteomics column inserted, but filled with NaN.
# Warning: RNMT did not match any columns in phosphoproteomics dataframe. RNMT_phosphoproteomics column inserted, but filled with NaN.
# Warning: ARF4 did not match any columns in phosphoproteomics dataframe. ARF4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPUSD3 did not match any columns in phosphoproteomics dataframe. RPUSD3_phosphoproteomics column inserted, but filled with NaN.
# Warning: COPZ2 did not match any columns in phosphoproteomics dataframe. COPZ2_phosphoproteomics column inserted, but filled with NaN.
# Warning: HGFAC did not match any columns in phosphoproteomics dataframe. HGFAC_phosphoproteomics column inserted, but filled with NaN.
# Warning: ABCD4 did not match any columns in phosphoproteomics dataframe. ABCD4_phosphoproteomics column inserted, but filled with NaN.
# Warning: RPS15 did not match any columns in phosphoproteomics dataframe. RPS15_phosphoproteomics column inserted, but filled with NaN.
# Warning: UTP11 did not match any columns in phosphoproteomics dataframe. UTP11_phosphoproteomics column inserted, but filled with NaN.
# Warning: AK5 did not match any columns in phosphoproteomics dataframe. AK5_phosphoproteomics column inserted, but filled with NaN.
# Warning: ENTPD6 did not match any columns in phosphoproteomics dataframe. ENTPD6_phosphoproteomics column inserted, but filled with NaN.
# Warning: PDZD11 did not match any columns in phosphoproteomics dataframe. PDZD11_phosphoproteomics column inserted, but filled with NaN.
# Warning: ANKRD44 did not match any columns in phosphoproteomics dataframe. ANKRD44_phosphoproteomics column inserted, but filled with NaN.
# Warning: PIGO did not match any columns in phosphoproteomics dataframe. PIGO_phosphoproteomics column inserted, but filled with NaN.
# Doing t-test comparisons
#
# No significant comparisons.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# TODO
