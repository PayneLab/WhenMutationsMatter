# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
from matplotlib import pylab
import seaborn as sns
import cptac

# %%
cluster = pd.read_csv(r'C:\Users\joncj\OneDrive\Documents\Research\GitHub\ccrcc.somatic.consensus.gdc.umichigan.wu.112918.maf.3D_Proximity.pairwise.recurrence.l0.r10.clusters', sep = '\t', engine = 'python')

# %%
cluster
# Out:
#     Cluster Gene/Drug       Mutation/Gene  Degree_Connectivity  \
# 0       0.0     AMY2A             p.G374E                    2
# 1       0.0     AMY2A             p.N377K                    2
# 2       1.0      PTK2            p.L1002V                    2
# 3      10.0     KIF22             p.G599D                    2
# 4      10.0     KIF22             p.L604F                    2
# 5      11.0     MTHFS             p.G149V                    2
# 6      12.0      MTOR            p.C1483R                    3
# 7      13.0     PBRM1      p.F872_I875del                    2
# 8      13.0     PBRM1             p.Q869H                    2
# 9      14.0     PBRM1             p.M248T                    2
# 10     15.0    PIK3CA  p.C420_L422delinsW                    3
# 11     15.0    PIK3R1      p.I571_T576del                    3
# 12     15.0    PIK3R1           p.Q572del                    3
# 13     16.0     SF3B3             p.F182V                    2
# ...
